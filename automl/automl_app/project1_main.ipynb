# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
nb_dir
# Out:
# '/home/kai/data/shiyi/AlphaBoosting/automl'

# %%
sys.path
# Out:
# ['',
#  '/home/kai/anaconda3/lib/python36.zip',
#  '/home/kai/anaconda3/lib/python3.6',
#  '/home/kai/anaconda3/lib/python3.6/lib-dynload',
#  '/home/kai/anaconda3/lib/python3.6/site-packages',
#  '/home/kai/anaconda3/lib/python3.6/site-packages/xgboost-0.7-py3.6.egg',
#  '/home/kai/anaconda3/lib/python3.6/site-packages/duckling-1.8.0-py3.6.egg',
#  '/home/kai/anaconda3/lib/python3.6/site-packages/JPype1-0.6.3-py3.6-linux-x86_64.egg',
#  '/home/kai/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/kai/.ipython',
#  '/home/kai/data/shiyi/AlphaBoosting/automl']

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from automl_libs import feature_engineering as fe
from automl_libs import encoding, kernels

# %%
# params
#param = {'trainLen': self.train_len, 'splitCol': 'a', 'col': self.label, 'coefficient': 10, 'n': 2, 'fillna': 22}
# feature_engineering_dict.append({'params': params, 'function': 'count', 'feature_cols': ['a','b']})
# feature_engineering_dict.append({'params': params, 'function': 'unique_count', 'feature_cols': ['a','b']})
# feature_engineering_dict.append({'params': params, 'function': 'cumulative_count', 'feature_cols': ['a','b']})
# feature_engineering_dict.append({'params': params, 'function': 'reverse_cumulative_count', 'feature_cols': ['a','b']})
# feature_engineering_dict.append({'params': params, 'function': 'variance', 'feature_cols': ['a','n']})
# feature_engineering_dict.append({'params': params, 'function': 'count_std_over_mean', 'feature_cols': ['a','b']})


# feature_engineering_dict.append({'params': params, 'function': 'time_to_n_next', 'feature_cols': ['a','t']})
# feature_engineering_dict.append({'params': params, 'function': 'count_in_previous_n_time_unit', 'feature_cols': ['a','t']})
# feature_engineering_dict.append({'params': params, 'function': 'count_in_next_n_time_unit', 'feature_cols': ['a','t']})

# feature_engineering_dict.append({'params': params, 'function': 'woe', 'feature_cols': ['a']})
# feature_engineering_dict.append({'params': params, 'function': 'chi_square', 'feature_cols': ['a']})
# feature_engineering_dict.append({'params': params, 'function': 'mean', 'feature_cols': ['a']})

# %%
categorical_features = ['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest', 'Distance']

# %%
import itertools
#params = {'split_col': 't', 'coefficient': 10, 'n': 2, 'fillna': 22}
def get_features_to_gen(function_list):
    features_to_gen = []
    for function in function_list:
        for i in range(2, len(categorical_features)+1):
            for combine in itertools.combinations(categorical_features, i):
                if function.__name__ == 'count_std_over_mean':
                    features_to_gen.append({'params': {'coefficient': 10}, 'function': function, 'feature_cols': list(combine)})
                else:
                    features_to_gen.append({'params': {}, 'function': function, 'feature_cols': list(combine)})
                
    return features_to_gen

features_to_gen = get_features_to_gen([fe.count, fe.unique_count, fe.cumulative_count,
                                      fe.reverse_cumulative_count, fe.variance, fe.count_std_over_mean])

features_to_gen
# Out:
# [{'feature_cols': ['Month', 'DayofMonth'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.unique_count>,
#   'params': {}},
# ...
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'UniqueCarrier', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'UniqueCarrier', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Origin', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'DepTime', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'UniqueCarrier', 'Origin', 'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'DepTime', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DepTime', 'UniqueCarrier', 'Origin', 'Dest', 'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month',
#    'DayofMonth',
#    'DayOfWeek',
#    'DepTime',
#    'UniqueCarrier',
#    'Origin',
#    'Dest',
#    'Distance'],
#   'function': <function automl_libs.feature_engineering.reverse_cumulative_count>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayofMonth'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Origin'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Dest'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['Month', 'Distance'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DayOfWeek'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'DepTime'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'UniqueCarrier'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Origin'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  {'feature_cols': ['DayofMonth', 'Dest'],
#   'function': <function automl_libs.feature_engineering.variance>,
#   'params': {}},
#  ...]

# %%
categorical_features
# Out:
# ['Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'DepTime',
#  'UniqueCarrier',
#  'Origin',
#  'Dest',
#  'Distance']

# %%
project_path = '/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/project1/'

# %%
import logger_config

logger_config.config(project_path+'log_project1.log')

# %%
from app import AlphaBoosting

automl_config_file = project_path + 'automl_config.json'
run_record_file_name = project_path + 'run_record.json' # don't created this file
b = AlphaBoosting(automl_config_file, features_to_gen)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 58, in __init__
#     self.logger.info('Run record file [{}] found. Continue from the previous run...'.format(run_record))
# Message: 'Run record file [project1/run_record.json] found. Continue from the previous run...'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 58, in __init__
#     self.logger.info('Run record file [{}] found. Continue from the previous run...'.format(run_record))
# Message: 'Run record file [project1/run_record.json] found. Continue from the previous run...'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 89, in __init__
#     self.logger.info('save run record')
# Message: 'save run record'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 89, in __init__
#     self.logger.info('save run record')
# Message: 'save run record'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 93, in __init__
#     self.logger.info('generate todo list')
# Message: 'generate todo list'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 93, in __init__
#     self.logger.info('generate todo list')
# Message: 'generate todo list'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 109, in __init__
#     self.logger.info('feature engineering')
# Message: 'feature engineering'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 109, in __init__
#     self.logger.info('feature engineering')
# Message: 'feature engineering'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 113, in __init__
#     self.logger.info('validation')
# Message: 'validation'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 113, in __init__
#     self.logger.info('validation')
# Message: 'validation'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 117, in __init__
#     self.logger.info('concat test')
# Message: 'concat test'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 117, in __init__
#     self.logger.info('concat test')
# Message: 'concat test'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 121, in __init__
#     self.logger.info('grid search')
# Message: 'grid search'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 577, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#   File "/home/kai/anaconda3/lib/python3.6/logging/__init__.py", line 513, in formatTime
#     ct = self.converter(record.created)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/logger_config.py", line 19, in customTime
#     utc_dt = utc.localize(datetime.utcnow())
# NameError: name 'utc' is not defined
# Call stack:
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/kai/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/kai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-9c28513e35b2>", line 5, in <module>
#     b = AlphaBoosting(automl_config_file, features_to_gen)
#   File "/home/kai/data/shiyi/AlphaBoosting/automl/automl_app/app.py", line 121, in __init__
#     self.logger.info('grid search')
# Message: 'grid search'
# Arguments: ()
# > /home/kai/data/shiyi/AlphaBoosting/automl/automl_libs/grid_search.py(52)lgb_grid_search()
# -> lgb_params['timestamp'] = utils.get_time()

# %%
import pandas as pd

gs_res = pd.read_csv('project1/project1_grid_search.csv', index_col='Unnamed: 0').sort_values(by=['val_auc'], ascending=False)

gs_res.head()
# Out:
#             bagging_fraction  bagging_freq  bagging_seed  best_round boosting  \
# 1529021613               1.0             1      16455427        2448     gbdt
# 1529016426               0.6             1      31060497         167     gbdt
# 1529018698               0.4             1      41499713        1720     gbdt
# 1529038836               0.9             1       4863757        4000     gbdt
# 1529005138               1.0             1       6682269        4000     gbdt
#
#                                        categorical_column    cv  \
# 1529021613  "[528, 536, 726, 728, 867, 1158, 1169, 1474]"  True
# 1529016426  "[528, 536, 726, 728, 867, 1158, 1169, 1474]"  True
# 1529018698  "[528, 536, 726, 728, 867, 1158, 1169, 1474]"  True
# 1529038836  "[528, 536, 726, 728, 867, 1158, 1169, 1474]"  True
# 1529005138                     "[0, 1, 2, 3, 4, 5, 6, 7]"   NaN
#
#             feature_fraction  feature_fraction_seed  learning_rate   ...     \
# 1529021613               0.7               16455427          0.030   ...
# 1529016426               1.0               31060497          0.100   ...
# 1529018698               0.3               41499713          0.100   ...
# 1529038836               1.0                4863757          0.001   ...
# 1529005138               1.0                6682269          0.001   ...
#
#             min_data_in_leaf num_leaves  num_threads  objective         preds  \
# 1529021613                37        127            4     binary           NaN
# 1529016426                45        127            4     binary           NaN
# 1529018698                45         15            4     binary           NaN
# 1529038836                37         61            4     binary           NaN
# 1529005138                28        127            4     binary  1.529005e+09
#
#            scale_pos_weight            timestamp  train_auc   val_auc  verbose
# 1529021613                2  2018-06-14 20:13:33        NaN  0.829998        1
# 1529016426                2  2018-06-14 18:47:06        NaN  0.819533        1
# 1529018698                2  2018-06-14 19:24:58        NaN  0.817727        1
# 1529038836                2  2018-06-15 01:00:36        NaN  0.809534        1
# 1529005138                2  2018-06-14 15:38:58   0.801038  0.766851        1
#
# [5 rows x 22 columns]
