# %%
import json
import pandas as pd

# %%
config_dict = json.load(open('automl_config.json','r'))

# %%
train = pd.read_pickle(config_dict['train_data_url'])
test = pd.read_pickle(config_dict['test_data_url'])

# %%
train.shape, test.shape
# Out:
# ((1000000, 9), (100000, 8))

# %%
for col in train.columns:
    print(col, train[col].nunique())
# Out:
# Month 12
# DayofMonth 31
# DayOfWeek 7
# DepTime 27
# UniqueCarrier 22
# Origin 291
# Dest 292
# Distance 10
# label 2

# %%
train.head(29)
# Out:
#     Month  DayofMonth  DayOfWeek  DepTime  UniqueCarrier  Origin  Dest  \
# 0       7          19          2       18             21     157   133
# 1       4           3          1       12             18      79   172
# 2       2           1          6        9             15     129    72
# 3       3          19          6        9             15     147   220
# 4       4          28          2       13             13      80   155
# 5       3          17          5       15             10      19   273
# 6       3          10          6       12             20      48    86
# 7       1          14          5        0              4     204   147
# 8       6          13          7       19             16     205   290
# 9       7          18          1        9              1     214    80
# 10     11          16          3       12             19      78   160
# 11     12           6          3        8             20      14    48
# 12      8           4          4       15              3     246   200
# 13      5           5          7       19             14      86    24
# 14     10          30          5       19             18      48   154
# 15      3          28          7       10             18      79   214
# 16      4           6          3       20              8      19   249
# 17      3          19          7       16             13     234   206
# 18      5          13          7       11             14     205   178
# 19      3           3          6       19              1      80   259
# 20      6          13          7       22              3     210   238
# 21     10          16          7       16             19     224    78
# 22      8          27          4       11              1      35    80
# 23      4           6          3       15              6     132   269
# 24      7          13          3       13              4      46   147
# 25      3          28          1        9             21     133   128
# 26      2           2          1        6             19     218    63
# 27      7          31          7       20             13      80   126
# 28      2          23          1       17             21     116    93
#
#     Distance  label
# 0          6      0
# 1          4      0
# 2          2      0
# 3          7      0
# 4          2      1
# 5          3      0
# 6          3      0
# 7          9      0
# 8          4      0
# 9          7      0
# 10         1      0
# 11         2      0
# 12         5      1
# 13         0      0
# 14         9      0
# 15         9      0
# 16         4      1
# 17         4      0
# 18         4      0
# 19         8      1
# 20         7      1
# 21         3      0
# 22         5      0
# 23         2      0
# 24         2      0
# 25         2      0
# 26         3      0
# 27         1      0
# 28         3      0
