# %%
import pandas as pd
from os import listdir
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 1000

# %matplotlib inline

# %%
for filename in listdir('output/'):
    if '_grid_search' in filename:
        print(filename)
    if '_stacknet' in filename:
        print(filename)
# Out:
# catb_bo2_newcat_80pnull_stacknet.csv
# xgb_bo2_w2v_newcat_grid_search.csv
# catb_bo2_newcat_grid_search.csv
# lgb_bo2_newcat_grid_search.csv
# x1g2b3_bo2_w2v_grid_search.csv
# lgb_grid_search.csv
# xgb_grid_search.csv
# lgb_fe_repro_1_stacknet.csv

# %%
gs_res = pd.read_csv('output/catb_bo2_newcat_grid_search.csv', index_col='Unnamed: 0').sort_values(by=['val_AUC'], ascending=False)
#0.829998
gs_res.head(10)
# Out:
#         cv   data_name  depth eval_metric gs_timespent  iterations  \
# 2uNj  True  bo2_newcat      5         AUC      6:42:53        8070
# WobY  True  bo2_newcat      6         AUC      7:52:01        6483
# t7zz  True  bo2_newcat      5         AUC      2:49:45        4997
#
#       l2_leaf_reg logging_level pred_timespent  random_seed  thread_count  \
# 2uNj          2.4       Verbose        2:18:02     11580801            15
# WobY          2.8       Verbose        2:12:22      2231986            15
# t7zz          0.4       Verbose        1:27:10     11505009            15
#
#                 timestamp  train_AUC   val_AUC
# 2uNj  2018-07-24 21:52:29   0.875846  0.790959
# WobY  2018-07-23 21:47:51   0.886156  0.790756
# t7zz  2018-07-23 16:07:14   0.857453  0.790182

# %%
# gs_res.drop(index=['0ePG', '4Ci9'], inplace=True)

# %%
# gs_res.to_csv('output/catb_bo2_newcat_grid_search.csv')

# %%
sn_res2 = pd.read_csv('output/lgb_fe_repro_1_stacknet.csv', index_col='Unnamed: 0').sort_values(by=['cv_val_auc'], ascending=False)
#0.829998
sn_res2.head(20)
# Out:
#       bagging_fraction  bagging_seed boosting  cv_train_auc  cv_val_auc  \
# pVfN              0.87      27821599     gbdt      0.923547    0.792136
# uvRx              0.82      39449137     gbdt      0.907418    0.791613
# iaaN              0.78      17455800     gbdt      0.931538    0.791320
# sFig              0.87      25836528     gbdt      0.918973    0.791251
# COun              0.86      19935998     gbdt      0.914218    0.790985
# FiAK              0.86      33115187     gbdt      0.893729    0.790709
# KXlE              0.78      21253759     gbdt      0.860614    0.790629
# d5iT              0.85      43151579     gbdt      0.853961    0.790175
# YcDT              0.81      37011015     gbdt      0.849043    0.790024
# tbo2              0.73      13388512     gbdt      0.922888    0.789736
#
#        data_name  feature_fraction  feature_fraction_seed  lambda_l1  \
# pVfN  fe_repro_1              0.32               27821599       0.43
# uvRx  fe_repro_1              0.45               39449137       0.13
# iaaN  fe_repro_1              0.56               17455800       0.20
# sFig  fe_repro_1              0.52               25836528       0.32
# COun  fe_repro_1              0.53               19935998       0.36
# FiAK  fe_repro_1              0.66               33115187       0.02
# KXlE  fe_repro_1              0.37               21253759       0.41
# d5iT  fe_repro_1              0.65               43151579       0.36
# YcDT  fe_repro_1              0.61               37011015       0.26
# tbo2  fe_repro_1              0.49               13388512       0.15
#
#       lambda_l2  learning_rate  max_depth metric  min_child_weight  \
# pVfN        2.4          0.004          8    auc                50
# uvRx        1.8          0.007          9    auc                55
# iaaN        1.2          0.005          8    auc                17
# sFig        1.2          0.007          8    auc                27
# COun        0.8          0.003          7    auc                43
# FiAK        0.6          0.009          6    auc                51
# KXlE        0.8          0.007          4    auc                16
# d5iT        1.5          0.003          4    auc                15
# YcDT        2.3          0.003          4    auc                38
# tbo2        1.4          0.005          7    auc                16
#
#       min_split_gain  num_leaves  num_threads objective    oof_seed  \
# pVfN           0.015          69           15    binary  27821599.0
# uvRx           0.048          41           15    binary  39449137.0
# iaaN           0.025          70           15    binary  17455800.0
# sFig           0.053          74           15    binary  25836528.0
# COun           0.018          58           15    binary  19935998.0
# FiAK           0.051          39           15    binary  33115187.0
# KXlE           0.012          48           15    binary         NaN
# d5iT           0.035          60           15    binary  43151579.0
# YcDT           0.052          47           15    binary  37011015.0
# tbo2           0.037          75           15    binary  13388512.0
#
#       scale_pos_weight
# pVfN               2.4
# uvRx               2.9
# iaaN               1.8
# sFig               1.2
# COun               2.7
# FiAK               2.8
# KXlE               1.7
# d5iT               2.1
# YcDT               2.0
# tbo2               4.7

# %%
temp = pd.concat([gs_lgb2_res, gs_lgb_res], axis=0)

# %%
temp.head(50).sort_values(by=['val_auc'], ascending=False)

# %%
gs_catb1_res = pd.read_csv('output/catb_bo2_newcat_grid_search.csv', index_col='Unnamed: 0').sort_values(by=['val_AUC'], ascending=False)
#0.829998
gs_catb1_res.head(20)
# Out:
#         cv   data_name  depth eval_metric gs_timespent  iterations  \
# 2uNj  True  bo2_newcat      5         AUC      6:42:53        8070
# WobY  True  bo2_newcat      6         AUC      7:52:01        6483
# t7zz  True  bo2_newcat      5         AUC      2:49:45        4997
#
#       l2_leaf_reg logging_level pred_timespent  random_seed  thread_count  \
# 2uNj          2.4       Verbose        2:18:02     11580801            15
# WobY          2.8       Verbose        2:12:22      2231986            15
# t7zz          0.4       Verbose        1:27:10     11505009            15
#
#                 timestamp  train_AUC   val_AUC
# 2uNj  2018-07-24 21:52:29   0.875846  0.790959
# WobY  2018-07-23 21:47:51   0.886156  0.790756
# t7zz  2018-07-23 16:07:14   0.857453  0.790182

# %%
for col in temp.columns:
    try:
        print(col, temp[col].max(), temp[col].min())
    except:
        print(col, 'NA')
        pass

# %%
temp.plot(x='bagging_fraction', y='val_auc', kind='scatter', ylim=[temp['val_auc'].min(),temp['val_auc'].max()])

# %%
gs_xgb2_res = pd.read_csv('output/xgb_bo2_w2v_newcat_grid_search.csv', index_col='Unnamed: 0').sort_values(by=['val_auc'], ascending=False)
#0.829998
gs_xgb2_res.head(20)

# %%
import pandas as pd

gs_nn_res = pd.read_csv('output/nn_grid_search.csv', index_col='Unnamed: 0').sort_values(by=['val_auc'], ascending=False)

gs_nn_res.head()

# %%
stacknet_res = pd.read_csv('output/oof/stacknet_report.csv').sort_values(by=['oof_cv_score'], ascending=False)
stacknet_res['num_model_data'] = stacknet_res['chosen model_data'].apply(lambda x: len(x.split('|')) if x is not np.nan else 0)
print(stacknet_res.shape)
stacknet_res
# Out:
# (54, 8)
#                               model_data  oof_cv_score  \
# 0                       0oNz__XGB_layer2      0.799394
# 37                       kKVa__NN_layer2      0.799271
# 34                      h1Vf__XGB_layer2      0.799210
# 11                   ClyI__LOGREG_layer2      0.798084
# 27                   cbzD__LOGREG_layer2      0.798074
# 6                        84KZ__NN_layer2      0.798050
# 47                       vNih__NN_layer2      0.798038
# 5                    7sFj__LOGREG_layer2      0.797824
# 28                       cvoz__NN_layer2      0.797592
# 2                       32Ps__LGB_layer2      0.797488
# 23                       SdAz__NN_layer2      0.797373
# 21                       Qeq2__NN_layer2      0.797250
# 10                      CUb4__LGB_layer2      0.797177
# 39       oFsf__XGB_bo2_w2v_newcat_layer1      0.797088
# 38  ksIj__LGB_flight_data_ordinal_layer1      0.797062
# 1   1CKg__LGB_flight_data_ordinal_layer1      0.797057
# 20       OuFu__XGB_bo2_w2v_newcat_layer1      0.796969
# 30  dQTL__LGB_flight_data_ordinal_layer1      0.796968
# 3   3VXI__LGB_flight_data_ordinal_layer1      0.796889
# 40  pC2i__LGB_flight_data_ordinal_layer1      0.796836
# 8   9QmW__LGB_flight_data_ordinal_layer1      0.796823
# 32       f4XK__XGB_bo2_w2v_newcat_layer1      0.796635
# 43  qHLQ__LGB_flight_data_ordinal_layer1      0.796536
# 33  fvQF__LGB_flight_data_ordinal_layer1      0.796483
# 24               VK0U__XGB_onehot_layer1      0.796329
# 7                    8Yok__LOGREG_layer2      0.796263
# 17                   Lt2A__LOGREG_layer2      0.796253
# 42                   phLT__LOGREG_layer2      0.796234
# 31                   djxf__LOGREG_layer2      0.796206
# 35                   hFte__LOGREG_layer2      0.796114
# 52                   yY2C__LOGREG_layer2      0.796021
# 4                6Keg__XGB_onehot_layer1      0.795969
# 16               KnJq__XGB_onehot_layer1      0.795360
# 22               Ro9e__XGB_onehot_layer1      0.793319
# 49               x26K__XGB_onehot_layer1      0.792943
# 48  vYhU__CATB_bo2_newcat_80pnull_layer1      0.792917
# 41           pVfN__LGB_fe_repro_1_layer1      0.792136
# 50         xa2m__LGB_simple_feats_layer1      0.792104
# 26         bQFq__LGB_simple_feats_layer1      0.792062
# 53  zTty__CATB_bo2_newcat_80pnull_layer1      0.792060
# 46           uvRx__LGB_fe_repro_1_layer1      0.791613
# 14           HyEX__LGB_fe_repro_1_layer1      0.791517
# 36           iaaN__LGB_fe_repro_1_layer1      0.791320
# 44           sFig__LGB_fe_repro_1_layer1      0.791251
# 9            COun__LGB_fe_repro_1_layer1      0.790985
# 12         Ff5g__LGB_simple_feats_layer1      0.790925
# 13           FiAK__LGB_fe_repro_1_layer1      0.790709
# 15           KXlE__LGB_fe_repro_1_layer1      0.790629
# 51         yOir__LGB_simple_feats_layer1      0.790499
# 19         Og6j__LGB_simple_feats_layer1      0.790393
# 29           d5iT__LGB_fe_repro_1_layer1      0.790175
# 25           YcDT__LGB_fe_repro_1_layer1      0.790024
# 45           tbo2__LGB_fe_repro_1_layer1      0.789736
# 18           NKXF__LGB_fe_repro_1_layer1      0.788959
#
#                                                                                                                                                                                                                                                                       chosen model_data  \
# 0                                                                                                    dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | vYhU__CATB | bQFq__LGB | xa2m__LGB
# 37                                                                                                   dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | vYhU__CATB | bQFq__LGB | xa2m__LGB
# 34  pC2i__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | Ro9e__XGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | x26K__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | sFig__LGB | zTty__CATB | vYhU__CATB | bQFq__LGB | xa2m__LGB | Ff5g__LGB
# 11                                                                                                   dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | vYhU__CATB | bQFq__LGB | xa2m__LGB
# 27  pC2i__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | Ro9e__XGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | x26K__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | sFig__LGB | zTty__CATB | vYhU__CATB | bQFq__LGB | xa2m__LGB | Ff5g__LGB
# 6                                                                                                                                                                             dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB
# 47                                                                                                                                        dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB
# 5                                                                                                                                         dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB
# 28                                                                                                                                                                                                                dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB
# 2                                                                                                    dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | vYhU__CATB | bQFq__LGB | xa2m__LGB
# 23                                                                                                                                        dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB
# 21                                                                                                                                                                                        pC2i__LGB | qHLQ__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | fvQF__LGB
# 10  pC2i__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | Ro9e__XGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | x26K__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB | HyEX__LGB | uvRx__LGB | pVfN__LGB | sFig__LGB | zTty__CATB | vYhU__CATB | bQFq__LGB | xa2m__LGB | Ff5g__LGB
# 39                                                                                                                                                                                                                                                                                  NaN
# 38                                                                                                                                                                                                                                                                                  NaN
# 1                                                                                                                                                                                                                                                                                   NaN
# 20                                                                                                                                                                                                                                                                                  NaN
# 30                                                                                                                                                                                                                                                                                  NaN
# 3                                                                                                                                                                                                                                                                                   NaN
# 40                                                                                                                                                                                                                                                                                  NaN
# 8                                                                                                                                                                                                                                                                                   NaN
# 32                                                                                                                                                                                                                                                                                  NaN
# 43                                                                                                                                                                                                                                                                                  NaN
# 33                                                                                                                                                                                                                                                                                  NaN
# 24                                                                                                                                                                                                                                                                                  NaN
# 7                                                                                                                                                                                                                             pC2i__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | ksIj__LGB
# 17                                                                                                                                                                                        pC2i__LGB | qHLQ__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | fvQF__LGB
# 42                                                                                                                                                    pC2i__LGB | qHLQ__LGB | dQTL__LGB | 3VXI__LGB | 1CKg__LGB | 9QmW__LGB | ksIj__LGB | fvQF__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB
# 31                                                                                                                                                                            dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB | f4XK__XGB | OuFu__XGB | oFsf__XGB
# 35                                                                                                                                                                                                                dQTL__LGB | 1CKg__LGB | ksIj__LGB | VK0U__XGB | KnJq__XGB | 6Keg__XGB
# 52                                                                                                                                                                                                                                                    VK0U__XGB | KnJq__XGB | 6Keg__XGB
# 4                                                                                                                                                                                                                                                                                   NaN
# 16                                                                                                                                                                                                                                                                                  NaN
# 22                                                                                                                                                                                                                                                                                  NaN
# 49                                                                                                                                                                                                                                                                                  NaN
# 48                                                                                                                                                                                                                                                                                  NaN
# 41                                                                                                                                                                                                                                                                                  NaN
# 50                                                                                                                                                                                                                                                                                  NaN
# 26                                                                                                                                                                                                                                                                                  NaN
# 53                                                                                                                                                                                                                                                                                  NaN
# 46                                                                                                                                                                                                                                                                                  NaN
# 14                                                                                                                                                                                                                                                                                  NaN
# 36                                                                                                                                                                                                                                                                                  NaN
# 44                                                                                                                                                                                                                                                                                  NaN
# 9                                                                                                                                                                                                                                                                                   NaN
# 12                                                                                                                                                                                                                                                                                  NaN
# 13                                                                                                                                                                                                                                                                                  NaN
# 15                                                                                                                                                                                                                                                                                  NaN
# 51                                                                                                                                                                                                                                                                                  NaN
# 19                                                                                                                                                                                                                                                                                  NaN
# 29                                                                                                                                                                                                                                                                                  NaN
# 25                                                                                                                                                                                                                                                                                  NaN
# 45                                                                                                                                                                                                                                                                                  NaN
# 18                                                                                                                                                                                                                                                                                  NaN
#
#               timestamp  nfolds  gs_val_auc        seed  num_model_data
# 0   2018-07-30 20:21:23     3.0         NaN         NaN              15
# 37  2018-07-30 20:21:23     3.0         NaN         NaN              15
# 34  2018-07-30 19:57:03     3.0         NaN         NaN              23
# 11  2018-07-30 20:21:23     3.0         NaN         NaN              15
# 27  2018-07-30 20:12:26     3.0         NaN         NaN              23
# 6                   NaN     NaN         NaN         NaN               9
# 47  2018-07-28 17:15:48     NaN         NaN         NaN              12
# 5   2018-07-28 17:08:38     NaN         NaN         NaN              12
# 28                  NaN     NaN         NaN         NaN               6
# 2   2018-07-30 20:21:23     3.0         NaN         NaN              15
# 23  2018-07-28 17:09:52     NaN         NaN         NaN              12
# 21                  NaN     NaN         NaN         NaN               8
# 10  2018-07-30 20:12:26     3.0         NaN         NaN              23
# 39                  NaN     NaN    0.797407         NaN               0
# 38                  NaN     NaN    0.797274         NaN               0
# 1                   NaN     NaN    0.797217         NaN               0
# 20                  NaN     NaN    0.796856         NaN               0
# 30                  NaN     NaN    0.797314         NaN               0
# 3                   NaN     NaN    0.797427         NaN               0
# 40                  NaN     NaN    0.797317         NaN               0
# 8                   NaN     NaN    0.797026         NaN               0
# 32                  NaN     NaN    0.796615         NaN               0
# 43                  NaN     NaN    0.797171         NaN               0
# 33                  NaN     NaN    0.797059         NaN               0
# 24                  NaN     NaN    0.796624         NaN               0
# 7                   NaN     NaN         NaN         NaN               5
# 17                  NaN     NaN         NaN         NaN               8
# 42                  NaN     NaN         NaN         NaN              11
# 31                  NaN     NaN         NaN         NaN               9
# 35                  NaN     NaN         NaN         NaN               6
# 52                  NaN     NaN         NaN         NaN               3
# 4                   NaN     NaN    0.796726         NaN               0
# 16                  NaN     NaN    0.796085         NaN               0
# 22                  NaN     NaN    0.792898         NaN               0
# 49                  NaN     NaN    0.793340         NaN               0
# 48  2018-07-30 17:31:31     6.0         NaN  24075891.0               0
# 41                  NaN     NaN         NaN         NaN               0
# 50  2018-07-30 14:05:17     8.0         NaN  40236651.0               0
# 26  2018-07-29 21:37:26     8.0         NaN  40281573.0               0
# 53  2018-07-30 06:02:35     6.0         NaN  27290883.0               0
# 46                  NaN     NaN         NaN         NaN               0
# 14                  NaN     NaN         NaN         NaN               0
# 36                  NaN     NaN         NaN         NaN               0
# 44                  NaN     NaN         NaN         NaN               0
# 9                   NaN     NaN         NaN         NaN               0
# 12  2018-07-30 15:38:00     8.0         NaN  36180885.0               0
# 13                  NaN     NaN         NaN         NaN               0
# 15                  NaN     NaN         NaN         NaN               0
# 51  2018-07-30 18:04:57     8.0         NaN  34484959.0               0
# 19  2018-07-30 12:25:50     8.0         NaN  31780438.0               0
# 29                  NaN     NaN         NaN         NaN               0
# 25                  NaN     NaN         NaN         NaN               0
# 45                  NaN     NaN         NaN         NaN               0
# 18                  NaN     NaN         NaN         NaN               0

# %%
stacknet_res[stacknet_res.model_data == 'IJCq__NN_layer2']['chosen model_data'].tolist()

# %%
# 1. oof_cv_score vs. gs_val_auc
# for NN, oof_cv_score != gs_val_auc is normal, because gs_val_auc is get by train+val in grid search, while 
# oof_cv_score is got by nfolds cv
# for LGB, if gs_cv is true in config file, then oof_cv_score == gs_val_auc (almost). otherwise, based on the same
# reason as NN, oof_cv_score != gs_val_auc is normal 

# 2. test_score
# for NN: the one(not showing in log) is got by train+val and load_weights when doing prediction after grid search
# (when do_preds is true in config file), and test_score is got during oof where all trainig data are used. It's 
# normal that they are not equal
# for LGB, since model is retrain using all training data when doing prediction after grid search, the one is not in 
# log == test_score

# %%
import os
import sys
#nb_dir = os.path.split(os.getcwd())[0]
#if nb_dir not in sys.path:
#    sys.path.append(nb_dir)
    
autolib_dir = '/home/kai/data/shiyi/AlphaBoosting/automl'
if autolib_dir not in sys.path:
    sys.path.append(autolib_dir)

print(sys.path)

# %load_ext autoreload
# %autoreload 2
# Out:
# ['', '/home/kai/anaconda3/envs/tf_gpu/lib/python35.zip', '/home/kai/anaconda3/envs/tf_gpu/lib/python3.5', '/home/kai/anaconda3/envs/tf_gpu/lib/python3.5/plat-linux', '/home/kai/anaconda3/envs/tf_gpu/lib/python3.5/lib-dynload', '/home/kai/.local/lib/python3.5/site-packages', '/home/kai/anaconda3/envs/tf_gpu/lib/python3.5/site-packages', '/home/kai/anaconda3/envs/tf_gpu/lib/python3.5/site-packages/IPython/extensions', '/home/kai/.ipython', '/home/kai/data/shiyi/AlphaBoosting/automl']

# %%
from automl_libs import BaseLayerResultsRepo

# %%
repo = BaseLayerResultsRepo(['TARGET'], 'output/oof/', load_from_file=True)

# %%
for i,(m,s) in enumerate(repo.show_scores()):
    print(i+1,s,m)
# Out:
# 1 0.7980504837639238 84KZ__NN_layer2
# 2 0.7980376580154528 vNih__NN_layer2
# 3 0.7978240481029633 7sFj__LOGREG_layer2
# 4 0.797592011293537 cvoz__NN_layer2
# 5 0.7974273799021107 3VXI__LGB_flight_data_ordinal_layer1
# 6 0.7974068000000001 oFsf__XGB_bo2_w2v_newcat_layer1
# 7 0.7973728184911024 SdAz__NN_layer2
# 8 0.7973165103016722 pC2i__LGB_flight_data_ordinal_layer1
# 9 0.7973143181135111 dQTL__LGB_flight_data_ordinal_layer1
# 10 0.7972740177867653 ksIj__LGB_flight_data_ordinal_layer1
# 11 0.7972499362605397 Qeq2__NN_layer2
# 12 0.7972168545179615 1CKg__LGB_flight_data_ordinal_layer1
# 13 0.7971714520828874 qHLQ__LGB_flight_data_ordinal_layer1
# 14 0.7970589480679557 fvQF__LGB_flight_data_ordinal_layer1
# 15 0.7970255969108454 9QmW__LGB_flight_data_ordinal_layer1
# 16 0.7968564 OuFu__XGB_bo2_w2v_newcat_layer1
# 17 0.7967264000000001 6Keg__XGB_onehot_layer1
# 18 0.7966236 VK0U__XGB_onehot_layer1
# 19 0.7966148000000002 f4XK__XGB_bo2_w2v_newcat_layer1
# 20 0.7962629152436195 8Yok__LOGREG_layer2
# 21 0.7962531776320189 Lt2A__LOGREG_layer2
# 22 0.7962340071676001 phLT__LOGREG_layer2
# 23 0.7962058918258211 djxf__LOGREG_layer2
# 24 0.7961136656788663 hFte__LOGREG_layer2
# 25 0.7960854000000002 KnJq__XGB_onehot_layer1
# 26 0.7960207785017805 yY2C__LOGREG_layer2
# 27 0.7933404000000001 x26K__XGB_onehot_layer1
# 28 0.7929166782534732 vYhU__CATB_bo2_newcat_80pnull_layer1
# 29 0.7928979999999999 Ro9e__XGB_onehot_layer1
# 30 0.792136 pVfN__LGB_fe_repro_1_layer1
# 31 0.79210361854147 xa2m__LGB_simple_feats_layer1
# 32 0.7920616070549078 bQFq__LGB_simple_feats_layer1
# 33 0.7920603163157931 zTty__CATB_bo2_newcat_80pnull_layer1
# 34 0.791613 uvRx__LGB_fe_repro_1_layer1
# 35 0.791517 HyEX__LGB_fe_repro_1_layer1
# 36 0.79132 iaaN__LGB_fe_repro_1_layer1
# 37 0.791251 sFig__LGB_fe_repro_1_layer1
# 38 0.790985 COun__LGB_fe_repro_1_layer1
# 39 0.7909251277619971 Ff5g__LGB_simple_feats_layer1
# 40 0.790709 FiAK__LGB_fe_repro_1_layer1
# 41 0.790629 KXlE__LGB_fe_repro_1_layer1
# 42 0.7904993367275223 yOir__LGB_simple_feats_layer1
# 43 0.7903928074278561 Og6j__LGB_simple_feats_layer1
# 44 0.790175 d5iT__LGB_fe_repro_1_layer1
# 45 0.790024 YcDT__LGB_fe_repro_1_layer1
# 46 0.789736 tbo2__LGB_fe_repro_1_layer1
# 47 0.788959 NKXF__LGB_fe_repro_1_layer1

# %%
repo.add_score('pVfN__LGB_fe_repro_1_layer1', 0.792136)

# %%
repo.remove('4RXv__NN_layer2')

# %%
repo.save()

# %%
repo.unlock_save()

# %%
repo_formerge = BaseLayerResultsRepo(['TARGET'], 'output_formerge/oof/', load_from_file=True)

# %%
for i,(m,s) in enumerate(repo_formerge.show_scores()):
    print(i+1,s,m)
# Out:
# 1 0.79210361854147 xa2m__LGB_simple_feats_layer1
# 2 0.7920616070549078 bQFq__LGB_simple_feats_layer1
# 3 0.7909251277619971 Ff5g__LGB_simple_feats_layer1
# 4 0.7904993367275223 yOir__LGB_simple_feats_layer1
# 5 0.7903928074278561 Og6j__LGB_simple_feats_layer1

# %%
repo.merge_another_repo(repo_formerge)
# Out:
# Merge: ['bQFq__LGB_simple_feats_layer1', 'Og6j__LGB_simple_feats_layer1', 'xa2m__LGB_simple_feats_layer1', 'Ff5g__LGB_simple_feats_layer1', 'yOir__LGB_simple_feats_layer1']
# Ignore: []

# %%
pd.read_pickle('/home/kai/data/shiyi/data/home_credit/')

# %%
gs_nn_res.head(0).T.to_dict()
