# %%
import pandas as pd

PATH = '/home/kai/data/kaggle/homecredit/'

credit = pd.read_csv(PATH + 'credit_card_balance.csv')
train = pd.read_csv(PATH + 'application_train.csv')
test = pd.read_csv(PATH + 'application_test.csv')

'done'
# Out:
# 'done'

# %%
def minus_name(col1, col2): return col1 + '_minus_' + col2
def minus(df, col1, col2): return df[col1] - df[col2]

def ratio_name(col1, col2): return col1 + '_divide_' + col2
def ratio(df, col1, col2): return df[col1] / (df[col2] + 1)

def positive_count(df, gp_col, col):
    group = (df[col] > 0).astype('int8')
    group = pd.concat([df[gp_col], group], axis=1).groupby(gp_col)[[col]].sum().reset_index().rename(index=str, columns={col: 'positivecount_'+'_'.join([gp_col, col])})
    return group.astype({gp_col: df[gp_col].dtype})

def count(df, gp_col, col):
    group = df[[gp_col,col]].groupby(gp_col)[[col]].count().reset_index().rename(index=str, columns={col:'count_'+gp_col})
    return group.astype({gp_col: df[gp_col].dtype})

def numerical(df, gp_col, col, agg_fun):
    _df = df.groupby(gp_col)[[col]].agg(agg_fun)
    
    columns = []
    for x in _df.columns.levels[0]:
        for y in _df.columns.levels[1]:
            columns.append('_'.join([x, y]))
    _df.columns = columns
    return _df.reset_index().astype({gp_col: df[gp_col].dtype})

def one_hot(df, gp_col, col):
    return pd.concat([df[gp_col], pd.get_dummies(df[col], prefix='onehot_' + col)], axis=1).groupby(gp_col).sum().reset_index().astype({gp_col: df[gp_col].dtype})

'done'
# Out:
# 'done'

# %%
ignore = ['AMT_DRAWINGS_ATM_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT', 'AMT_DRAWINGS_POS_CURRENT',
          'AMT_INST_MIN_REGULARITY', 'AMT_RECEIVABLE_PRINCIPAL']
credit = credit[[x for x in credit.columns if x not in ignore]]
credit.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_CURRENT',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT', 'AMT_RECIVABLE',
#        'AMT_TOTAL_RECEIVABLE', 'CNT_DRAWINGS_ATM_CURRENT',
#        'CNT_DRAWINGS_CURRENT', 'CNT_DRAWINGS_OTHER_CURRENT',
#        'CNT_DRAWINGS_POS_CURRENT', 'CNT_INSTALMENT_MATURE_CUM',
#        'NAME_CONTRACT_STATUS', 'SK_DPD', 'SK_DPD_DEF'],
#       dtype='object')

# %%
df = credit[['SK_ID_CURR', 'SK_ID_PREV']].groupby(['SK_ID_CURR', 'SK_ID_PREV']).size().reset_index()[['SK_ID_CURR', 'SK_ID_PREV']]
merged_col = 'SK_ID_PREV'

# minus
name1 = minus_name('SK_DPD', 'SK_DPD_DEF')
credit[name1] = minus(credit, 'SK_DPD', 'SK_DPD_DEF')

# ratio
numerator = [x for x in credit.columns if 'AMT' in x] + ['SK_DPD', 'SK_DPD_DEF', name1]
denominator = [x for x in credit.columns if 'CNT' in x] + numerator + ['MONTHS_BALANCE']
for x in numerator:
    for y in denominator:
        if (x != y) and (ratio_name(y, x) not in credit.columns):
            credit[ratio_name(x, y)] = ratio(credit, x, y)
print('ratio\t', df.shape)
            
# one hot encoding sum
df = df.merge(one_hot(credit, merged_col, 'NAME_CONTRACT_STATUS'), on=merged_col, how='left')
print('one hot sum\t', df.shape)

# count
df = df.merge(count(credit, merged_col, 'NAME_CONTRACT_STATUS'), on=merged_col, how='left')
count_name = [x for x in df.columns if 'count_' in x][0]
print('count\t', df.shape)

# positive count
for x in ['SK_DPD', 'SK_DPD_DEF', name1]:
    df = df.merge(positive_count(credit, merged_col, x), on=merged_col, how='left')
print('positive count\t', df.shape)
    
# categorical ratio
for x in df.columns:
    if 'positivecount_' in x or 'onehot_' in x:
        df[ratio_name(x, count_name)] = ratio(df, x, count_name)
print('categorical ratio\t', df.shape)
        
# numerical
ignored = ['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS', 'MONTHS_BALANCE']
for x in set(credit.columns) - set(ignored):
    df = df.merge(numerical(credit, merged_col, x, ['mean', 'median', 'sum']), on=merged_col, how='left')
print('numerical\t', df.shape)

columns = []
for x in df.columns:
    tmp = 'creditcard_' + x if x != merged_col and x != 'SK_ID_CURR' else x
    columns.append(tmp)
df.columns = columns
'done'
# Out:
# ratio	 (104307, 2)
# one hot sum	 (104307, 9)
# count	 (104307, 10)
# positive count	 (104307, 13)
# categorical ratio	 (104307, 23)
# numerical	 (104307, 383)
# 'done'

# %%
merged_col = 'SK_ID_CURR'
df2 = pd.concat([train['SK_ID_CURR'], test['SK_ID_CURR']], ignore_index=True).to_frame()
        
# numerical
ignored = ['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS', 'MONTHS_BALANCE']
for x in set(df.columns) - set(ignored):
    df2 = df2.merge(numerical(df, merged_col, x, ['mean', 'median']), on=merged_col, how='left')
print('numerical\t', df2.shape)

# df2 = df2.merge(df.drop('SK_ID_PREV', axis=1), on='SK_ID_CURR', how='left')

'done'
# Out:
# numerical	 (356255, 763)
# 'done'

# %%
print(df2.columns.values)
df2.shape
# Out:
# ['SK_ID_CURR'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_median_median'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_DEF_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_median_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_mean_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_median_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Active_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Active_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_median_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_median_median'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_SK_DPD_mean_mean' 'creditcard_SK_DPD_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused_median'
#  'creditcard_count_SK_ID_PREV_mean' 'creditcard_count_SK_ID_PREV_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median_median'
#  'creditcard_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_sum_median'
#  'creditcard_AMT_RECIVABLE_sum_mean' 'creditcard_AMT_RECIVABLE_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_DEF_divide_count_SK_ID_PREV_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_DEF_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_median_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_sum_median'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_SK_DPD_DEF_median_mean' 'creditcard_SK_DPD_DEF_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand_divide_count_SK_ID_PREV_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_sum_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_mean_median'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed_divide_count_SK_ID_PREV_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_median_median'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_sum_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_median'
#  'creditcard_AMT_PAYMENT_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_sum_mean' 'creditcard_AMT_BALANCE_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_SK_DPD_median_mean' 'creditcard_SK_DPD_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_median_median'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_sum_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_SK_DPD_DEF_mean_mean' 'creditcard_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_sum_median'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_RECIVABLE_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_median_median'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_mean_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_median_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_median'
#  'creditcard_SK_DPD_sum_mean' 'creditcard_SK_DPD_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_SK_DPD_DEF_sum_mean' 'creditcard_SK_DPD_DEF_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_mean_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_divide_count_SK_ID_PREV_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_mean_median'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_median_mean'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_PREV_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_sum_mean'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_sum_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_mean_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved_median'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_mean_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_BALANCE_mean_mean' 'creditcard_AMT_BALANCE_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_sum_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean_median'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_median_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_median_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_sum_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_sum_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_sum_median'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Active_mean'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Active_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_mean_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_minus_SK_DPD_DEF_divide_count_SK_ID_PREV_mean'
#  'creditcard_positivecount_SK_ID_PREV_SK_DPD_minus_SK_DPD_DEF_divide_count_SK_ID_PREV_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_mean_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_mean_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_median_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_median_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_sum_median'
#  'creditcard_AMT_BALANCE_median_mean'
#  'creditcard_AMT_BALANCE_median_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_sum_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_sum_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_median_mean'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_mean_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_mean_median'
#  'creditcard_AMT_PAYMENT_CURRENT_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_median_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median_median'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_mean_mean'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_median_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_median_median']
# (356255, 763)

# %%
df2.to_pickle(PATH + 'inter/credit2curr0.pkl')
'done'
# Out:
# 'done'

# %%
print(train.shape, test.shape)
# Out:
# (307511, 122) (48744, 121)
