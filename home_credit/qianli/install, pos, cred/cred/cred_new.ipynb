# %%
import pandas as pd

PATH = '/home/kai/data/kaggle/homecredit/'

# credit = pd.read_csv(PATH + 'credit_card_balance.csv')
train = pd.read_csv(PATH + 'application_train.csv')
test = pd.read_csv(PATH + 'application_test.csv')
length_credit = len(credit)
'done'
# Out:
# 'done'

# %%
# intersection
credit = pd.read_csv(PATH + 'credit_card_balance.csv')
month = -100
credit = credit[credit['MONTHS_BALANCE']>-24]
print('credit', len(credit)/length_credit)
# Out:
# credit 0.4500381739816973

# %%
credit.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT',
#        'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT',
#        'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT',
#        'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE',
#        'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT',
#        'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT',
#        'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS', 'SK_DPD',
#        'SK_DPD_DEF'],
#       dtype='object')

# %%
credit.MONTHS_BALANCE.max()
# Out:
# -1

# %%
credit.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  MONTHS_BALANCE   AMT_BALANCE  \
# count  3.840312e+06  3.840312e+06    3.840312e+06  3.840312e+06
# mean   1.904504e+06  2.783242e+05   -3.452192e+01  5.830016e+04
# std    5.364695e+05  1.027045e+05    2.666775e+01  1.063070e+05
# min    1.000018e+06  1.000060e+05   -9.600000e+01 -4.202502e+05
# 25%    1.434385e+06  1.895170e+05   -5.500000e+01  0.000000e+00
# 50%    1.897122e+06  2.783960e+05   -2.800000e+01  0.000000e+00
# 75%    2.369328e+06  3.675800e+05   -1.100000e+01  8.904669e+04
# max    2.843496e+06  4.562500e+05   -1.000000e+00  1.505902e+06
#
#        AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# count             3.840312e+06              3.090496e+06
# mean              1.538080e+05              5.961325e+03
# std               1.651457e+05              2.822569e+04
# min               0.000000e+00             -6.827310e+03
# 25%               4.500000e+04              0.000000e+00
# 50%               1.125000e+05              0.000000e+00
# 75%               1.800000e+05              0.000000e+00
# max               1.350000e+06              2.115000e+06
#
#        AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# count          3.840312e+06                3.090496e+06
# mean           7.433388e+03                2.881696e+02
# std            3.384608e+04                8.201989e+03
# min           -6.211620e+03                0.000000e+00
# 25%            0.000000e+00                0.000000e+00
# 50%            0.000000e+00                0.000000e+00
# 75%            0.000000e+00                0.000000e+00
# max            2.287098e+06                1.529847e+06
#
#        AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY      ...       \
# count              3.090496e+06             3.535076e+06      ...
# mean               2.968805e+03             3.540204e+03      ...
# std                2.079689e+04             5.600154e+03      ...
# min                0.000000e+00             0.000000e+00      ...
# 25%                0.000000e+00             0.000000e+00      ...
# 50%                0.000000e+00             0.000000e+00      ...
# 75%                0.000000e+00             6.633911e+03      ...
# max                2.239274e+06             2.028820e+05      ...
#
#        AMT_RECEIVABLE_PRINCIPAL  AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# count              3.840312e+06   3.840312e+06          3.840312e+06
# mean               5.596588e+04   5.808881e+04          5.809829e+04
# std                1.025336e+05   1.059654e+05          1.059718e+05
# min               -4.233058e+05  -4.202502e+05         -4.202502e+05
# 25%                0.000000e+00   0.000000e+00          0.000000e+00
# 50%                0.000000e+00   0.000000e+00          0.000000e+00
# 75%                8.535924e+04   8.889949e+04          8.891451e+04
# max                1.472317e+06   1.493338e+06          1.493338e+06
#
#        CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# count              3.090496e+06          3.840312e+06
# mean               3.094490e-01          7.031439e-01
# std                1.100401e+00          3.190347e+00
# min                0.000000e+00          0.000000e+00
# 25%                0.000000e+00          0.000000e+00
# 50%                0.000000e+00          0.000000e+00
# 75%                0.000000e+00          0.000000e+00
# max                5.100000e+01          1.650000e+02
#
#        CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# count                3.090496e+06              3.090496e+06
# mean                 4.812496e-03              5.594791e-01
# std                  8.263861e-02              3.240649e+00
# min                  0.000000e+00              0.000000e+00
# 25%                  0.000000e+00              0.000000e+00
# 50%                  0.000000e+00              0.000000e+00
# 75%                  0.000000e+00              0.000000e+00
# max                  1.200000e+01              1.650000e+02
#
#        CNT_INSTALMENT_MATURE_CUM        SK_DPD    SK_DPD_DEF
# count               3.535076e+06  3.840312e+06  3.840312e+06
# mean                2.082508e+01  9.283667e+00  3.316220e-01
# std                 2.005149e+01  9.751570e+01  2.147923e+01
# min                 0.000000e+00  0.000000e+00  0.000000e+00
# 25%                 4.000000e+00  0.000000e+00  0.000000e+00
# 50%                 1.500000e+01  0.000000e+00  0.000000e+00
# 75%                 3.200000e+01  0.000000e+00  0.000000e+00
# max                 1.200000e+02  3.260000e+03  3.260000e+03
#
# [8 rows x 22 columns]

# %%
credit['AMT_BALANCE'] >= credit['AMT_CREDIT_LIMIT_ACTUAL'] + credit['AMT_DRAWINGS_ATM_CURRENT'] + credit['AMT_DRAWINGS_CURRENT'] + credit['']

# %%
x = credit.sort_values(['SK_ID_PREV','SK_ID_CURR','MONTHS_BALANCE'], ascending = False)

# %%
x = credit.NAME_CONTRACT_STATUS == 'Completed'
credit.loc[x].head(20)
# Out:
#      SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 17      1039039      276642              -6          0.0
# 18      2016842      302450              -3          0.0
# 46      1426111      116448              -7          0.0
# 53      1894367      113120              -1          0.0
# 69      1079749      140209              -3          0.0
# 72      1259317      277061              -7          0.0
# 79      1245301      183994              -6          0.0
# 91      1081753      274239              -4          0.0
# 92      2683662      161019              -4          0.0
# 97      1960212      285273              -1          0.0
# 104     2332604      155018              -6          0.0
# 105     1799652      317323              -6          0.0
# 133     1642352      152002              -7          0.0
# 134     2502806      309694              -7          0.0
# 141     2413836      222627              -2          0.0
# 143     2181480      122315              -1          0.0
# 160     1899794      372599              -2          0.0
# 170     2250490      237951              -7          0.0
# 183     2486217      147847              -6          0.0
# 213     1750131      410544              -3          0.0
#
#      AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  AMT_DRAWINGS_CURRENT  \
# 17                     67500                       0.0                  0.00
# 18                         0                       0.0                  0.00
# 46                         0                       0.0                  0.00
# 53                         0                       0.0               2145.78
# 69                    112500                       0.0                  0.00
# 72                    135000                       0.0                  0.00
# 79                         0                       0.0                  0.00
# 91                     45000                       0.0                  0.00
# 92                    225000                       0.0                  0.00
# 97                         0                       0.0                  0.00
# 104                   180000                       0.0                  0.00
# 105                        0                       0.0                  0.00
# 133                        0                       0.0                  0.00
# 134                   180000                       0.0                  0.00
# 141                        0                       0.0                  0.00
# 143                        0                       0.0                  0.00
# 160                   202500                       NaN                  0.00
# 170                        0                       0.0                  0.00
# 183                   247500                       NaN                  0.00
# 213                    45000                       0.0                  0.00
#
#      AMT_DRAWINGS_OTHER_CURRENT  AMT_DRAWINGS_POS_CURRENT  \
# 17                          0.0                       0.0
# 18                          0.0                       0.0
# 46                          0.0                       0.0
# 53                          0.0                       0.0
# 69                          0.0                       0.0
# 72                          0.0                       0.0
# 79                          0.0                       0.0
# 91                          0.0                       0.0
# 92                          0.0                       0.0
# 97                          0.0                       0.0
# 104                         0.0                       0.0
# 105                         0.0                       0.0
# 133                         0.0                       0.0
# 134                         0.0                       0.0
# 141                         0.0                       0.0
# 143                         0.0                       0.0
# 160                         NaN                       NaN
# 170                         0.0                       0.0
# 183                         NaN                       NaN
# 213                         0.0                       0.0
#
#      AMT_INST_MIN_REGULARITY     ...      AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# 17                     0.000     ...                0.0                   0.0
# 18                     0.000     ...                0.0                   0.0
# 46                     0.000     ...                0.0                   0.0
# 53                   811.035     ...                0.0                   0.0
# 69                     0.000     ...                0.0                   0.0
# 72                     0.000     ...                0.0                   0.0
# 79                     0.000     ...                0.0                   0.0
# 91                     0.000     ...                0.0                   0.0
# 92                 10805.805     ...                0.0                   0.0
# 97                     0.000     ...                0.0                   0.0
# 104                    0.000     ...                0.0                   0.0
# 105                    0.000     ...                0.0                   0.0
# 133                    0.000     ...                0.0                   0.0
# 134                    0.000     ...                0.0                   0.0
# 141                    0.000     ...                0.0                   0.0
# 143                    0.000     ...                0.0                   0.0
# 160                    0.000     ...                0.0                   0.0
# 170                    0.000     ...                0.0                   0.0
# 183                    0.000     ...                0.0                   0.0
# 213                    0.000     ...                0.0                   0.0
#
#      CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# 17                        0.0                     0
# 18                        0.0                     0
# 46                        0.0                     0
# 53                        0.0                     0
# 69                        0.0                     0
# 72                        0.0                     0
# 79                        0.0                     0
# 91                        0.0                     0
# 92                        0.0                     0
# 97                        0.0                     0
# 104                       0.0                     0
# 105                       0.0                     0
# 133                       0.0                     0
# 134                       0.0                     0
# 141                       0.0                     0
# 143                       0.0                     0
# 160                       NaN                     0
# 170                       0.0                     0
# 183                       NaN                     0
# 213                       0.0                     0
#
#      CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# 17                          0.0                       0.0
# 18                          0.0                       0.0
# 46                          0.0                       0.0
# 53                          0.0                       0.0
# 69                          0.0                       0.0
# 72                          0.0                       0.0
# 79                          0.0                       0.0
# 91                          0.0                       0.0
# 92                          0.0                       0.0
# 97                          0.0                       0.0
# 104                         0.0                       0.0
# 105                         0.0                       0.0
# 133                         0.0                       0.0
# 134                         0.0                       0.0
# 141                         0.0                       0.0
# 143                         0.0                       0.0
# 160                         NaN                       NaN
# 170                         0.0                       0.0
# 183                         NaN                       NaN
# 213                         0.0                       0.0
#
#      CNT_INSTALMENT_MATURE_CUM  NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 17                        33.0             Completed       0           0
# 18                         2.0             Completed       0           0
# 46                        15.0             Completed       0           0
# 53                         8.0             Completed       0           0
# 69                        35.0             Completed       0           0
# 72                        45.0             Completed       0           0
# 79                        49.0             Completed       0           0
# 91                        76.0             Completed       0           0
# 92                        42.0             Completed       0           0
# 97                        20.0             Completed       0           0
# 104                       43.0             Completed       0           0
# 105                        4.0             Completed       0           0
# 133                       13.0             Completed       0           0
# 134                       46.0             Completed       0           0
# 141                       53.0             Completed       0           0
# 143                       23.0             Completed       0           0
# 160                        0.0             Completed       0           0
# 170                        9.0             Completed       0           0
# 183                        0.0             Completed       0           0
# 213                        1.0             Completed       0           0
#
# [20 rows x 23 columns]

# %%
amt_list = [col for col in credit.columns if 'AMT' in col]

# %%
for col1 in amt_list:
    for col2 in amt_list:
        if col2 != col1:
            tmp1 = credit[col1] > credit[col2]
            tmp2 = credit[col1] == credit[col2]
            tmp3 = credit[col1] < credit[col2]
            print(col1,col2)
            print(tmp1.sum()/len(credit),tmp2.sum()/len(credit),tmp3.sum()/len(credit))
# Out:
# AMT_BALANCE AMT_CREDIT_LIMIT_ACTUAL
# 0.08914744427015305 0.19425661248356904 0.716595943246278
# AMT_BALANCE AMT_DRAWINGS_ATM_CURRENT
# 0.43012234422619827 0.3658069969314993 0.008821939467418272
# AMT_BALANCE AMT_DRAWINGS_CURRENT
# 0.4173343207531055 0.557694270673841 0.02497140857305344
# AMT_BALANCE AMT_DRAWINGS_OTHER_CURRENT
# 0.43735899583158866 0.36643611248252744 0.0009561723109997313
# AMT_BALANCE AMT_DRAWINGS_POS_CURRENT
# 0.42543392307708333 0.3647591654011445 0.014558192146888065
# AMT_BALANCE AMT_INST_MIN_REGULARITY
# 0.40771036311633013 0.47213273296544656 0.04067482017086112
# AMT_BALANCE AMT_PAYMENT_CURRENT
# 0.3960657363255902 0.06007376483994009 0.34387987226037886
# AMT_BALANCE AMT_PAYMENT_TOTAL_CURRENT
# 0.4079751853495237 0.5071147865069296 0.08491002814354667
# AMT_BALANCE AMT_RECEIVABLE_PRINCIPAL
# 0.4293195448703126 0.5706804551296873 0.0
# AMT_BALANCE AMT_RECIVABLE
# 0.12753182553917494 0.845008166003179 0.02746000845764615
# AMT_BALANCE AMT_TOTAL_RECEIVABLE
# 0.12749328700376428 0.8449938442501547 0.027512868746081047
# AMT_CREDIT_LIMIT_ACTUAL AMT_BALANCE
# 0.716595943246278 0.19425661248356904 0.08914744427015305
# AMT_CREDIT_LIMIT_ACTUAL AMT_DRAWINGS_ATM_CURRENT
# 0.6537362068498601 0.15034221177862633 0.0006728619966294405
# AMT_CREDIT_LIMIT_ACTUAL AMT_DRAWINGS_CURRENT
# 0.7979260539247853 0.19947155335295674 0.0026023927222579833
# AMT_CREDIT_LIMIT_ACTUAL AMT_DRAWINGS_OTHER_CURRENT
# 0.6583405202493964 0.1463862831978235 2.447717789596262e-05
# AMT_CREDIT_LIMIT_ACTUAL AMT_DRAWINGS_POS_CURRENT
# 0.6576621899470668 0.14646336026864484 0.0006257304094042359
# AMT_CREDIT_LIMIT_ACTUAL AMT_INST_MIN_REGULARITY
# 0.7517149648257746 0.1681475359293724 0.0006554154974908288
# AMT_CREDIT_LIMIT_ACTUAL AMT_PAYMENT_CURRENT
# 0.6473445386728995 0.027205341649324324 0.12546949310368533
# AMT_CREDIT_LIMIT_ACTUAL AMT_PAYMENT_TOTAL_CURRENT
# 0.7985562110578516 0.18284686244242657 0.0185969264997219
# AMT_CREDIT_LIMIT_ACTUAL AMT_RECEIVABLE_PRINCIPAL
# 0.7986702642910264 0.20049204335481075 0.000837692354162891
# AMT_CREDIT_LIMIT_ACTUAL AMT_RECIVABLE
# 0.7301867660752563 0.18274192305208536 0.08707131087265826
# AMT_CREDIT_LIMIT_ACTUAL AMT_TOTAL_RECEIVABLE
# 0.7300318307470851 0.1827390587014805 0.08722911055143437
# AMT_DRAWINGS_ATM_CURRENT AMT_BALANCE
# 0.008821939467418272 0.3658069969314993 0.43012234422619827
# AMT_DRAWINGS_ATM_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 0.0006728619966294405 0.15034221177862633 0.6537362068498601
# AMT_DRAWINGS_ATM_CURRENT AMT_DRAWINGS_CURRENT
# 7.811865285945517e-07 0.7311267938646652 0.07362370557392212
# AMT_DRAWINGS_ATM_CURRENT AMT_DRAWINGS_OTHER_CURRENT
# 0.11024260528832032 0.6915912040480044 0.002917471288791119
# AMT_DRAWINGS_ATM_CURRENT AMT_DRAWINGS_POS_CURRENT
# 0.10325645416309925 0.6483082624536757 0.053186564008340986
# AMT_DRAWINGS_ATM_CURRENT AMT_INST_MIN_REGULARITY
# 0.06867488891527564 0.3669519559869094 0.35803523255402164
# AMT_DRAWINGS_ATM_CURRENT AMT_PAYMENT_CURRENT
# 0.05833354164974096 0.09045306735494407 0.6440476711267209
# AMT_DRAWINGS_ATM_CURRENT AMT_PAYMENT_TOTAL_CURRENT
# 0.0660928070427611 0.35766963725863943 0.3809888363237154
# AMT_DRAWINGS_ATM_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.01426368482560792 0.4057675522197155 0.38472004357979245
# AMT_DRAWINGS_ATM_CURRENT AMT_RECIVABLE
# 0.037560489876864174 0.35274165224075543 0.41444913850749626
# AMT_DRAWINGS_ATM_CURRENT AMT_TOTAL_RECEIVABLE
# 0.037557625526259325 0.3526981661906637 0.4144954889081929
# AMT_DRAWINGS_CURRENT AMT_BALANCE
# 0.02497140857305344 0.557694270673841 0.4173343207531055
# AMT_DRAWINGS_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 0.0026023927222579833 0.19947155335295674 0.7979260539247853
# AMT_DRAWINGS_CURRENT AMT_DRAWINGS_ATM_CURRENT
# 0.07362370557392212 0.7311267938646652 7.811865285945517e-07
# AMT_DRAWINGS_CURRENT AMT_DRAWINGS_OTHER_CURRENT
# 0.1582907847070759 0.6464597147315114 7.811865285945517e-07
# AMT_DRAWINGS_CURRENT AMT_DRAWINGS_POS_CURRENT
# 0.11500523915765178 0.6897452602809355 7.811865285945517e-07
# AMT_DRAWINGS_CURRENT AMT_INST_MIN_REGULARITY
# 0.10348091509231541 0.4845614106353859 0.3324755905249365
# AMT_DRAWINGS_CURRENT AMT_PAYMENT_CURRENT
# 0.08437048864779736 0.09289766039842597 0.6227512243796858
# AMT_DRAWINGS_CURRENT AMT_PAYMENT_TOTAL_CURRENT
# 0.09718533285837193 0.5444677411626972 0.35834692597893086
# AMT_DRAWINGS_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.03233695595566194 0.599962190572016 0.36770085347232206
# AMT_DRAWINGS_CURRENT AMT_RECIVABLE
# 0.05430157758015495 0.5443424909226126 0.40135593149723253
# AMT_DRAWINGS_CURRENT AMT_TOTAL_RECEIVABLE
# 0.05429845283404057 0.5442987444770112 0.4014028026889482
# AMT_DRAWINGS_OTHER_CURRENT AMT_BALANCE
# 0.0009561723109997313 0.36643611248252744 0.43735899583158866
# AMT_DRAWINGS_OTHER_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 2.447717789596262e-05 0.1463862831978235 0.6583405202493964
# AMT_DRAWINGS_OTHER_CURRENT AMT_DRAWINGS_ATM_CURRENT
# 0.002917471288791119 0.6915912040480044 0.11024260528832032
# AMT_DRAWINGS_OTHER_CURRENT AMT_DRAWINGS_CURRENT
# 7.811865285945517e-07 0.6464597147315114 0.1582907847070759
# AMT_DRAWINGS_OTHER_CURRENT AMT_DRAWINGS_POS_CURRENT
# 0.003090634302629578 0.732955551528105 0.06870509479438129
# AMT_DRAWINGS_OTHER_CURRENT AMT_INST_MIN_REGULARITY
# 0.0018454229760498627 0.3748875091398824 0.4169291453402744
# AMT_DRAWINGS_OTHER_CURRENT AMT_PAYMENT_CURRENT
# 0.0019092198758850843 0.0952914763175492 0.6956335839379717
# AMT_DRAWINGS_OTHER_CURRENT AMT_PAYMENT_TOTAL_CURRENT
# 0.002267003305981389 0.37023346019802555 0.4322508171211089
# AMT_DRAWINGS_OTHER_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.0011525105251864952 0.40310006062007464 0.4004987094798548
# AMT_DRAWINGS_OTHER_CURRENT AMT_RECIVABLE
# 0.028778651317913753 0.3554099250269249 0.4205627042802772
# AMT_DRAWINGS_OTHER_CURRENT AMT_TOTAL_RECEIVABLE
# 0.02877630775832797 0.35536513699928546 0.42060983586750245
# AMT_DRAWINGS_POS_CURRENT AMT_BALANCE
# 0.014558192146888065 0.3647591654011445 0.42543392307708333
# AMT_DRAWINGS_POS_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 0.0006257304094042359 0.14646336026864484 0.6576621899470668
# AMT_DRAWINGS_POS_CURRENT AMT_DRAWINGS_ATM_CURRENT
# 0.053186564008340986 0.6483082624536757 0.10325645416309925
# AMT_DRAWINGS_POS_CURRENT AMT_DRAWINGS_CURRENT
# 7.811865285945517e-07 0.6897452602809355 0.11500523915765178
# AMT_DRAWINGS_POS_CURRENT AMT_DRAWINGS_OTHER_CURRENT
# 0.06870509479438129 0.732955551528105 0.003090634302629578
# AMT_DRAWINGS_POS_CURRENT AMT_INST_MIN_REGULARITY
# 0.044115426038301056 0.3648914463199865 0.3846552050979191
# AMT_DRAWINGS_POS_CURRENT AMT_PAYMENT_CURRENT
# 0.029078887340403592 0.09215423121871348 0.6716011615722889
# AMT_DRAWINGS_POS_CURRENT AMT_PAYMENT_TOTAL_CURRENT
# 0.036341318101237606 0.36253799170484063 0.40587197081903764
# AMT_DRAWINGS_POS_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.015571911865494262 0.39973601103243694 0.3894433577271847
# AMT_DRAWINGS_POS_CURRENT AMT_RECIVABLE
# 0.04276475453036108 0.352527346736411 0.4094591793583438
# AMT_DRAWINGS_POS_CURRENT AMT_TOTAL_RECEIVABLE
# 0.042762671366284824 0.3524825587087716 0.40950605055005945
# AMT_INST_MIN_REGULARITY AMT_BALANCE
# 0.04067482017086112 0.47213273296544656 0.40771036311633013
# AMT_INST_MIN_REGULARITY AMT_CREDIT_LIMIT_ACTUAL
# 0.0006554154974908288 0.1681475359293724 0.7517149648257746
# AMT_INST_MIN_REGULARITY AMT_DRAWINGS_ATM_CURRENT
# 0.35803523255402164 0.3669519559869094 0.06867488891527564
# AMT_INST_MIN_REGULARITY AMT_DRAWINGS_CURRENT
# 0.3324755905249365 0.4845614106353859 0.10348091509231541
# AMT_INST_MIN_REGULARITY AMT_DRAWINGS_OTHER_CURRENT
# 0.4169291453402744 0.3748875091398824 0.0018454229760498627
# AMT_INST_MIN_REGULARITY AMT_DRAWINGS_POS_CURRENT
# 0.3846552050979191 0.3648914463199865 0.044115426038301056
# AMT_INST_MIN_REGULARITY AMT_PAYMENT_CURRENT
# 0.0323275817173188 0.19660564037505285 0.5580627303198282
# AMT_INST_MIN_REGULARITY AMT_PAYMENT_TOTAL_CURRENT
# 0.0558082259983043 0.5812702197113151 0.2834394705430184
# AMT_INST_MIN_REGULARITY AMT_RECEIVABLE_PRINCIPAL
# 0.04609911902991215 0.48463067584092123 0.3897881213818044
# AMT_INST_MIN_REGULARITY AMT_RECIVABLE
# 0.06883451136261845 0.44596506742160535 0.405718337468414
# AMT_INST_MIN_REGULARITY AMT_TOTAL_RECEIVABLE
# 0.06879779559577451 0.4459507456685811 0.4057693749882822
# AMT_PAYMENT_CURRENT AMT_BALANCE
# 0.34387987226037886 0.06007376483994009 0.3960657363255902
# AMT_PAYMENT_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 0.12546949310368533 0.027205341649324324 0.6473445386728995
# AMT_PAYMENT_CURRENT AMT_DRAWINGS_ATM_CURRENT
# 0.6440476711267209 0.09045306735494407 0.05833354164974096
# AMT_PAYMENT_CURRENT AMT_DRAWINGS_CURRENT
# 0.6227512243796858 0.09289766039842597 0.08437048864779736
# AMT_PAYMENT_CURRENT AMT_DRAWINGS_OTHER_CURRENT
# 0.6956335839379717 0.0952914763175492 0.0019092198758850843
# AMT_PAYMENT_CURRENT AMT_DRAWINGS_POS_CURRENT
# 0.6716011615722889 0.09215423121871348 0.029078887340403592
# AMT_PAYMENT_CURRENT AMT_INST_MIN_REGULARITY
# 0.5580627303198282 0.19660564037505285 0.0323275817173188
# AMT_PAYMENT_CURRENT AMT_PAYMENT_TOTAL_CURRENT
# 0.30914988157212225 0.49086949185378687 0.0
# AMT_PAYMENT_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.34611458652317834 0.07438067532013024 0.3795241115826006
# AMT_PAYMENT_CURRENT AMT_RECIVABLE
# 0.3442267190790748 0.0603588979228771 0.39543375642395723
# AMT_PAYMENT_CURRENT AMT_TOTAL_RECEIVABLE
# 0.344199377550574 0.060352648430648345 0.3954673474446868
# AMT_PAYMENT_TOTAL_CURRENT AMT_BALANCE
# 0.08491002814354667 0.5071147865069296 0.4079751853495237
# AMT_PAYMENT_TOTAL_CURRENT AMT_CREDIT_LIMIT_ACTUAL
# 0.0185969264997219 0.18284686244242657 0.7985562110578516
# AMT_PAYMENT_TOTAL_CURRENT AMT_DRAWINGS_ATM_CURRENT
# 0.3809888363237154 0.35766963725863943 0.0660928070427611
# AMT_PAYMENT_TOTAL_CURRENT AMT_DRAWINGS_CURRENT
# 0.35834692597893086 0.5444677411626972 0.09718533285837193
# AMT_PAYMENT_TOTAL_CURRENT AMT_DRAWINGS_OTHER_CURRENT
# 0.4322508171211089 0.37023346019802555 0.002267003305981389
# AMT_PAYMENT_TOTAL_CURRENT AMT_DRAWINGS_POS_CURRENT
# 0.40587197081903764 0.36253799170484063 0.036341318101237606
# AMT_PAYMENT_TOTAL_CURRENT AMT_INST_MIN_REGULARITY
# 0.2834394705430184 0.5812702197113151 0.0558082259983043
# AMT_PAYMENT_TOTAL_CURRENT AMT_PAYMENT_CURRENT
# 0.0 0.49086949185378687 0.30914988157212225
# AMT_PAYMENT_TOTAL_CURRENT AMT_RECEIVABLE_PRINCIPAL
# 0.08643490424736323 0.5258419107614173 0.38772318499121944
# AMT_PAYMENT_TOTAL_CURRENT AMT_RECIVABLE
# 0.1120104304025298 0.48349118509121136 0.40449838450625886
# AMT_PAYMENT_TOTAL_CURRENT AMT_TOTAL_RECEIVABLE
# 0.11198621362014337 0.4834849355989826 0.404528850780874
# AMT_RECEIVABLE_PRINCIPAL AMT_BALANCE
# 0.0 0.5706804551296873 0.4293195448703126
# AMT_RECEIVABLE_PRINCIPAL AMT_CREDIT_LIMIT_ACTUAL
# 0.000837692354162891 0.20049204335481075 0.7986702642910264
# AMT_RECEIVABLE_PRINCIPAL AMT_DRAWINGS_ATM_CURRENT
# 0.38472004357979245 0.4057675522197155 0.01426368482560792
# AMT_RECEIVABLE_PRINCIPAL AMT_DRAWINGS_CURRENT
# 0.36770085347232206 0.599962190572016 0.03233695595566194
# AMT_RECEIVABLE_PRINCIPAL AMT_DRAWINGS_OTHER_CURRENT
# 0.4004987094798548 0.40310006062007464 0.0011525105251864952
# AMT_RECEIVABLE_PRINCIPAL AMT_DRAWINGS_POS_CURRENT
# 0.3894433577271847 0.39973601103243694 0.015571911865494262
# AMT_RECEIVABLE_PRINCIPAL AMT_INST_MIN_REGULARITY
# 0.3897881213818044 0.48463067584092123 0.04609911902991215
# AMT_RECEIVABLE_PRINCIPAL AMT_PAYMENT_CURRENT
# 0.3795241115826006 0.07438067532013024 0.34611458652317834
# AMT_RECEIVABLE_PRINCIPAL AMT_PAYMENT_TOTAL_CURRENT
# 0.38772318499121944 0.5258419107614173 0.08643490424736323
# AMT_RECEIVABLE_PRINCIPAL AMT_RECIVABLE
# 0.02812115265634667 0.5610807142752985 0.4107981330683549
# AMT_RECEIVABLE_PRINCIPAL AMT_TOTAL_RECEIVABLE
# 0.02811906949227042 0.56103540545664 0.4108455250510896
# AMT_RECIVABLE AMT_BALANCE
# 0.02746000845764615 0.845008166003179 0.12753182553917494
# AMT_RECIVABLE AMT_CREDIT_LIMIT_ACTUAL
# 0.08707131087265826 0.18274192305208536 0.7301867660752563
# AMT_RECIVABLE AMT_DRAWINGS_ATM_CURRENT
# 0.41444913850749626 0.35274165224075543 0.037560489876864174
# AMT_RECIVABLE AMT_DRAWINGS_CURRENT
# 0.40135593149723253 0.5443424909226126 0.05430157758015495
# AMT_RECIVABLE AMT_DRAWINGS_OTHER_CURRENT
# 0.4205627042802772 0.3554099250269249 0.028778651317913753
# AMT_RECIVABLE AMT_DRAWINGS_POS_CURRENT
# 0.4094591793583438 0.352527346736411 0.04276475453036108
# AMT_RECIVABLE AMT_INST_MIN_REGULARITY
# 0.405718337468414 0.44596506742160535 0.06883451136261845
# AMT_RECIVABLE AMT_PAYMENT_CURRENT
# 0.39543375642395723 0.0603588979228771 0.3442267190790748
# AMT_RECIVABLE AMT_PAYMENT_TOTAL_CURRENT
# 0.40449838450625886 0.48349118509121136 0.1120104304025298
# AMT_RECIVABLE AMT_RECEIVABLE_PRINCIPAL
# 0.4107981330683549 0.5610807142752985 0.02812115265634667
# AMT_RECIVABLE AMT_TOTAL_RECEIVABLE
# 0.0 0.9970721128908276 0.0029278871091723796
# AMT_TOTAL_RECEIVABLE AMT_BALANCE
# 0.027512868746081047 0.8449938442501547 0.12749328700376428
# AMT_TOTAL_RECEIVABLE AMT_CREDIT_LIMIT_ACTUAL
# 0.08722911055143437 0.1827390587014805 0.7300318307470851
# AMT_TOTAL_RECEIVABLE AMT_DRAWINGS_ATM_CURRENT
# 0.4144954889081929 0.3526981661906637 0.037557625526259325
# AMT_TOTAL_RECEIVABLE AMT_DRAWINGS_CURRENT
# 0.4014028026889482 0.5442987444770112 0.05429845283404057
# AMT_TOTAL_RECEIVABLE AMT_DRAWINGS_OTHER_CURRENT
# 0.42060983586750245 0.35536513699928546 0.02877630775832797
# AMT_TOTAL_RECEIVABLE AMT_DRAWINGS_POS_CURRENT
# 0.40950605055005945 0.3524825587087716 0.042762671366284824
# AMT_TOTAL_RECEIVABLE AMT_INST_MIN_REGULARITY
# 0.4057693749882822 0.4459507456685811 0.06879779559577451
# AMT_TOTAL_RECEIVABLE AMT_PAYMENT_CURRENT
# 0.3954673474446868 0.060352648430648345 0.344199377550574
# AMT_TOTAL_RECEIVABLE AMT_PAYMENT_TOTAL_CURRENT
# 0.404528850780874 0.4834849355989826 0.11198621362014337
# AMT_TOTAL_RECEIVABLE AMT_RECEIVABLE_PRINCIPAL
# 0.4108455250510896 0.56103540545664 0.02811906949227042
# AMT_TOTAL_RECEIVABLE AMT_RECIVABLE
# 0.0029278871091723796 0.9970721128908276 0.0

# %%
credit[credit['SK_ID_PREV'] == 1384354].sort_values('MONTHS_BALANCE',ascending = False)[:5]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 773974      1384354      116448              -1   188923.905
# 2149173     1384354      116448              -2   130276.800
# 2268722     1384354      116448              -3   160899.300
# 1148392     1384354      116448              -4   133171.200
# 2074068     1384354      116448              -5        0.000
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 773974                    225000                   40500.0
# 2149173                   225000                       0.0
# 2268722                   225000                       0.0
# 1148392                   225000                  148500.0
# 2074068                   225000                       NaN
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 773974               56668.50                         0.0
# 2149173                  0.00                         0.0
# 2268722                  0.00                         0.0
# 1148392             178734.06                         0.0
# 2074068                  0.00                         NaN
#
#          AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY     ...      \
# 773974                   16168.50                  7112.16     ...
# 2149173                      0.00                  7900.56     ...
# 2268722                      0.00                  6206.40     ...
# 1148392                  30234.06                     0.00     ...
# 2074068                       NaN                     0.00     ...
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 773974      184486.230            184486.230                       2.0
# 2149173     129614.625            129614.625                       0.0
# 2268722     159752.970            159752.970                       0.0
# 1148392     130480.200            130480.200                       4.0
# 2074068          0.000                 0.000                       NaN
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 773974                      3                         0.0
# 2149173                     0                         0.0
# 2268722                     0                         0.0
# 1148392                     6                         0.0
# 2074068                     0                         NaN
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  \
# 773974                        1.0                        3.0
# 2149173                       0.0                        2.0
# 2268722                       0.0                        1.0
# 1148392                       2.0                        0.0
# 2074068                       NaN                        0.0
#
#          NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 773974                 Active       0           0
# 2149173                Active       0           0
# 2268722                Active       0           0
# 1148392                Active       0           0
# 2074068                Active       0           0
#
# [5 rows x 23 columns]

# %%
credit[credit['SK_ID_CURR'] == 116448].sort_values(['SK_ID_PREV','MONTHS_BALANCE'],ascending = False)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 959987      1426111      116448              -1          0.0
# 777653      1426111      116448              -2          0.0
# 2331358     1426111      116448              -3          0.0
# 3027066     1426111      116448              -4          0.0
# 3280708     1426111      116448              -5          0.0
# 390787      1426111      116448              -6          0.0
# 46          1426111      116448              -7          0.0
# 2561863     1426111      116448              -8          0.0
# 1945152     1426111      116448              -9          0.0
# 456620      1426111      116448             -10          0.0
# 3764388     1426111      116448             -11          0.0
# 64183       1426111      116448             -12          0.0
# 2922450     1426111      116448             -13          0.0
# 1628860     1426111      116448             -14          0.0
# 3107648     1426111      116448             -15          0.0
# 392090      1426111      116448             -16          0.0
# 1270430     1426111      116448             -17          0.0
# 1365044     1426111      116448             -18          0.0
# 3008377     1426111      116448             -19          0.0
# 3480946     1426111      116448             -20          0.0
# 3276535     1426111      116448             -21          0.0
# 3058617     1426111      116448             -22          0.0
# 2441351     1426111      116448             -23          0.0
# 2088747     1426111      116448             -24          0.0
# 1244440     1426111      116448             -25          0.0
# 2847141     1426111      116448             -26          0.0
# 3607618     1426111      116448             -27          0.0
# 3697428     1426111      116448             -28          0.0
# 2016291     1426111      116448             -29          0.0
# 286753      1426111      116448             -30          0.0
# ...             ...         ...             ...          ...
# 2268722     1384354      116448              -3     160899.3
# 1148392     1384354      116448              -4     133171.2
# 2074068     1384354      116448              -5          0.0
# 1686035     1384354      116448              -6          0.0
# 1483312     1384354      116448              -7          0.0
# 2937775     1384354      116448              -8          0.0
# 2901445     1384354      116448              -9          0.0
# 3434991     1384354      116448             -10          0.0
# 1531265     1384354      116448             -11          0.0
# 107944      1384354      116448             -12          0.0
# 1942726     1384354      116448             -13          0.0
# 1513878     1384354      116448             -14          0.0
# 2041838     1384354      116448             -15          0.0
# 1242606     1384354      116448             -16          0.0
# 1003247     1384354      116448             -17          0.0
# 1989478     1384354      116448             -18          0.0
# 2558829     1384354      116448             -19          0.0
# 3460922     1384354      116448             -20          0.0
# 3733088     1384354      116448             -21          0.0
# 823185      1384354      116448             -22          0.0
# 491045      1384354      116448             -23          0.0
# 1141634     1384354      116448             -24          0.0
# 2355155     1384354      116448             -25          0.0
# 2381665     1384354      116448             -26          0.0
# 1161605     1384354      116448             -27          0.0
# 2165930     1384354      116448             -28          0.0
# 946814      1384354      116448             -29          0.0
# 3829221     1384354      116448             -30          0.0
# 207521      1384354      116448             -31          0.0
# 1397004     1384354      116448             -32          0.0
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 959987                         0                       0.0
# 777653                         0                       0.0
# 2331358                        0                       0.0
# 3027066                        0                       0.0
# 3280708                        0                       0.0
# 390787                         0                       0.0
# 46                             0                       0.0
# 2561863                        0                       0.0
# 1945152                        0                       0.0
# 456620                         0                       0.0
# 3764388                        0                       0.0
# 64183                          0                       0.0
# 2922450                        0                       0.0
# 1628860                        0                       0.0
# 3107648                        0                       0.0
# 392090                         0                       0.0
# 1270430                        0                       0.0
# 1365044                        0                       0.0
# 3008377                        0                       0.0
# 3480946                        0                       0.0
# 3276535                        0                       0.0
# 3058617                        0                       0.0
# 2441351                        0                       0.0
# 2088747                        0                       0.0
# 1244440                        0                       0.0
# 2847141                        0                       0.0
# 3607618                        0                       0.0
# 3697428                        0                       0.0
# 2016291                        0                       0.0
# 286753                         0                       0.0
# ...                          ...                       ...
# 2268722                   225000                       0.0
# 1148392                   225000                  148500.0
# 2074068                   225000                       NaN
# 1686035                   225000                       NaN
# 1483312                   225000                       NaN
# 2937775                   225000                       NaN
# 2901445                   225000                       NaN
# 3434991                   225000                       NaN
# 1531265                   225000                       NaN
# 107944                    225000                       NaN
# 1942726                   225000                       NaN
# 1513878                   225000                       NaN
# 2041838                   225000                       NaN
# 1242606                   225000                       NaN
# 1003247                   225000                       NaN
# 1989478                   225000                       NaN
# 2558829                   225000                       NaN
# 3460922                   225000                       NaN
# 3733088                   225000                       NaN
# 823185                    225000                       NaN
# 491045                    225000                       NaN
# 1141634                   225000                       NaN
# 2355155                   225000                       NaN
# 2381665                   225000                       NaN
# 1161605                   225000                       NaN
# 2165930                   225000                       NaN
# 946814                    225000                       NaN
# 3829221                   225000                       NaN
# 207521                    225000                       NaN
# 1397004                   225000                       NaN
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 959987                   0.00                         0.0
# 777653                   0.00                         0.0
# 2331358                  0.00                         0.0
# 3027066                  0.00                         0.0
# 3280708                  0.00                         0.0
# 390787                   0.00                         0.0
# 46                       0.00                         0.0
# 2561863                  0.00                         0.0
# 1945152                  0.00                         0.0
# 456620                   0.00                         0.0
# 3764388                  0.00                         0.0
# 64183                    0.00                         0.0
# 2922450                  0.00                         0.0
# 1628860                  0.00                         0.0
# 3107648                  0.00                         0.0
# 392090                   0.00                         0.0
# 1270430                  0.00                         0.0
# 1365044                  0.00                         0.0
# 3008377                  0.00                         0.0
# 3480946                  0.00                         0.0
# 3276535                  0.00                         0.0
# 3058617                  0.00                         0.0
# 2441351                  0.00                         0.0
# 2088747                  0.00                         0.0
# 1244440                  0.00                         0.0
# 2847141                  0.00                         0.0
# 3607618                  0.00                         0.0
# 3697428                  0.00                         0.0
# 2016291                  0.00                         0.0
# 286753                   0.00                         0.0
# ...                       ...                         ...
# 2268722                  0.00                         0.0
# 1148392             178734.06                         0.0
# 2074068                  0.00                         NaN
# 1686035                  0.00                         NaN
# 1483312                  0.00                         NaN
# 2937775                  0.00                         NaN
# 2901445                  0.00                         NaN
# 3434991                  0.00                         NaN
# 1531265                  0.00                         NaN
# 107944                   0.00                         NaN
# 1942726                  0.00                         NaN
# 1513878                  0.00                         NaN
# 2041838                  0.00                         NaN
# 1242606                  0.00                         NaN
# 1003247                  0.00                         NaN
# 1989478                  0.00                         NaN
# 2558829                  0.00                         NaN
# 3460922                  0.00                         NaN
# 3733088                  0.00                         NaN
# 823185                   0.00                         NaN
# 491045                   0.00                         NaN
# 1141634                  0.00                         NaN
# 2355155                  0.00                         NaN
# 2381665                  0.00                         NaN
# 1161605                  0.00                         NaN
# 2165930                  0.00                         NaN
# 946814                   0.00                         NaN
# 3829221                  0.00                         NaN
# 207521                   0.00                         NaN
# 1397004                  0.00                         NaN
#
#          AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY     ...      \
# 959987                       0.00                      0.0     ...
# 777653                       0.00                      0.0     ...
# 2331358                      0.00                      0.0     ...
# 3027066                      0.00                      0.0     ...
# 3280708                      0.00                      0.0     ...
# 390787                       0.00                      0.0     ...
# 46                           0.00                      0.0     ...
# 2561863                      0.00                      0.0     ...
# 1945152                      0.00                      0.0     ...
# 456620                       0.00                      0.0     ...
# 3764388                      0.00                      0.0     ...
# 64183                        0.00                      0.0     ...
# 2922450                      0.00                      0.0     ...
# 1628860                      0.00                      0.0     ...
# 3107648                      0.00                      0.0     ...
# 392090                       0.00                      0.0     ...
# 1270430                      0.00                      0.0     ...
# 1365044                      0.00                      0.0     ...
# 3008377                      0.00                      0.0     ...
# 3480946                      0.00                      0.0     ...
# 3276535                      0.00                      0.0     ...
# 3058617                      0.00                      0.0     ...
# 2441351                      0.00                      0.0     ...
# 2088747                      0.00                      0.0     ...
# 1244440                      0.00                      0.0     ...
# 2847141                      0.00                      0.0     ...
# 3607618                      0.00                      0.0     ...
# 3697428                      0.00                      0.0     ...
# 2016291                      0.00                      0.0     ...
# 286753                       0.00                      0.0     ...
# ...                           ...                      ...     ...
# 2268722                      0.00                   6206.4     ...
# 1148392                  30234.06                      0.0     ...
# 2074068                       NaN                      0.0     ...
# 1686035                       NaN                      0.0     ...
# 1483312                       NaN                      0.0     ...
# 2937775                       NaN                      0.0     ...
# 2901445                       NaN                      0.0     ...
# 3434991                       NaN                      0.0     ...
# 1531265                       NaN                      0.0     ...
# 107944                        NaN                      0.0     ...
# 1942726                       NaN                      0.0     ...
# 1513878                       NaN                      0.0     ...
# 2041838                       NaN                      0.0     ...
# 1242606                       NaN                      0.0     ...
# 1003247                       NaN                      0.0     ...
# 1989478                       NaN                      0.0     ...
# 2558829                       NaN                      0.0     ...
# 3460922                       NaN                      0.0     ...
# 3733088                       NaN                      0.0     ...
# 823185                        NaN                      0.0     ...
# 491045                        NaN                      0.0     ...
# 1141634                       NaN                      0.0     ...
# 2355155                       NaN                      0.0     ...
# 2381665                       NaN                      0.0     ...
# 1161605                       NaN                      0.0     ...
# 2165930                       NaN                      0.0     ...
# 946814                        NaN                      0.0     ...
# 3829221                       NaN                      0.0     ...
# 207521                        NaN                      NaN     ...
# 1397004                       NaN                      NaN     ...
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 959987            0.00                  0.00                       0.0
# 777653            0.00                  0.00                       0.0
# 2331358           0.00                  0.00                       0.0
# 3027066           0.00                  0.00                       0.0
# 3280708           0.00                  0.00                       0.0
# 390787            0.00                  0.00                       0.0
# 46                0.00                  0.00                       0.0
# 2561863           0.00                  0.00                       0.0
# 1945152           0.00                  0.00                       0.0
# 456620            0.00                  0.00                       0.0
# 3764388           0.00                  0.00                       0.0
# 64183             0.00                  0.00                       0.0
# 2922450           0.00                  0.00                       0.0
# 1628860           0.00                  0.00                       0.0
# 3107648           0.00                  0.00                       0.0
# 392090            0.00                  0.00                       0.0
# 1270430           0.00                  0.00                       0.0
# 1365044           0.00                  0.00                       0.0
# 3008377           0.00                  0.00                       0.0
# 3480946           0.00                  0.00                       0.0
# 3276535           0.00                  0.00                       0.0
# 3058617           0.00                  0.00                       0.0
# 2441351           0.00                  0.00                       0.0
# 2088747           0.00                  0.00                       0.0
# 1244440           0.00                  0.00                       0.0
# 2847141           0.00                  0.00                       0.0
# 3607618           0.00                  0.00                       0.0
# 3697428           0.00                  0.00                       0.0
# 2016291           0.00                  0.00                       0.0
# 286753            0.00                  0.00                       0.0
# ...                ...                   ...                       ...
# 2268722      159752.97             159752.97                       0.0
# 1148392      130480.20             130480.20                       4.0
# 2074068           0.00                  0.00                       NaN
# 1686035           0.00                  0.00                       NaN
# 1483312           0.00                  0.00                       NaN
# 2937775           0.00                  0.00                       NaN
# 2901445           0.00                  0.00                       NaN
# 3434991           0.00                  0.00                       NaN
# 1531265           0.00                  0.00                       NaN
# 107944            0.00                  0.00                       NaN
# 1942726           0.00                  0.00                       NaN
# 1513878           0.00                  0.00                       NaN
# 2041838           0.00                  0.00                       NaN
# 1242606           0.00                  0.00                       NaN
# 1003247           0.00                  0.00                       NaN
# 1989478           0.00                  0.00                       NaN
# 2558829           0.00                  0.00                       NaN
# 3460922           0.00                  0.00                       NaN
# 3733088           0.00                  0.00                       NaN
# 823185            0.00                  0.00                       NaN
# 491045            0.00                  0.00                       NaN
# 1141634           0.00                  0.00                       NaN
# 2355155           0.00                  0.00                       NaN
# 2381665           0.00                  0.00                       NaN
# 1161605           0.00                  0.00                       NaN
# 2165930           0.00                  0.00                       NaN
# 946814            0.00                  0.00                       NaN
# 3829221           0.00                  0.00                       NaN
# 207521            0.00                  0.00                       NaN
# 1397004           0.00                  0.00                       NaN
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 959987                      0                         0.0
# 777653                      0                         0.0
# 2331358                     0                         0.0
# 3027066                     0                         0.0
# 3280708                     0                         0.0
# 390787                      0                         0.0
# 46                          0                         0.0
# 2561863                     0                         0.0
# 1945152                     0                         0.0
# 456620                      0                         0.0
# 3764388                     0                         0.0
# 64183                       0                         0.0
# 2922450                     0                         0.0
# 1628860                     0                         0.0
# 3107648                     0                         0.0
# 392090                      0                         0.0
# 1270430                     0                         0.0
# 1365044                     0                         0.0
# 3008377                     0                         0.0
# 3480946                     0                         0.0
# 3276535                     0                         0.0
# 3058617                     0                         0.0
# 2441351                     0                         0.0
# 2088747                     0                         0.0
# 1244440                     0                         0.0
# 2847141                     0                         0.0
# 3607618                     0                         0.0
# 3697428                     0                         0.0
# 2016291                     0                         0.0
# 286753                      0                         0.0
# ...                       ...                         ...
# 2268722                     0                         0.0
# 1148392                     6                         0.0
# 2074068                     0                         NaN
# 1686035                     0                         NaN
# 1483312                     0                         NaN
# 2937775                     0                         NaN
# 2901445                     0                         NaN
# 3434991                     0                         NaN
# 1531265                     0                         NaN
# 107944                      0                         NaN
# 1942726                     0                         NaN
# 1513878                     0                         NaN
# 2041838                     0                         NaN
# 1242606                     0                         NaN
# 1003247                     0                         NaN
# 1989478                     0                         NaN
# 2558829                     0                         NaN
# 3460922                     0                         NaN
# 3733088                     0                         NaN
# 823185                      0                         NaN
# 491045                      0                         NaN
# 1141634                     0                         NaN
# 2355155                     0                         NaN
# 2381665                     0                         NaN
# 1161605                     0                         NaN
# 2165930                     0                         NaN
# 946814                      0                         NaN
# 3829221                     0                         NaN
# 207521                      0                         NaN
# 1397004                     0                         NaN
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  \
# 959987                        0.0                       15.0
# 777653                        0.0                       15.0
# 2331358                       0.0                       15.0
# 3027066                       0.0                       15.0
# 3280708                       0.0                       15.0
# 390787                        0.0                       15.0
# 46                            0.0                       15.0
# 2561863                       0.0                       15.0
# 1945152                       0.0                       15.0
# 456620                        0.0                       15.0
# 3764388                       0.0                       15.0
# 64183                         0.0                       15.0
# 2922450                       0.0                       15.0
# 1628860                       0.0                       15.0
# 3107648                       0.0                       15.0
# 392090                        0.0                       15.0
# 1270430                       0.0                       15.0
# 1365044                       0.0                       15.0
# 3008377                       0.0                       15.0
# 3480946                       0.0                       15.0
# 3276535                       0.0                       15.0
# 3058617                       0.0                       15.0
# 2441351                       0.0                       15.0
# 2088747                       0.0                       15.0
# 1244440                       0.0                       15.0
# 2847141                       0.0                       15.0
# 3607618                       0.0                       15.0
# 3697428                       0.0                       15.0
# 2016291                       0.0                       15.0
# 286753                        0.0                       15.0
# ...                           ...                        ...
# 2268722                       0.0                        1.0
# 1148392                       2.0                        0.0
# 2074068                       NaN                        0.0
# 1686035                       NaN                        0.0
# 1483312                       NaN                        0.0
# 2937775                       NaN                        0.0
# 2901445                       NaN                        0.0
# 3434991                       NaN                        0.0
# 1531265                       NaN                        0.0
# 107944                        NaN                        0.0
# 1942726                       NaN                        0.0
# 1513878                       NaN                        0.0
# 2041838                       NaN                        0.0
# 1242606                       NaN                        0.0
# 1003247                       NaN                        0.0
# 1989478                       NaN                        0.0
# 2558829                       NaN                        0.0
# 3460922                       NaN                        0.0
# 3733088                       NaN                        0.0
# 823185                        NaN                        0.0
# 491045                        NaN                        0.0
# 1141634                       NaN                        0.0
# 2355155                       NaN                        0.0
# 2381665                       NaN                        0.0
# 1161605                       NaN                        0.0
# 2165930                       NaN                        0.0
# 946814                        NaN                        0.0
# 3829221                       NaN                        0.0
# 207521                        NaN                        NaN
# 1397004                       NaN                        NaN
#
#          NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 959987              Completed       0           0
# 777653              Completed       0           0
# 2331358             Completed       0           0
# 3027066             Completed       0           0
# 3280708             Completed       0           0
# 390787              Completed       0           0
# 46                  Completed       0           0
# 2561863             Completed       0           0
# 1945152             Completed       0           0
# 456620              Completed       0           0
# 3764388             Completed       0           0
# 64183               Completed       0           0
# 2922450             Completed       0           0
# 1628860             Completed       0           0
# 3107648             Completed       0           0
# 392090              Completed       0           0
# 1270430             Completed       0           0
# 1365044             Completed       0           0
# 3008377             Completed       0           0
# 3480946             Completed       0           0
# 3276535             Completed       0           0
# 3058617             Completed       0           0
# 2441351             Completed       0           0
# 2088747             Completed       0           0
# 1244440             Completed       0           0
# 2847141             Completed       0           0
# 3607618             Completed       0           0
# 3697428             Completed       0           0
# 2016291             Completed       0           0
# 286753              Completed       0           0
# ...                       ...     ...         ...
# 2268722                Active       0           0
# 1148392                Active       0           0
# 2074068                Active       0           0
# 1686035                Active       0           0
# 1483312                Active       0           0
# 2937775                Active       0           0
# 2901445                Active       0           0
# 3434991                Active       0           0
# 1531265                Active       0           0
# 107944                 Active       0           0
# 1942726                Active       0           0
# 1513878                Active       0           0
# 2041838                Active       0           0
# 1242606                Active       0           0
# 1003247                Active       0           0
# 1989478                Active       0           0
# 2558829                Active       0           0
# 3460922                Active       0           0
# 3733088                Active       0           0
# 823185                 Active       0           0
# 491045                 Active       0           0
# 1141634                Active       0           0
# 2355155                Active       0           0
# 2381665                Active       0           0
# 1161605                Active       0           0
# 2165930                Active       0           0
# 946814                 Active       0           0
# 3829221                Active       0           0
# 207521                 Active       0           0
# 1397004                Active       0           0
#
# [127 rows x 23 columns]

# %%
def minus_name(col1, col2): return col1 + '_minus_' + col2
def minus(df, col1, col2): return df[col1] - df[col2]

def ratio_name(col1, col2): return col1 + '_divide_' + col2
def ratio(df, col1, col2): return df[col1] / (df[col2])

def positive_count(df, gp_col, col):
    group = (df[col] > 0).astype('int8')
    group = pd.concat([df[gp_col], group], axis=1).groupby(gp_col)[[col]].sum().reset_index().rename(index=str, columns={col: 'positivecount_'+'_'.join([gp_col, col])})
    return group.astype({gp_col: df[gp_col].dtype})

def count(df, gp_col, col):
    group = df[[gp_col,col]].groupby(gp_col)[[col]].count().reset_index().rename(index=str, columns={col:'count_'+gp_col})
    return group.astype({gp_col: df[gp_col].dtype})

def numerical(df, gp_col, col, agg_fun):
    _df = df.groupby(gp_col)[[col]].agg(agg_fun)
    
    columns = []
    for x in _df.columns.levels[0]:
        for y in _df.columns.levels[1]:
            columns.append('_'.join([x, y]))
    _df.columns = columns
    return _df.reset_index().astype({gp_col: df[gp_col].dtype})

def one_hot(df, gp_col, col):
    return pd.concat([df[gp_col], pd.get_dummies(df[col], prefix='onehot_' + col)], axis=1).groupby(gp_col).sum().reset_index().astype({gp_col: df[gp_col].dtype})

'done'
# Out:
# 'done'

# %%
ignore = ['AMT_DRAWINGS_ATM_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT', 'AMT_DRAWINGS_POS_CURRENT',
          'AMT_INST_MIN_REGULARITY', 'AMT_RECEIVABLE_PRINCIPAL']
credit = credit[[x for x in credit.columns if x not in ignore]]
credit.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_CURRENT',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT', 'AMT_RECIVABLE',
#        'AMT_TOTAL_RECEIVABLE', 'CNT_DRAWINGS_ATM_CURRENT',
#        'CNT_DRAWINGS_CURRENT', 'CNT_DRAWINGS_OTHER_CURRENT',
#        'CNT_DRAWINGS_POS_CURRENT', 'CNT_INSTALMENT_MATURE_CUM',
#        'NAME_CONTRACT_STATUS', 'SK_DPD', 'SK_DPD_DEF'],
#       dtype='object')

# %%
credit.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT',
#        'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT',
#        'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT',
#        'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE',
#        'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT',
#        'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT',
#        'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS', 'SK_DPD',
#        'SK_DPD_DEF'],
#       dtype='object')

# %%
df = pd.concat([train['SK_ID_CURR'], test['SK_ID_CURR']], ignore_index=True).to_frame()
# For each credit_card(prev):
# 1. count num of records;
# 2. count num and ratio of status: active approved
# 3. Add shift

#1. count num of records in a prev id
x = credit[['SK_ID_PREV', 'SK_ID_CURR','MONTHS_BALANCE']].groupby(['SK_ID_PREV', 'SK_ID_CURR']).count().reset_index().rename(index = str, columns = {'MONTHS_BALANCE':'prev_count'})
# count agg fun for num of records in a prev id
tmp = numerical(x, 'SK_ID_CURR','prev_count',['min','max','std','mean'])
df = df.merge(tmp, on  = 'SK_ID_CURR', how = 'left')

del tmp,x
gc.collect()
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c05db1b64b48> in <module>()
#       8 # count agg fun for num of records in a prev id
#       9 tmp = numerical(x, 'SK_ID_CURR','prev_count',['min','max','std','mean'])
# ---> 10 df = df.merge(tmp, on  = 'SK_ID_CURR', how = 'left')
#      11
#      12 del tmp,x
#
# NameError: name 'df' is not defined

# %%
_df = credit[['NAME_CONTRACT_STATUS']]
m = pd.get_dummies(_df['NAME_CONTRACT_STATUS'])
credit = pd.concat([credit, m], axis = 1)

# %%
credit.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE',
#        'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT',
#        'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT',
#        'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY',
#        'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT',
#        'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE',
#        'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT',
#        'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT',
#        'CNT_INSTALMENT_MATURE_CUM', 'NAME_CONTRACT_STATUS', 'SK_DPD',
#        'SK_DPD_DEF', 'Active', 'Completed', 'Demand', 'Signed'],
#       dtype='object')

# %%
x = credit[['SK_ID_PREV', 'SK_ID_CURR','Active']].groupby(['SK_ID_PREV', 'SK_ID_CURR']).count().reset_index().rename(index = str, columns = {'Active':'prev_active'})
y = credit[['SK_ID_PREV', 'SK_ID_CURR','Completed']].groupby(['SK_ID_PREV', 'SK_ID_CURR']).count().reset_index().rename(index = str, columns = {'Completed':'prev_complete'})
tmp1 = numerical(x, 'SK_ID_CURR','prev_active',['min','max','std','mean'])
tmp2 = numerical(y, 'SK_ID_CURR','prev_complete',['min','max','std','mean'])
df = df.merge(tmp1, on  = 'SK_ID_CURR', how = 'left')
df = df.merge(tmp2, on  = 'SK_ID_CURR', how = 'left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-77c6ba53e260> in <module>()
#       3 tmp1 = numerical(x, 'SK_ID_CURR','prev_active',['min','max','std','mean'])
#       4 tmp2 = numerical(y, 'SK_ID_CURR','prev_complete',['min','max','std','mean'])
# ----> 5 df = df.merge(tmp1, on  = 'SK_ID_CURR', how = 'left')
#       6 df = df.merge(tmp2, on  = 'SK_ID_CURR', how = 'left')
#
# NameError: name 'df' is not defined

# %%
merged_col = 'SK_ID_CURR'

# minus
name1 = minus_name('SK_DPD', 'SK_DPD_DEF')
credit[name1] = minus(credit, 'SK_DPD', 'SK_DPD_DEF')

# ratio
numerator = [x for x in credit.columns if 'AMT' in x] + ['SK_DPD', 'SK_DPD_DEF', name1]
denominator = [x for x in credit.columns if 'CNT' in x] + numerator + ['MONTHS_BALANCE']
for x in numerator:
    for y in denominator:
        if (x != y) and (ratio_name(y, x) not in credit.columns):
            credit[ratio_name(x, y)] = ratio(credit, x, y)
print('ratio\t', df.shape)
            
# one hot encoding sum
df = df.merge(one_hot(credit, merged_col, 'NAME_CONTRACT_STATUS'), on=merged_col, how='left')
print('one hot sum\t', df.shape)

# count
df = df.merge(count(credit, merged_col, 'NAME_CONTRACT_STATUS'), on=merged_col, how='left')
count_name = [x for x in df.columns if 'count_' in x][0]
print('count\t', df.shape)

# positive count
for x in ['SK_DPD', 'SK_DPD_DEF', name1]:
    df = df.merge(positive_count(credit, merged_col, x), on=merged_col, how='left')
print('positive count\t', df.shape)
    
# categorical ratio
for x in df.columns:
    if 'positivecount_' in x or 'onehot_' in x:
        df[ratio_name(x, count_name)] = ratio(df, x, count_name)
print('categorical ratio\t', df.shape)
        
# numerical
ignored = ['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS', 'MONTHS_BALANCE']
for x in set(credit.columns) - set(ignored):
    df = df.merge(numerical(credit, merged_col, x, ['mean', 'median', 'sum', 'std']), on=merged_col, how='left')
print('numerical\t', df.shape)

# %% [markdown]
# # Rename

# %%
columns = []
for x in df.columns:
    tmp = 'creditcard_' + x if x != merged_col else x
    columns.append(tmp)
df.columns = columns
'done'
print(df.columns.values)
df.shape
# Out:
# ['SK_ID_CURR' 'creditcard_onehot_NAME_CONTRACT_STATUS_Active'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed'
#  'creditcard_count_SK_ID_CURR'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD_DEF'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD_minus_SK_DPD_DEF'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Active_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Completed_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Demand_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Sent proposal_divide_count_SK_ID_CURR'
#  'creditcard_onehot_NAME_CONTRACT_STATUS_Signed_divide_count_SK_ID_CURR'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD_divide_count_SK_ID_CURR'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD_DEF_divide_count_SK_ID_CURR'
#  'creditcard_positivecount_SK_ID_CURR_SK_DPD_minus_SK_DPD_DEF_divide_count_SK_ID_CURR'
#  'creditcard_AMT_RECIVABLE_mean' 'creditcard_AMT_RECIVABLE_median'
#  'creditcard_AMT_RECIVABLE_sum' 'creditcard_AMT_RECIVABLE_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_std'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_DEF_std'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_SK_DPD_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_SK_DPD_mean' 'creditcard_SK_DPD_median'
#  'creditcard_SK_DPD_sum' 'creditcard_SK_DPD_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_sum'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_std'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_DEF_std'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_sum'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_std'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_mean'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_median'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_sum'
#  'creditcard_SK_DPD_DEF_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_DEF_std'
#  'creditcard_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_MONTHS_BALANCE_std'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_SK_DPD_DEF_mean' 'creditcard_SK_DPD_DEF_median'
#  'creditcard_SK_DPD_DEF_sum' 'creditcard_SK_DPD_DEF_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_std'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_SK_DPD_DEF_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_RECIVABLE_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_BALANCE_mean' 'creditcard_AMT_BALANCE_median'
#  'creditcard_AMT_BALANCE_sum' 'creditcard_AMT_BALANCE_std'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_BALANCE_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_std'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_mean'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_median'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_sum'
#  'creditcard_SK_DPD_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_SK_DPD_DEF_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_PAYMENT_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_sum' 'creditcard_AMT_PAYMENT_CURRENT_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_SK_DPD_DEF_std'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_SK_DPD_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_SK_DPD_DEF_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_DEF_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_DEF_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_RECIVABLE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_mean'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_median'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_sum'
#  'creditcard_SK_DPD_divide_SK_DPD_DEF_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_std'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_mean'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_median'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_sum'
#  'creditcard_CNT_DRAWINGS_ATM_CURRENT_std'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_mean'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_median'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_sum'
#  'creditcard_SK_DPD_minus_SK_DPD_DEF_divide_CNT_DRAWINGS_POS_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_std'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_mean'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_median'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_sum'
#  'creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_std'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_mean'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_sum'
#  'creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_std'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_mean'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_median'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_sum'
#  'creditcard_AMT_DRAWINGS_CURRENT_divide_SK_DPD_std'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_mean'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_median'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_sum'
#  'creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_CURRENT_std'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_mean'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_median'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_sum'
#  'creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_SK_DPD_minus_SK_DPD_DEF_std'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_median'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_sum'
#  'creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_std'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_median'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_sum'
#  'creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_std']
# (356255, 502)

# %%
df.to_pickle(PATH + 'inter/credit2curr.pkl')
'done'
# Out:
# 'done'
