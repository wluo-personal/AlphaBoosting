# %%
import pandas as pd
import numpy as np

PATH = '/home/kai/data/kaggle/homecredit/'

train_cleaned = pd.read_pickle(PATH+'train_0.pkl')
test_cleaned = pd.read_pickle(PATH+'test_0.pkl')
print('done')
# Out:
# done

# %%
print(train_cleaned.shape, test_cleaned.shape)
# Out:
# (307511, 1754) (48744, 1753)

# %%
import pandas as pd
import numpy as np

PATH = '/home/kai/data/kaggle/homecredit/'

train_cleaned = pd.read_pickle(PATH+'train_merge.pkl')
test_cleaned = pd.read_pickle(PATH+'test_merge.pkl')
print('done')
from sklearn.preprocessing import LabelEncoder

categorical_feats = [
    'NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY','NAME_TYPE_SUITE',
    'NAME_INCOME_TYPE','NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
    'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
    'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
    'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3',
    'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9',
    'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14',
    'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19',
    'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21','WEEKDAY_APPR_PROCESS_START', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 
    'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE'
]

categorical_feats = [x for x in train_cleaned.columns if x in categorical_feats]

target = train_cleaned['TARGET']
ignore_cols = ['ORGANIZATION_TYPE', 'TARGET', 'SK_ID_CURR']
features = [x for x in train_cleaned.columns if x not in ignore_cols]
train = train_cleaned[features]
test = test_cleaned[features]

for x in categorical_feats:
    if train_cleaned[x].dtype == 'object':
        print(x)
        train_cleaned[x].fillna('na', inplace=True)
        test_cleaned[x].fillna('na', inplace=True)
        train_cleaned[x] = LabelEncoder().fit_transform(train_cleaned[x])
        test_cleaned[x] = LabelEncoder().fit_transform(test_cleaned[x])
    else:
        train_cleaned[x].fillna('na', inplace=True)
        test_cleaned[x].fillna('na', inplace=True)
print('done')
# Out:
# NAME_CONTRACT_TYPE
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# OCCUPATION_TYPE
# WEEKDAY_APPR_PROCESS_START
# FONDKAPREMONT_MODE
# HOUSETYPE_MODE
# WALLSMATERIAL_MODE
# EMERGENCYSTATE_MODE
# done

# %%
print(train.shape, test.shape)
# Out:
# (307511, 1751) (48744, 1751)

# %%
target = train_cleaned['TARGET']
ignore_cols = ['ORGANIZATION_TYPE', 'TARGET', 'SK_ID_CURR']
features = [x for x in train.columns if x not in ignore_cols]
train = train[features]
test = test[features]

from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm

lgbm_train = lgbm.Dataset(data=train,
                          label=target,
                          
                          categorical_feature=[],#categorical_feats,
                          free_raw_data=False)

lgbm_params = {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 
          'learning_rate': 0.01, 'num_leaves': 48, 'num_iteration': 4000, 'verbose': 0 ,
          'colsample_bytree':.8, 'subsample':.9, 'max_depth':7, 'reg_alpha':.1, 'reg_lambda':.1, 
          'min_split_gain':.01, 'min_child_weight':1,'num_threads': 12,'feature_fraction': 0.95}

# lgbm_params = {
#     'objective': 'binary',
#     'boosting': 'gbdt',
#     'num_boost_round': 5000,
#     'learning_rate': 0.04,
#     'num_leaves': 76,
#     'num_threads': 20, # best speed: set to number of real cpu cores, which is vCPU/2
#     'device': 'cpu',
#     'max_depth': 7, # no limit. This is used to deal with over-fitting when #data is small.
#     'min_child_samples': 20,
#     'min_child_weight': 5,
#     'min_split_gain': 0,
#     'reg_alpha': 0,
#     'reg_lambda': 0.1,
#     'subsample': 1.0,
#     'subsample_for_bin': 200000,
#     'subsample_freq': 1,
#     'bagging_seed': 2018,
#     'early_stopping_round':300,
#     'verbose': 0,
#     'scale_pos_weight': 1,#*0.00246100785192494,
#     'metric' : [ 'auc'],
#     'feature_fraction': 0.8,
#     'drop_seed': 2018,
#     'data_random_seed': 2018,
#     'max_bin': 188,
#     'colsample_bytree': 0.45
# }

# lgbm_params = {
#     'boosting': 'dart',
#     'application': 'binary',
#     'learning_rate': 0.1,
#     'min_data_in_leaf': 30,
#     'num_leaves': 31,
#     'max_depth': -1,
#     'feature_fraction': 0.5,
#     'scale_pos_weight': 2,
#     'drop_rate': 0.02
# }

cv_results = lgbm.cv(train_set=lgbm_train,
                     params=lgbm_params,
                     nfold=5,
                     early_stopping_rounds=150,
                     verbose_eval=100,
                     metrics=['auc'])

optimum_boost_rounds = np.argmax(cv_results['auc-mean'])
print('Optimum boost rounds = {}'.format(optimum_boost_rounds))
print('Best CV result = {}'.format(np.max(cv_results['auc-mean'])))

clf = lgbm.train(train_set=lgbm_train,
                 params=lgbm_params,
                 num_boost_round=optimum_boost_rounds)

""" Predict on test set and create submission """
y_pred = clf.predict(test)
out_df = pd.DataFrame({'SK_ID_CURR': test_cleaned['SK_ID_CURR'], 'TARGET': y_pred})
print('done')
# Out:
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.739752 + 0.00380806
# [200]	cv_agg's auc: 0.748659 + 0.0034222
# [300]	cv_agg's auc: 0.759524 + 0.00341384
# [400]	cv_agg's auc: 0.768842 + 0.00348434

# %%
print((out_df['TARGET']< 0 ).sum())
out_df.to_csv(PATH + 'inter/submod_798.csv', index=False)
print('done')

# out_df.to_csv(PATH + 'su

# out_df.to_csv(PATH + 'submission_withinstall.csv', index=False)
# print('done')

# out_df.to_csv(PATH + 'submission_withinstall.csv', index=False)
# print('done')

'''

withprev auc: 7811 pb 0.771
withinstall auc: 7815 pb 0.768
total_version_1 auc: 0.7895 pb 0.781
'''
# Out:
# 0
# done
# '\n\nwithprev auc: 7811 pb 0.771\nwithinstall auc: 7815 pb 0.768\ntotal_version_1 auc: 0.7895 pb 0.781\n'

# %%
import matplotlib.pyplot as plt
out_df[['TARGET']].hist()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, (ax, ax1) = plt.subplots(1, 2, figsize=[15, 7])
lgbm.plot_importance(clf, ax=ax, max_num_features=30, importance_type='split')
lgbm.plot_importance(clf, ax=ax1, max_num_features=30, importance_type='gain')
ax.set_title('Importance by splits')
ax1.set_title('Importance by gain')
plt.tight_layout()
plt.show()

# %%
x = [x for x in zip(clf.feature_name(), clf.feature_importance('gain'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_3', 370401.76518294215)),
#  (1, ('EXT_SOURCE_2', 305871.66384446621)),
#  (2, ('EXT_SOURCE_1', 125409.80600100756)),
#  (3, ('DAYS_BIRTH', 64593.368727385998)),
#  (4, ('AMT_CREDIT', 58220.931566357613)),
#  (5, ('OCCUPATION_TYPE', 56742.093196868896)),
#  (6, ('AMT_GOODS_PRICE', 53823.823379933834)),
#  (7, ('AMT_ANNUITY', 51912.383253246546)),
#  (8, ('DAYS_EMPLOYED', 42867.732374660671)),
#  (9, ('DAYS_ID_PUBLISH', 35627.413402825594)),
#  (10, ('OWN_CAR_AGE', 30585.114282250404)),
#  (11, ('DAYS_LAST_PHONE_CHANGE', 27340.072450399399)),
#  (12, ('DAYS_REGISTRATION', 24124.657078504562)),
#  (13, ('CODE_GENDER', 23675.214492797852)),
#  (14, ('NAME_EDUCATION_TYPE', 23035.018190741539)),
#  (15, ('AMT_INCOME_TOTAL', 20303.670858681202)),
#  (16, ('REGION_POPULATION_RELATIVE', 15190.978127300739)),
#  (17, ('FLAG_DOCUMENT_3', 13105.426163196564)),
#  (18, ('AMT_REQ_CREDIT_BUREAU_YEAR', 12750.371052742004)),
#  (19, ('HOUR_APPR_PROCESS_START', 10119.466076791286)),
#  (20, ('TOTALAREA_MODE', 10024.080109417439)),
#  (21, ('NAME_FAMILY_STATUS', 9819.5281727313995)),
#  (22, ('NAME_CONTRACT_TYPE', 9009.0875558853149)),
#  (23, ('NAME_INCOME_TYPE', 8427.0661201477051)),
#  (24, ('DEF_30_CNT_SOCIAL_CIRCLE', 8271.6995475292206)),
#  (25, ('REGION_RATING_CLIENT_W_CITY', 8254.1082797050476)),
#  (26, ('AMT_REQ_CREDIT_BUREAU_QRT', 7523.0533792972565)),
#  (27, ('APARTMENTS_AVG', 7033.0415381193161)),
#  (28, ('WEEKDAY_APPR_PROCESS_START', 6750.588716506958)),
#  (29, ('LIVINGAREA_AVG', 6644.3340891003609)),
#  (30, ('LANDAREA_AVG', 6491.437716126442)),
#  (31, ('YEARS_BEGINEXPLUATATION_AVG', 6407.6408468484879)),
#  (32, ('BASEMENTAREA_MODE', 6290.5004813075066)),
#  (33, ('LANDAREA_MODE', 6256.0410393476486)),
#  (34, ('APARTMENTS_MODE', 6216.3237082958221)),
#  (35, ('LIVINGAREA_MODE', 6181.6689909696579)),
#  (36, ('BASEMENTAREA_AVG', 5932.3948100209236)),
#  (37, ('NONLIVINGAREA_AVG', 5831.3365128040314)),
#  (38, ('YEARS_BEGINEXPLUATATION_MEDI', 5425.0238738059998)),
#  (39, ('COMMONAREA_AVG', 5193.2505268752575)),
#  (40, ('LIVINGAPARTMENTS_AVG', 5036.6068001389503)),
#  (41, ('DEF_60_CNT_SOCIAL_CIRCLE', 5025.9451193809509)),
#  (42, ('COMMONAREA_MODE', 4750.4438974261284)),
#  (43, ('NONLIVINGAREA_MODE', 4682.9816707372665)),
#  (44, ('OBS_60_CNT_SOCIAL_CIRCLE', 4675.0543168187141)),
#  (45, ('YEARS_BEGINEXPLUATATION_MODE', 4626.0440710783005)),
#  (46, ('OBS_30_CNT_SOCIAL_CIRCLE', 4623.6451410055161)),
#  (47, ('YEARS_BUILD_AVG', 4478.0528464317322)),
#  (48, ('REG_CITY_NOT_LIVE_CITY', 4420.5034754276276)),
#  (49, ('LIVINGAREA_MEDI', 4316.9622299671173)),
#  (50, ('FLAG_WORK_PHONE', 4255.7086489200592)),
#  (51, ('APARTMENTS_MEDI', 3862.5749617815018)),
#  (52, ('ENTRANCES_AVG', 3814.0231606960297)),
#  (53, ('LIVINGAPARTMENTS_MODE', 3701.6461025476456)),
#  (54, ('FLOORSMAX_AVG', 3685.3838980197906)),
#  (55, ('NONLIVINGAREA_MEDI', 3669.7689279317856)),
#  (56, ('COMMONAREA_MEDI', 3584.1289923191071)),
#  (57, ('BASEMENTAREA_MEDI', 3502.5803741812706)),
#  (58, ('NAME_HOUSING_TYPE', 3291.1430438756943)),
#  (59, ('YEARS_BUILD_MODE', 3252.516642510891)),
#  (60, ('NONLIVINGAPARTMENTS_AVG', 3150.2587524652481)),
#  (61, ('LANDAREA_MEDI', 2991.6214163303375)),
#  (62, ('FLOORSMIN_AVG', 2843.8482298851013)),
#  (63, ('AMT_REQ_CREDIT_BUREAU_MON', 2820.3670075535774)),
#  (64, ('CNT_FAM_MEMBERS', 2470.7793973684311)),
#  (65, ('LIVINGAPARTMENTS_MEDI', 2458.2131221294403)),
#  (66, ('WALLSMATERIAL_MODE', 2429.7355046272278)),
#  (67, ('CNT_CHILDREN', 2237.0046550035477)),
#  (68, ('ENTRANCES_MODE', 2191.1736227869987)),
#  (69, ('NONLIVINGAPARTMENTS_MODE', 2099.8410257101059)),
#  (70, ('YEARS_BUILD_MEDI', 1893.6190475225449)),
#  (71, ('REGION_RATING_CLIENT', 1857.1964888572693)),
#  (72, ('NAME_TYPE_SUITE', 1778.2242138385773)),
#  (73, ('FLAG_DOCUMENT_16', 1668.9809775352478)),
#  (74, ('FLOORSMIN_MODE', 1602.583705663681)),
#  (75, ('FLAG_DOCUMENT_18', 1580.7053577899933)),
#  (76, ('ELEVATORS_AVG', 1564.8632345199585)),
#  (77, ('ENTRANCES_MEDI', 1554.8067126274109)),
#  (78, ('AMT_REQ_CREDIT_BUREAU_WEEK', 1477.4377131462097)),
#  (79, ('FLOORSMAX_MODE', 1472.6915628910065)),
#  (80, ('NONLIVINGAPARTMENTS_MEDI', 1413.7618863582611)),
#  (81, ('FLAG_OWN_REALTY', 1342.8245658874512)),
#  (82, ('FLAG_PHONE', 1272.9216920137405)),
#  (83, ('ELEVATORS_MODE', 1256.3647606372833)),
#  (84, ('ELEVATORS_MEDI', 1085.0817217826843)),
#  (85, ('FLOORSMAX_MEDI', 1052.2288522720337)),
#  (86, ('FLAG_OWN_CAR', 958.99382495880127)),
#  (87, ('AMT_REQ_CREDIT_BUREAU_DAY', 809.15036964416504)),
#  (88, ('FLAG_DOCUMENT_5', 731.22700929641724)),
#  (89, ('FLAG_DOCUMENT_8', 706.90123963356018)),
#  (90, ('FLAG_DOCUMENT_13', 704.42759788036346)),
#  (91, ('REG_REGION_NOT_WORK_REGION', 701.1356897354126)),
#  (92, ('REG_CITY_NOT_WORK_CITY', 697.5465449988842)),
#  (93, ('AMT_REQ_CREDIT_BUREAU_HOUR', 624.72290658950806)),
#  (94, ('HOUSETYPE_MODE', 597.40164661407471)),
#  (95, ('FLOORSMIN_MEDI', 513.69814920425415)),
#  (96, ('LIVE_CITY_NOT_WORK_CITY', 512.6419712305069)),
#  (97, ('FONDKAPREMONT_MODE', 489.41501069068909)),
#  (98, ('FLAG_DOCUMENT_11', 476.1351900100708)),
#  (99, ('FLAG_DOCUMENT_14', 458.47223234176636)),
#  (100, ('FLAG_EMAIL', 432.38747310638428)),
#  (101, ('LIVE_REGION_NOT_WORK_REGION', 400.91387104988098)),
#  (102, ('EMERGENCYSTATE_MODE', 291.84088015556335)),
#  (103, ('FLAG_DOCUMENT_6', 277.65498995780945)),
#  (104, ('REG_REGION_NOT_LIVE_REGION', 157.72870874404907)),
#  (105, ('FLAG_DOCUMENT_15', 153.7691707611084)),
#  (106, ('FLAG_DOCUMENT_21', 123.14613914489746)),
#  (107, ('FLAG_CONT_MOBILE', 113.41744995117188)),
#  (108, ('FLAG_DOCUMENT_9', 63.838900566101074)),
#  (109, ('FLAG_EMP_PHONE', 35.449700355529785)),
#  (110, ('FLAG_MOBIL', 0.0)),
#  (111, ('FLAG_DOCUMENT_2', 0.0)),
#  (112, ('FLAG_DOCUMENT_4', 0.0)),
#  (113, ('FLAG_DOCUMENT_7', 0.0)),
#  (114, ('FLAG_DOCUMENT_10', 0.0)),
#  (115, ('FLAG_DOCUMENT_12', 0.0)),
#  (116, ('FLAG_DOCUMENT_17', 0.0)),
#  (117, ('FLAG_DOCUMENT_19', 0.0)),
#  (118, ('FLAG_DOCUMENT_20', 0.0))]

# %%
x = [x for x in zip(clf.feature_name(), clf.feature_importance('split'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_1', 6341)),
#  (1, ('EXT_SOURCE_3', 5644)),
#  (2, ('EXT_SOURCE_2', 5143)),
#  (3, ('DAYS_BIRTH', 4000)),
#  (4, ('AMT_CREDIT', 3606)),
#  (5, ('AMT_ANNUITY', 3385)),
#  (6, ('OCCUPATION_TYPE', 3178)),
#  (7, ('DAYS_ID_PUBLISH', 3107)),
#  (8, ('AMT_GOODS_PRICE', 3052)),
#  (9, ('DAYS_EMPLOYED', 2786)),
#  (10, ('DAYS_LAST_PHONE_CHANGE', 2521)),
#  (11, ('DAYS_REGISTRATION', 2376)),
#  (12, ('AMT_INCOME_TOTAL', 2156)),
#  (13, ('OWN_CAR_AGE', 1964)),
#  (14, ('REGION_POPULATION_RELATIVE', 1666)),
#  (15, ('AMT_REQ_CREDIT_BUREAU_YEAR', 1129)),
#  (16, ('HOUR_APPR_PROCESS_START', 1095)),
#  (17, ('CODE_GENDER', 981)),
#  (18, ('TOTALAREA_MODE', 935)),
#  (19, ('LANDAREA_AVG', 708)),
#  (20, ('WEEKDAY_APPR_PROCESS_START', 690)),
#  (21, ('APARTMENTS_AVG', 672)),
#  (22, ('YEARS_BEGINEXPLUATATION_AVG', 660)),
#  (23, ('BASEMENTAREA_MODE', 655)),
#  (24, ('LANDAREA_MODE', 645)),
#  (25, ('FLAG_DOCUMENT_3', 644)),
#  (26, ('AMT_REQ_CREDIT_BUREAU_QRT', 640)),
#  (27, ('LIVINGAREA_MODE', 634)),
#  (28, ('APARTMENTS_MODE', 631)),
#  (29, ('BASEMENTAREA_AVG', 627)),
#  (30, ('LIVINGAREA_AVG', 627)),
#  (31, ('NAME_EDUCATION_TYPE', 608)),
#  (32, ('NONLIVINGAREA_AVG', 596)),
#  (33, ('NAME_FAMILY_STATUS', 589)),
#  (34, ('COMMONAREA_AVG', 546)),
#  (35, ('OBS_30_CNT_SOCIAL_CIRCLE', 533)),
#  (36, ('DEF_30_CNT_SOCIAL_CIRCLE', 531)),
#  (37, ('NAME_CONTRACT_TYPE', 523)),
#  (38, ('YEARS_BEGINEXPLUATATION_MEDI', 523)),
#  (39, ('YEARS_BUILD_AVG', 513)),
#  (40, ('COMMONAREA_MODE', 498)),
#  (41, ('LIVINGAPARTMENTS_AVG', 497)),
#  (42, ('OBS_60_CNT_SOCIAL_CIRCLE', 494)),
#  (43, ('NONLIVINGAREA_MODE', 491)),
#  (44, ('YEARS_BEGINEXPLUATATION_MODE', 463)),
#  (45, ('REGION_RATING_CLIENT_W_CITY', 422)),
#  (46, ('LIVINGAREA_MEDI', 422)),
#  (47, ('APARTMENTS_MEDI', 418)),
#  (48, ('COMMONAREA_MEDI', 400)),
#  (49, ('ENTRANCES_AVG', 395)),
#  (50, ('LIVINGAPARTMENTS_MODE', 381)),
#  (51, ('NONLIVINGAREA_MEDI', 377)),
#  (52, ('FLAG_WORK_PHONE', 363)),
#  (53, ('DEF_60_CNT_SOCIAL_CIRCLE', 359)),
#  (54, ('YEARS_BUILD_MODE', 357)),
#  (55, ('BASEMENTAREA_MEDI', 355)),
#  (56, ('NONLIVINGAPARTMENTS_AVG', 344)),
#  (57, ('AMT_REQ_CREDIT_BUREAU_MON', 330)),
#  (58, ('NAME_HOUSING_TYPE', 329)),
#  (59, ('LANDAREA_MEDI', 307)),
#  (60, ('NAME_INCOME_TYPE', 304)),
#  (61, ('REG_CITY_NOT_LIVE_CITY', 301)),
#  (62, ('FLOORSMIN_AVG', 301)),
#  (63, ('FLOORSMAX_AVG', 284)),
#  (64, ('CNT_FAM_MEMBERS', 279)),
#  (65, ('CNT_CHILDREN', 262)),
#  (66, ('LIVINGAPARTMENTS_MEDI', 241)),
#  (67, ('NONLIVINGAPARTMENTS_MODE', 215)),
#  (68, ('ENTRANCES_MODE', 213)),
#  (69, ('YEARS_BUILD_MEDI', 209)),
#  (70, ('WALLSMATERIAL_MODE', 205)),
#  (71, ('NAME_TYPE_SUITE', 204)),
#  (72, ('FLOORSMIN_MODE', 171)),
#  (73, ('FLAG_OWN_REALTY', 165)),
#  (74, ('ENTRANCES_MEDI', 163)),
#  (75, ('ELEVATORS_AVG', 160)),
#  (76, ('AMT_REQ_CREDIT_BUREAU_WEEK', 156)),
#  (77, ('FLAG_PHONE', 154)),
#  (78, ('NONLIVINGAPARTMENTS_MEDI', 152)),
#  (79, ('FLOORSMAX_MODE', 149)),
#  (80, ('REGION_RATING_CLIENT', 138)),
#  (81, ('FLAG_DOCUMENT_16', 138)),
#  (82, ('FLAG_DOCUMENT_18', 137)),
#  (83, ('ELEVATORS_MODE', 132)),
#  (84, ('ELEVATORS_MEDI', 105)),
#  (85, ('REG_REGION_NOT_WORK_REGION', 93)),
#  (86, ('FLOORSMAX_MEDI', 91)),
#  (87, ('FLAG_DOCUMENT_5', 86)),
#  (88, ('FLAG_DOCUMENT_8', 86)),
#  (89, ('FLAG_DOCUMENT_13', 80)),
#  (90, ('AMT_REQ_CREDIT_BUREAU_DAY', 78)),
#  (91, ('REG_CITY_NOT_WORK_CITY', 77)),
#  (92, ('FLAG_DOCUMENT_14', 69)),
#  (93, ('FONDKAPREMONT_MODE', 68)),
#  (94, ('LIVE_CITY_NOT_WORK_CITY', 65)),
#  (95, ('FLAG_DOCUMENT_11', 64)),
#  (96, ('HOUSETYPE_MODE', 62)),
#  (97, ('FLAG_OWN_CAR', 57)),
#  (98, ('FLOORSMIN_MEDI', 56)),
#  (99, ('AMT_REQ_CREDIT_BUREAU_HOUR', 56)),
#  (100, ('FLAG_EMAIL', 48)),
#  (101, ('LIVE_REGION_NOT_WORK_REGION', 47)),
#  (102, ('EMERGENCYSTATE_MODE', 40)),
#  (103, ('FLAG_DOCUMENT_15', 40)),
#  (104, ('FLAG_DOCUMENT_6', 28)),
#  (105, ('REG_REGION_NOT_LIVE_REGION', 17)),
#  (106, ('FLAG_CONT_MOBILE', 14)),
#  (107, ('FLAG_DOCUMENT_21', 14)),
#  (108, ('FLAG_DOCUMENT_9', 7)),
#  (109, ('FLAG_EMP_PHONE', 4)),
#  (110, ('FLAG_MOBIL', 0)),
#  (111, ('FLAG_DOCUMENT_2', 0)),
#  (112, ('FLAG_DOCUMENT_4', 0)),
#  (113, ('FLAG_DOCUMENT_7', 0)),
#  (114, ('FLAG_DOCUMENT_10', 0)),
#  (115, ('FLAG_DOCUMENT_12', 0)),
#  (116, ('FLAG_DOCUMENT_17', 0)),
#  (117, ('FLAG_DOCUMENT_19', 0)),
#  (118, ('FLAG_DOCUMENT_20', 0))]

# %%
old_merge = pd.read_csv(PATH+'submission/old_merge.csv')

# %%
old_merge
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.023489
# 1          100005  0.127016
# 2          100013  0.009863
# 3          100028  0.039796
# 4          100038  0.144527
# 5          100042  0.037338
# 6          100057  0.007515
# 7          100065  0.023357
# 8          100066  0.015897
# 9          100067  0.150622
# 10         100074  0.056399
# 11         100090  0.027365
# 12         100091  0.172701
# 13         100092  0.035143
# 14         100106  0.054853
# 15         100107  0.179196
# 16         100109  0.059310
# 17         100117  0.029505
# 18         100128  0.066887
# 19         100141  0.035894
# 20         100150  0.029396
# 21         100168  0.007962
# 22         100169  0.033148
# 23         100170  0.152186
# 24         100171  0.044568
# 25         100172  0.130434
# 26         100184  0.071963
# 27         100187  0.058243
# 28         100212  0.025122
# 29         100222  0.028343
# ...           ...       ...
# 48714      455963  0.044835
# 48715      455965  0.005892
# 48716      456007  0.230816
# 48717      456008  0.015419
# 48718      456009  0.022138
# 48719      456010  0.107903
# 48720      456011  0.027143
# 48721      456013  0.280287
# 48722      456028  0.140444
# 48723      456058  0.108408
# 48724      456111  0.064415
# 48725      456114  0.145046
# 48726      456115  0.046725
# 48727      456116  0.009234
# 48728      456119  0.011142
# 48729      456120  0.098119
# 48730      456122  0.070033
# 48731      456123  0.026651
# 48732      456166  0.069435
# 48733      456167  0.040824
# 48734      456168  0.044356
# 48735      456169  0.050027
# 48736      456170  0.009835
# 48737      456189  0.123121
# 48738      456202  0.073755
# 48739      456221  0.055149
# 48740      456222  0.064512
# 48741      456223  0.010161
# 48742      456224  0.018363
# 48743      456250  0.255544
#
# [48744 rows x 2 columns]

# %%
len(old_merge)
# Out:
# 48744

# %%
old = old_merge.copy()
old_half = old[old['TARGET'] > 0.5]

# %%
half_index = old_half['TARGET']

# %%
len(half_index)
# Out:
# 173

# %%
test_half = test.iloc[half_index]

# %%
len(test_half)
# Out:
# 173

# %%
test.head()
# Out:
#    NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                   0            0             0                1
# 2                   0            1             1                1
# 3                   0            0             0                1
# 4                   0            1             1                0
# 5                   0            0             1                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
# 2             0          202500.0    663264.0      69777.0         630000.0
# 3             2          315000.0   1575000.0      49018.5        1575000.0
# 4             1          180000.0    625500.0      32067.0         625500.0
# 5             0          270000.0    959688.0      34600.5         810000.0
#
#    NAME_TYPE_SUITE          ...           bureau_STATUS_5_std  \
# 0                6          ...                           0.0
# 2                7          ...                           0.0
# 3                6          ...                           0.0
# 4                6          ...                           NaN
# 5                6          ...                           0.0
#
#    bureau_STATUS_5_mean  bureau_STATUS_C_max  bureau_STATUS_C_min  \
# 0                   0.0                 44.0                  0.0
# 2                   0.0                 44.0                  0.0
# 3                   0.0                 62.0                  0.0
# 4                   NaN                  NaN                  NaN
# 5                   0.0                 64.0                  0.0
#
#    bureau_STATUS_C_std  bureau_STATUS_C_mean  bureau_STATUS_X_max  \
# 0            15.614006             24.598837                  9.0
# 2            16.856547             29.230435                 40.0
# 3            25.617228             29.530357                 60.0
# 4                  NaN                   NaN                  NaN
# 5            27.843471             28.900813                 54.0
#
#    bureau_STATUS_X_min  bureau_STATUS_X_std  bureau_STATUS_X_mean
# 0                  0.0             3.265070              5.488372
# 2                  0.0            15.090151              7.195652
# 3                  0.0            20.048258             12.091071
# 4                  NaN                  NaN                   NaN
# 5                  0.0            18.638727             16.411382
#
# [5 rows x 896 columns]

# %%
len(test)
# Out:
# 48743

# %%
half_index
# Out:
# 37       1
# 202      1
# 538      1
# 634      1
# 998      1
# 1610     1
# 1935     1
# 1993     1
# 2035     1
# 2513     1
# 2585     1
# 2593     1
# 2764     1
# 2830     1
# 3100     1
# 3577     1
# 3640     1
# 4465     1
# 4525     1
# 4556     1
# 4567     1
# 4934     1
# 5604     1
# 5627     1
# 5719     1
# 5793     1
# 5817     1
# 6373     1
# 6678     1
# 6969     1
#         ..
# 38881    1
# 39398    1
# 39553    1
# 39942    1
# 40533    1
# 41177    1
# 41338    1
# 41339    1
# 41472    1
# 42508    1
# 42746    1
# 42965    1
# 43121    1
# 43145    1
# 43171    1
# 43222    1
# 43643    1
# 44076    1
# 44283    1
# 45083    1
# 45233    1
# 45243    1
# 46145    1
# 46351    1
# 46700    1
# 47505    1
# 47611    1
# 47901    1
# 48367    1
# 48662    1
# Name: TARGET, Length: 173, dtype: int64

# %%
df = pd.read_csv(PATH+'submission/modify_final.csv')

# %%
df.drop('Unnamed: 0', inplace = True, axis = 1)

# %%
df
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.024523
# 1          100005  0.129060
# 2          100013  0.012418
# 3          100028  0.031481
# 4          100038  0.144279
# 5          100042  0.036397
# 6          100057  0.008326
# 7          100065  0.025811
# 8          100066  0.014751
# 9          100067  0.099353
# 10         100074  0.072192
# 11         100090  0.030698
# 12         100091  0.213301
# 13         100092  0.034594
# 14         100106  0.049256
# 15         100107  0.150751
# 16         100109  0.057043
# 17         100117  0.028426
# 18         100128  0.075554
# 19         100141  0.032349
# 20         100150  0.028501
# 21         100168  0.008143
# 22         100169  0.028617
# 23         100170  0.149131
# 24         100171  0.043267
# 25         100172  0.127384
# 26         100184  0.064406
# 27         100187  0.061829
# 28         100212  0.023971
# 29         100222  0.032772
# ...           ...       ...
# 48714      455963  0.035335
# 48715      455965  0.006915
# 48716      456007  0.268831
# 48717      456008  0.015332
# 48718      456009  0.022454
# 48719      456010  0.101899
# 48720      456011  0.030228
# 48721      456013  0.311572
# 48722      456028  0.129589
# 48723      456058  0.097006
# 48724      456111  0.061963
# 48725      456114  0.155817
# 48726      456115  0.039436
# 48727      456116  0.009587
# 48728      456119  0.011772
# 48729      456120  0.096688
# 48730      456122  0.062215
# 48731      456123  0.026343
# 48732      456166  0.071397
# 48733      456167  0.040553
# 48734      456168  0.048392
# 48735      456169  0.046556
# 48736      456170  0.010549
# 48737      456189  0.134339
# 48738      456202  0.081014
# 48739      456221  0.065460
# 48740      456222  0.060860
# 48741      456223  0.010852
# 48742      456224  0.015203
# 48743      456250  0.281254
#
# [48744 rows x 2 columns]

# %%
df.to_csv(PATH + 'submission/mod_2.csv', index = False)

# %%
len(df)
# Out:
# 48744

# %%
df = pd.DataFrame({'a':[1,2,3,np.nan]})
df, _ = pd.factorize(df['a'])

# %%
df
# Out:
# array([ 0,  1,  2, -1])
