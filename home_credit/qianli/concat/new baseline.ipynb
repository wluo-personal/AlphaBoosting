# %%
import os
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
PATH = '/home/kai/data/kaggle/homecredit/'

# %%
train = pd.read_pickle(PATH + 'test/train_ori.pkl')
test = pd.read_pickle(PATH + 'test/test_ori.pkl')
# train = pd.read_pickle(PATH + 'test/train_w_prev_2.pkl')
# test = pd.read_pickle(PATH + 'test/test_w_prev_2.pkl')

print(train.shape,test.shape)
train.shape, test.shape
prev = pd.read_pickle(PATH + 'test/prev2curr_0.pkl')
print(prev.shape)
pos = pd.read_pickle(PATH +'test/pos/all_agg.pkl')
print(pos.shape)
cred = pd.read_pickle(PATH + 'inter/credit2curr.pkl')
print(cred.shape)
install = pd.read_pickle(PATH + 'inter/old_inst2curr.pkl')
print(install.shape)
bureau = pd.read_pickle(PATH + 'inter/bureau2curr.pkl')
print(bureau.shape)
# Out:
# (307511, 329) (48744, 328)
# (356255, 818)
# (356255, 137)
# (356255, 502)
# (356255, 60)
# (356255, 554)

# %%
files = [prev,pos,cred,install,bureau]
# files = [prev,cred,install,bureau]
# files = [prev,pos,install,bureau]
# files = [pos,cred,install,bureau]
for tmp in files:
#     cols = [col for col in tmp.columns if 'std' not in col]
#     tmp = tmp[cols]
#     print(tmp.shape)
    train = train.merge(tmp, on='SK_ID_CURR', how='left')
    test = test.merge(tmp, on='SK_ID_CURR', how='left')
    print(train.shape,test.shape)
# Out:
# (307511, 1146) (48744, 1145)
# (307511, 1282) (48744, 1281)
# (307511, 1783) (48744, 1782)
# (307511, 1842) (48744, 1841)
# (307511, 2395) (48744, 2394)

# %%
print(train.shape, test.shape)
# Out:
# (307511, 2395) (48744, 2394)

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
PATH = '/home/kai/data/kaggle/homecredit/'
print('begin cv')
target = train['TARGET']
test_df = test.copy()
ignore_cols = ['ORGANIZATION_TYPE', 'TARGET', 'SK_ID_CURR']
features = [x for x in train.columns if x not in ignore_cols]
train = train[features]
test = test[features]

from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm

lgbm_train = lgbm.Dataset(data=train,
                          label=target,

                          categorical_feature=[],#categorical_feats,
                          free_raw_data=False)

# lgbm_params = {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 
#           'learning_rate': 0.01, 'num_leaves': 48, 'num_iteration': 4000, 'verbose': 0 ,
#           'colsample_bytree':.8, 'subsample':.9, 'max_depth':7, 'reg_alpha':.1, 'reg_lambda':.1, 
#           'min_split_gain':.01, 'min_child_weight':1,'num_threads': 12,'feature_fraction': 0.2,
#               'scale_pos_weight':1}
# lgbm_params = {
#     'task': 'train',
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': 'auc',
#     'learning_rate': 0.05,
#     'num_iteration': 4000,
#     'num_threads': 8,

#     'num_leaves': int(round(44.368535336628419)),
#     'feature_fraction': 0.28231763168020257,
#     'bagging_fraction': 0.94901525271474951,
#     'max_depth': int(round(8.0430115561596267)),
#     'lambda_l1': 0.30680079516647751,
#     'lambda_l2': 0.079128660903201031,
#     'min_split_gain': 0.054005067457890979,
#     'min_child_weight': 98.172643147364937}
lgbm_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'learning_rate': 0.02,
    'num_iteration': 4000,
    'num_threads': 8,

    'num_leaves': int(round(44.368535336628419)),
    'feature_fraction': 0.15,
    'bagging_fraction': 0.94901525271474951,
    'max_depth': int(round(8.0430115561596267)),
    'lambda_l1': 0.30680079516647751,
    'lambda_l2': 0.079128660903201031,
    'min_split_gain': 0.054005067457890979,
    'min_child_weight': 15.172643147364937}


cv_results = lgbm.cv(train_set=lgbm_train,
                     params=lgbm_params,
                     nfold=5,
                     early_stopping_rounds=150,
                     verbose_eval=100,
                     metrics=['auc'])

optimum_boost_rounds = np.argmax(cv_results['auc-mean'])
print('Optimum boost rounds = {}'.format(optimum_boost_rounds))
print('Best CV result = {}'.format(np.max(cv_results['auc-mean'])))

clf = lgbm.train(train_set=lgbm_train,
                 params=lgbm_params,
                 num_boost_round=optimum_boost_rounds,
                verbose_eval=100)

""" Predict on test set and create submission """
y_pred = clf.predict(test)
out_df = pd.DataFrame({'SK_ID_CURR': test_df['SK_ID_CURR'], 'TARGET': y_pred})
#     small_len = out_df[out_df['TARGET']< threshold1]
#     large_len = out_df[out_df['TARGET']> threshold2]
#     print('length of small and large,',len(small_len),len(large_len))
print((out_df['TARGET']>0.5).sum(),'more than half')
# Out:
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.761279 + 0.00336603
# [200]	cv_agg's auc: 0.77363 + 0.00278012
# [300]	cv_agg's auc: 0.782606 + 0.00269742
# [400]	cv_agg's auc: 0.787647 + 0.00262401
# [500]	cv_agg's auc: 0.790502 + 0.00240743
# [600]	cv_agg's auc: 0.792433 + 0.00223408
# [700]	cv_agg's auc: 0.79367 + 0.00223838
# [800]	cv_agg's auc: 0.794572 + 0.00220899
# [900]	cv_agg's auc: 0.795125 + 0.00211476
# [1000]	cv_agg's auc: 0.795581 + 0.00218749
# [1100]	cv_agg's auc: 0.795764 + 0.00210343
# [1200]	cv_agg's auc: 0.795837 + 0.00201961
# [1300]	cv_agg's auc: 0.796017 + 0.00198905
# [1400]	cv_agg's auc: 0.796035 + 0.00194835
# [1500]	cv_agg's auc: 0.795985 + 0.0019969
# Optimum boost rounds = 1407
# Best CV result = 0.7960597695596988
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# 191 more than half

# %% [markdown]
# New baseline
# -----
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.761279 + 0.00336603
# [200]	cv_agg's auc: 0.77363 + 0.00278012
# [300]	cv_agg's auc: 0.782606 + 0.00269742
# [400]	cv_agg's auc: 0.787647 + 0.00262401
# [500]	cv_agg's auc: 0.790502 + 0.00240743
# [600]	cv_agg's auc: 0.792433 + 0.00223408
# [700]	cv_agg's auc: 0.79367 + 0.00223838
# [800]	cv_agg's auc: 0.794572 + 0.00220899
# [900]	cv_agg's auc: 0.795125 + 0.00211476
# [1000]	cv_agg's auc: 0.795581 + 0.00218749
# [1100]	cv_agg's auc: 0.795764 + 0.00210343
# [1200]	cv_agg's auc: 0.795837 + 0.00201961
# [1300]	cv_agg's auc: 0.796017 + 0.00198905
# [1400]	cv_agg's auc: 0.796035 + 0.00194835
# [1500]	cv_agg's auc: 0.795985 + 0.0019969
# Optimum boost rounds = 1407
# Best CV result = 0.7960597695596988
# lgbm_params = {
#     'task': 'train',
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': 'auc',
#     'learning_rate': 0.02,
#     'num_iteration': 4000,
#     'num_threads': 8,
#
#     'num_leaves': int(round(44.368535336628419)),
#     'feature_fraction': 0.15,
#     'bagging_fraction': 0.94901525271474951,
#     'max_depth': int(round(8.0430115561596267)),
#     'lambda_l1': 0.30680079516647751,
#     'lambda_l2': 0.079128660903201031,
#     'min_split_gain': 0.054005067457890979,
#     'min_child_weight': 15.172643147364937}

# %% [markdown]
# bayes para pos_new with 24, 60 & install test
# -----
# [100]	cv_agg's auc: 0.780129 + 0.00283542
# [200]	cv_agg's auc: 0.788692 + 0.00258271

# %% [markdown]
# bayes para pos_new with 24, 60
# --------
# [100]	cv_agg's auc: 0.779969 + 0.00297851

# %% [markdown]
# baye paras/train with modified prev"
# ----------
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.780408 + 0.00290047
# [200]	cv_agg's auc: 0.789804 + 0.00263968
# [300]	cv_agg's auc: 0.792796 + 0.00252429
# [400]	cv_agg's auc: 0.79391 + 0.00252326
# [500]	cv_agg's auc: 0.794314 + 0.00242975
# [600]	cv_agg's auc: 0.794392 + 0.00237447
# [700]	cv_agg's auc: 0.794313 + 0.00234948
# Optimum boost rounds = 617
# Best CV result = 0.7944380747322322

# %% [markdown]
# without std bayes para, 7788 (train with prev)
# with std bayes para, 7789 (train without prev)

# %% [markdown]
# baseline bayes para, train only pre+:
#     [100]	cv_agg's auc: 0.780408 + 0.00290047
# [200]	cv_agg's auc: 0.789804 + 0.00263968
# [300]	cv_agg's auc: 0.792796 + 0.00252429

# %%
(out_df['TARGET']>0.5).sum()
out_df.to_csv(PATH+'submission/06_29_0.csv', index = False)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm
fig, (ax, ax1) = plt.subplots(1, 2, figsize=[15, 7])
lgbm.plot_importance(clf, ax=ax, max_num_features=30, importance_type='split')
lgbm.plot_importance(clf, ax=ax1, max_num_features=30, importance_type='gain')
ax.set_title('Importance by splits')
ax1.set_title('Importance by gain')
plt.tight_layout()
plt.show()

x = [x for x in zip(clf.feature_name(), clf.feature_importance('gain'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_2', 103722.85124921799)),
#  (1, ('EXT_SOURCE_3', 80692.24569177628)),
#  (2, ('EXT_SOURCE_1', 43751.28642129898)),
#  (3, ('AMT_CREDIT_divide_AMT_ANNUITY', 22537.60350751877)),
#  (4, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 18218.130947589874)),
#  (5,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_max',
#    16156.803945541382)),
#  (6,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 15232.60248708725)),
#  (7, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 13218.40020275116)),
#  (8, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 12084.994063854218)),
#  (9, ('CODE_GENDER', 11914.894889831543)),
#  (10, ('DAYS_BIRTH', 11898.05585694313)),
#  (11, ('bureau_DAYS_CREDIT_median', 11551.562866926193)),
#  (12, ('NAME_EDUCATION_TYPE', 11013.319427967072)),
#  (13,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median',
#    9940.5343375206)),
#  (14,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_mean',
#    8741.809082508087)),
#  (15,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR',
#    8542.163812875748)),
#  (16, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 8419.299959897995)),
#  (17, ('bureau_DAYS_CREDIT_mean', 7610.277688026428)),
#  (18, ('bureau_DAYS_CREDIT_max', 6239.304851531982)),
#  (19,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    5740.827585220337)),
#  (20, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 5568.252915143967)),
#  (21, ('AMT_GOODS_PRICE', 5447.961851939559)),
#  (22, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 5411.908405780792)),
#  (23,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 4976.538128852844)),
#  (24, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 4705.562971115112)),
#  (25,
#   ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR',
#    4674.972584247589)),
#  (26, ('AMT_ANNUITY', 4235.027987003326)),
#  (27,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_sum',
#    4176.766260623932)),
#  (28, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 4029.669385433197)),
#  (29,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_max',
#    3694.9468059539795)),
#  (30,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median',
#    3604.4039249420166)),
#  (31,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    3584.9917998313904)),
#  (32,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_max',
#    3481.3293805122375)),
#  (33,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median',
#    3409.554506778717)),
#  (34, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 3386.313033103943)),
#  (35, ('bureau_DAYS_CREDIT_UPDATE_median', 3377.5189352035522)),
#  (36, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 3361.9110226631165)),
#  (37,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_sum',
#    3341.144656896591)),
#  (38, ('NAME_INCOME_TYPE', 3336.08744764328)),
#  (39, ('install_DAYS_ENTRY_PAYMENT_std', 3329.6060466766357)),
#  (40, ('bureau_DAYS_CREDIT_ENDDATE_median', 3292.6384625434875)),
#  (41,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR',
#    3235.4869659245014)),
#  (42, ('AMT_ANNUITY_divide_DAYS_BIRTH', 3220.110638141632)),
#  (43, ('install_DAYS_INSTALMENT_std', 3109.9907915592194)),
#  (44, ('AMT_CREDIT_divide_DAYS_BIRTH', 2909.743183374405)),
#  (45, ('bureau_DAYS_CREDIT_ENDDATE_max', 2838.4771089553833)),
#  (46, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_mean', 2818.0236525535583)),
#  (47,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median',
#    2812.628571510315)),
#  (48, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 2796.0269527435303)),
#  (49,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_sum',
#    2794.3038806915283)),
#  (50,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean',
#    2773.7106595039368)),
#  (51, ('bureau_onehot_CREDIT_ACTIVE_Active', 2740.13045835495)),
#  (52, ('REGION_RATING_CLIENT_W_CITY', 2705.221583843231)),
#  (53, ('DAYS_EMPLOYED', 2694.7977175712585)),
#  (54, ('DAYS_LAST_PHONE_CHANGE', 2691.9763209819794)),
#  (55, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 2664.407520055771)),
#  (56,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 2640.360295534134)),
#  (57,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_max',
#    2571.5639901161194)),
#  (58, ('CNT_INSTALMENT_FUTURE_mean', 2560.941523551941)),
#  (59,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 2547.664908885956)),
#  (60,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 2543.8286924362183)),
#  (61,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 2505.531102657318)),
#  (62,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std',
#    2501.2011320590973)),
#  (63,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean',
#    2497.856701850891)),
#  (64,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    2438.9713950157166)),
#  (65, ('CNT_INSTALMENT_FUTURE_std', 2437.5860781669617)),
#  (66,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum',
#    2412.4860496520996)),
#  (67, ('creditcard_CNT_DRAWINGS_CURRENT_std', 2391.117283344269)),
#  (68, ('REGION_POPULATION_RELATIVE', 2375.266185283661)),
#  (69, ('DAYS_ID_PUBLISH', 2366.2545375823975)),
#  (70, ('NAME_FAMILY_STATUS', 2363.618101119995)),
#  (71,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    2352.7973251342773)),
#  (72, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_mean', 2329.719759464264)),
#  (73, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_std', 2218.275653362274)),
#  (74, ('AMT_CREDIT', 2201.779267311096)),
#  (75, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 2180.4214260578156)),
#  (76, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 2177.010051727295)),
#  (77, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 2163.0593761205673)),
#  (78,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR',
#    2134.9531376361847)),
#  (79, ('bureau_DAYS_ENDDATE_FACT_max', 2124.248827457428)),
#  (80,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 2054.4448823928833)),
#  (81, ('OWN_CAR_AGE', 2048.3769040107727)),
#  (82,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min',
#    2015.8232924938202)),
#  (83, ('prev_CNT_PAYMENT_mean', 2002.5160574913025)),
#  (84, ('FLAG_DOCUMENT_3', 2000.9629092216492)),
#  (85, ('REGION_RATING_CLIENT_times_livingsum_AVG', 1982.5031929016113)),
#  (86,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    1929.3662991523743)),
#  (87,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    1926.9012808799744)),
#  (88,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean',
#    1916.5756900310516)),
#  (89, ('install_AMT_PAYMENT_sum', 1898.7894711494446)),
#  (90, ('OCCUPATION_TYPE', 1885.0357339382172)),
#  (91, ('prev_CNT_PAYMENT_max', 1869.94650888443)),
#  (92,
#   ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR',
#    1831.866347193718)),
#  (93,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    1812.1482753753662)),
#  (94,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    1805.38081407547)),
#  (95, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 1802.3438558578491)),
#  (96, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 1787.8204941749573)),
#  (97, ('possible_future_install_std', 1787.6900248527527)),
#  (98, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 1765.817114830017)),
#  (99, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 1751.8093626499176)),
#  (100,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    1744.6112213134766)),
#  (101,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    1741.2860226631165)),
#  (102,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    1678.8946204185486)),
#  (103, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 1669.5354375839233)),
#  (104,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max',
#    1662.1794290542603)),
#  (105, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 1650.6923406124115)),
#  (106,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    1620.9998142719269)),
#  (107,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_mean',
#    1580.9953145980835)),
#  (108, ('install_DAYS_ENTRY_PAYMENT_sum', 1572.6511569023132)),
#  (109, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 1559.0332074165344)),
#  (110,
#   ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 1555.1957012414932)),
#  (111, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 1550.4200921058655)),
#  (112, ('bureau_DAYS_CREDIT_ENDDATE_mean', 1546.7837071418762)),
#  (113, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 1521.0314438343048)),
#  (114,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    1515.422872543335)),
#  (115, ('bureau_DAYS_CREDIT_UPDATE_mean', 1506.4043774604797)),
#  (116, ('DAYS_REGISTRATION', 1504.0790548324585)),
#  (117,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_sum',
#    1494.4354820251465)),
#  (118,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    1490.1583728790283)),
#  (119,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 1488.689133644104)),
#  (120, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 1483.567010641098)),
#  (121, ('prev_HOUR_APPR_PROCESS_START_mean', 1471.9994459152222)),
#  (122, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 1468.882334947586)),
#  (123, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 1458.2061967849731)),
#  (124, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 1457.309723854065)),
#  (125,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median',
#    1451.003805398941)),
#  (126, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 1447.4685740470886)),
#  (127, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 1412.6524925231934)),
#  (128, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 1400.202612876892)),
#  (129,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum',
#    1386.7260587215424)),
#  (130, ('count_prev_sum', 1374.460793018341)),
#  (131, ('bureau_DAYS_CREDIT_min', 1371.6575593948364)),
#  (132, ('prev_onehot_NAME_YIELD_GROUP_2.0', 1366.8686308860779)),
#  (133,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE',
#    1366.4180717468262)),
#  (134, ('SK_DPD_DEF_std', 1361.7717027664185)),
#  (135,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min',
#    1361.5644083023071)),
#  (136,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_mean',
#    1361.1543045043945)),
#  (137, ('onehot_NAME_CONTRACT_STATUS_Active', 1344.5929012298584)),
#  (138,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    1340.8231637477875)),
#  (139, ('bureau_onehot_CREDIT_TYPE_Microloan', 1327.296956062317)),
#  (140,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_min',
#    1323.3541450500488)),
#  (141,
#   ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR',
#    1322.2276272773743)),
#  (142, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 1314.868884086609)),
#  (143, ('REGION_RATING_CLIENT', 1313.4208517074585)),
#  (144, ('install_AMT_INSTALMENT_std', 1312.9039015769958)),
#  (145,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    1299.7676668167114)),
#  (146, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 1295.3189597129822)),
#  (147, ('install_DAYS_INSTALMENT_sum', 1294.722885608673)),
#  (148,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 1282.086287021637)),
#  (149,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 1282.0516080856323)),
#  (150, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 1279.7549619674683)),
#  (151, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 1277.0400819778442)),
#  (152, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 1273.9884645938873)),
#  (153,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    1268.4369778633118)),
#  (154, ('bureau_DAYS_ENDDATE_FACT_mean', 1268.2673239707947)),
#  (155, ('possible_future_install_max', 1248.6343235969543)),
#  (156, ('CNT_INSTALMENT_FUTURE_max', 1247.3715410232544)),
#  (157, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 1245.5239896774292)),
#  (158, ('CNT_INSTALMENT_std', 1223.158625125885)),
#  (159, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 1211.1802690029144)),
#  (160, ('install_DAYS_ENTRY_PAYMENT_min', 1210.2541201114655)),
#  (161, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 1207.460223197937)),
#  (162, ('possible_future_install_mean', 1205.5761036872864)),
#  (163, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 1198.5179829597473)),
#  (164,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    1197.145601272583)),
#  (165,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    1180.0805082321167)),
#  (166,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    1160.3038499355316)),
#  (167,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    1159.040929555893)),
#  (168, ('install_DAYS_ENTRY_PAYMENT_max', 1141.5871901512146)),
#  (169, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 1134.4388275146484)),
#  (170,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_sum', 1130.8375153541565)),
#  (171,
#   ('prev_onehot_NAME_PRODUCT_TYPE_walk-in_divide_count_SK_ID_CURR',
#    1116.473985671997)),
#  (172,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    1111.8731546401978)),
#  (173,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 1105.1129202842712)),
#  (174,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    1104.0812540054321)),
#  (175,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 1099.60218667984)),
#  (176, ('possible_future_install_sum', 1095.7224569320679)),
#  (177,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    1093.3714034557343)),
#  (178,
#   ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR',
#    1084.206262588501)),
#  (179, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 1084.1058540344238)),
#  (180, ('bureau_DAYS_ENDDATE_FACT_min', 1084.0300159454346)),
#  (181, ('install_DAYS_INSTALMENT_max', 1080.0593569278717)),
#  (182,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_std',
#    1059.3180158138275)),
#  (183,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    1058.9952039718628)),
#  (184,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median',
#    1053.5889325141907)),
#  (185,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    1053.2861754894257)),
#  (186,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 1052.7757892608643)),
#  (187,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 1046.6444649100304)),
#  (188, ('SK_DPD_DEF_mean', 1041.9446802139282)),
#  (189,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    1041.3685717582703)),
#  (190,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    1040.7523283958435)),
#  (191, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 1035.419291973114)),
#  (192, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 1032.617681503296)),
#  (193, ('count_prev_std', 1020.8808960914612)),
#  (194, ('bureau_DAYS_CREDIT_ENDDATE_sum', 1013.8687233924866)),
#  (195,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std',
#    1005.0510702133179)),
#  (196,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std',
#    1000.4060266017914)),
#  (197, ('install_DAYS_INSTALMENT_median', 997.213849067688)),
#  (198,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 995.8906655311584)),
#  (199, ('bureau_DAYS_CREDIT_UPDATE_max', 994.215372800827)),
#  (200, ('APARTMENTS_MEDI', 983.2344751358032)),
#  (201,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    980.9362196922302)),
#  (202, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 978.4274552464485)),
#  (203,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum', 976.9613547325134)),
#  (204, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 975.5441722869873)),
#  (205,
#   ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR',
#    973.3483912944794)),
#  (206, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 968.6241064071655)),
#  (207,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std',
#    966.9987182617188)),
#  (208, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 962.6488771438599)),
#  (209, ('LIVINGAREA_MEDI', 961.8891448974609)),
#  (210, ('TOTALAREA_MODE', 961.4044008255005)),
#  (211, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_sum', 959.3186131715775)),
#  (212, ('bureau_onehot_CREDIT_TYPE_Mortgage', 956.6329307556152)),
#  (213, ('CNT_INSTALMENT_max', 947.72230052948)),
#  (214, ('install_AMT_PAYMENT_median', 943.1801595687866)),
#  (215,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    939.0719752311707)),
#  (216, ('count_prev_mean', 936.9769282341003)),
#  (217,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    936.2540235519409)),
#  (218, ('install_AMT_INSTALMENT_sum', 934.7588064670563)),
#  (219, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 931.3892893791199)),
#  (220,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    930.44842004776)),
#  (221, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_max', 928.7514624595642)),
#  (222,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max',
#    926.3532180786133)),
#  (223, ('prev_onehot_CODE_REJECT_REASON_SCOFR', 912.1037020683289)),
#  (224, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 906.5713891983032)),
#  (225, ('creditcard_CNT_DRAWINGS_CURRENT_mean', 906.3371181488037)),
#  (226,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median',
#    901.5709671974182)),
#  (227,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR',
#    900.3515999317169)),
#  (228, ('REGION_RATING_CLIENT_times_livingsum_MEDI', 897.2770071029663)),
#  (229, ('bureau_AMT_CREDIT_SUM_sum', 895.9883584976196)),
#  (230, ('prev_DAYS_DECISION_mean', 892.2104926109314)),
#  (231, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 887.744460105896)),
#  (232, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 887.665228843689)),
#  (233, ('install_AMT_PAYMENT_min', 881.4464621543884)),
#  (234, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 881.1373453140259)),
#  (235,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min', 875.365777015686)),
#  (236, ('REG_CITY_NOT_LIVE_CITY', 874.6646404266357)),
#  (237, ('bureau_DAYS_ENDDATE_FACT_std', 871.3376874923706)),
#  (238, ('prev_HOUR_APPR_PROCESS_START_median', 865.587895154953)),
#  (239,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum', 865.5171728134155)),
#  (240, ('install_count_SK_ID_CURR', 862.6078562736511)),
#  (241, ('bureau_DAYS_CREDIT_std', 862.3759462833405)),
#  (242, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 861.3883419036865)),
#  (243, ('install_DAYS_INSTALMENT_min', 858.8834903240204)),
#  (244, ('prev_HOUR_APPR_PROCESS_START_max', 855.8734006881714)),
#  (245,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 855.1336815357208)),
#  (246,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    854.5375037193298)),
#  (247,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 848.3582246303558)),
#  (248, ('livingsum_AVG_divide_members', 847.6390423774719)),
#  (249, ('FLOORSMAX_AVG', 847.387204170227)),
#  (250,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 843.5459487438202)),
#  (251, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 842.3607974052429)),
#  (252,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    841.0526061058044)),
#  (253,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    839.7747559547424)),
#  (254, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 837.2757198810577)),
#  (255, ('prev_DAYS_DECISION_max', 835.9097547531128)),
#  (256,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    832.0125691890717)),
#  (257,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    831.5284326076508)),
#  (258, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 815.512526512146)),
#  (259,
#   ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean',
#    815.2430992126465)),
#  (260, ('install_DAYS_ENTRY_PAYMENT_median', 813.7988901138306)),
#  (261,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    804.8336172103882)),
#  (262,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    802.6359453201294)),
#  (263, ('install_AMT_PAYMENT_max', 801.3761749267578)),
#  (264,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median',
#    799.1870894432068)),
#  (265,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std',
#    795.9615375995636)),
#  (266, ('bureau_DAYS_CREDIT_UPDATE_std', 795.1688624620438)),
#  (267,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean',
#    786.226550579071)),
#  (268, ('bureau_AMT_CREDIT_SUM_max', 780.7438645362854)),
#  (269,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_median',
#    779.4645600318909)),
#  (270,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 773.1341705322266)),
#  (271,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max', 772.7269053459167)),
#  (272, ('AMT_ANNUITY_divide_OWN_CAR_AGE', 772.1815519332886)),
#  (273,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean',
#    772.1591882705688)),
#  (274,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    769.9267086982727)),
#  (275,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median',
#    768.9069757461548)),
#  (276, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in', 768.7438135147095)),
#  (277,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_min', 767.4011626243591)),
#  (278, ('bureau_DAYS_ENDDATE_FACT_median', 767.1654984951019)),
#  (279,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    767.1098685264587)),
#  (280, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 760.9104535579681)),
#  (281, ('install_AMT_PAYMENT_std', 759.5919785499573)),
#  (282,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean',
#    757.0713133811951)),
#  (283, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 754.2629761695862)),
#  (284, ('bureau_AMT_CREDIT_SUM_mean', 752.5222992897034)),
#  (285, ('bureau_DAYS_CREDIT_sum', 751.4533412456512)),
#  (286,
#   ('prev_onehot_CODE_REJECT_REASON_SCOFR_divide_count_SK_ID_CURR',
#    749.1491422653198)),
#  (287,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std',
#    747.4239196777344)),
#  (288,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_mean',
#    746.6630825996399)),
#  (289, ('APARTMENTS_AVG', 742.101037979126)),
#  (290,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    742.0343976020813)),
#  (291, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 739.5302977561951)),
#  (292,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median',
#    737.8071966171265)),
#  (293,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median',
#    737.5942344665527)),
#  (294, ('bureau_DAYS_CREDIT_UPDATE_min', 737.5093879699707)),
#  (295,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    735.7789206504822)),
#  (296,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean',
#    734.5497689247131)),
#  (297, ('bureau_DAYS_ENDDATE_FACT_sum', 734.0905015468597)),
#  (298,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    733.5208411216736)),
#  (299,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_mean', 732.1619818210602)),
#  (300,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    731.7451148033142)),
#  (301, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 731.2677521705627)),
#  (302,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    728.758246421814)),
#  (303, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_min', 728.5779967308044)),
#  (304,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    724.9306473731995)),
#  (305, ('bureau_AMT_CREDIT_SUM_median', 723.286527633667)),
#  (306, ('count_prev_max', 722.3491220474243)),
#  (307,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_std',
#    721.2649617195129)),
#  (308,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    717.0880632400513)),
#  (309,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_mean',
#    716.9354948997498)),
#  (310,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    714.5794925689697)),
#  (311, ('install_AMT_INSTALMENT_median', 714.1391434669495)),
#  (312,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 712.9581007957458)),
#  (313, ('bureau_DAYS_CREDIT_ENDDATE_std', 711.8851294517517)),
#  (314, ('install_AMT_INSTALMENT_max', 706.5879564285278)),
#  (315,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    704.991691827774)),
#  (316, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 700.8883192539215)),
#  (317, ('bureau_AMT_CREDIT_SUM_std', 700.709178686142)),
#  (318, ('SK_DPD_DEF_mean_sum', 699.070033788681)),
#  (319,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    694.7124624252319)),
#  (320, ('livingsum_MEDI_divide_members', 693.4142818450928)),
#  (321,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_sum',
#    689.37482380867)),
#  (322,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std',
#    689.0722646713257)),
#  (323,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max',
#    686.8948895931244)),
#  (324, ('prev_AMT_ANNUITY_min', 684.8964281082153)),
#  (325,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE',
#    683.4948883056641)),
#  (326,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    683.1930975914001)),
#  (327,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    681.3419270515442)),
#  (328,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median',
#    680.5873513221741)),
#  (329,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    680.274519443512)),
#  (330,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    679.0860614776611)),
#  (331,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean',
#    678.6703853607178)),
#  (332,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 678.0157017707825)),
#  (333, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 675.7229025363922)),
#  (334, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 675.5840902328491)),
#  (335,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 675.2736983299255)),
#  (336, ('bureau_DAYS_CREDIT_UPDATE_sum', 673.463457107544)),
#  (337, ('AMT_CREDIT_divide_OWN_CAR_AGE', 673.1516966819763)),
#  (338,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_std',
#    672.9136471748352)),
#  (339, ('REGION_RATING_CLIENT_times_livingsum_MODE', 669.5864901542664)),
#  (340,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE',
#    669.2819091081619)),
#  (341, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_sum', 666.391902923584)),
#  (342,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    662.6742038726807)),
#  (343,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_std', 661.3353524208069)),
#  (344,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 659.9688906669617)),
#  (345, ('install_DAYS_INSTALMENT_mean', 659.6926336288452)),
#  (346,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean',
#    658.3180713653564)),
#  (347, ('bureau_AMT_CREDIT_SUM_DEBT_std', 654.8941297531128)),
#  (348, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_max', 654.7214105129242)),
#  (349,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_median',
#    652.8206791877747)),
#  (350,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min', 652.4665896892548)),
#  (351,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_max', 651.3674311637878)),
#  (352, ('livingsum_MEDI', 648.3880410194397)),
#  (353, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 648.2010390758514)),
#  (354, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 647.4621820449829)),
#  (355, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 646.3369636535645)),
#  (356,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_min',
#    645.8457927703857)),
#  (357, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_min', 643.934751033783)),
#  (358,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    643.3487904071808)),
#  (359,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    641.4250302314758)),
#  (360, ('prev_DAYS_LAST_DUE_min', 639.6597204208374)),
#  (361, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 638.0869903564453)),
#  (362,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_std', 635.9963159561157)),
#  (363,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_max', 635.0204482078552)),
#  (364, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_max', 634.6926770210266)),
#  (365,
#   ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    629.8472847938538)),
#  (366,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean',
#    626.3995895385742)),
#  (367,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max',
#    626.023871421814)),
#  (368,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_std',
#    625.3084120750427)),
#  (369,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_std',
#    624.8785486221313)),
#  (370, ('bureau_AMT_CREDIT_SUM_DEBT_max', 622.2599875330925)),
#  (371,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    621.3693585395813)),
#  (372, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_min', 620.3499164581299)),
#  (373, ('prev_HOUR_APPR_PROCESS_START_min', 619.6728000640869)),
#  (374, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 616.991708278656)),
#  (375, ('AMT_INCOME_TOTAL', 616.3732151985168)),
#  (376,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 616.0605473518372)),
#  (377, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 616.0540928840637)),
#  (378,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std',
#    615.105281829834)),
#  (379, ('prev_DAYS_FIRST_DUE_median', 614.5444602966309)),
#  (380, ('AMT_INCOME_TOTAL_divide_DAYS_LAST_PHONE_CHANGE', 614.243670463562)),
#  (381,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    612.8350529670715)),
#  (382, ('CNT_INSTALMENT_mean', 610.9207615852356)),
#  (383, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 609.2200374603271)),
#  (384,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_median',
#    608.9656157493591)),
#  (385,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median',
#    605.2871079444885)),
#  (386,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    604.3944292068481)),
#  (387,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_mean', 604.1059079170227)),
#  (388,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR',
#    602.2338004112244)),
#  (389,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    602.081609249115)),
#  (390,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    599.7476122379303)),
#  (391, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_max', 597.175929069519)),
#  (392,
#   ('creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean',
#    596.4416701793671)),
#  (393, ('OWN_CAR_AGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 596.3391666412354)),
#  (394, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 596.140368938446)),
#  (395, ('dpd_divide_count_prev_min', 595.6705055236816)),
#  (396,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    595.2958645820618)),
#  (397, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_sum', 594.5587286949158)),
#  (398,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 594.4790554046631)),
#  (399, ('livingsum_AVG', 593.7116513252258)),
#  (400,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_0.0_divide_count_SK_ID_CURR',
#    591.5671210289001)),
#  (401,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median',
#    590.5036859512329)),
#  (402, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 589.1692905426025)),
#  (403, ('prev_DAYS_FIRST_DUE_max', 588.9071898460388)),
#  (404,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    588.7029819488525)),
#  (405,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_min', 587.8117980957031)),
#  (406, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OWN_CAR_AGE', 586.939197063446)),
#  (407,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    583.4627475738525)),
#  (408, ('install_DAYS_ENTRY_PAYMENT_mean', 583.0710756778717)),
#  (409,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    581.4075727462769)),
#  (410, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 581.1276216506958)),
#  (411, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 580.910651922226)),
#  (412, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 579.6416563987732)),
#  (413, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 578.6810600757599)),
#  (414,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    578.2491493225098)),
#  (415, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 578.2178692817688)),
#  (416,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_sum',
#    574.7631206512451)),
#  (417,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    574.4846453666687)),
#  (418, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 573.8412399291992)),
#  (419,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 573.5048513412476)),
#  (420,
#   ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 572.003466129303)),
#  (421,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    571.656934261322)),
#  (422, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_mean', 569.8870098590851)),
#  (423,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean', 568.30295753479)),
#  (424,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    567.7632858753204)),
#  (425, ('prev_DAYS_LAST_DUE_1ST_VERSION_sum', 567.7369470596313)),
#  (426, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 567.095892906189)),
#  (427, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 566.6415252685547)),
#  (428, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 564.9684433937073)),
#  (429,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_0.0_divide_count_SK_ID_CURR',
#    563.7471313476562)),
#  (430, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_min', 563.0946321487427)),
#  (431, ('prev_DAYS_DECISION_median', 561.7101378440857)),
#  (432,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    561.6553092002869)),
#  (433, ('diff_max_min', 561.3606824874878)),
#  (434, ('APARTMENTS_MODE', 560.6026396751404)),
#  (435,
#   ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    560.36740899086)),
#  (436, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 559.8657126426697)),
#  (437,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_mean',
#    559.1429424285889)),
#  (438, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_min', 557.6769108772278)),
#  (439,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    557.2510499954224)),
#  (440,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_std', 556.9182224273682)),
#  (441, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 555.9576478004456)),
#  (442, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 554.6843681335449)),
#  (443,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median',
#    554.5349035263062)),
#  (444, ('bureau_DAYS_CREDIT_ENDDATE_min', 554.1793112754822)),
#  (445, ('prev_onehot_NAME_YIELD_GROUP_1.0', 553.6912322044373)),
#  (446, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 551.9485912322998)),
#  (447, ('AMT_ANNUITY_divide_DEF_30_CNT_SOCIAL_CIRCLE', 549.4929313659668)),
#  (448,
#   ('positivecount_SK_ID_CURR_SK_ID_PREV_SK_DPD_DEF_mean', 549.2848315238953)),
#  (449,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    548.435341835022)),
#  (450,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    545.3026432991028)),
#  (451, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 540.3780450820923)),
#  (452,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_sum',
#    540.1827123165131)),
#  (453, ('prev_DAYS_DECISION_min', 540.0408787727356)),
#  (454, ('prev_DAYS_FIRST_DUE_min', 539.3045701980591)),
#  (455,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    538.5753407478333)),
#  (456,
#   ('creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    538.2434949874878)),
#  (457,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    536.9338612556458)),
#  (458,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_std',
#    536.7724936008453)),
#  (459,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 536.5846033096313)),
#  (460,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    534.3621287345886)),
#  (461,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 532.7846736907959)),
#  (462,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    531.211320400238)),
#  (463, ('prev_RATE_DOWN_PAYMENT_max', 530.8545088768005)),
#  (464,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    530.6294040679932)),
#  (465,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    530.0106477737427)),
#  (466, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 529.7913224697113)),
#  (467, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 528.9207239151001)),
#  (468, ('def_divide_count_prev_min', 528.0696020126343)),
#  (469, ('install_AMT_INSTALMENT_mean', 528.0258388519287)),
#  (470, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 527.2506093978882)),
#  (471,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    525.9191027879715)),
#  (472,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_median',
#    524.6757621765137)),
#  (473,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_std',
#    524.3276295661926)),
#  (474,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 523.2692079544067)),
#  (475,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_median',
#    522.7044382095337)),
#  (476, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 521.9700260162354)),
#  (477, ('SK_DPD_DEF_max', 521.1983165740967)),
#  (478, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 520.2083435058594)),
#  (479, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 520.0667777061462)),
#  (480,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    519.9310390949249)),
#  (481, ('install_AMT_PAYMENT_mean', 519.6459488868713)),
#  (482,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median',
#    518.7901678085327)),
#  (483,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_sum', 517.6032500267029)),
#  (484,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    517.5430612564087)),
#  (485,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    517.3728585243225)),
#  (486,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    517.3613228797913)),
#  (487,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_median',
#    516.7896776199341)),
#  (488,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    515.8887214660645)),
#  (489,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_max',
#    515.8857507705688)),
#  (490, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 514.7269344329834)),
#  (491,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_median',
#    514.6768789291382)),
#  (492,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_min',
#    513.992838382721)),
#  (493,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    512.0043196678162)),
#  (494,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    510.70267820358276)),
#  (495, ('SK_DPD_DEF_min_max', 510.585720539093)),
#  (496,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max',
#    510.2991371154785)),
#  (497, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 508.53853964805603)),
#  (498, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_mean', 507.64413833618164)),
#  (499, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 505.3530673980713)),
#  (500,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_max', 505.31790041923523)),
#  (501, ('def_divide_count_prev_mean', 505.28654956817627)),
#  (502, ('prev_DAYS_DECISION_sum', 503.9480061531067)),
#  (503, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_max', 502.29580783843994)),
#  (504, ('bureau_AMT_CREDIT_MAX_OVERDUE_mean', 502.12995624542236)),
#  (505, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 501.6494641304016)),
#  (506,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_mean', 500.9210305213928)),
#  (507, ('YEARS_BEGINEXPLUATATION_MEDI', 500.8054208755493)),
#  (508,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    500.6916718482971)),
#  (509, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_max', 500.23018646240234)),
#  (510, ('prev_AMT_CREDIT_divide_DAYS_DECISION_median', 499.8475384712219)),
#  (511,
#   ('prev_onehot_NAME_YIELD_GROUP_0.0_divide_count_SK_ID_CURR',
#    499.34420895576477)),
#  (512, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_median', 498.76518845558167)),
#  (513, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_mean', 498.7351803779602)),
#  (514,
#   ('bureau_onehot_CREDIT_TYPE_Credit_card_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    498.5864591598511)),
#  (515,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    498.45550060272217)),
#  (516, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 498.3093214035034)),
#  (517,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min',
#    497.92450618743896)),
#  (518,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max',
#    497.8568654060364)),
#  (519,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    497.5667600631714)),
#  (520, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_max', 497.02150774002075)),
#  (521,
#   ('prev_onehot_NAME_PORTFOLIO_POS_divide_count_SK_ID_CURR',
#    495.70081186294556)),
#  (522, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_sum', 495.2287378311157)),
#  (523, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_sum', 493.45002937316895)),
#  (524, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 493.3487687110901)),
#  (525,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    493.083863735199)),
#  (526, ('LIVINGAREA_AVG', 493.05738973617554)),
#  (527, ('CNT_INSTALMENT_FUTURE_sum', 492.7533812522888)),
#  (528, ('prev_AMT_GOODS_PRICE_min', 492.7497899532318)),
#  (529, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 492.3851580619812)),
#  (530, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_MON', 491.01639199256897)),
#  (531, ('AMT_CREDIT_divide_DEF_60_CNT_SOCIAL_CIRCLE', 490.58802795410156)),
#  (532, ('prev_AMT_ANNUITY_mean', 488.9531078338623)),
#  (533,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    486.60136461257935)),
#  (534, ('NAME_CONTRACT_TYPE', 486.58820056915283)),
#  (535,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_std',
#    486.5718309879303)),
#  (536,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median', 486.39780926704407)),
#  (537, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_sum', 486.2225923538208)),
#  (538, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_sum', 485.3006682395935)),
#  (539, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_min', 485.1540985107422)),
#  (540, ('livingsum_MODE_divide_members', 485.0044102668762)),
#  (541, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_max', 483.86054039001465)),
#  (542,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_sum',
#    483.52509689331055)),
#  (543,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_min', 481.29539012908936)),
#  (544, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_mean', 479.6920289993286)),
#  (545,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum',
#    478.7989377975464)),
#  (546, ('prev_CNT_PAYMENT_sum', 477.71528244018555)),
#  (547,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    477.65115880966187)),
#  (548, ('bureau_AMT_CREDIT_SUM_min', 477.00514793395996)),
#  (549, ('prev_DAYS_FIRST_DUE_mean', 476.73517656326294)),
#  (550, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_median', 476.2287085056305)),
#  (551, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 475.6794320344925)),
#  (552, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 474.9615001678467)),
#  (553, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_median', 474.9229521751404)),
#  (554,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    473.9319677352905)),
#  (555,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    473.85995650291443)),
#  (556,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_min',
#    473.2426595687866)),
#  (557,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    472.73865842819214)),
#  (558,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    472.6937232017517)),
#  (559,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_median',
#    472.46963930130005)),
#  (560,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    471.673770904541)),
#  (561,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    471.29262113571167)),
#  (562, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 471.1490888595581)),
#  (563,
#   ('creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_mean',
#    471.06378173828125)),
#  (564,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    470.9152979850769)),
#  (565,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 470.325270652771)),
#  (566,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    470.14051580429077)),
#  (567,
#   ('prev_onehot_NAME_CLIENT_TYPE_New_divide_count_SK_ID_CURR',
#    469.9529004096985)),
#  (568, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 469.26309299468994)),
#  (569,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 467.4883313179016)),
#  (570, ('prev_AMT_CREDIT_median', 467.36137771606445)),
#  (571,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    467.17619943618774)),
#  (572,
#   ('prev_onehot_NAME_CLIENT_TYPE_Refreshed_divide_count_SK_ID_CURR',
#    467.0472779273987)),
#  (573,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 466.8969798088074)),
#  (574, ('CNT_INSTALMENT_sum', 466.03553891181946)),
#  (575, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_max', 465.62634229660034)),
#  (576,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    465.471529006958)),
#  (577,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_std',
#    464.6138916015625)),
#  (578, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_mean', 463.7396402359009)),
#  (579,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    462.66766023635864)),
#  (580,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    461.0820713043213)),
#  (581, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 459.9507613182068)),
#  (582,
#   ('install_positivecount_SK_ID_CURR_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    459.2172315120697)),
#  (583,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    459.0623002052307)),
#  (584,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    458.35005140304565)),
#  (585,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_mean',
#    456.94765758514404)),
# ...
#    346.2645044326782)),
#  (823,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_min', 344.2983887195587)),
#  (824, ('bureau_onehot_STATUS_0_mean', 344.16223764419556)),
#  (825,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_median', 343.6838617324829)),
#  (826, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_mean', 343.5045118331909)),
#  (827,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_sum',
#    343.329149723053)),
#  (828, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_median', 343.2224817276001)),
#  (829,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    342.9714312553406)),
#  (830,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_median',
#    341.5805768966675)),
#  (831,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_min', 341.53259801864624)),
#  (832,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_0.0_divide_count_SK_ID_CURR',
#    340.7828378677368)),
#  (833,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    340.3039286136627)),
#  (834, ('bureau_AMT_CREDIT_SUM_OVERDUE_max', 339.82921266555786)),
#  (835, ('livingsum_MODE', 339.65696954727173)),
#  (836, ('bureau_MONTHS_BALANCE_std_min', 339.54564809799194)),
#  (837, ('AMT_ANNUITY_divide_CNT_CHILDREN', 339.53197956085205)),
#  (838, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_min', 339.0358991622925)),
#  (839,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    338.71086406707764)),
#  (840,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    338.30742025375366)),
#  (841,
#   ('prev_onehot_CODE_REJECT_REASON_SCO_divide_count_SK_ID_CURR',
#    337.37520122528076)),
#  (842,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_std',
#    337.258948802948)),
#  (843,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_std',
#    336.83513832092285)),
#  (844,
#   ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_LAST_PHONE_CHANGE',
#    336.62937927246094)),
#  (845,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_sum', 335.97204971313477)),
#  (846,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_max',
#    335.4445586204529)),
#  (847, ('bureau_onehot_STATUS_1_std', 334.32012009620667)),
#  (848, ('bureau_onehot_STATUS_C_mean', 334.30355882644653)),
#  (849,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    334.2120318412781)),
#  (850,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_median',
#    333.64820098876953)),
#  (851, ('prev_AMT_DOWN_PAYMENT_median', 333.363089799881)),
#  (852, ('prev_RATE_DOWN_PAYMENT_mean', 333.25223779678345)),
#  (853,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    332.84822034835815)),
#  (854, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 332.0243511199951)),
#  (855, ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan', 331.56070947647095)),
#  (856,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_mean',
#    331.3256587982178)),
#  (857,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 330.6968603134155)),
#  (858, ('bureau_onehot_CREDIT_TYPE_Credit_card', 330.0810708999634)),
#  (859, ('prev_DAYS_FIRST_DUE_sum', 329.86327934265137)),
#  (860,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    329.7549022436142)),
#  (861,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    329.7539415359497)),
#  (862,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_median',
#    328.3640899658203)),
#  (863,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_TOTAL_CURRENT_sum',
#    328.180871963501)),
#  (864, ('bureau_MONTHS_BALANCE_sum_sum', 328.035391330719)),
#  (865,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_median', 327.9275894165039)),
#  (866,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    327.76643085479736)),
#  (867,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean',
#    327.5238513946533)),
#  (868,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    327.4806122779846)),
#  (869,
#   ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_sum', 326.89136934280396)),
#  (870,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_max', 326.4565830230713)),
#  (871, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_mean', 326.39114141464233)),
#  (872,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 326.0843482017517)),
#  (873, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_max', 325.95922231674194)),
#  (874,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    325.7062792778015)),
#  (875,
#   ('OBS_60_CNT_SOCIAL_CIRCLE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    325.4573998451233)),
#  (876,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_min',
#    325.3696918487549)),
#  (877,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    325.03774976730347)),
#  (878,
#   ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR',
#    323.51942014694214)),
#  (879,
#   ('creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_sum',
#    323.39618253707886)),
#  (880,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_median',
#    322.50405979156494)),
#  (881,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_ID_PUBLISH', 322.4483947753906)),
#  (882, ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity', 322.32115840911865)),
#  (883,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    321.92663955688477)),
#  (884,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    321.9118084907532)),
#  (885,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    321.52879762649536)),
#  (886, ('req_total', 320.84455013275146)),
#  (887, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_max', 320.67176055908203)),
#  (888, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_sum', 319.7227997779846)),
#  (889, ('bureau_AMT_ANNUITY_std', 319.65701150894165)),
#  (890, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_max', 319.64089012145996)),
#  (891, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_sum', 319.19794034957886)),
#  (892, ('prev_DAYS_LAST_DUE_sum', 319.19079208374023)),
#  (893,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    318.8447196483612)),
#  (894,
#   ('creditcard_AMT_BALANCE_divide_AMT_TOTAL_RECEIVABLE_median',
#    318.0214409828186)),
#  (895,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    317.97188782691956)),
#  (896, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_max', 316.83823823928833)),
#  (897,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    315.96783924102783)),
#  (898,
#   ('positivecount_SK_ID_CURR_SK_ID_PREV_SK_DPD_DEF_std', 315.1635694503784)),
#  (899, ('FLAG_DOCUMENT_18', 313.8112018108368)),
#  (900,
#   ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 313.6305525302887)),
#  (901,
#   ('AMT_REQ_CREDIT_BUREAU_MON_divide_DAYS_REGISTRATION', 312.7300806045532)),
#  (902,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    312.66781997680664)),
#  (903, ('WEEKDAY_APPR_PROCESS_START', 312.2097980976105)),
#  (904,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    311.8726806640625)),
#  (905,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_mean', 311.81291031837463)),
#  (906,
#   ('prev_onehot_NAME_PRODUCT_TYPE_XNA_divide_count_SK_ID_CURR',
#    311.6852502822876)),
#  (907,
#   ('prev_onehot_NAME_PRODUCT_TYPE_x-sell_divide_count_SK_ID_CURR',
#    310.6512279510498)),
#  (908,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_sum', 310.42725229263306)),
#  (909,
#   ('bureau_onehot_CREDIT_TYPE_Consumer_credit_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    309.87278985977173)),
#  (910,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_sum',
#    309.8016014099121)),
#  (911, ('bureau_MONTHS_BALANCE_std_max', 309.05386114120483)),
#  (912,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    308.6712613105774)),
#  (913,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean', 308.54862880706787)),
#  (914,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    308.0330672264099)),
#  (915,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    307.5651206970215)),
#  (916,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    306.986909866333)),
#  (917,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    306.74399614334106)),
#  (918,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean',
#    306.67594814300537)),
#  (919,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    306.63237953186035)),
#  (920,
#   ('creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_std', 305.1658010482788)),
#  (921,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CREDIT_DAY_OVERDUE_max',
#    304.89897060394287)),
#  (922, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 303.8364462852478)),
#  (923,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_max',
#    303.441810131073)),
#  (924, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_max', 303.37937021255493)),
#  (925,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    302.58194971084595)),
#  (926, ('diff_def_max_std', 302.20827770233154)),
#  (927,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    300.9052104949951)),
#  (928,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    300.61794996261597)),
#  (929,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_max',
#    299.6695418357849)),
#  (930,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_median',
#    299.4900612831116)),
#  (931,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_mean', 299.193058013916)),
#  (932,
#   ('DEF_60_CNT_SOCIAL_CIRCLE_divide_OBS_60_CNT_SOCIAL_CIRCLE',
#    298.53856658935547)),
#  (933,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    298.14611053466797)),
#  (934,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max',
#    298.11862993240356)),
#  (935,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    297.70512080192566)),
#  (936,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    297.37257146835327)),
#  (937,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Furniture_divide_count_SK_ID_CURR',
#    297.12788915634155)),
#  (938,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    297.0138493180275)),
#  (939,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_mean', 296.74921798706055)),
#  (940,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    296.58202266693115)),
#  (941,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    295.9501624107361)),
#  (942, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_sum', 295.81371879577637)),
#  (943,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    295.69313859939575)),
#  (944,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    295.5596604347229)),
#  (945,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    295.48445987701416)),
#  (946, ('prev_AMT_DOWN_PAYMENT_max', 294.68937849998474)),
#  (947,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_median',
#    294.42324113845825)),
#  (948,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    294.19461154937744)),
#  (949,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    294.12661504745483)),
#  (950,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    293.884548664093)),
#  (951,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_median', 293.81520819664)),
#  (952,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    293.7522988319397)),
#  (953, ('prev_AMT_ANNUITY_median', 293.42629957199097)),
#  (954, ('bureau_onehot_STATUS_C_max', 292.55848836898804)),
#  (955,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    292.08184814453125)),
#  (956,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_std',
#    291.3253085613251)),
#  (957, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_max', 290.8016505241394)),
#  (958,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    290.64226150512695)),
#  (959,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_median', 290.2282500267029)),
#  (960,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_sum', 290.21502017974854)),
#  (961,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min', 290.1380081176758)),
#  (962,
#   ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_min', 289.82232189178467)),
#  (963, ('prev_AMT_CREDIT_divide_DAYS_DECISION_max', 289.60659170150757)),
#  (964, ('creditcard_CNT_DRAWINGS_POS_CURRENT_mean', 289.1629128456116)),
#  (965,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_mean',
#    289.13959789276123)),
#  (966, ('unique_cnt_install_std', 289.022319316864)),
#  (967,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    287.2168297767639)),
#  (968, ('LIVINGAPARTMENTS_MEDI', 287.095009803772)),
#  (969, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_max', 286.5803999900818)),
#  (970,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    286.551739692688)),
#  (971,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_median',
#    286.5141806602478)),
#  (972, ('BASEMENTAREA_MEDI', 285.30336904525757)),
#  (973,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    284.97323727607727)),
#  (974,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    284.8347427845001)),
#  (975,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_mean',
#    284.7744297981262)),
#  (976,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_median',
#    284.3137512207031)),
#  (977,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    284.26289987564087)),
#  (978, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_median', 283.8073000907898)),
#  (979,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_median', 283.8033404350281)),
#  (980, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_sum', 283.62865233421326)),
#  (981, ('CNT_FAM_MEMBERS', 283.4644775390625)),
#  (982,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    283.45410108566284)),
#  (983,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_mean',
#    283.12787342071533)),
#  (984, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_mean', 282.1457304954529)),
#  (985,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_sum', 281.97888231277466)),
#  (986, ('bureau_AMT_CREDIT_SUM_DEBT_median', 281.67684984207153)),
#  (987,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    281.5568616390228)),
#  (988, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_max', 281.24848890304565)),
#  (989,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    281.07503271102905)),
#  (990,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min',
#    280.5318956375122)),
#  (991, ('LANDAREA_MEDI', 280.4443392753601)),
#  (992,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    279.94318151474)),
#  (993, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_min', 279.8284306526184)),
#  (994,
#   ('prev_onehot_CHANNEL_TYPE_Stone_divide_count_SK_ID_CURR',
#    279.5722885131836)),
#  (995,
#   ('creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median', 278.9136576652527)),
#  (996,
#   ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_sum', 278.74707221984863)),
#  (997,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_sum', 278.6225986480713)),
#  (998, ('prev_AMT_CREDIT_sum', 278.29735803604126)),
#  (999,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_CNT_FAM_MEMBERS', 277.8575830459595)),
#  ...]

# %%
x = [x for x in zip(clf.feature_name(), clf.feature_importance('split'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('AMT_CREDIT_divide_AMT_ANNUITY', 693)),
#  (1, ('EXT_SOURCE_2', 629)),
#  (2, ('EXT_SOURCE_1', 623)),
#  (3, ('EXT_SOURCE_3', 504)),
#  (4, ('DAYS_BIRTH', 421)),
#  (5,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_max',
#    294)),
#  (6, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 250)),
#  (7, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 242)),
#  (8, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 239)),
#  (9, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 230)),
#  (10, ('AMT_GOODS_PRICE', 206)),
#  (11,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_mean',
#    202)),
#  (12, ('AMT_ANNUITY', 197)),
#  (13, ('CODE_GENDER', 187)),
#  (14,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_max',
#    185)),
#  (15, ('bureau_DAYS_CREDIT_ENDDATE_max', 183)),
#  (16, ('bureau_DAYS_CREDIT_max', 179)),
#  (17, ('REGION_POPULATION_RELATIVE', 178)),
#  (18, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 178)),
#  (19, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 177)),
#  (20, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 176)),
#  (21, ('NAME_EDUCATION_TYPE', 170)),
#  (22, ('DAYS_ID_PUBLISH', 160)),
#  (23, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 158)),
#  (24,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_sum',
#    152)),
#  (25, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median', 150)),
#  (26, ('DAYS_EMPLOYED', 148)),
#  (27, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 148)),
#  (28,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_sum',
#    146)),
#  (29, ('bureau_DAYS_ENDDATE_FACT_max', 145)),
#  (30, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 144)),
#  (31, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std', 141)),
#  (32,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_max',
#    137)),
#  (33, ('OCCUPATION_TYPE', 136)),
#  (34, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 136)),
#  (35, ('NAME_FAMILY_STATUS', 126)),
#  (36, ('bureau_DAYS_CREDIT_ENDDATE_median', 125)),
#  (37, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 123)),
#  (38, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 123)),
#  (39, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 122)),
#  (40, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min', 122)),
#  (41, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 120)),
#  (42, ('bureau_DAYS_CREDIT_median', 119)),
#  (43,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR', 118)),
#  (44,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_sum',
#    117)),
#  (45, ('AMT_ANNUITY_divide_DAYS_BIRTH', 116)),
#  (46, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 114)),
#  (47, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_max', 113)),
#  (48, ('AMT_CREDIT', 112)),
#  (49, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_mean', 112)),
#  (50, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 107)),
#  (51, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 105)),
#  (52, ('creditcard_CNT_DRAWINGS_CURRENT_std', 105)),
#  (53, ('bureau_DAYS_CREDIT_UPDATE_median', 105)),
#  (54, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum', 105)),
#  (55, ('AMT_CREDIT_divide_DAYS_BIRTH', 104)),
#  (56, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 104)),
#  (57, ('DAYS_REGISTRATION', 103)),
#  (58, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 103)),
#  (59, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 102)),
#  (60, ('CNT_INSTALMENT_FUTURE_std', 102)),
#  (61, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max', 102)),
#  (62, ('install_DAYS_ENTRY_PAYMENT_std', 101)),
#  (63, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_std', 100)),
#  (64, ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR', 97)),
#  (65,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_mean',
#    97)),
#  (66, ('CNT_INSTALMENT_FUTURE_mean', 95)),
#  (67, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median', 95)),
#  (68,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_mean',
#    95)),
#  (69, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 94)),
#  (70, ('bureau_DAYS_CREDIT_mean', 94)),
#  (71, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 93)),
#  (72, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median', 93)),
#  (73, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 92)),
#  (74,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_min',
#    92)),
#  (75,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_std',
#    92)),
#  (76, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean', 92)),
#  (77, ('NAME_INCOME_TYPE', 91)),
#  (78, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_sum', 91)),
#  (79, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 91)),
#  (80, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 91)),
#  (81, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min', 90)),
#  (82, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 90)),
#  (83, ('DAYS_LAST_PHONE_CHANGE', 88)),
#  (84, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 88)),
#  (85, ('bureau_DAYS_CREDIT_ENDDATE_mean', 88)),
#  (86, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 87)),
#  (87, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 87)),
#  (88, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum', 86)),
#  (89, ('count_prev_std', 85)),
#  (90, ('bureau_onehot_CREDIT_ACTIVE_Active', 85)),
#  (91,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR', 84)),
#  (92, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_mean', 84)),
#  (93, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 83)),
#  (94,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    83)),
#  (95, ('install_DAYS_ENTRY_PAYMENT_sum', 83)),
#  (96, ('bureau_DAYS_CREDIT_UPDATE_max', 83)),
#  (97, ('prev_CNT_PAYMENT_mean', 82)),
#  (98, ('install_DAYS_INSTALMENT_std', 82)),
#  (99, ('install_AMT_PAYMENT_sum', 82)),
#  (100, ('bureau_DAYS_ENDDATE_FACT_mean', 82)),
#  (101, ('possible_future_install_std', 81)),
#  (102, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std', 81)),
#  (103, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 80)),
#  (104, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 80)),
#  (105, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 79)),
#  (106,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR', 79)),
#  (107, ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR', 79)),
#  (108, ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR', 79)),
#  (109, ('prev_HOUR_APPR_PROCESS_START_mean', 79)),
#  (110, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean', 79)),
#  (111, ('onehot_NAME_CONTRACT_STATUS_Active', 78)),
#  (112, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 78)),
#  (113, ('possible_future_install_sum', 77)),
#  (114, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 76)),
#  (115, ('install_AMT_INSTALMENT_std', 76)),
#  (116, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 76)),
#  (117, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 75)),
#  (118, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 75)),
#  (119,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    75)),
#  (120, ('bureau_DAYS_CREDIT_min', 75)),
#  (121, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 74)),
#  (122,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    74)),
#  (123, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_max', 74)),
#  (124, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 74)),
#  (125, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 73)),
#  (126,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    73)),
#  (127, ('install_AMT_PAYMENT_min', 73)),
#  (128, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean', 73)),
#  (129,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    72)),
#  (130, ('install_AMT_PAYMENT_median', 72)),
#  (131, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 72)),
#  (132, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min', 72)),
#  (133, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 71)),
#  (134, ('possible_future_install_max', 71)),
#  (135, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 70)),
#  (136, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 70)),
#  (137, ('bureau_DAYS_ENDDATE_FACT_std', 70)),
#  (138, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min', 70)),
#  (139, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 69)),
#  (140,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    69)),
#  (141, ('prev_DAYS_DECISION_max', 69)),
#  (142, ('install_DAYS_ENTRY_PAYMENT_max', 69)),
#  (143, ('bureau_DAYS_CREDIT_ENDDATE_sum', 69)),
#  (144, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum', 68)),
#  (145, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean', 68)),
#  (146, ('OWN_CAR_AGE', 67)),
#  (147, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_sum', 67)),
#  (148, ('install_DAYS_INSTALMENT_max', 67)),
#  (149, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 67)),
#  (150, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median', 66)),
#  (151, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 66)),
#  (152, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max', 66)),
#  (153, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum', 66)),
#  (154, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 65)),
#  (155,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    65)),
#  (156, ('CNT_INSTALMENT_std', 65)),
#  (157, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median', 65)),
#  (158, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std', 65)),
#  (159, ('bureau_DAYS_ENDDATE_FACT_min', 65)),
#  (160, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 65)),
#  (161, ('REGION_RATING_CLIENT_W_CITY', 64)),
#  (162, ('count_prev_mean', 64)),
#  (163, ('bureau_DAYS_CREDIT_std', 64)),
#  (164, ('FLAG_DOCUMENT_3', 63)),
#  (165, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 63)),
#  (166, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 63)),
#  (167, ('bureau_DAYS_CREDIT_UPDATE_mean', 63)),
#  (168, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 62)),
#  (169, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 62)),
#  (170, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max', 62)),
#  (171, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 62)),
#  (172, ('count_prev_sum', 62)),
#  (173, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median', 62)),
#  (174, ('bureau_DAYS_CREDIT_ENDDATE_std', 62)),
#  (175, ('livingsum_AVG_divide_members', 61)),
#  (176, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_mean', 61)),
#  (177, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_min', 61)),
#  (178, ('bureau_DAYS_CREDIT_UPDATE_std', 61)),
#  (179, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 60)),
#  (180, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 60)),
#  (181, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 60)),
#  (182, ('possible_future_install_mean', 60)),
#  (183, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_max', 60)),
#  (184,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_std',
#    60)),
#  (185, ('install_DAYS_INSTALMENT_min', 60)),
#  (186, ('install_AMT_INSTALMENT_median', 60)),
#  (187,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_min',
#    60)),
#  (188, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 60)),
#  (189, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std', 60)),
#  (190, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean', 60)),
#  (191, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std', 60)),
#  (192, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min', 60)),
#  (193, ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR', 59)),
#  (194, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 59)),
#  (195, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 58)),
#  (196,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    58)),
#  (197, ('install_DAYS_INSTALMENT_median', 58)),
#  (198, ('bureau_DAYS_ENDDATE_FACT_median', 58)),
#  (199, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_mean', 58)),
#  (200, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 58)),
#  (201, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median', 58)),
#  (202, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 57)),
#  (203, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 57)),
#  (204, ('install_DAYS_ENTRY_PAYMENT_median', 57)),
#  (205, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 57)),
#  (206, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std', 57)),
#  (207, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 56)),
#  (208,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR', 56)),
#  (209, ('install_DAYS_ENTRY_PAYMENT_min', 56)),
#  (210, ('install_DAYS_INSTALMENT_sum', 56)),
#  (211, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean', 56)),
#  (212, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 55)),
#  (213, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 55)),
#  (214, ('prev_onehot_NAME_CLIENT_TYPE_Refreshed_divide_count_SK_ID_CURR', 55)),
#  (215, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_max', 55)),
#  (216, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 55)),
#  (217, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median', 55)),
#  (218, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_std', 55)),
#  (219, ('install_AMT_INSTALMENT_sum', 55)),
#  (220,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    55)),
#  (221, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum', 55)),
#  (222, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median', 55)),
#  (223, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_std', 55)),
#  (224, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 54)),
#  (225, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE', 54)),
#  (226, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean', 54)),
#  (227, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max', 54)),
#  (228, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max', 54)),
#  (229, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean', 54)),
#  (230,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    53)),
#  (231, ('prev_AMT_ANNUITY_min', 53)),
#  (232, ('install_AMT_PAYMENT_max', 53)),
#  (233,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    53)),
#  (234, ('bureau_AMT_CREDIT_SUM_mean', 53)),
#  (235, ('bureau_AMT_CREDIT_SUM_median', 53)),
#  (236, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std', 53)),
#  (237, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 52)),
#  (238,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    52)),
#  (239, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 52)),
#  (240, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_max', 52)),
#  (241, ('prev_HOUR_APPR_PROCESS_START_median', 52)),
#  (242, ('install_AMT_PAYMENT_std', 52)),
#  (243, ('bureau_DAYS_CREDIT_UPDATE_min', 52)),
#  (244, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum', 52)),
#  (245, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 52)),
#  (246, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 51)),
#  (247, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max', 51)),
#  (248, ('prev_DAYS_DECISION_mean', 51)),
#  (249, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 51)),
#  (250, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 51)),
#  (251, ('bureau_DAYS_CREDIT_sum', 51)),
#  (252, ('bureau_DAYS_CREDIT_UPDATE_sum', 51)),
#  (253, ('bureau_AMT_CREDIT_SUM_std', 51)),
#  (254, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std', 51)),
#  (255, ('TOTALAREA_MODE', 50)),
#  (256, ('livingsum_MEDI_divide_members', 50)),
#  (257, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 50)),
#  (258, ('AMT_ANNUITY_divide_OWN_CAR_AGE', 50)),
#  (259, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 50)),
#  (260,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    50)),
#  (261, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 50)),
#  (262, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min', 50)),
#  (263, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 50)),
#  (264,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    50)),
#  (265, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std', 50)),
#  (266, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_max', 50)),
#  (267, ('AMT_INCOME_TOTAL', 49)),
#  (268, ('AMT_INCOME_TOTAL_divide_DAYS_LAST_PHONE_CHANGE', 49)),
#  (269, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 49)),
#  (270,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    49)),
#  (271,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    49)),
#  (272, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_min', 49)),
#  (273, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_min', 49)),
#  (274, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 49)),
#  (275, ('prev_HOUR_APPR_PROCESS_START_max', 49)),
#  (276, ('SK_DPD_DEF_std', 49)),
#  (277, ('count_prev_max', 49)),
#  (278, ('install_count_SK_ID_CURR', 49)),
#  (279, ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 49)),
#  (280, ('bureau_onehot_CREDIT_TYPE_Microloan', 49)),
#  (281, ('REGION_RATING_CLIENT_times_livingsum_AVG', 48)),
#  (282,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 48)),
#  (283, ('prev_CNT_PAYMENT_max', 48)),
#  (284, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max', 48)),
#  (285,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    48)),
#  (286,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    48)),
#  (287,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    48)),
#  (288, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 48)),
#  (289, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 48)),
#  (290, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median', 48)),
#  (291, ('LIVINGAREA_MEDI', 47)),
#  (292, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 47)),
#  (293, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 47)),
#  (294, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median', 47)),
#  (295, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_min', 47)),
#  (296, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 47)),
#  (297, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 47)),
#  (298, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max', 47)),
#  (299, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean', 47)),
#  (300, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean', 47)),
#  (301, ('REG_CITY_NOT_LIVE_CITY', 46)),
#  (302, ('AMT_CREDIT_divide_OWN_CAR_AGE', 46)),
#  (303, ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR', 46)),
#  (304, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min', 46)),
#  (305, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_mean', 46)),
#  (306, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 46)),
#  (307, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std', 46)),
#  (308, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 46)),
#  (309, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum', 46)),
#  (310, ('prev_onehot_NAME_YIELD_GROUP_2.0', 45)),
#  (311, ('prev_onehot_CODE_REJECT_REASON_SCO_divide_count_SK_ID_CURR', 45)),
#  (312,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    45)),
#  (313, ('prev_onehot_NAME_YIELD_GROUP_0.0_divide_count_SK_ID_CURR', 45)),
#  (314, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 45)),
#  (315, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 45)),
#  (316, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 45)),
#  (317, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min', 45)),
#  (318, ('prev_DAYS_DECISION_median', 45)),
#  (319, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 45)),
#  (320, ('prev_DAYS_FIRST_DUE_max', 45)),
#  (321, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_max', 45)),
#  (322, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 45)),
#  (323, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 45)),
#  (324, ('creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_mean', 45)),
#  (325, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_mean', 45)),
#  (326, ('bureau_DAYS_ENDDATE_FACT_sum', 45)),
#  (327, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_mean', 45)),
#  (328, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_sum', 45)),
#  (329, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_std', 45)),
#  (330, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 44)),
#  (331, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_MON', 44)),
#  (332, ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 44)),
#  (333,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Canceled_divide_count_SK_ID_CURR', 44)),
#  (334,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 44)),
#  (335, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 44)),
#  (336, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 44)),
#  (337,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    44)),
#  (338,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    44)),
#  (339,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    44)),
#  (340, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 44)),
#  (341,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    44)),
#  (342,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    44)),
#  (343,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_median',
#    44)),
#  (344, ('bureau_AMT_CREDIT_SUM_max', 44)),
#  (345, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min', 44)),
#  (346, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_median', 44)),
#  (347, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 43)),
#  (348, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 43)),
#  (349, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 43)),
#  (350, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_sum', 43)),
#  (351, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 43)),
#  (352, ('prev_AMT_ANNUITY_mean', 43)),
#  (353, ('prev_DAYS_LAST_DUE_1ST_VERSION_sum', 43)),
#  (354, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_min', 43)),
#  (355, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 43)),
#  (356, ('prev_AMT_CREDIT_divide_DAYS_DECISION_median', 43)),
#  (357, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 43)),
#  (358, ('CNT_INSTALMENT_FUTURE_sum', 43)),
#  (359,
#   ('install_positivecount_SK_ID_CURR_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    43)),
#  (360, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 43)),
#  (361, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 43)),
#  (362, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_median', 43)),
#  (363, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean', 43)),
#  (364,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    42)),
#  (365,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    42)),
#  (366, ('prev_DAYS_DECISION_sum', 42)),
#  (367, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 42)),
#  (368,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    42)),
#  (369, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_median', 42)),
#  (370, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_min', 42)),
#  (371, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_max', 42)),
#  (372, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_max', 42)),
#  (373,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    42)),
#  (374, ('SK_DPD_DEF_mean', 42)),
#  (375, ('install_DAYS_ENTRY_PAYMENT_mean', 42)),
#  (376, ('install_AMT_INSTALMENT_max', 42)),
#  (377,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_median',
#    42)),
#  (378, ('bureau_AMT_CREDIT_SUM_sum', 42)),
#  (379, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 42)),
#  (380, ('bureau_DAYS_CREDIT_ENDDATE_min', 42)),
#  (381, ('NAME_HOUSING_TYPE', 41)),
#  (382,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR', 41)),
#  (383, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median', 41)),
#  (384, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 41)),
#  (385, ('prev_AMT_CREDIT_mean', 41)),
#  (386, ('prev_AMT_CREDIT_median', 41)),
#  (387, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_median', 41)),
#  (388,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median',
#    41)),
#  (389, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean', 41)),
#  (390, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 40)),
#  (391, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median', 40)),
#  (392,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    40)),
#  (393, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median', 40)),
#  (394, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_max', 40)),
#  (395, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean', 40)),
#  (396, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 40)),
#  (397, ('prev_DAYS_FIRST_DUE_median', 40)),
#  (398, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_sum', 40)),
#  (399,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 40)),
#  (400, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 40)),
#  (401, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 40)),
#  (402,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 40)),
#  (403, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 40)),
#  (404, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 40)),
#  (405, ('positivecount_SK_ID_CURR_SK_ID_PREV_SK_DPD_DEF_mean', 40)),
#  (406, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean', 40)),
#  (407, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max', 40)),
#  (408, ('bureau_onehot_STATUS_0_std', 40)),
#  (409, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OWN_CAR_AGE', 39)),
#  (410, ('prev_onehot_NAME_PAYMENT_TYPE_XNA_divide_count_SK_ID_CURR', 39)),
#  (411, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 39)),
#  (412, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_median', 39)),
#  (413, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 39)),
#  (414, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 39)),
#  (415,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    39)),
#  (416,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    39)),
#  (417, ('prev_AMT_GOODS_PRICE_min', 39)),
#  (418, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_max', 39)),
#  (419, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_mean', 39)),
#  (420, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_mean', 39)),
#  (421, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_min', 39)),
#  (422, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_max', 39)),
#  (423, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_mean', 39)),
#  (424,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 39)),
#  (425, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_sum', 39)),
#  (426, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_mean', 39)),
#  (427, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 39)),
#  (428, ('CNT_INSTALMENT_mean', 39)),
#  (429, ('CNT_INSTALMENT_FUTURE_max', 39)),
#  (430, ('creditcard_CNT_DRAWINGS_CURRENT_mean', 39)),
#  (431,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_std', 39)),
#  (432,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    39)),
#  (433, ('install_DAYS_INSTALMENT_mean', 39)),
#  (434, ('install_AMT_INSTALMENT_mean', 39)),
#  (435, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 39)),
#  (436, ('YEARS_BEGINEXPLUATATION_MEDI', 38)),
#  (437, ('livingsum_MODE_divide_members', 38)),
#  (438, ('prev_RATE_DOWN_PAYMENT_max', 38)),
#  (439,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    38)),
#  (440, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 38)),
#  (441,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    38)),
#  (442, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_median', 38)),
#  (443,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    38)),
#  (444,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 38)),
#  (445,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 38)),
#  (446, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_min', 38)),
#  (447, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 38)),
#  (448, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 38)),
#  (449, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_median', 38)),
#  (450, ('bureau_AMT_CREDIT_SUM_DEBT_max', 38)),
#  (451, ('bureau_AMT_CREDIT_SUM_DEBT_std', 38)),
#  (452, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_min', 38)),
#  (453, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_std', 38)),
#  (454, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_mean', 38)),
#  (455, ('bureau_onehot_STATUS_1_std', 38)),
#  (456, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_median', 38)),
#  (457, ('APARTMENTS_AVG', 37)),
#  (458, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 37)),
#  (459, ('prev_DAYS_TERMINATION_min', 37)),
#  (460, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 37)),
#  (461,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    37)),
#  (462, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_min', 37)),
#  (463, ('prev_AMT_GOODS_PRICE_median', 37)),
#  (464, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_min', 37)),
#  (465, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 37)),
#  (466, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_mean', 37)),
#  (467,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 37)),
#  (468, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 37)),
#  (469, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 37)),
#  (470, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_min', 37)),
#  (471, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_mean', 37)),
#  (472, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_min', 37)),
#  (473, ('FLAG_DOCUMENT_18', 36)),
#  (474, ('AMT_INCOME_TOTAL_divide_OBS_30_CNT_SOCIAL_CIRCLE', 36)),
#  (475, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 36)),
#  (476, ('prev_onehot_CHANNEL_TYPE_Country-wide_divide_count_SK_ID_CURR', 36)),
#  (477,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_0.0_divide_count_SK_ID_CURR', 36)),
#  (478, ('prev_onehot_NAME_YIELD_GROUP_3.0_divide_count_SK_ID_CURR', 36)),
#  (479,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 36)),
#  (480, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 36)),
#  (481, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_min', 36)),
#  (482,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    36)),
#  (483, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_max', 36)),
#  (484, ('prev_DAYS_DECISION_min', 36)),
#  (485,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    36)),
#  (486, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 36)),
#  (487,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    36)),
#  (488,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    36)),
#  (489,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 36)),
#  (490, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 36)),
#  (491, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 36)),
#  (492, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_sum', 36)),
#  (493, ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median', 36)),
#  (494, ('bureau_onehot_CREDIT_TYPE_Mortgage', 36)),
#  (495, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min', 36)),
#  (496, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_mean', 36)),
#  (497, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_median', 36)),
#  (498, ('bureau_MONTHS_BALANCE_std_median', 36)),
#  (499, ('YEARS_BEGINEXPLUATATION_MODE', 35)),
#  (500, ('livingsum_MEDI', 35)),
#  (501, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 35)),
#  (502,
#   ('prev_onehot_NAME_PAYMENT_TYPE_Cash_through_the_bank_divide_count_SK_ID_CURR',
#    35)),
#  (503,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_1.0_divide_count_SK_ID_CURR', 35)),
#  (504, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 35)),
#  (505,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    35)),
#  (506, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_median', 35)),
#  (507, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 35)),
#  (508,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    35)),
#  (509, ('prev_AMT_GOODS_PRICE_mean', 35)),
#  (510, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_median', 35)),
#  (511, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_min', 35)),
#  (512,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    35)),
#  (513,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    35)),
#  (514,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    35)),
#  (515,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    35)),
#  (516,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    35)),
#  (517, ('prev_DAYS_FIRST_DUE_mean', 35)),
#  (518, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum', 35)),
#  (519, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_median', 35)),
#  (520,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 35)),
#  (521, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_median', 35)),
#  (522, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_sum', 35)),
#  (523, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_sum', 35)),
#  (524, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 35)),
#  (525, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_mean', 35)),
#  (526, ('CNT_INSTALMENT_sum', 35)),
#  (527,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_std', 35)),
#  (528, ('install_AMT_PAYMENT_mean', 35)),
#  (529, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 35)),
#  (530, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 35)),
#  (531, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_sum', 35)),
#  (532, ('bureau_AMT_CREDIT_SUM_min', 35)),
#  (533, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_UPDATE_std', 35)),
#  (534, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_max', 35)),
#  (535, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_min', 35)),
#  (536, ('REGION_RATING_CLIENT', 34)),
#  (537, ('APARTMENTS_MODE', 34)),
#  (538, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 34)),
#  (539, ('prev_onehot_NAME_PORTFOLIO_POS_divide_count_SK_ID_CURR', 34)),
#  (540, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_max', 34)),
#  (541,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    34)),
#  (542, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_max', 34)),
#  (543, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median', 34)),
#  (544,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 34)),
#  (545,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    34)),
#  (546,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    34)),
#  (547, ('prev_DAYS_FIRST_DUE_min', 34)),
#  (548,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    34)),
#  (549, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_median', 34)),
#  (550,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 34)),
#  (551, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_max', 34)),
#  (552, ('SK_DPD_DEF_mean_sum', 34)),
#  (553,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_mean', 34)),
#  (554, ('bureau_MONTHS_BALANCE_sum_sum', 34)),
#  (555, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum', 34)),
#  (556, ('APARTMENTS_MEDI', 33)),
#  (557, ('livingsum_AVG', 33)),
#  (558, ('prev_onehot_NAME_CLIENT_TYPE_New_divide_count_SK_ID_CURR', 33)),
#  (559,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Consumer_electronics_divide_count_SK_ID_CURR',
#    33)),
#  (560,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 33)),
#  (561, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_max', 33)),
#  (562,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 33)),
#  (563, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_min', 33)),
#  (564, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_median', 33)),
#  (565, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_mean', 33)),
#  (566, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 33)),
#  (567, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 33)),
#  (568, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 33)),
#  (569, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_median', 33)),
#  (570,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    33)),
#  (571,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    33)),
#  (572, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_sum', 33)),
#  (573,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    33)),
#  (574, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_median', 33)),
#  (575, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 33)),
#  (576, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_max', 33)),
#  (577, ('prev_AMT_APPLICATION_median', 33)),
#  (578, ('prev_AMT_APPLICATION_sum', 33)),
#  (579,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    33)),
#  (580,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 33)),
#  (581, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 33)),
#  (582, ('prev_HOUR_APPR_PROCESS_START_min', 33)),
#  (583, ('prev_HOUR_APPR_PROCESS_START_sum', 33)),
#  (584, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max', 33)),
#  (585, ('WEEKDAY_APPR_PROCESS_START', 32)),
#  (586, ('HOUR_APPR_PROCESS_START', 32)),
#  (587, ('AMT_CREDIT_divide_OBS_60_CNT_SOCIAL_CIRCLE', 32)),
#  (588, ('AMT_ANNUITY_divide_DEF_30_CNT_SOCIAL_CIRCLE', 32)),
#  (589, ('AMT_ANNUITY_divide_OBS_60_CNT_SOCIAL_CIRCLE', 32)),
#  (590, ('AMT_REQ_CREDIT_BUREAU_MON_divide_DAYS_REGISTRATION', 32)),
#  (591,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 32)),
#  (592, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_sum', 32)),
#  (593, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 32)),
#  (594, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_mean', 32)),
#  (595, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 32)),
#  (596, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_mean', 32)),
#  (597, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_median', 32)),
#  (598,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    32)),
#  (599, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_mean', 32)),
#  (600, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_mean', 32)),
#  (601, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 32)),
#  (602, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_max', 32)),
#  (603, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median', 32)),
#  (604, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_mean', 32)),
#  (605, ('prev_DAYS_LAST_DUE_min', 32)),
#  (606,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 32)),
#  (607,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    32)),
#  (608,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    32)),
#  (609, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_mean', 32)),
#  (610,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median',
#    32)),
#  (611, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_std', 32)),
#  (612,
#   ('bureau_onehot_CREDIT_TYPE_Credit_card_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    32)),
#  (613, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_sum', 32)),
#  (614, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_median', 32)),
#  (615, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_max', 32)),
#  (616, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max', 32)),
#  (617, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 31)),
#  (618,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Furniture_divide_count_SK_ID_CURR', 31)),
#  (619, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 31)),
#  (620, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_median', 31)),
#  (621, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_sum', 31)),
#  (622, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_mean', 31)),
#  (623,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    31)),
#  (624, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_median', 31)),
#  (625,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    31)),
#  (626,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    31)),
#  (627, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_mean', 31)),
#  (628,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    31)),
#  (629,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    31)),
#  (630,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    31)),
#  (631, ('prev_DAYS_FIRST_DUE_sum', 31)),
#  (632,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 31)),
#  (633, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_mean', 31)),
#  (634,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    31)),
#  (635, ('prev_AMT_APPLICATION_mean', 31)),
#  (636,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    31)),
#  (637,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    31)),
#  (638,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    31)),
#  (639, ('CNT_INSTALMENT_max', 31)),
#  (640,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median', 31)),
#  (641, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_std', 31)),
#  (642, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_max', 31)),
#  (643, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum', 31)),
#  (644, ('YEARS_BEGINEXPLUATATION_AVG', 30)),
#  (645, ('AMT_GOODS_PRICE_divide_CNT_CHILDREN', 30)),
#  (646, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_ID_PUBLISH', 30)),
#  (647, ('prev_onehot_NAME_SELLER_INDUSTRY_XNA_divide_count_SK_ID_CURR', 30)),
#  (648, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 30)),
#  (649, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_median', 30)),
#  (650, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_sum', 30)),
#  (651, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min', 30)),
#  (652, ('prev_RATE_DOWN_PAYMENT_mean', 30)),
#  (653,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    30)),
#  (654, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 30)),
#  (655, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 30)),
#  (656,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    30)),
#  (657,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    30)),
#  (658, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_mean', 30)),
#  (659,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    30)),
#  (660, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_std', 30)),
#  (661, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_sum', 30)),
#  (662, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_mean', 30)),
#  (663, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_median', 30)),
#  (664, ('bureau_onehot_STATUS_0_mean', 30)),
#  (665,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_2.0_divide_count_SK_ID_CURR', 29)),
#  (666,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 29)),
#  (667, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 29)),
#  (668, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_mean', 29)),
#  (669, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_max', 29)),
#  (670,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    29)),
#  (671, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median', 29)),
#  (672,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 29)),
#  (673,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    29)),
#  (674,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    29)),
#  (675,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 29)),
#  (676,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 29)),
#  (677, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 29)),
#  (678,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    29)),
#  (679,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    29)),
#  (680,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    29)),
#  (681,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    29)),
#  (682, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max', 29)),
#  (683,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    29)),
#  (684,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 29)),
#  (685, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_min', 29)),
#  (686,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    29)),
#  (687, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_max', 29)),
#  (688, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_median', 29)),
#  (689, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 29)),
#  (690, ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median', 29)),
#  (691,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_median', 29)),
#  (692, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_median', 29)),
#  (693, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_median', 29)),
#  (694, ('bureau_AMT_CREDIT_MAX_OVERDUE_mean', 29)),
#  (695, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_std', 29)),
#  (696, ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_ENDDATE_min', 29)),
#  (697, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_max', 29)),
#  (698, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_std', 29)),
#  (699, ('livingsum_MODE', 28)),
#  (700, ('OBS_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 28)),
#  (701, ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 28)),
#  (702, ('AMT_ANNUITY_divide_DEF_60_CNT_SOCIAL_CIRCLE', 28)),
#  (703, ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR', 28)),
#  (704, ('prev_CNT_PAYMENT_sum', 28)),
#  (705, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_mean', 28)),
#  (706,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    28)),
#  (707, ('prev_DAYS_TERMINATION_median', 28)),
#  (708,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    28)),
#  (709,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    28)),
#  (710,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    28)),
#  (711, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_min', 28)),
#  (712, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 28)),
#  (713,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    28)),
#  (714, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_sum', 28)),
#  (715,
# ...
#    26)),
#  (776, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_min', 26)),
#  (777,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 26)),
#  (778,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    26)),
#  (779, ('prev_AMT_DOWN_PAYMENT_sum', 26)),
#  (780,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    26)),
#  (781, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_sum', 26)),
#  (782,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 26)),
#  (783,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    26)),
#  (784, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_median', 26)),
#  (785, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_max', 26)),
#  (786,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    26)),
#  (787,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 26)),
#  (788,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    26)),
#  (789, ('creditcard_CNT_DRAWINGS_POS_CURRENT_mean', 26)),
#  (790,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    26)),
#  (791, ('bureau_MONTHS_BALANCE_median_median', 26)),
#  (792, ('bureau_MONTHS_BALANCE_mean_median', 26)),
#  (793, ('bureau_onehot_STATUS_X_mean', 26)),
#  (794, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_max', 26)),
#  (795, ('LIVINGAREA_AVG', 25)),
#  (796, ('BASEMENTAREA_MEDI', 25)),
#  (797, ('LANDAREA_MEDI', 25)),
#  (798, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 25)),
#  (799, ('prev_onehot_CHANNEL_TYPE_Stone_divide_count_SK_ID_CURR', 25)),
#  (800, ('prev_CNT_PAYMENT_median', 25)),
#  (801, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_median', 25)),
#  (802, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_sum', 25)),
#  (803, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_min', 25)),
#  (804,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    25)),
#  (805,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    25)),
#  (806, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_min', 25)),
#  (807,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    25)),
#  (808, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_min', 25)),
#  (809, ('prev_AMT_DOWN_PAYMENT_median', 25)),
#  (810,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    25)),
#  (811,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    25)),
#  (812,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    25)),
#  (813, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_median', 25)),
#  (814, ('prev_AMT_ANNUITY_median', 25)),
#  (815, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_max', 25)),
#  (816,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    25)),
#  (817, ('prev_DAYS_LAST_DUE_1ST_VERSION_min', 25)),
#  (818,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    25)),
#  (819,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    25)),
#  (820,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    25)),
#  (821,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median',
#    25)),
#  (822,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_sum', 25)),
#  (823,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median', 25)),
#  (824, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean', 25)),
#  (825, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_std', 25)),
#  (826, ('bureau_MONTHS_BALANCE_max_mean', 25)),
#  (827, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_min', 25)),
#  (828, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_std', 25)),
#  (829, ('bureau_MONTHS_BALANCE_min_mean', 25)),
#  (830, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_max', 25)),
#  (831, ('bureau_MONTHS_BALANCE_std_max', 25)),
#  (832, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_median', 25)),
#  (833, ('bureau_AMT_ANNUITY_std', 25)),
#  (834,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_median', 25)),
#  (835, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_max', 25)),
#  (836, ('AMT_INCOME_TOTAL_divide_CNT_CHILDREN', 24)),
#  (837, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_LAST_PHONE_CHANGE', 24)),
#  (838,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_1.0_divide_count_SK_ID_CURR', 24)),
#  (839, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_sum', 24)),
#  (840,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    24)),
#  (841, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 24)),
#  (842, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 24)),
#  (843,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    24)),
#  (844, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min', 24)),
#  (845, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 24)),
#  (846, ('prev_AMT_GOODS_PRICE_sum', 24)),
#  (847, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 24)),
#  (848,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 24)),
#  (849,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    24)),
#  (850, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_mean', 24)),
#  (851, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_median', 24)),
#  (852,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    24)),
#  (853, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max', 24)),
#  (854,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 24)),
#  (855,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    24)),
#  (856, ('prev_AMT_ANNUITY_max', 24)),
#  (857, ('prev_DAYS_LAST_DUE_sum', 24)),
#  (858, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_mean', 24)),
#  (859,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum',
#    24)),
#  (860, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_sum', 24)),
#  (861, ('prev_DAYS_LAST_DUE_1ST_VERSION_max', 24)),
#  (862,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    24)),
#  (863,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    24)),
#  (864, ('prev_AMT_CREDIT_divide_DAYS_DECISION_max', 24)),
#  (865, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_max', 24)),
#  (866, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_sum', 24)),
#  (867, ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean', 24)),
#  (868, ('bureau_count_SK_ID_CURR', 24)),
#  (869,
#   ('bureau_onehot_CREDIT_TYPE_Consumer_credit_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    24)),
#  (870, ('bureau_onehot_STATUS_C_max', 24)),
#  (871, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_std', 24)),
#  (872,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_max', 24)),
#  (873,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_std', 24)),
#  (874, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean', 24)),
#  (875, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_sum', 24)),
#  (876, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_mean', 24)),
#  (877, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_std', 24)),
#  (878, ('BASEMENTAREA_MODE', 23)),
#  (879, ('LIVINGAPARTMENTS_MEDI', 23)),
#  (880, ('OBS_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 23)),
#  (881, ('CONTACT', 23)),
#  (882, ('AMT_INCOME_TOTAL_divide_OBS_60_CNT_SOCIAL_CIRCLE', 23)),
#  (883, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_CNT_FAM_MEMBERS', 23)),
#  (884, ('prev_onehot_CODE_REJECT_REASON_SCOFR', 23)),
#  (885, ('prev_onehot_NAME_YIELD_GROUP_1.0', 23)),
#  (886, ('prev_onehot_CODE_REJECT_REASON_VERIF_divide_count_SK_ID_CURR', 23)),
#  (887,
#   ('prev_onehot_CHANNEL_TYPE_Contact_center_divide_count_SK_ID_CURR', 23)),
#  (888, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_max', 23)),
#  (889, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_sum', 23)),
#  (890, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_max', 23)),
#  (891, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean', 23)),
#  (892,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    23)),
#  (893, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_mean', 23)),
#  (894, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_sum', 23)),
#  (895,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    23)),
#  (896, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_median', 23)),
#  (897, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_max', 23)),
#  (898,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    23)),
#  (899,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    23)),
#  (900,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    23)),
#  (901, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_median', 23)),
#  (902,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 23)),
#  (903, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_sum', 23)),
#  (904, ('SK_DPD_DEF_min_max', 23)),
#  (905, ('unique_cnt_install_std', 23)),
#  (906, ('creditcard_CNT_DRAWINGS_POS_CURRENT_std', 23)),
#  (907, ('bureau_MONTHS_BALANCE_median_max', 23)),
#  (908, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_min', 23)),
#  (909, ('bureau_MONTHS_BALANCE_std_sum', 23)),
#  (910, ('REGION_RATING_CLIENT_times_livingsum_MEDI', 22)),
#  (911, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 22)),
#  (912, ('OBS_60_CNT_SOCIAL_CIRCLE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 22)),
#  (913, ('AMT_CREDIT_divide_OBS_30_CNT_SOCIAL_CIRCLE', 22)),
#  (914, ('AMT_ANNUITY_divide_OBS_30_CNT_SOCIAL_CIRCLE', 22)),
#  (915, ('AMT_GOODS_PRICE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 22)),
#  (916, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_BIRTH', 22)),
#  (917,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_0.0_divide_count_SK_ID_CURR', 22)),
#  (918,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 22)),
#  (919,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    22)),
#  (920,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    22)),
#  (921, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_max', 22)),
#  (922, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_mean', 22)),
#  (923, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_max', 22)),
#  (924,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    22)),
#  (925, ('prev_RATE_DOWN_PAYMENT_sum', 22)),
#  (926,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    22)),
#  (927, ('prev_AMT_CREDIT_sum', 22)),
#  (928, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_mean', 22)),
#  (929, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 22)),
#  (930, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 22)),
#  (931, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_median', 22)),
#  (932, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_sum', 22)),
#  (933,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    22)),
#  (934,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    22)),
#  (935, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean', 22)),
#  (936,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    22)),
#  (937,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    22)),
#  (938, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_max', 22)),
#  (939, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_mean', 22)),
#  (940,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    22)),
#  (941, ('diff_sum_sum', 22)),
#  (942, ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_mean', 22)),
#  (943,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_mean', 22)),
#  (944, ('creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_std', 22)),
#  (945,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_ATM_CURRENT_mean',
#    22)),
#  (946,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_CURRENT_median', 22)),
#  (947, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean', 22)),
#  (948, ('bureau_AMT_CREDIT_SUM_DEBT_median', 22)),
#  (949, ('bureau_MONTHS_BALANCE_median_mean', 22)),
#  (950, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_max', 22)),
#  (951, ('bureau_MONTHS_BALANCE_min_std', 22)),
#  (952, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_median', 22)),
#  (953, ('bureau_MONTHS_BALANCE_std_mean', 22)),
#  (954, ('bureau_MONTHS_BALANCE_std_std', 22)),
#  (955, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max', 22)),
#  (956, ('bureau_AMT_ANNUITY_divide_CREDIT_DAY_OVERDUE_std', 22)),
#  (957, ('YEARS_BUILD_AVG', 21)),
#  (958, ('REGION_RATING_CLIENT_times_livingsum_MODE', 21)),
#  (959, ('AMT_CREDIT_divide_CNT_CHILDREN', 21)),
#  (960, ('AMT_CREDIT_divide_DEF_60_CNT_SOCIAL_CIRCLE', 21)),
#  (961, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_REGISTRATION', 21)),
#  (962, ('OWN_CAR_AGE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 21)),
#  (963, ('OWN_CAR_AGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 21)),
#  (964, ('prev_onehot_CODE_REJECT_REASON_HC', 21)),
#  (965,
#   ('prev_onehot_NAME_CONTRACT_TYPE_Consumer_loans_divide_count_SK_ID_CURR',
#    21)),
#  (966, ('prev_onehot_NAME_PRODUCT_TYPE_x-sell_divide_count_SK_ID_CURR', 21)),
#  (967, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_median', 21)),
#  (968, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_max', 21)),
#  (969, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_sum', 21)),
#  (970,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    21)),
#  (971, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_sum', 21)),
#  (972,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    21)),
#  (973,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    21)),
#  (974, ('prev_WEEKDAY_APPR_PROCESS_START_sum', 21)),
#  (975, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max', 21)),
#  (976, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 21)),
#  (977, ('prev_RATE_DOWN_PAYMENT_median', 21)),
#  (978, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_median', 21)),
#  (979,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    21)),
#  (980,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    21)),
#  (981,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    21)),
#  (982, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_sum', 21)),
#  (983, ('prev_AMT_GOODS_PRICE_max', 21)),
#  (984, ('prev_AMT_CREDIT_max', 21)),
#  (985,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    21)),
#  (986, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_sum', 21)),
#  (987, ('prev_AMT_DOWN_PAYMENT_max', 21)),
#  (988, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_max', 21)),
#  (989,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    21)),
#  (990,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    21)),
#  (991, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_sum', 21)),
#  (992,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    21)),
#  (993, ('SK_DPD_std', 21)),
#  (994, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_mean', 21)),
#  (995,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean', 21)),
#  (996,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_mean',
#    21)),
#  (997,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    21)),
#  (998,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_median', 21)),
#  (999, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_mean', 21)),
#  ...]
