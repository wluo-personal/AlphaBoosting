# %%
import os
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
PATH = '/home/kai/data/kaggle/homecredit/'

# %%
train = pd.read_pickle(PATH + 'test/train_ori.pkl')
test = pd.read_pickle(PATH + 'test/test_ori.pkl')
# train = pd.read_pickle(PATH + 'test/train_w_prev_2.pkl')
# test = pd.read_pickle(PATH + 'test/test_w_prev_2.pkl')

print(train.shape,test.shape)
train.shape, test.shape
prev = pd.read_pickle(PATH + 'test/prev2curr_0.pkl')
print(prev.shape)
pos = pd.read_pickle(PATH + 'inter/poscash2curr.pkl')
print(pos.shape)
cred = pd.read_pickle(PATH + 'inter/credit2curr.pkl')
print(cred.shape)
install = pd.read_pickle(PATH + 'test/install2curr.pkl')
print(install.shape)
bureau = pd.read_pickle(PATH + 'inter/bureau2curr.pkl')
print(bureau.shape)
# Out:
# (307511, 329) (48744, 328)
# (356255, 818)
# (356255, 116)
# (356255, 502)
# (356255, 13)
# (356255, 554)

# %%
# files = [prev,pos,cred,install,bureau]
# files = [prev,cred,install,bureau]
files = [prev,pos,install,bureau]
# files = [pos,cred,install,bureau]
for tmp in files:
#     cols = [col for col in tmp.columns if 'std' not in col]
#     tmp = tmp[cols]
#     print(tmp.shape)
    train = train.merge(tmp, on='SK_ID_CURR', how='left')
    test = test.merge(tmp, on='SK_ID_CURR', how='left')
    print(train.shape,test.shape)
# Out:
# (307511, 1146) (48744, 1145)
# (307511, 1261) (48744, 1260)
# (307511, 1273) (48744, 1272)
# (307511, 1826) (48744, 1825)

# %%
print(train.shape, test.shape)
# Out:
# (307511, 1826) (48744, 1825)

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
PATH = '/home/kai/data/kaggle/homecredit/'
print('begin cv')
target = train['TARGET']
test_df = test.copy()
ignore_cols = ['ORGANIZATION_TYPE', 'TARGET', 'SK_ID_CURR']
features = [x for x in train.columns if x not in ignore_cols]
train = train[features]
test = test[features]

from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm

lgbm_train = lgbm.Dataset(data=train,
                          label=target,

                          categorical_feature=[],#categorical_feats,
                          free_raw_data=False)

# lgbm_params = {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 
#           'learning_rate': 0.01, 'num_leaves': 48, 'num_iteration': 4000, 'verbose': 0 ,
#           'colsample_bytree':.8, 'subsample':.9, 'max_depth':7, 'reg_alpha':.1, 'reg_lambda':.1, 
#           'min_split_gain':.01, 'min_child_weight':1,'num_threads': 12,'feature_fraction': 0.2,
#               'scale_pos_weight':1}
lgbm_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'learning_rate': 0.05,
    'num_iteration': 4000,
    'num_threads': 8,

    'num_leaves': int(round(44.368535336628419)),
    'feature_fraction': 0.28231763168020257,
    'bagging_fraction': 0.94901525271474951,
    'max_depth': int(round(8.0430115561596267)),
    'lambda_l1': 0.30680079516647751,
    'lambda_l2': 0.079128660903201031,
    'min_split_gain': 0.054005067457890979,
    'min_child_weight': 98.172643147364937}


cv_results = lgbm.cv(train_set=lgbm_train,
                     params=lgbm_params,
                     nfold=5,
                     early_stopping_rounds=150,
                     verbose_eval=100,
                     metrics=['auc'])

optimum_boost_rounds = np.argmax(cv_results['auc-mean'])
print('Optimum boost rounds = {}'.format(optimum_boost_rounds))
print('Best CV result = {}'.format(np.max(cv_results['auc-mean'])))

clf = lgbm.train(train_set=lgbm_train,
                 params=lgbm_params,
                 num_boost_round=optimum_boost_rounds,
                verbose_eval=100)

""" Predict on test set and create submission """
y_pred = clf.predict(test)
out_df = pd.DataFrame({'SK_ID_CURR': test_df['SK_ID_CURR'], 'TARGET': y_pred})
#     small_len = out_df[out_df['TARGET']< threshold1]
#     large_len = out_df[out_df['TARGET']> threshold2]
#     print('length of small and large,',len(small_len),len(large_len))
print((out_df['TARGET']>0.5).sum(),'more than half')
# Out:
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.777842 + 0.00317354
# [200]	cv_agg's auc: 0.787348 + 0.00279641
# [300]	cv_agg's auc: 0.790192 + 0.00264448
# [400]	cv_agg's auc: 0.791166 + 0.0026351
# [500]	cv_agg's auc: 0.791533 + 0.00261128
# [600]	cv_agg's auc: 0.791456 + 0.00265955
# Optimum boost rounds = 525
# Best CV result = 0.7915621489169146
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# 209 more than half

# %% [markdown]
# baye paras/train with modified prev"
# ----------
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.780408 + 0.00290047
# [200]	cv_agg's auc: 0.789804 + 0.00263968
# [300]	cv_agg's auc: 0.792796 + 0.00252429
# [400]	cv_agg's auc: 0.79391 + 0.00252326
# [500]	cv_agg's auc: 0.794314 + 0.00242975
# [600]	cv_agg's auc: 0.794392 + 0.00237447
# [700]	cv_agg's auc: 0.794313 + 0.00234948
# Optimum boost rounds = 617
# Best CV result = 0.7944380747322322

# %% [markdown]
# without std bayes para, 7788 (train with prev)
# with std bayes para, 7789 (train without prev)

# %% [markdown]
# baseline bayes para, train only pre+:
#     [100]	cv_agg's auc: 0.780408 + 0.00290047
# [200]	cv_agg's auc: 0.789804 + 0.00263968
# [300]	cv_agg's auc: 0.792796 + 0.00252429

# %%
(out_df['TARGET']>0.5).sum()
out_df.to_csv(PATH+'submission/06_29_0.csv', index = False)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm
fig, (ax, ax1) = plt.subplots(1, 2, figsize=[15, 7])
lgbm.plot_importance(clf, ax=ax, max_num_features=30, importance_type='split')
lgbm.plot_importance(clf, ax=ax1, max_num_features=30, importance_type='gain')
ax.set_title('Importance by splits')
ax1.set_title('Importance by gain')
plt.tight_layout()
plt.show()

x = [x for x in zip(clf.feature_name(), clf.feature_importance('gain'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_2', 53499.19410824776)),
#  (1, ('EXT_SOURCE_3', 39017.76660704613)),
#  (2, ('EXT_SOURCE_1', 18916.186606645584)),
#  (3,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 8787.067180633545)),
#  (4, ('AMT_CREDIT_divide_AMT_ANNUITY', 8761.689419746399)),
#  (5, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 7706.609332084656)),
#  (6, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 5707.103170156479)),
#  (7, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 5458.056015968323)),
#  (8, ('DAYS_BIRTH', 4798.076858282089)),
#  (9, ('CODE_GENDER', 4624.598827838898)),
#  (10, ('NAME_EDUCATION_TYPE', 4234.880920410156)),
#  (11, ('bureau_DAYS_CREDIT_mean', 4096.211060523987)),
#  (12,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median',
#    4041.3598403930664)),
#  (13, ('bureau_DAYS_CREDIT_median', 4013.530813217163)),
#  (14,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR',
#    3940.977993965149)),
#  (15, ('LATE_DAYS_mean', 3712.1283860206604)),
#  (16, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 3601.5957973003387)),
#  (17, ('LATE_AMT_mean', 3593.2545957565308)),
#  (18, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 2579.331400871277)),
#  (19, ('LATE_AREA_sum', 2333.072006225586)),
#  (20,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    2191.942714691162)),
#  (21, ('EARLY_AMT_sum', 2137.921187400818)),
#  (22, ('AMT_GOODS_PRICE', 2130.316159725189)),
#  (23, ('AMT_ANNUITY', 2125.552966117859)),
#  (24, ('LATE_AMT_max', 2124.920593738556)),
#  (25, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 1993.7778730392456)),
#  (26, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 1889.96608543396)),
#  (27,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 1864.560331583023)),
#  (28,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    1699.3166089057922)),
#  (29, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_min', 1624.7900161743164)),
#  (30,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    1604.8580102920532)),
#  (31, ('EARLY_AREA_sum', 1584.6754531860352)),
#  (32,
#   ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR',
#    1521.6283922195435)),
#  (33,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_sum', 1482.2135016918182)),
#  (34,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR',
#    1474.1939182281494)),
#  (35, ('poscash_MONTHS_BALANCE_std', 1426.50834774971)),
#  (36, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 1418.5088171958923)),
#  (37, ('bureau_DAYS_CREDIT_max', 1410.2464442253113)),
#  (38, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 1375.7222290039062)),
#  (39, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 1316.7504897117615)),
#  (40,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std',
#    1301.0143473148346)),
#  (41,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Active_divide_positivecount_SK_ID_CURR_SK_DPD',
#    1276.4739875793457)),
#  (42, ('AMT_CREDIT_divide_DAYS_BIRTH', 1251.4318552017212)),
#  (43, ('LATE_AMT_sum', 1241.4528369903564)),
#  (44, ('DAYS_EMPLOYED', 1217.3431215286255)),
#  (45, ('bureau_onehot_CREDIT_ACTIVE_Active', 1204.7054929733276)),
#  (46, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 1197.491946697235)),
#  (47,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    1186.5818343162537)),
#  (48, ('NAME_FAMILY_STATUS', 1170.516348361969)),
#  (49,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min',
#    1122.3417205810547)),
#  (50, ('DAYS_ID_PUBLISH', 1115.026515007019)),
#  (51, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_std', 1100.2202591896057)),
#  (52, ('AMT_ANNUITY_divide_DAYS_BIRTH', 1090.666913986206)),
#  (53, ('poscash_CNT_INSTALMENT_FUTURE_std', 1084.0820055007935)),
#  (54,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean',
#    1066.0303783416748)),
#  (55,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum',
#    1064.661822795868)),
#  (56, ('prev_CNT_PAYMENT_max', 1049.80198097229)),
#  (57, ('prev_DAYS_DECISION_min', 1045.2791266441345)),
#  (58, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 1018.1806833744049)),
#  (59, ('NAME_INCOME_TYPE', 1017.299437046051)),
#  (60, ('bureau_DAYS_CREDIT_UPDATE_median', 1015.804386138916)),
#  (61, ('poscash_CNT_INSTALMENT_FUTURE_mean', 1004.6637215614319)),
#  (62, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 989.3690052032471)),
#  (63, ('FLAG_DOCUMENT_3', 958.801673412323)),
#  (64, ('bureau_DAYS_ENDDATE_FACT_max', 953.9974956512451)),
#  (65, ('REGION_POPULATION_RELATIVE', 946.5002191066742)),
#  (66, ('REGION_RATING_CLIENT_W_CITY', 941.4803261756897)),
#  (67, ('prev_CNT_PAYMENT_mean', 923.0492062568665)),
#  (68, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 906.7802143096924)),
#  (69, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 901.4736595153809)),
#  (70,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 900.0523600578308)),
#  (71,
#   ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR',
#    871.284040927887)),
#  (72,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 842.2928447723389)),
#  (73,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean',
#    840.0239191055298)),
#  (74,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 833.740053653717)),
#  (75, ('poscash_MONTHS_BALANCE_sum', 829.4363470077515)),
#  (76, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 827.229926109314)),
#  (77,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max', 821.7109799385071)),
#  (78,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 806.8154492378235)),
#  (79,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    806.0644035339355)),
#  (80, ('poscash_MONTHS_BALANCE_min', 781.4083762168884)),
#  (81,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    781.0811228752136)),
#  (82, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 780.3786106109619)),
#  (83, ('bureau_DAYS_CREDIT_ENDDATE_max', 777.3025603294373)),
#  (84, ('OCCUPATION_TYPE', 749.9142374992371)),
#  (85, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 737.1748027801514)),
#  (86, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_mean', 723.5294933319092)),
#  (87,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    722.625301361084)),
#  (88, ('EARLY_AMT_mean', 684.7217793464661)),
#  (89, ('OWN_CAR_AGE', 673.4524846076965)),
#  (90, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 655.4040222167969)),
#  (91, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 650.4574384689331)),
#  (92,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    641.9743700027466)),
#  (93,
#   ('prev_onehot_NAME_PRODUCT_TYPE_walk-in_divide_count_SK_ID_CURR',
#    637.884271144867)),
#  (94,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    634.2487163543701)),
#  (95, ('bureau_DAYS_CREDIT_ENDDATE_mean', 633.7317385673523)),
#  (96, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 616.3367991447449)),
#  (97, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 607.9859433174133)),
#  (98, ('prev_HOUR_APPR_PROCESS_START_mean', 606.7777876853943)),
#  (99, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 605.6771426200867)),
#  (100, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 605.2022953033447)),
#  (101, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 601.5553016662598)),
#  (102, ('DAYS_LAST_PHONE_CHANGE', 596.0211701393127)),
#  (103,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    594.5280466079712)),
#  (104, ('LATE_DAYS_max', 583.2730612754822)),
#  (105, ('AMT_CREDIT', 576.2935876846313)),
#  (106,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    572.6939249038696)),
#  (107,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min',
#    569.9281520843506)),
#  (108, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 564.1902976036072)),
#  (109, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 562.3984937667847)),
#  (110,
#   ('prev_onehot_NAME_CLIENT_TYPE_New_divide_count_SK_ID_CURR',
#    561.0464415550232)),
#  (111,
#   ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR',
#    554.8105792999268)),
#  (112, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 548.0905990600586)),
#  (113, ('bureau_DAYS_CREDIT_ENDDATE_median', 546.0988714694977)),
#  (114, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 545.9363307952881)),
#  (115, ('poscash_CNT_INSTALMENT_std', 545.3759107589722)),
#  (116, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 540.0007781982422)),
#  (117,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum',
#    539.6967906951904)),
#  (118,
#   ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR',
#    538.9331498146057)),
#  (119, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 531.6218686103821)),
#  (120,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min', 527.4328546524048)),
#  (121, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 525.5081300735474)),
#  (122,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean',
#    518.8888139724731)),
#  (123, ('bureau_onehot_CREDIT_TYPE_Microloan', 517.3146548271179)),
#  (124, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 516.1129503250122)),
#  (125, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 515.0169975757599)),
#  (126, ('prev_DAYS_DECISION_median', 505.15251111984253)),
#  (127, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 501.47704315185547)),
#  (128,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min',
#    496.70516777038574)),
#  (129,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std', 494.8610830307007)),
#  (130, ('prev_onehot_NAME_YIELD_GROUP_2.0', 494.20705461502075)),
#  (131,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    493.3187656402588)),
#  (132,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 493.17780017852783)),
#  (133,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max', 490.055299282074)),
#  (134, ('prev_DAYS_FIRST_DUE_min', 469.70229053497314)),
#  (135,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    469.0769371986389)),
#  (136, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 467.95694303512573)),
#  (137, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 467.6049633026123)),
#  (138, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 467.5850901603699)),
#  (139,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 464.57310342788696)),
#  (140,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    455.9006586074829)),
#  (141, ('REG_CITY_NOT_LIVE_CITY', 452.0303201675415)),
#  (142,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum',
#    442.74791049957275)),
#  (143,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median',
#    440.5066907405853)),
#  (144,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    436.09478855133057)),
#  (145, ('bureau_DAYS_CREDIT_ENDDATE_sum', 434.9162082672119)),
#  (146,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE',
#    434.8376998901367)),
#  (147, ('bureau_DAYS_CREDIT_ENDDATE_std', 434.80623149871826)),
#  (148, ('poscash_SK_DPD_divide_MONTHS_BALANCE_std', 433.46746730804443)),
#  (149,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    433.31846618652344)),
#  (150, ('DAYS_REGISTRATION', 433.1238102912903)),
#  (151, ('TOTALAREA_MODE', 431.3681392669678)),
#  (152,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    430.1047782897949)),
#  (153,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    428.7764005661011)),
#  (154, ('bureau_DAYS_ENDDATE_FACT_min', 427.31421756744385)),
#  (155,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    425.41639041900635)),
#  (156,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    424.9291706085205)),
#  (157,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR',
#    424.0264081954956)),
#  (158,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    422.9046993255615)),
#  (159,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    421.2131586074829)),
#  (160, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 419.64977979660034)),
#  (161, ('poscash_MONTHS_BALANCE_median', 413.4092767238617)),
#  (162,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    406.9372019767761)),
#  (163,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    404.50670623779297)),
#  (164, ('bureau_DAYS_CREDIT_UPDATE_mean', 403.45918369293213)),
#  (165,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median',
#    402.578485250473)),
#  (166, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 402.4306173324585)),
#  (167, ('poscash_count_SK_ID_CURR', 402.3971185684204)),
#  (168,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 394.8261308670044)),
#  (169,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 390.2278723716736)),
#  (170,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max',
#    387.7646894454956)),
#  (171,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    384.8778214454651)),
#  (172,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    384.848669052124)),
#  (173, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 383.2311096191406)),
#  (174, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 381.4026770591736)),
#  (175,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 379.21232748031616)),
#  (176,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean',
#    376.5079917907715)),
#  (177, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 373.4637508392334)),
#  (178, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 371.4372806549072)),
#  (179,
#   ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR',
#    368.15614223480225)),
#  (180,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 368.10256719589233)),
#  (181, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 367.95181226730347)),
#  (182,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    365.84478759765625)),
#  (183, ('EARLY_DAYS_max', 365.3083610534668)),
#  (184, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 364.9585256576538)),
#  (185, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 364.85282468795776)),
#  (186, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_min', 364.2214970588684)),
#  (187,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR',
#    363.1007008552551)),
#  (188, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 362.548219203949)),
#  (189,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    362.38421154022217)),
#  (190,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std',
#    360.7191982269287)),
#  (191,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    360.1994791030884)),
#  (192, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in', 359.7914743423462)),
#  (193,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    357.45668745040894)),
#  (194,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    355.8064908981323)),
#  (195,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median',
#    354.35515785217285)),
#  (196, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 353.79660964012146)),
#  (197, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 353.527530670166)),
#  (198, ('livingsum_MEDI_divide_members', 353.3427782058716)),
#  (199, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 353.0582094192505)),
#  (200,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    352.8160619735718)),
#  (201, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 351.0773639678955)),
#  (202,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 350.8915410041809)),
#  (203, ('poscash_CNT_INSTALMENT_FUTURE_max', 348.1391725540161)),
#  (204, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 347.26995277404785)),
#  (205,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    344.7067494392395)),
#  (206,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std',
#    343.67734956741333)),
#  (207,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_0.0_divide_count_SK_ID_CURR',
#    342.7164921760559)),
#  (208,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    342.04208993911743)),
#  (209, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 341.4852695465088)),
#  (210,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    339.0493230819702)),
#  (211, ('REGION_RATING_CLIENT_times_livingsum_AVG', 337.5288953781128)),
#  (212, ('bureau_AMT_CREDIT_SUM_sum', 335.0172209739685)),
#  (213,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 334.72003746032715)),
#  (214, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 334.6393709182739)),
#  (215,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    334.3207497596741)),
#  (216,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std',
#    333.9076075553894)),
#  (217, ('bureau_DAYS_CREDIT_UPDATE_max', 332.86239862442017)),
#  (218,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    332.0968494415283)),
#  (219, ('bureau_DAYS_CREDIT_min', 331.8786404132843)),
#  (220, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 330.628782749176)),
#  (221,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean',
#    328.5327010154724)),
#  (222,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    327.15894508361816)),
#  (223,
#   ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 325.92889738082886)),
#  (224,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_mean', 324.2696189880371)),
#  (225,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR',
#    323.99115896224976)),
#  (226,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    323.4561324119568)),
#  (227,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 322.0518102645874)),
#  (228,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max',
#    321.62653970718384)),
#  (229, ('poscash_SK_DPD_divide_MONTHS_BALANCE_min', 318.3160710334778)),
#  (230,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    317.6636710166931)),
#  (231, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 317.141095161438)),
#  (232, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 316.10748863220215)),
#  (233, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 314.7966103553772)),
#  (234, ('bureau_AMT_CREDIT_SUM_DEBT_std', 312.82587146759033)),
#  (235, ('AMT_INCOME_TOTAL_divide_DAYS_LAST_PHONE_CHANGE', 312.1458399295807)),
#  (236, ('bureau_onehot_CREDIT_TYPE_Mortgage', 309.8419222831726)),
#  (237,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    308.251238822937)),
#  (238,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    305.20113229751587)),
#  (239,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median',
#    305.13758087158203)),
#  (240,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    304.7659606933594)),
#  (241, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 304.6007413864136)),
#  (242,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 303.4240303039551)),
#  (243, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 303.1835594177246)),
#  (244, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 301.9880828857422)),
#  (245,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min',
#    297.91429805755615)),
#  (246, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_min', 297.9092392921448)),
#  (247, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 296.4966011047363)),
#  (248,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    295.2359380722046)),
#  (249, ('prev_DAYS_FIRST_DUE_median', 294.6077699661255)),
#  (250,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean',
#    293.87359046936035)),
#  (251, ('REGION_RATING_CLIENT', 293.3427028656006)),
#  (252, ('poscash_MONTHS_BALANCE_mean', 292.7952289581299)),
#  (253,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_std',
#    291.34570121765137)),
#  (254,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 290.6148319244385)),
#  (255, ('poscash_CNT_INSTALMENT_FUTURE_median', 290.35921573638916)),
#  (256, ('AMT_GOODS_PRICE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 290.0749034881592)),
#  (257, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 288.33006858825684)),
#  (258,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    287.5104684829712)),
#  (259, ('bureau_DAYS_CREDIT_std', 287.0250606536865)),
#  (260, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 286.54370975494385)),
#  (261, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_min', 286.04159927368164)),
#  (262,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean',
#    285.7803292274475)),
#  (263, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 284.3912115097046)),
#  (264,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    284.33147263526917)),
#  (265,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    283.57166957855225)),
#  (266, ('prev_DAYS_DECISION_mean', 283.3352403640747)),
#  (267, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 283.3107981681824)),
#  (268,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    282.9216032028198)),
#  (269, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 281.8927607536316)),
#  (270, ('prev_DAYS_LAST_DUE_1ST_VERSION_max', 279.9123682975769)),
#  (271, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 279.80402183532715)),
#  (272,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    277.91019582748413)),
#  (273,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum',
#    277.38720059394836)),
#  (274,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median',
#    276.1500701904297)),
#  (275, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 275.6797800064087)),
#  (276, ('poscash_onehot_NAME_CONTRACT_STATUS_Active', 274.0405488014221)),
#  (277, ('LIVINGAREA_AVG', 272.80896759033203)),
#  (278, ('FLOORSMAX_MEDI', 269.9267921447754)),
#  (279, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_mean', 269.00488805770874)),
#  (280,
#   ('prev_AMT_APPLICATION_divide_DAYS_DECISION_median', 267.0828495025635)),
#  (281, ('OWN_CAR_AGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 266.32900047302246)),
#  (282, ('bureau_DAYS_CREDIT_UPDATE_std', 264.9215998649597)),
#  (283, ('prev_HOUR_APPR_PROCESS_START_max', 264.5293607711792)),
#  (284, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 264.0192804336548)),
#  (285,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    263.8238732814789)),
#  (286, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 263.4977569580078)),
#  (287,
#   ('prev_onehot_NAME_YIELD_GROUP_3.0_divide_count_SK_ID_CURR',
#    262.1010193824768)),
#  (288,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 260.35882091522217)),
#  (289, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 259.8074789047241)),
#  (290, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 259.72089862823486)),
#  (291, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 259.4219193458557)),
#  (292, ('prev_DAYS_DECISION_max', 259.09896087646484)),
#  (293, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_mean', 258.87508964538574)),
#  (294, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 258.337055683136)),
#  (295,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 256.2233896255493)),
#  (296,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    256.0765480995178)),
#  (297, ('EARLY_AMT_max', 255.54427814483643)),
#  (298,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean',
#    255.18101978302002)),
#  (299, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_mean', 254.81333255767822)),
#  (300, ('prev_AMT_ANNUITY_min', 253.44464874267578)),
#  (301,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    252.14053058624268)),
#  (302, ('poscash_MONTHS_BALANCE_max', 249.70018005371094)),
#  (303, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_mean', 249.3063883781433)),
#  (304,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    249.23830032348633)),
#  (305,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std', 249.0493094921112)),
#  (306, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 248.61824083328247)),
#  (307,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    248.16696786880493)),
#  (308,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    247.63964986801147)),
#  (309, ('poscash_CNT_INSTALMENT_max', 246.9261989593506)),
#  (310,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    245.9207706451416)),
#  (311,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    244.82163047790527)),
#  (312,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    244.67645931243896)),
#  (313, ('prev_onehot_CODE_REJECT_REASON_SCOFR', 243.69409561157227)),
#  (314, ('livingsum_MODE_divide_members', 242.67384004592896)),
#  (315,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median',
#    242.637948513031)),
#  (316, ('prev_AMT_ANNUITY_median', 239.56416988372803)),
#  (317, ('livingsum_AVG_divide_members', 239.48983144760132)),
#  (318, ('poscash_CNT_INSTALMENT_mean', 239.4070587158203)),
#  (319, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 239.3356170654297)),
#  (320,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 238.947039604187)),
#  (321,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    238.5776891708374)),
#  (322, ('EARLY_DAYS_mean', 237.8509383201599)),
#  (323, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_min', 237.6532096862793)),
#  (324, ('bureau_DAYS_ENDDATE_FACT_std', 237.57991790771484)),
#  (325,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    234.07288885116577)),
#  (326,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_median',
#    233.5569305419922)),
#  (327,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    233.3748893737793)),
#  (328,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    232.11381340026855)),
#  (329,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    231.41222381591797)),
#  (330, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_median', 230.95545101165771)),
#  (331,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max',
#    230.72699880599976)),
#  (332, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 230.342031955719)),
#  (333, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_mean', 230.2040901184082)),
#  (334,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean',
#    229.90197944641113)),
#  (335, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_max', 229.36696195602417)),
#  (336,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max',
#    229.14807987213135)),
#  (337, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 227.37224817276)),
#  (338,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_mean',
#    226.03300094604492)),
#  (339,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    225.23741054534912)),
#  (340, ('WEEKDAY_APPR_PROCESS_START', 225.00592041015625)),
#  (341, ('prev_DAYS_DECISION_sum', 224.98865008354187)),
#  (342,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min',
#    224.90976810455322)),
#  (343,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_ID_PUBLISH', 224.2011694908142)),
#  (344, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 223.73226070404053)),
#  (345,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 223.4364013671875)),
#  (346,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max',
#    223.2138786315918)),
#  (347, ('bureau_DAYS_ENDDATE_FACT_median', 222.02303075790405)),
#  (348,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 221.1269497871399)),
#  (349,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    220.91588687896729)),
#  (350, ('prev_onehot_NAME_YIELD_GROUP_1.0', 220.72259712219238)),
#  (351, ('YEARS_BEGINEXPLUATATION_MEDI', 219.59099054336548)),
#  (352, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 219.20327949523926)),
#  (353,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    218.19641017913818)),
#  (354,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_mean', 217.9311294555664)),
#  (355, ('prev_AMT_CREDIT_sum', 217.58823108673096)),
#  (356, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 217.55890083312988)),
#  (357,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    217.15750980377197)),
#  (358, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_min', 216.12343740463257)),
#  (359, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_max', 215.84970712661743)),
#  (360, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_mean', 215.6048014163971)),
#  (361, ('poscash_CNT_INSTALMENT_sum', 215.39077138900757)),
#  (362, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 213.71889638900757)),
#  (363, ('poscash_SK_DPD_DEF_mean', 213.576904296875)),
#  (364,
#   ('prev_onehot_CODE_REJECT_REASON_SCOFR_divide_count_SK_ID_CURR',
#    213.0995044708252)),
#  (365,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    212.96806144714355)),
#  (366, ('bureau_AMT_CREDIT_SUM_max', 212.878577709198)),
#  (367, ('prev_HOUR_APPR_PROCESS_START_sum', 211.88825225830078)),
#  (368, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_max', 210.63846015930176)),
#  (369,
#   ('prev_onehot_NAME_PAYMENT_TYPE_Cash_through_the_bank_divide_count_SK_ID_CURR',
#    210.2114691734314)),
#  (370, ('FLOORSMAX_AVG', 209.74670791625977)),
#  (371,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_min', 209.59766960144043)),
#  (372,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_std',
#    209.31500148773193)),
#  (373, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 209.1113085746765)),
#  (374,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    208.7480983734131)),
#  (375, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 207.6281180381775)),
#  (376, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_min', 206.7287516593933)),
#  (377,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 206.5948281288147)),
#  (378,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_sum', 206.0490608215332)),
#  (379,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    205.9459729194641)),
#  (380, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 205.4669909477234)),
#  (381,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std',
#    205.43898010253906)),
#  (382, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 204.98341846466064)),
#  (383,
#   ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 204.64601945877075)),
#  (384,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    204.4171404838562)),
#  (385, ('AMT_INCOME_TOTAL', 204.3988904953003)),
#  (386,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 204.26313877105713)),
#  (387,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    203.9040174484253)),
#  (388, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_median', 203.8371090888977)),
#  (389,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    203.0664300918579)),
#  (390,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    202.95907020568848)),
#  (391, ('LIVINGAREA_MEDI', 202.8639430999756)),
#  (392, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 201.43983125686646)),
#  (393,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    201.3167290687561)),
#  (394, ('bureau_DAYS_CREDIT_sum', 200.7287998199463)),
#  (395, ('prev_AMT_CREDIT_median', 199.98218202590942)),
#  (396,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    199.94189882278442)),
#  (397, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_sum', 199.3839693069458)),
#  (398,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE',
#    199.37789011001587)),
#  (399, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 198.4292230606079)),
#  (400, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 198.09252858161926)),
#  (401,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_median',
#    198.02306985855103)),
#  (402, ('REGION_RATING_CLIENT_times_livingsum_MODE', 196.76179790496826)),
#  (403,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    196.47045946121216)),
#  (404,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_mean', 195.49037981033325)),
#  (405,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min', 195.26153802871704)),
#  (406, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_mean', 194.8765926361084)),
#  (407,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    194.73178052902222)),
#  (408, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 194.15759801864624)),
#  (409, ('prev_CNT_PAYMENT_median', 193.34380912780762)),
#  (410,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum',
#    192.8985915184021)),
#  (411, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_mean', 192.484769821167)),
#  (412, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_mean', 191.4938998222351)),
#  (413, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 190.86331224441528)),
#  (414, ('OWN_CAR_AGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 190.85436463356018)),
#  (415, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_max', 190.67130756378174)),
#  (416,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    190.42746019363403)),
#  (417,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    189.49869203567505)),
#  (418,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_min',
#    189.22780323028564)),
#  (419,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    189.22502326965332)),
#  (420,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    188.66495037078857)),
#  (421,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_min', 187.58533000946045)),
#  (422,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    187.56087970733643)),
#  (423,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std',
#    186.77502870559692)),
#  (424,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 185.93598175048828)),
#  (425, ('prev_HOUR_APPR_PROCESS_START_min', 185.87195110321045)),
#  (426, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 185.2224678993225)),
#  (427,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    184.0416498184204)),
#  (428, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_sum', 183.42884016036987)),
#  (429,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    183.12429904937744)),
#  (430,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    182.63720893859863)),
#  (431,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    182.59947109222412)),
#  (432,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_max', 182.25342798233032)),
#  (433,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    181.84505987167358)),
#  (434,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    181.68222999572754)),
#  (435, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 181.41553163528442)),
#  (436,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    180.98159170150757)),
#  (437, ('prev_DAYS_FIRST_DUE_max', 180.74007272720337)),
#  (438,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    180.29708003997803)),
#  (439,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 180.08121061325073)),
#  (440, ('prev_DAYS_FIRST_DUE_sum', 180.07241821289062)),
#  (441,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 180.06732082366943)),
#  (442, ('prev_DAYS_TERMINATION_min', 179.8900923728943)),
#  (443,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min',
#    179.73877024650574)),
#  (444,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    179.660747051239)),
#  (445,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    179.16851615905762)),
#  (446, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 178.85891914367676)),
#  (447,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    178.34983205795288)),
#  (448, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_max', 178.02760934829712)),
#  (449, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 177.96614933013916)),
#  (450,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_sum',
#    177.6468687057495)),
#  (451, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 177.6325602531433)),
#  (452, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 177.36357975006104)),
#  (453,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    177.26320934295654)),
#  (454,
#   ('prev_onehot_NAME_PRODUCT_TYPE_XNA_divide_count_SK_ID_CURR',
#    176.26143836975098)),
#  (455, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 175.91218042373657)),
#  (456, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_max', 175.64217042922974)),
#  (457,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    175.41656017303467)),
#  (458,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    175.34665870666504)),
#  (459,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_mean',
#    175.1632809638977)),
#  (460,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    175.12389993667603)),
#  (461,
#   ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_60_CNT_SOCIAL_CIRCLE',
#    174.31282997131348)),
#  (462, ('bureau_AMT_CREDIT_MAX_OVERDUE_max', 174.12090015411377)),
#  (463,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min',
#    174.11295223236084)),
#  (464, ('bureau_AMT_CREDIT_SUM_std', 173.86898946762085)),
#  (465,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median', 172.99993133544922)),
#  (466,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 172.19157075881958)),
#  (467, ('poscash_SK_DPD_DEF_std', 172.1809287071228)),
#  (468,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    171.90826988220215)),
#  (469,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    171.5259609222412)),
#  (470,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_median', 171.06038999557495)),
#  (471,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_max',
#    171.04214715957642)),
#  (472,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    170.96777153015137)),
#  (473,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_sum',
#    170.74499988555908)),
#  (474,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 170.62734985351562)),
#  (475,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    170.2934694290161)),
#  (476,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    170.26519870758057)),
#  (477,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Consumer_electronics_divide_count_SK_ID_CURR',
#    170.10891008377075)),
#  (478,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    170.04567003250122)),
#  (479, ('LIVINGAREA_MODE', 169.85399913787842)),
#  (480,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min',
#    169.42439031600952)),
#  (481, ('prev_AMT_ANNUITY_max', 169.10935974121094)),
#  (482,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    168.84762239456177)),
#  (483,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    168.60845804214478)),
#  (484, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_median', 168.19414949417114)),
#  (485, ('bureau_DAYS_ENDDATE_FACT_mean', 167.63578939437866)),
#  (486,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    167.38898038864136)),
#  (487,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    166.40862941741943)),
#  (488,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    166.13999223709106)),
#  (489,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_median',
#    166.0426893234253)),
#  (490, ('prev_DAYS_FIRST_DUE_mean', 165.89574003219604)),
#  (491,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    165.8128900527954)),
#  (492,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    165.70740795135498)),
#  (493, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 165.01946878433228)),
#  (494,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_std', 164.63960003852844)),
#  (495,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_0.0_divide_count_SK_ID_CURR',
#    164.53436946868896)),
#  (496,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_2.0_divide_count_SK_ID_CURR',
#    164.45116090774536)),
#  (497, ('poscash_CNT_INSTALMENT_FUTURE_sum', 164.18160104751587)),
#  (498,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    164.02315044403076)),
#  (499, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 164.02182006835938)),
#  (500,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    163.60224962234497)),
#  (501, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_mean', 163.44012022018433)),
#  (502,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 163.35861921310425)),
#  (503,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    163.23929023742676)),
#  (504,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 162.92674684524536)),
#  (505,
#   ('bureau_onehot_CREDIT_TYPE_Credit_card_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    162.75931072235107)),
#  (506,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    162.72089958190918)),
#  (507, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 162.3716902732849)),
#  (508,
#   ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    162.08370113372803)),
#  (509,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    161.70402908325195)),
#  (510,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE',
#    161.5272388458252)),
#  (511, ('prev_AMT_ANNUITY_sum', 161.4677324295044)),
#  (512,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_median',
#    161.40761137008667)),
#  (513,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    161.23315858840942)),
#  (514,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    160.88980913162231)),
#  (515, ('bureau_DAYS_ENDDATE_FACT_sum', 160.64878749847412)),
#  (516, ('bureau_DAYS_CREDIT_UPDATE_min', 160.61127138137817)),
#  (517, ('bureau_count_SK_ID_CURR', 159.70999956130981)),
#  (518,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    159.49235820770264)),
#  (519, ('prev_RATE_DOWN_PAYMENT_max', 159.46108770370483)),
#  (520, ('NAME_HOUSING_TYPE', 159.27449083328247)),
#  (521, ('prev_AMT_CREDIT_mean', 159.2720799446106)),
#  (522,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    159.13998985290527)),
#  (523,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_mean',
#    158.55585193634033)),
#  (524, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_sum', 158.13628005981445)),
#  (525, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 157.37894105911255)),
#  (526,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    157.01879024505615)),
#  (527,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    156.47994804382324)),
#  (528,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    156.3193016052246)),
#  (529, ('bureau_AMT_CREDIT_SUM_min', 156.23276948928833)),
#  (530, ('poscash_SK_DPD_divide_MONTHS_BALANCE_mean', 155.94488334655762)),
#  (531,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_mean', 155.93215036392212)),
#  (532,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    155.63842010498047)),
#  (533,
#   ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    155.09027004241943)),
#  (534, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_mean', 155.04665851593018)),
#  (535,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    155.0005874633789)),
#  (536, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_mean', 153.46048069000244)),
#  (537, ('bureau_AMT_CREDIT_SUM_mean', 153.34113025665283)),
#  (538,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    153.18088912963867)),
#  (539, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 153.03100776672363)),
#  (540,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    152.93598175048828)),
#  (541,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_max', 152.8444995880127)),
#  (542, ('YEARS_BEGINEXPLUATATION_MODE', 152.2058596611023)),
#  (543,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    151.84854888916016)),
#  (544,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_sum', 151.3096981048584)),
#  (545,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    150.87124824523926)),
#  (546, ('prev_AMT_GOODS_PRICE_median', 150.36110162734985)),
#  (547,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    150.31634044647217)),
#  (548,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    150.19655752182007)),
#  (549, ('prev_RATE_DOWN_PAYMENT_median', 150.0896601676941)),
#  (550, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OWN_CAR_AGE', 149.7257695198059)),
#  (551, ('prev_DAYS_LAST_DUE_sum', 149.66252088546753)),
#  (552,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_sum',
#    149.27580070495605)),
#  (553,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 148.9739909172058)),
#  (554, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_MON', 148.66767930984497)),
#  (555,
#   ('prev_onehot_CHANNEL_TYPE_Stone_divide_count_SK_ID_CURR',
#    148.47579145431519)),
#  (556, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 148.39946937561035)),
#  (557,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_median',
#    148.39872932434082)),
#  (558, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_sum', 148.36583995819092)),
#  (559,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_mean', 148.3644495010376)),
#  (560, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_max', 148.1885290145874)),
#  (561,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    148.14221954345703)),
#  (562,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    148.00980949401855)),
#  (563,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_sum', 147.84384894371033)),
#  (564,
#   ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_median', 147.15907859802246)),
#  (565, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_max', 147.1581907272339)),
#  (566,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    147.06331062316895)),
#  (567, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_max', 146.81968021392822)),
#  (568,
#   ('AMT_REQ_CREDIT_BUREAU_MON_divide_DAYS_REGISTRATION', 146.728609085083)),
#  (569,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    146.69320011138916)),
#  (570, ('prev_AMT_DOWN_PAYMENT_mean', 146.21807670593262)),
#  (571,
#   ('bureau_onehot_CREDIT_ACTIVE_Closed_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    145.95648002624512)),
#  (572,
#   ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_mean', 145.70267868041992)),
#  (573,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    145.11956119537354)),
#  (574,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max',
#    145.00693225860596)),
#  (575, ('prev_AMT_GOODS_PRICE_sum', 144.73131799697876)),
#  (576,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    144.3926591873169)),
#  (577,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    143.14665985107422)),
#  (578,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    142.94385957717896)),
#  (579,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    142.8076295852661)),
#  (580, ('prev_AMT_DOWN_PAYMENT_median', 142.71447086334229)),
#  (581,
# ...
#  (811, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_sum', 96.9149694442749)),
#  (812, ('bureau_MONTHS_BALANCE_mean_max', 96.8887209892273)),
#  (813, ('bureau_onehot_STATUS_0_max', 96.51719999313354)),
#  (814, ('bureau_MONTHS_BALANCE_sum_median', 96.32649898529053)),
#  (815, ('bureau_onehot_STATUS_0_mean', 96.17201137542725)),
#  (816,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    96.08957052230835)),
#  (817,
#   ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_std', 96.06281805038452)),
#  (818,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    95.88663148880005)),
#  (819,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    95.81579113006592)),
#  (820,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_sum', 95.57772064208984)),
#  (821, ('bureau_onehot_STATUS_0_std', 95.27619981765747)),
#  (822,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_median', 95.21731996536255)),
#  (823, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_mean', 95.15017080307007)),
#  (824, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 95.03795909881592)),
#  (825, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_median', 95.014892578125)),
#  (826,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    94.96747922897339)),
#  (827,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    94.38433074951172)),
#  (828, ('prev_WEEKDAY_APPR_PROCESS_START_median', 94.3702597618103)),
#  (829, ('prev_DAYS_LAST_DUE_mean', 93.9407606124878)),
#  (830, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_mean', 93.72223901748657)),
#  (831,
#   ('OBS_60_CNT_SOCIAL_CIRCLE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    93.39354038238525)),
#  (832,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min',
#    93.10347843170166)),
#  (833,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 93.08123016357422)),
#  (834, ('NONLIVINGAREA_AVG', 92.83975076675415)),
#  (835,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    92.64541149139404)),
#  (836,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    92.16913080215454)),
#  (837,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    92.14841175079346)),
#  (838,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum',
#    91.67217016220093)),
#  (839, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_mean', 91.43930149078369)),
#  (840, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_sum', 90.9549617767334)),
#  (841,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    90.81562042236328)),
#  (842,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    90.70672035217285)),
#  (843,
#   ('prev_onehot_NAME_PRODUCT_TYPE_x-sell_divide_count_SK_ID_CURR',
#    90.67698049545288)),
#  (844, ('prev_onehot_NAME_TYPE_SUITE_nan', 89.05220031738281)),
#  (845, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 88.80689907073975)),
#  (846,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_median', 88.58059048652649)),
#  (847, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 88.5537805557251)),
#  (848,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    88.40231943130493)),
#  (849, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 88.06960964202881)),
#  (850,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max', 87.91740989685059)),
#  (851,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    87.86800050735474)),
#  (852,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_max',
#    87.8294997215271)),
#  (853, ('prev_WEEKDAY_APPR_PROCESS_START_max', 87.49422931671143)),
#  (854, ('bureau_AMT_ANNUITY_divide_CNT_CREDIT_PROLONG_max', 87.4355993270874)),
#  (855,
#   ('prev_onehot_NAME_CONTRACT_TYPE_Cash_loans_divide_count_SK_ID_CURR',
#    87.06799030303955)),
#  (856,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    87.00220203399658)),
#  (857,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    86.98793935775757)),
#  (858, ('prev_AMT_GOODS_PRICE_mean', 86.96043157577515)),
#  (859,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_median', 86.68701171875)),
#  (860, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_mean', 86.64781975746155)),
#  (861,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    86.63157892227173)),
#  (862, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_min', 86.51430082321167)),
#  (863, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_median', 86.49828100204468)),
#  (864,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    86.0278787612915)),
#  (865, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_max', 85.97577857971191)),
#  (866,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    85.87162113189697)),
#  (867,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_min',
#    85.77869033813477)),
#  (868, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_mean', 85.76087951660156)),
#  (869, ('bureau_onehot_STATUS_1_std', 85.38132953643799)),
#  (870,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    85.31549119949341)),
#  (871,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    84.94360065460205)),
#  (872,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    84.87265014648438)),
#  (873,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum',
#    84.86546087265015)),
#  (874, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_median', 84.1891508102417)),
#  (875,
#   ('AMT_INCOME_TOTAL_divide_OBS_30_CNT_SOCIAL_CIRCLE', 84.11575078964233)),
#  (876,
#   ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR',
#    84.00640106201172)),
#  (877,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_mean',
#    83.15251970291138)),
#  (878, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_sum', 83.11010074615479)),
#  (879,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    82.97880125045776)),
#  (880, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_max', 82.83572006225586)),
#  (881,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    82.56990098953247)),
#  (882,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_sum',
#    82.53437995910645)),
#  (883, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_min', 82.43335008621216)),
#  (884,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    82.35281896591187)),
#  (885,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    82.29959011077881)),
#  (886,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_sum', 82.16929721832275)),
#  (887, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_sum', 82.0686092376709)),
#  (888,
#   ('DEF_60_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    81.91522884368896)),
#  (889, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_median', 81.72910976409912)),
#  (890,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    81.7190990447998)),
#  (891,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    81.57375907897949)),
#  (892,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_sum',
#    81.40010190010071)),
#  (893,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min',
#    81.3514609336853)),
#  (894, ('bureau_onehot_STATUS_0_median', 81.31357049942017)),
#  (895,
#   ('OBS_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    81.13837909698486)),
#  (896,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_mean', 80.72407054901123)),
#  (897,
#   ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_QRT', 80.64211988449097)),
#  (898, ('AMT_CREDIT_divide_OBS_60_CNT_SOCIAL_CIRCLE', 80.43323850631714)),
#  (899, ('bureau_MONTHS_BALANCE_std_median', 80.06743907928467)),
#  (900,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_sum', 80.0610990524292)),
#  (901,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    79.97869062423706)),
#  (902,
#   ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 79.84242916107178)),
#  (903,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean', 79.31233882904053)),
#  (904, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_min', 78.62540912628174)),
#  (905, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_sum', 78.60193967819214)),
#  (906,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    78.14276218414307)),
#  (907,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_std',
#    77.99492025375366)),
#  (908,
#   ('bureau_onehot_CREDIT_TYPE_Consumer_credit_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    77.96268939971924)),
#  (909,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    77.8868088722229)),
#  (910, ('bureau_onehot_STATUS_0_min', 77.78656101226807)),
#  (911, ('prev_WEEKDAY_APPR_PROCESS_START_sum', 77.45165061950684)),
#  (912,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_std',
#    77.20545053482056)),
#  (913, ('bureau_AMT_CREDIT_SUM_divide_AMT_ANNUITY_std', 76.76181077957153)),
#  (914, ('bureau_onehot_STATUS_C_mean', 76.62679862976074)),
#  (915,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_max',
#    76.57819938659668)),
#  (916,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_std', 76.43161058425903)),
#  (917,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum',
#    76.33559989929199)),
#  (918,
#   ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_median', 76.21257972717285)),
#  (919, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_sum', 76.12534999847412)),
#  (920,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    76.01611995697021)),
#  (921,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median', 75.86419868469238)),
#  (922,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_median', 75.40442085266113)),
#  (923,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    75.34860038757324)),
#  (924, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_max', 75.3127293586731)),
#  (925,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    75.26205062866211)),
#  (926, ('AMT_CREDIT_divide_OBS_30_CNT_SOCIAL_CIRCLE', 75.24383020401001)),
#  (927,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_min',
#    75.05737018585205)),
#  (928, ('prev_onehot_NAME_YIELD_GROUP_4.0', 74.96467018127441)),
#  (929, ('bureau_onehot_STATUS_1_mean', 74.95909881591797)),
#  (930, ('WALLSMATERIAL_MODE', 74.90203189849854)),
#  (931,
#   ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_UPDATE_mean', 74.67091941833496)),
#  (932,
#   ('AMT_REQ_CREDIT_BUREAU_MON_divide_AMT_REQ_CREDIT_BUREAU_YEAR',
#    74.6615800857544)),
#  (933,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    74.60910034179688)),
#  (934, ('bureau_onehot_STATUS_X_min', 74.5219087600708)),
#  (935, ('bureau_onehot_STATUS_C_max', 74.46220111846924)),
#  (936,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices', 74.34910106658936)),
#  (937,
#   ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_FUTURE_mean', 73.96390867233276)),
#  (938, ('BASEMENTAREA_AVG', 73.90639066696167)),
#  (939,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    73.82909965515137)),
#  (940,
#   ('AMT_REQ_CREDIT_BUREAU_QRT_divide_CNT_FAM_MEMBERS', 73.19799900054932)),
#  (941,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_mean',
#    73.11379957199097)),
#  (942, ('livingsum_AVG', 73.09221124649048)),
#  (943,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_median',
#    72.54517936706543)),
#  (944,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    72.0980896949768)),
#  (945, ('prev_AMT_APPLICATION_sum', 72.04514122009277)),
#  (946, ('YEARS_BUILD_MEDI', 72.01910066604614)),
#  (947,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_median', 71.61657047271729)),
#  (948, ('prev_onehot_NAME_YIELD_GROUP_3.0', 71.55096101760864)),
#  (949,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean', 71.50263166427612)),
#  (950, ('prev_AMT_DOWN_PAYMENT_max', 71.4192910194397)),
#  (951, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_sum', 71.34857034683228)),
#  (952, ('AMT_CREDIT_divide_CNT_CHILDREN', 71.33844184875488)),
#  (953, ('poscash_SK_DPD_sum', 71.31964063644409)),
#  (954, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_median', 71.31411027908325)),
#  (955, ('bureau_MONTHS_BALANCE_std_min', 71.19298934936523)),
#  (956,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_sum', 71.0751895904541)),
#  (957,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    70.89609909057617)),
#  (958,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    70.31030082702637)),
#  (959, ('bureau_MONTHS_BALANCE_mean_std', 70.29720115661621)),
#  (960,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    70.21809101104736)),
#  (961, ('bureau_MONTHS_BALANCE_min_std', 70.0598201751709)),
#  (962, ('poscash_SK_DPD_divide_MONTHS_BALANCE_sum', 70.0350112915039)),
#  (963, ('AMT_GOODS_PRICE_divide_CNT_CHILDREN', 69.76624011993408)),
#  (964,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_mean',
#    69.58190107345581)),
#  (965,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_median', 69.5026388168335)),
#  (966, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_mean', 69.4350996017456)),
#  (967, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_min', 69.12877988815308)),
#  (968,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    69.12261962890625)),
#  (969, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_mean', 68.8980803489685)),
#  (970, ('COMMONAREA_AVG', 68.80076026916504)),
#  (971, ('COMMONAREA_MODE', 68.76443862915039)),
#  (972, ('bureau_MONTHS_BALANCE_min_median', 68.50370025634766)),
#  (973, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 68.41061878204346)),
#  (974, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_mean', 68.07649993896484)),
#  (975, ('LIVE_CITY_NOT_WORK_CITY', 67.98946952819824)),
#  (976,
#   ('AMT_INCOME_TOTAL_divide_OBS_60_CNT_SOCIAL_CIRCLE', 67.53609991073608)),
#  (977,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_std', 67.41629028320312)),
#  (978,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_max',
#    67.40460109710693)),
#  (979,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CNT_CREDIT_PROLONG_mean',
#    66.99279117584229)),
#  (980,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    66.8045597076416)),
#  (981, ('prev_onehot_CHANNEL_TYPE_Contact_center', 66.75919103622437)),
#  (982,
#   ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_min_mean', 66.69990062713623)),
#  (983, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_sum', 66.67555904388428)),
#  (984, ('livingsum_MODE', 66.64342880249023)),
#  (985,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median', 66.5033597946167)),
#  (986, ('FLOORSMAX_MODE', 66.39359951019287)),
#  (987, ('prev_DAYS_LAST_DUE_1ST_VERSION_min', 66.24579048156738)),
#  (988,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    66.0925703048706)),
#  (989, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 65.94037055969238)),
#  (990,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_1.0_divide_count_SK_ID_CURR',
#    65.9080400466919)),
#  (991,
#   ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_QRT', 65.80264043807983)),
#  (992, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_max', 65.48516082763672)),
#  (993, ('LIVINGAPARTMENTS_AVG', 64.95789051055908)),
#  (994, ('bureau_AMT_CREDIT_SUM_DEBT_median', 64.88387966156006)),
#  (995, ('prev_AMT_APPLICATION_min', 64.79020977020264)),
#  (996, ('prev_RATE_DOWN_PAYMENT_sum', 64.73206043243408)),
#  (997,
#   ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_max', 64.51347017288208)),
#  (998,
#   ('prev_onehot_NAME_PORTFOLIO_Cash_divide_count_SK_ID_CURR',
#    64.47922945022583)),
#  (999,
#   ('AMT_REQ_CREDIT_BUREAU_WEEK_divide_DAYS_LAST_PHONE_CHANGE',
#    64.45960140228271)),
#  ...]

# %%
x = [x for x in zip(clf.feature_name(), clf.feature_importance('split'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_1', 331)),
#  (1, ('EXT_SOURCE_2', 284)),
#  (2, ('AMT_CREDIT_divide_AMT_ANNUITY', 284)),
#  (3, ('EXT_SOURCE_3', 221)),
#  (4, ('DAYS_BIRTH', 181)),
#  (5, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 154)),
#  (6, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 128)),
#  (7, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 120)),
#  (8, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 119)),
#  (9, ('LATE_DAYS_mean', 109)),
#  (10, ('AMT_ANNUITY', 98)),
#  (11, ('LATE_AMT_max', 96)),
#  (12, ('LATE_AMT_mean', 94)),
#  (13, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 93)),
#  (14, ('LATE_AREA_sum', 93)),
#  (15, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 82)),
#  (16, ('REGION_POPULATION_RELATIVE', 80)),
#  (17, ('EARLY_AMT_sum', 80)),
#  (18, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median', 79)),
#  (19, ('CODE_GENDER', 78)),
#  (20, ('NAME_EDUCATION_TYPE', 78)),
#  (21,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR', 75)),
#  (22, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 74)),
#  (23, ('DAYS_EMPLOYED', 72)),
#  (24, ('DAYS_ID_PUBLISH', 72)),
#  (25, ('bureau_DAYS_CREDIT_max', 72)),
#  (26, ('poscash_MONTHS_BALANCE_std', 69)),
#  (27, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std', 69)),
#  (28, ('EARLY_AREA_sum', 68)),
#  (29, ('AMT_GOODS_PRICE', 67)),
#  (30, ('NAME_FAMILY_STATUS', 67)),
#  (31, ('bureau_DAYS_ENDDATE_FACT_max', 67)),
#  (32, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 64)),
#  (33, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min', 64)),
#  (34, ('LATE_AMT_sum', 62)),
#  (35, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 61)),
#  (36, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 60)),
#  (37, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max', 58)),
#  (38, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 57)),
#  (39, ('poscash_CNT_INSTALMENT_FUTURE_std', 57)),
#  (40, ('OCCUPATION_TYPE', 56)),
#  (41, ('bureau_DAYS_CREDIT_ENDDATE_max', 56)),
#  (42, ('bureau_DAYS_CREDIT_mean', 55)),
#  (43, ('AMT_ANNUITY_divide_DAYS_BIRTH', 48)),
#  (44, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 48)),
#  (45, ('bureau_DAYS_CREDIT_median', 48)),
#  (46, ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR', 46)),
#  (47,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Active_divide_positivecount_SK_ID_CURR_SK_DPD',
#    46)),
#  (48, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 45)),
#  (49, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_min', 45)),
#  (50, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 44)),
#  (51, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum', 43)),
#  (52, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 42)),
#  (53, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 42)),
#  (54, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 42)),
#  (55, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 41)),
#  (56,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR', 41)),
#  (57,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    41)),
#  (58, ('bureau_onehot_CREDIT_ACTIVE_Active', 41)),
#  (59, ('bureau_DAYS_CREDIT_UPDATE_median', 41)),
#  (60, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min', 41)),
#  (61, ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR', 40)),
#  (62, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 40)),
#  (63, ('poscash_CNT_INSTALMENT_FUTURE_mean', 40)),
#  (64, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 39)),
#  (65, ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR', 39)),
#  (66, ('AMT_CREDIT_divide_DAYS_BIRTH', 38)),
#  (67, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 38)),
#  (68, ('prev_DAYS_DECISION_min', 38)),
#  (69, ('poscash_MONTHS_BALANCE_min', 38)),
#  (70, ('EARLY_DAYS_max', 38)),
#  (71, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 38)),
#  (72, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 38)),
#  (73, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min', 38)),
#  (74, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 37)),
#  (75, ('bureau_DAYS_CREDIT_ENDDATE_median', 37)),
#  (76, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 36)),
#  (77, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_std', 36)),
#  (78, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 36)),
#  (79, ('bureau_DAYS_CREDIT_ENDDATE_mean', 36)),
#  (80, ('NAME_INCOME_TYPE', 35)),
#  (81, ('DAYS_LAST_PHONE_CHANGE', 35)),
#  (82, ('prev_CNT_PAYMENT_mean', 35)),
#  (83, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 35)),
#  (84, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 35)),
#  (85, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 35)),
#  (86, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 34)),
#  (87, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 34)),
#  (88,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    34)),
#  (89, ('prev_HOUR_APPR_PROCESS_START_mean', 34)),
#  (90, ('poscash_MONTHS_BALANCE_sum', 34)),
#  (91, ('bureau_DAYS_CREDIT_ENDDATE_sum', 34)),
#  (92, ('bureau_DAYS_CREDIT_ENDDATE_std', 34)),
#  (93, ('REGION_RATING_CLIENT_W_CITY', 33)),
#  (94, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min', 33)),
#  (95, ('poscash_CNT_INSTALMENT_std', 33)),
#  (96, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 33)),
#  (97, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median', 33)),
#  (98, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean', 33)),
#  (99, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 32)),
#  (100, ('prev_DAYS_DECISION_median', 32)),
#  (101, ('poscash_MONTHS_BALANCE_median', 32)),
#  (102, ('EARLY_AMT_mean', 32)),
#  (103, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean', 32)),
#  (104, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max', 32)),
#  (105, ('FLAG_DOCUMENT_3', 31)),
#  (106, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 31)),
#  (107, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 31)),
#  (108, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean', 31)),
#  (109, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std', 31)),
#  (110, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min', 31)),
#  (111, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum', 31)),
#  (112, ('DAYS_REGISTRATION', 30)),
#  (113,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR', 30)),
#  (114, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 30)),
#  (115, ('LATE_DAYS_max', 30)),
#  (116, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 30)),
#  (117, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 30)),
#  (118, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median', 30)),
#  (119, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 29)),
#  (120, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max', 29)),
#  (121, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 29)),
#  (122, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 28)),
#  (123, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 28)),
#  (124, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 28)),
#  (125, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_min', 28)),
#  (126,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    28)),
#  (127, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std', 28)),
#  (128, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean', 28)),
#  (129, ('OWN_CAR_AGE', 27)),
#  (130, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 27)),
#  (131, ('bureau_DAYS_CREDIT_min', 27)),
#  (132, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean', 27)),
#  (133, ('bureau_DAYS_CREDIT_UPDATE_max', 27)),
#  (134, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median', 27)),
#  (135, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum', 27)),
#  (136, ('AMT_CREDIT', 26)),
#  (137, ('AMT_INCOME_TOTAL_divide_DAYS_LAST_PHONE_CHANGE', 26)),
#  (138, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 26)),
#  (139, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 26)),
#  (140, ('prev_onehot_NAME_CLIENT_TYPE_New_divide_count_SK_ID_CURR', 26)),
#  (141, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_min', 26)),
#  (142, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 26)),
#  (143, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 26)),
#  (144,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    26)),
#  (145, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 26)),
#  (146, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 26)),
#  (147, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 26)),
#  (148, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 25)),
#  (149, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 25)),
#  (150, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 25)),
#  (151, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 25)),
#  (152,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR', 25)),
#  (153, ('prev_CNT_PAYMENT_max', 25)),
#  (154,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    25)),
#  (155,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    25)),
#  (156, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 25)),
#  (157, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 25)),
#  (158, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max', 25)),
#  (159, ('REG_CITY_NOT_LIVE_CITY', 24)),
#  (160, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 24)),
#  (161, ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR', 24)),
#  (162, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max', 24)),
#  (163, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 24)),
#  (164, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median', 24)),
#  (165, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max', 24)),
#  (166, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min', 24)),
#  (167, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_sum', 24)),
#  (168, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_mean', 24)),
#  (169,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    24)),
#  (170, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std', 24)),
#  (171, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 24)),
#  (172, ('livingsum_MEDI_divide_members', 23)),
#  (173, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 23)),
#  (174, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean', 23)),
#  (175, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_median', 23)),
#  (176,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    23)),
#  (177, ('prev_DAYS_DECISION_max', 23)),
#  (178, ('prev_DAYS_FIRST_DUE_min', 23)),
#  (179,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    23)),
#  (180, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 23)),
#  (181, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 23)),
#  (182, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 23)),
#  (183, ('prev_HOUR_APPR_PROCESS_START_max', 23)),
#  (184, ('poscash_count_SK_ID_CURR', 23)),
#  (185, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_mean', 23)),
#  (186, ('EARLY_DAYS_mean', 23)),
#  (187,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    23)),
#  (188, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum', 23)),
#  (189, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std', 23)),
#  (190, ('bureau_DAYS_CREDIT_UPDATE_std', 23)),
#  (191, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std', 23)),
#  (192, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean', 23)),
#  (193, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 23)),
#  (194, ('WEEKDAY_APPR_PROCESS_START', 22)),
#  (195, ('YEARS_BEGINEXPLUATATION_MEDI', 22)),
#  (196, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 22)),
#  (197, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 22)),
#  (198, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 22)),
#  (199, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 22)),
#  (200, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 22)),
#  (201,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    22)),
#  (202,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    22)),
#  (203, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 22)),
#  (204, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 22)),
#  (205, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 22)),
#  (206, ('poscash_MONTHS_BALANCE_mean', 22)),
#  (207, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median', 22)),
#  (208, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min', 22)),
#  (209, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean', 22)),
#  (210, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 21)),
#  (211,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    21)),
#  (212, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 21)),
#  (213, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 21)),
#  (214,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    21)),
#  (215,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    21)),
#  (216,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    21)),
#  (217,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 21)),
#  (218, ('prev_AMT_ANNUITY_median', 21)),
#  (219, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 21)),
#  (220,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    21)),
#  (221, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 21)),
#  (222, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 21)),
#  (223, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 21)),
#  (224, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_max', 21)),
#  (225, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_mean', 21)),
#  (226, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median', 21)),
#  (227, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_max', 21)),
#  (228, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 21)),
#  (229, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max', 21)),
#  (230, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 20)),
#  (231, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 20)),
#  (232, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 20)),
#  (233, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 20)),
#  (234, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 20)),
#  (235, ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR', 20)),
#  (236,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    20)),
#  (237, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median', 20)),
#  (238, ('prev_DAYS_DECISION_mean', 20)),
#  (239, ('prev_DAYS_DECISION_sum', 20)),
#  (240,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    20)),
#  (241,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    20)),
#  (242, ('prev_DAYS_FIRST_DUE_median', 20)),
#  (243, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 20)),
#  (244, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 20)),
#  (245, ('bureau_DAYS_CREDIT_std', 20)),
#  (246, ('bureau_DAYS_CREDIT_UPDATE_mean', 20)),
#  (247, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean', 20)),
#  (248, ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 19)),
#  (249, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE', 19)),
#  (250, ('prev_onehot_NAME_YIELD_GROUP_2.0', 19)),
#  (251, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in_divide_count_SK_ID_CURR', 19)),
#  (252, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum', 19)),
#  (253, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 19)),
#  (254,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 19)),
#  (255, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 19)),
#  (256, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_min', 19)),
#  (257,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    19)),
#  (258,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    19)),
#  (259,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    19)),
#  (260, ('prev_AMT_ANNUITY_min', 19)),
#  (261, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_max', 19)),
#  (262, ('poscash_CNT_INSTALMENT_mean', 19)),
#  (263, ('poscash_SK_DPD_divide_MONTHS_BALANCE_min', 19)),
#  (264, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_std', 19)),
#  (265, ('bureau_AMT_CREDIT_SUM_sum', 19)),
#  (266, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean', 19)),
#  (267, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median', 19)),
#  (268, ('NAME_HOUSING_TYPE', 18)),
#  (269, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 18)),
#  (270, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_ID_PUBLISH', 18)),
#  (271, ('prev_onehot_NAME_CLIENT_TYPE_Refreshed_divide_count_SK_ID_CURR', 18)),
#  (272,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Consumer_electronics_divide_count_SK_ID_CURR',
#    18)),
#  (273, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 18)),
#  (274, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 18)),
#  (275, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_median', 18)),
#  (276, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_mean', 18)),
#  (277,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    18)),
#  (278,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    18)),
#  (279,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    18)),
#  (280, ('prev_AMT_CREDIT_mean', 18)),
#  (281, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 18)),
#  (282, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_max', 18)),
#  (283, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 18)),
#  (284, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 18)),
#  (285, ('prev_HOUR_APPR_PROCESS_START_sum', 18)),
#  (286, ('poscash_SK_DPD_divide_MONTHS_BALANCE_std', 18)),
#  (287, ('EARLY_AMT_max', 18)),
#  (288, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 18)),
#  (289, ('bureau_AMT_CREDIT_SUM_DEBT_std', 18)),
#  (290, ('bureau_DAYS_ENDDATE_FACT_median', 18)),
#  (291, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 18)),
#  (292, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_std', 18)),
#  (293, ('AMT_INCOME_TOTAL', 17)),
#  (294, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 17)),
#  (295, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 17)),
#  (296, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 17)),
#  (297, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 17)),
#  (298, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 17)),
#  (299,
#   ('prev_onehot_NAME_PAYMENT_TYPE_Cash_through_the_bank_divide_count_SK_ID_CURR',
#    17)),
#  (300, ('prev_onehot_NAME_YIELD_GROUP_3.0_divide_count_SK_ID_CURR', 17)),
#  (301,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_0.0_divide_count_SK_ID_CURR', 17)),
#  (302, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_median', 17)),
#  (303, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min', 17)),
#  (304,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    17)),
#  (305,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    17)),
#  (306, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean', 17)),
#  (307, ('prev_AMT_CREDIT_median', 17)),
#  (308, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_sum', 17)),
#  (309, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 17)),
#  (310,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 17)),
#  (311, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 17)),
#  (312, ('poscash_CNT_INSTALMENT_sum', 17)),
#  (313,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    17)),
#  (314, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 17)),
#  (315, ('bureau_DAYS_ENDDATE_FACT_min', 17)),
#  (316, ('bureau_DAYS_ENDDATE_FACT_std', 17)),
#  (317, ('bureau_AMT_CREDIT_SUM_min', 17)),
#  (318, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 17)),
#  (319, ('livingsum_MODE_divide_members', 16)),
#  (320, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 16)),
#  (321,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    16)),
#  (322, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 16)),
#  (323, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_mean', 16)),
#  (324, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 16)),
#  (325, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_min', 16)),
#  (326,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min',
#    16)),
#  (327, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 16)),
#  (328, ('prev_AMT_CREDIT_sum', 16)),
#  (329,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    16)),
#  (330,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 16)),
#  (331, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_mean', 16)),
#  (332,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    16)),
#  (333, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_max', 16)),
#  (334, ('prev_DAYS_LAST_DUE_1ST_VERSION_max', 16)),
#  (335, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_max', 16)),
#  (336, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 16)),
#  (337, ('poscash_onehot_NAME_CONTRACT_STATUS_Active', 16)),
#  (338, ('poscash_MONTHS_BALANCE_max', 16)),
#  (339, ('bureau_DAYS_CREDIT_sum', 16)),
#  (340, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std', 16)),
#  (341, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std', 16)),
#  (342, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum', 16)),
#  (343, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max', 16)),
#  (344, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_min', 16)),
#  (345, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_MON', 15)),
#  (346, ('prev_onehot_CODE_REJECT_REASON_SCO_divide_count_SK_ID_CURR', 15)),
#  (347,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR', 15)),
#  (348, ('prev_onehot_NAME_YIELD_GROUP_0.0_divide_count_SK_ID_CURR', 15)),
#  (349, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 15)),
#  (350, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_sum', 15)),
#  (351,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    15)),
#  (352, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 15)),
#  (353, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_median', 15)),
#  (354, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_mean', 15)),
#  (355,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    15)),
#  (356,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    15)),
#  (357,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    15)),
#  (358,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    15)),
#  (359,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    15)),
#  (360, ('prev_DAYS_FIRST_DUE_max', 15)),
#  (361, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max', 15)),
#  (362,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 15)),
#  (363, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 15)),
#  (364, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_min', 15)),
#  (365,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 15)),
#  (366,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 15)),
#  (367, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_max', 15)),
#  (368, ('poscash_CNT_INSTALMENT_FUTURE_sum', 15)),
#  (369, ('poscash_CNT_INSTALMENT_FUTURE_max', 15)),
#  (370, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_mean', 15)),
#  (371, ('bureau_AMT_CREDIT_SUM_max', 15)),
#  (372, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max', 15)),
#  (373, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean', 15)),
#  (374, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std', 15)),
#  (375, ('FLAG_DOCUMENT_18', 14)),
#  (376, ('livingsum_AVG_divide_members', 14)),
#  (377, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 14)),
#  (378, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OWN_CAR_AGE', 14)),
#  (379,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Canceled_divide_count_SK_ID_CURR', 14)),
#  (380, ('prev_onehot_NAME_PRODUCT_TYPE_XNA_divide_count_SK_ID_CURR', 14)),
#  (381, ('prev_onehot_NAME_SELLER_INDUSTRY_XNA_divide_count_SK_ID_CURR', 14)),
#  (382, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median', 14)),
#  (383,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 14)),
#  (384, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median', 14)),
#  (385, ('prev_RATE_DOWN_PAYMENT_median', 14)),
#  (386, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min', 14)),
#  (387, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 14)),
#  (388, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min', 14)),
#  (389, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_mean', 14)),
#  (390, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 14)),
#  (391, ('prev_AMT_DOWN_PAYMENT_median', 14)),
#  (392,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    14)),
#  (393,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    14)),
#  (394, ('prev_DAYS_FIRST_DUE_sum', 14)),
#  (395,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 14)),
#  (396, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_mean', 14)),
#  (397, ('prev_AMT_ANNUITY_max', 14)),
#  (398,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    14)),
#  (399, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 14)),
#  (400, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 14)),
#  (401,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    14)),
#  (402,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    14)),
#  (403,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min',
#    14)),
#  (404, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 14)),
#  (405,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    14)),
#  (406,
#   ('bureau_onehot_CREDIT_TYPE_Credit_card_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    14)),
#  (407, ('bureau_DAYS_ENDDATE_FACT_mean', 14)),
#  (408, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std', 14)),
#  (409, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 14)),
#  (410, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum', 14)),
#  (411, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_max', 14)),
#  (412, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_mean', 14)),
#  (413, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_std', 14)),
#  (414, ('HOUR_APPR_PROCESS_START', 13)),
#  (415, ('LIVINGAREA_AVG', 13)),
#  (416, ('CONTACT', 13)),
#  (417, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 13)),
#  (418, ('AMT_REQ_CREDIT_BUREAU_MON_divide_DAYS_REGISTRATION', 13)),
#  (419, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 13)),
#  (420, ('prev_onehot_CHANNEL_TYPE_Stone_divide_count_SK_ID_CURR', 13)),
#  (421,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 13)),
#  (422,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 13)),
#  (423,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 13)),
#  (424, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_max', 13)),
#  (425, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 13)),
#  (426, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 13)),
#  (427,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    13)),
#  (428, ('prev_DAYS_TERMINATION_min', 13)),
#  (429, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max', 13)),
#  (430, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_mean', 13)),
#  (431, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_max', 13)),
#  (432, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 13)),
#  (433, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min', 13)),
#  (434,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    13)),
#  (435, ('prev_RATE_DOWN_PAYMENT_max', 13)),
#  (436, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_mean', 13)),
#  (437,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    13)),
#  (438, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 13)),
#  (439,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    13)),
#  (440, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 13)),
#  (441, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_max', 13)),
#  (442, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 13)),
#  (443,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 13)),
#  (444, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 13)),
#  (445, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 13)),
#  (446, ('prev_DAYS_FIRST_DUE_mean', 13)),
#  (447,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 13)),
#  (448,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    13)),
#  (449, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_median', 13)),
#  (450, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_median', 13)),
#  (451, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_sum', 13)),
#  (452, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_min', 13)),
#  (453, ('prev_AMT_ANNUITY_sum', 13)),
#  (454, ('prev_DAYS_LAST_DUE_sum', 13)),
#  (455, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_sum', 13)),
#  (456, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max', 13)),
#  (457, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_max', 13)),
#  (458, ('prev_HOUR_APPR_PROCESS_START_min', 13)),
#  (459, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_median', 13)),
#  (460, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min', 13)),
#  (461, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 13)),
#  (462, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 13)),
#  (463, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_mean', 13)),
#  (464, ('bureau_DAYS_CREDIT_UPDATE_min', 13)),
#  (465, ('bureau_AMT_CREDIT_SUM_std', 13)),
#  (466, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 13)),
#  (467, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 13)),
#  (468, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean', 13)),
#  (469, ('bureau_MONTHS_BALANCE_std_sum', 13)),
#  (470, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_max', 13)),
#  (471, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 13)),
#  (472, ('YEARS_BEGINEXPLUATATION_MODE', 12)),
#  (473, ('FLOORSMAX_MEDI', 12)),
#  (474, ('TOTALAREA_MODE', 12)),
#  (475, ('OBS_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 12)),
#  (476, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 12)),
#  (477, ('AMT_GOODS_PRICE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 12)),
#  (478, ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity', 12)),
#  (479,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_0.0_divide_count_SK_ID_CURR', 12)),
#  (480, ('prev_onehot_NAME_YIELD_GROUP_4.0_divide_count_SK_ID_CURR', 12)),
#  (481,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_2.0_divide_count_SK_ID_CURR', 12)),
#  (482, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 12)),
#  (483,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 12)),
#  (484, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_max', 12)),
#  (485,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min',
#    12)),
#  (486, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_mean', 12)),
#  (487, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min', 12)),
#  (488,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    12)),
#  (489,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    12)),
#  (490,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    12)),
#  (491, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_mean', 12)),
#  (492, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 12)),
#  (493,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    12)),
#  (494, ('prev_AMT_GOODS_PRICE_median', 12)),
#  (495, ('prev_AMT_GOODS_PRICE_sum', 12)),
#  (496, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median', 12)),
#  (497, ('prev_AMT_CREDIT_min', 12)),
#  (498,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    12)),
#  (499, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_median', 12)),
#  (500, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_mean', 12)),
#  (501, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_mean', 12)),
#  (502,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    12)),
#  (503,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    12)),
#  (504,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 12)),
#  (505,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    12)),
#  (506,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 12)),
#  (507, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 12)),
#  (508, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_mean', 12)),
#  (509,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 12)),
#  (510, ('prev_AMT_APPLICATION_mean', 12)),
#  (511,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    12)),
#  (512,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    12)),
#  (513, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_sum', 12)),
#  (514, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 12)),
#  (515, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 12)),
#  (516,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 12)),
#  (517, ('prev_AMT_CREDIT_divide_DAYS_DECISION_max', 12)),
#  (518, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_mean', 12)),
#  (519,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    12)),
#  (520, ('prev_HOUR_APPR_PROCESS_START_median', 12)),
#  (521, ('poscash_CNT_INSTALMENT_FUTURE_median', 12)),
#  (522, ('bureau_onehot_CREDIT_TYPE_Microloan', 12)),
#  (523, ('bureau_count_SK_ID_CURR', 12)),
#  (524, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 12)),
#  (525, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 12)),
#  (526, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_sum', 12)),
#  (527, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_sum', 12)),
#  (528, ('bureau_AMT_CREDIT_SUM_mean', 12)),
#  (529, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_min', 12)),
#  (530, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_median', 12)),
#  (531, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum', 12)),
#  (532, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_std', 12)),
#  (533, ('bureau_onehot_STATUS_1_std', 12)),
#  (534, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 11)),
#  (535, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 11)),
#  (536, ('AMT_ANNUITY_divide_OBS_30_CNT_SOCIAL_CIRCLE', 11)),
#  (537, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_REGISTRATION', 11)),
#  (538, ('prev_onehot_CHANNEL_TYPE_Country-wide_divide_count_SK_ID_CURR', 11)),
#  (539,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_1.0_divide_count_SK_ID_CURR', 11)),
#  (540, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_median', 11)),
#  (541, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_max', 11)),
#  (542, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_sum', 11)),
#  (543,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    11)),
#  (544,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    11)),
#  (545, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_max', 11)),
#  (546, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_max', 11)),
#  (547, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_sum', 11)),
#  (548, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 11)),
#  (549, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_max', 11)),
#  (550,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    11)),
#  (551,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    11)),
#  (552, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 11)),
#  (553,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    11)),
#  (554,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean', 11)),
#  (555, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 11)),
#  (556, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 11)),
#  (557, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_max', 11)),
#  (558, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_sum', 11)),
#  (559, ('prev_AMT_DOWN_PAYMENT_mean', 11)),
#  (560, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_max', 11)),
#  (561, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 11)),
#  (562,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    11)),
#  (563, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum', 11)),
#  (564,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    11)),
#  (565, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_min', 11)),
#  (566, ('prev_AMT_APPLICATION_median', 11)),
#  (567,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    11)),
#  (568, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_median', 11)),
#  (569, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_max', 11)),
#  (570, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_max', 11)),
#  (571,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 11)),
#  (572, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_sum', 11)),
#  (573,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 11)),
#  (574, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 11)),
#  (575,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    11)),
#  (576, ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 11)),
#  (577, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_min', 11)),
#  (578,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_median', 11)),
#  (579, ('bureau_AMT_CREDIT_SUM_median', 11)),
#  (580, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean', 11)),
#  (581, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_median', 11)),
#  (582, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_median', 11)),
#  (583, ('bureau_MONTHS_BALANCE_std_std', 11)),
#  (584, ('bureau_DAYS_CREDIT_ENDDATE_min', 11)),
#  (585, ('bureau_onehot_STATUS_0_std', 11)),
#  (586, ('bureau_onehot_STATUS_X_mean', 11)),
#  (587, ('bureau_AMT_CREDIT_SUM_divide_AMT_ANNUITY_median', 11)),
#  (588, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_median', 11)),
#  (589, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_min', 11)),
#  (590, ('APARTMENTS_AVG', 10)),
#  (591, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 10)),
#  (592, ('AMT_ANNUITY_divide_CNT_CHILDREN', 10)),
#  (593, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in', 10)),
#  (594, ('prev_onehot_NAME_PAYMENT_TYPE_XNA_divide_count_SK_ID_CURR', 10)),
#  (595,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Furniture_divide_count_SK_ID_CURR', 10)),
#  (596,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 10)),
#  (597, ('prev_CNT_PAYMENT_median', 10)),
#  (598, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_median', 10)),
#  (599, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_sum', 10)),
#  (600,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    10)),
#  (601,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    10)),
#  (602, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_median', 10)),
#  (603, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_max', 10)),
#  (604, ('prev_WEEKDAY_APPR_PROCESS_START_median', 10)),
#  (605, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 10)),
#  (606, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 10)),
#  (607, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_max', 10)),
#  (608,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 10)),
#  (609,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    10)),
#  (610, ('prev_AMT_GOODS_PRICE_min', 10)),
#  (611, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_median', 10)),
#  (612,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    10)),
#  (613, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_min', 10)),
#  (614,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    10)),
#  (615,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    10)),
#  (616,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    10)),
#  (617,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    10)),
#  (618,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min',
#    10)),
#  (619, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_sum', 10)),
#  (620, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean', 10)),
#  (621, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 10)),
#  (622, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_sum', 10)),
#  (623,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 10)),
#  (624, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_max', 10)),
#  (625, ('prev_AMT_ANNUITY_mean', 10)),
#  (626, ('prev_DAYS_LAST_DUE_min', 10)),
#  (627, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_sum', 10)),
#  (628, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_max', 10)),
#  (629,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    10)),
#  (630, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_mean', 10)),
#  (631, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_median', 10)),
#  (632, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_max', 10)),
#  (633,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    10)),
#  (634, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_min', 10)),
#  (635,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 10)),
#  (636,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 10)),
#  (637,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    10)),
#  (638, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_mean', 10)),
#  (639, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_sum', 10)),
#  (640, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 10)),
#  (641, ('poscash_CNT_INSTALMENT_median', 10)),
#  (642, ('poscash_SK_DPD_DEF_std', 10)),
#  (643, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_max', 10)),
#  (644, ('bureau_onehot_CREDIT_TYPE_Mortgage', 10)),
#  (645, ('bureau_DAYS_ENDDATE_FACT_sum', 10)),
#  (646, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_max', 10)),
#  (647, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_mean', 10)),
#  (648, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_mean', 10)),
#  (649, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_sum', 10)),
#  (650, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_max', 10)),
#  (651, ('FLOORSMAX_AVG', 9)),
#  (652, ('LANDAREA_AVG', 9)),
#  (653, ('LIVINGAREA_MODE', 9)),
#  (654, ('APARTMENTS_MEDI', 9)),
#  (655, ('REGION_RATING_CLIENT_times_livingsum_AVG', 9)),
#  (656, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 9)),
#  (657, ('AMT_CREDIT_divide_OWN_CAR_AGE', 9)),
#  (658, ('AMT_ANNUITY_divide_OWN_CAR_AGE', 9)),
#  (659, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_LAST_PHONE_CHANGE', 9)),
#  (660, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OBS_60_CNT_SOCIAL_CIRCLE', 9)),
#  (661, ('prev_onehot_NAME_YIELD_GROUP_1.0', 9)),
#  (662, ('prev_onehot_NAME_PRODUCT_TYPE_x-sell_divide_count_SK_ID_CURR', 9)),
#  (663,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 9)),
#  (664,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 9)),
#  (665, ('prev_CNT_PAYMENT_sum', 9)),
#  (666, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_sum', 9)),
#  (667, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_mean', 9)),
#  (668, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_sum', 9)),
#  (669, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_mean', 9)),
#  (670, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 9)),
#  (671,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    9)),
#  (672,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    9)),
#  (673, ('prev_DAYS_TERMINATION_median', 9)),
#  (674, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_mean', 9)),
#  (675, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max', 9)),
#  (676,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    9)),
#  (677, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_min', 9)),
#  (678,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    9)),
#  (679, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_median', 9)),
#  (680, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_min', 9)),
#  (681, ('prev_AMT_GOODS_PRICE_mean', 9)),
#  (682, ('prev_AMT_GOODS_PRICE_max', 9)),
#  (683,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    9)),
#  (684,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    9)),
#  (685,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    9)),
#  (686, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_mean', 9)),
#  (687,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    9)),
#  (688,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    9)),
#  (689,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    9)),
#  (690,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    9)),
#  (691, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max', 9)),
#  (692,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    9)),
#  (693,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 9)),
#  (694, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_median', 9)),
#  (695, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_sum', 9)),
#  (696, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_mean', 9)),
#  (697,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    9)),
#  (698,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 9)),
#  (699, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_median', 9)),
#  (700, ('prev_DAYS_LAST_DUE_1ST_VERSION_mean', 9)),
#  (701, ('prev_DAYS_LAST_DUE_1ST_VERSION_sum', 9)),
#  (702,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    9)),
#  (703,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    9)),
#  (704, ('prev_AMT_CREDIT_divide_DAYS_DECISION_median', 9)),
#  (705, ('poscash_SK_DPD_divide_MONTHS_BALANCE_mean', 9)),
#  (706, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_sum', 9)),
#  (707, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_std', 9)),
#  (708, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_min', 9)),
#  (709, ('bureau_DAYS_CREDIT_UPDATE_sum', 9)),
#  (710, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_max', 9)),
#  (711, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_std', 9)),
#  (712, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_mean', 9)),
#  (713, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_median', 9)),
#  (714, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_max', 9)),
#  (715, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max', 9)),
#  (716, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_std', 9)),
#  (717, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_min', 9)),
#  (718, ('bureau_onehot_STATUS_0_mean', 9)),
#  (719, ('bureau_onehot_STATUS_0_max', 9)),
#  (720, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_mean', 9)),
#  (721, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CNT_CREDIT_PROLONG_sum', 9)),
#  (722, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_ENDDATE_max', 9)),
#  (723, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_std', 9)),
# ...
#  (765, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_median', 8)),
#  (766, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_min', 8)),
#  (767, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_sum', 8)),
#  (768,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    8)),
#  (769,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    8)),
#  (770,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    8)),
#  (771,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    8)),
#  (772,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    8)),
#  (773, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_median', 8)),
#  (774, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_mean', 8)),
#  (775,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 8)),
#  (776, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_mean', 8)),
#  (777, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_median', 8)),
#  (778, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_min', 8)),
#  (779, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_min', 8)),
#  (780,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 8)),
#  (781,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    8)),
#  (782, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_sum', 8)),
#  (783,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    8)),
#  (784,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 8)),
#  (785,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 8)),
#  (786,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Returned_to_the_store_divide_positivecount_SK_ID_CURR_SK_DPD',
#    8)),
#  (787, ('bureau_onehot_CREDIT_TYPE_Credit_card', 8)),
#  (788, ('bureau_AMT_CREDIT_SUM_DEBT_max', 8)),
#  (789, ('bureau_MONTHS_BALANCE_max_mean', 8)),
#  (790, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_median', 8)),
#  (791, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_sum', 8)),
#  (792, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_mean', 8)),
#  (793, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_median', 8)),
#  (794, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_median', 8)),
#  (795, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_std', 8)),
#  (796, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum', 8)),
#  (797, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_sum', 8)),
#  (798,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_median', 8)),
#  (799, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_sum', 8)),
#  (800, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_median', 8)),
#  (801, ('REGION_RATING_CLIENT', 7)),
#  (802, ('LIVE_CITY_NOT_WORK_CITY', 7)),
#  (803, ('NONLIVINGAPARTMENTS_AVG', 7)),
#  (804, ('LIVINGAREA_MEDI', 7)),
#  (805, ('WALLSMATERIAL_MODE', 7)),
#  (806, ('FLAG_DOCUMENT_16', 7)),
#  (807, ('livingsum_MEDI', 7)),
#  (808, ('OBS_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 7)),
#  (809, ('OBS_60_CNT_SOCIAL_CIRCLE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 7)),
#  (810, ('req_total', 7)),
#  (811, ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_QRT', 7)),
#  (812, ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 7)),
#  (813, ('AMT_REQ_CREDIT_BUREAU_MON_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 7)),
#  (814, ('OWN_CAR_AGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 7)),
#  (815, ('prev_onehot_CHANNEL_TYPE_Contact_center', 7)),
#  (816, ('prev_onehot_CODE_REJECT_REASON_LIMIT_divide_count_SK_ID_CURR', 7)),
#  (817, ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR', 7)),
#  (818,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_1.0_divide_count_SK_ID_CURR', 7)),
#  (819, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 7)),
#  (820, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_min', 7)),
#  (821, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_sum', 7)),
#  (822, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 7)),
#  (823, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_sum', 7)),
#  (824, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_median', 7)),
#  (825, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_min', 7)),
#  (826, ('prev_WEEKDAY_APPR_PROCESS_START_sum', 7)),
#  (827, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean', 7)),
#  (828,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    7)),
#  (829,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    7)),
#  (830,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    7)),
#  (831, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_min', 7)),
#  (832, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_sum', 7)),
#  (833,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    7)),
#  (834, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 7)),
#  (835, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 7)),
#  (836, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_mean', 7)),
#  (837, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_min', 7)),
#  (838,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 7)),
#  (839,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    7)),
#  (840,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 7)),
#  (841,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 7)),
#  (842, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 7)),
#  (843, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_median', 7)),
#  (844, ('prev_AMT_DOWN_PAYMENT_sum', 7)),
#  (845,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    7)),
#  (846,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    7)),
#  (847, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_median', 7)),
#  (848,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    7)),
#  (849,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    7)),
#  (850,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    7)),
#  (851, ('prev_DAYS_LAST_DUE_mean', 7)),
#  (852, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_mean', 7)),
#  (853, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_max', 7)),
#  (854, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_median', 7)),
#  (855, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_median', 7)),
#  (856,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    7)),
#  (857, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_mean', 7)),
#  (858, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_sum', 7)),
#  (859,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    7)),
#  (860,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    7)),
#  (861,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 7)),
#  (862, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_median', 7)),
#  (863, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_sum', 7)),
#  (864, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_sum', 7)),
#  (865, ('poscash_CNT_INSTALMENT_max', 7)),
#  (866, ('poscash_SK_DPD_divide_MONTHS_BALANCE_sum', 7)),
#  (867, ('poscash_SK_DPD_DEF_mean', 7)),
#  (868, ('bureau_MONTHS_BALANCE_median_median', 7)),
#  (869, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_mean', 7)),
#  (870, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_max', 7)),
#  (871, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_std', 7)),
#  (872, ('bureau_MONTHS_BALANCE_sum_median', 7)),
#  (873, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_std', 7)),
#  (874, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_max', 7)),
#  (875, ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_min', 7)),
#  (876, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_mean', 7)),
#  (877, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_mean', 7)),
#  (878,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_median', 7)),
#  (879, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_std', 7)),
#  (880, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_min', 7)),
#  (881, ('bureau_MONTHS_BALANCE_std_median', 7)),
#  (882, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_median', 7)),
#  (883, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_std', 7)),
#  (884, ('bureau_onehot_STATUS_0_min', 7)),
#  (885, ('bureau_onehot_STATUS_X_min', 7)),
#  (886, ('bureau_AMT_CREDIT_SUM_divide_AMT_ANNUITY_std', 7)),
#  (887, ('bureau_AMT_CREDIT_MAX_OVERDUE_mean', 7)),
#  (888, ('bureau_AMT_CREDIT_MAX_OVERDUE_max', 7)),
#  (889, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_median', 7)),
#  (890, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_median', 7)),
#  (891, ('YEARS_BEGINEXPLUATATION_AVG', 6)),
#  (892, ('COMMONAREA_AVG', 6)),
#  (893, ('APARTMENTS_MODE', 6)),
#  (894, ('COMMONAREA_MODE', 6)),
#  (895, ('YEARS_BUILD_MEDI', 6)),
#  (896, ('ENTRANCES_MEDI', 6)),
#  (897, ('livingsum_AVG', 6)),
#  (898, ('REGION_RATING_CLIENT_times_livingsum_MEDI', 6)),
#  (899, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 6)),
#  (900, ('DEF_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 6)),
#  (901, ('DEF_60_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 6)),
#  (902, ('DEF_60_CNT_SOCIAL_CIRCLE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 6)),
#  (903, ('AMT_INCOME_TOTAL_divide_CNT_CHILDREN', 6)),
#  (904, ('AMT_CREDIT_divide_DEF_60_CNT_SOCIAL_CIRCLE', 6)),
#  (905, ('AMT_GOODS_PRICE_divide_CNT_CHILDREN', 6)),
#  (906, ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_MON', 6)),
#  (907, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_OBS_60_CNT_SOCIAL_CIRCLE', 6)),
#  (908, ('OWN_CAR_AGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 6)),
#  (909, ('prev_onehot_CODE_REJECT_REASON_HC', 6)),
#  (910, ('prev_onehot_CODE_REJECT_REASON_SCOFR', 6)),
#  (911, ('prev_onehot_NAME_YIELD_GROUP_4.0', 6)),
#  (912,
#   ('prev_onehot_NAME_CONTRACT_TYPE_Consumer_loans_divide_count_SK_ID_CURR',
#    6)),
#  (913, ('prev_onehot_NAME_PORTFOLIO_Cash_divide_count_SK_ID_CURR', 6)),
#  (914, ('prev_onehot_CHANNEL_TYPE_Contact_center_divide_count_SK_ID_CURR', 6)),
#  (915,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Clothing_divide_count_SK_ID_CURR', 6)),
#  (916, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_mean', 6)),
#  (917, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 6)),
#  (918, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_min', 6)),
#  (919, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_max', 6)),
#  (920,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 6)),
#  (921,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum',
#    6)),
#  (922, ('prev_DAYS_TERMINATION_sum', 6)),
#  (923, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 6)),
#  (924, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_median', 6)),
#  (925, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_max', 6)),
#  (926, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_sum', 6)),
#  (927,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    6)),
#  (928,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    6)),
#  (929, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean', 6)),
#  (930,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    6)),
#  (931,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    6)),
#  (932, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_median', 6)),
#  (933,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    6)),
#  (934, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_max', 6)),
#  (935,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    6)),
#  (936,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    6)),
#  (937, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min', 6)),
#  (938,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    6)),
#  (939,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum',
#    6)),
#  (940, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_mean', 6)),
#  (941, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_sum', 6)),
#  (942,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 6)),
#  (943, ('prev_AMT_APPLICATION_min', 6)),
#  (944, ('prev_AMT_APPLICATION_sum', 6)),
#  (945,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    6)),
#  (946,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    6)),
#  (947, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_median', 6)),
#  (948, ('poscash_CNT_INSTALMENT_min', 6)),
#  (949, ('poscash_SK_DPD_sum', 6)),
#  (950, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_FUTURE_mean', 6)),
#  (951, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_sum', 6)),
#  (952, ('poscash_SK_DPD_divide_CNT_INSTALMENT_mean', 6)),
#  (953,
#   ('bureau_onehot_CREDIT_ACTIVE_Closed_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    6)),
#  (954,
#   ('bureau_onehot_CREDIT_TYPE_Consumer_credit_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    6)),
#  (955, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_mean', 6)),
#  (956, ('bureau_AMT_CREDIT_SUM_DEBT_median', 6)),
#  (957, ('bureau_MONTHS_BALANCE_sum_mean', 6)),
#  (958, ('bureau_MONTHS_BALANCE_min_std', 6)),
#  (959, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_sum', 6)),
#  (960, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_ENDDATE_max', 6)),
#  (961, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_min', 6)),
#  (962, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_median', 6)),
#  (963, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_UPDATE_mean', 6)),
#  (964, ('bureau_MONTHS_BALANCE_mean_median', 6)),
#  (965, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_max', 6)),
#  (966, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_std', 6)),
#  (967, ('bureau_onehot_STATUS_0_median', 6)),
#  (968, ('bureau_AMT_ANNUITY_divide_CNT_CREDIT_PROLONG_max', 6)),
#  (969, ('bureau_AMT_CREDIT_MAX_OVERDUE_sum', 6)),
#  (970, ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_std', 6)),
#  (971, ('bureau_onehot_STATUS_1_max', 6)),
#  (972, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_max', 6)),
#  (973, ('NAME_CONTRACT_TYPE', 5)),
#  (974, ('CNT_FAM_MEMBERS', 5)),
#  (975, ('BASEMENTAREA_AVG', 5)),
#  (976, ('HOUSETYPE_MODE', 5)),
#  (977, ('livingsum_MODE', 5)),
#  (978, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 5)),
#  (979, ('AMT_CREDIT_divide_CNT_CHILDREN', 5)),
#  (980, ('AMT_GOODS_PRICE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 5)),
#  (981, ('AMT_GOODS_PRICE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 5)),
#  (982, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_CNT_FAM_MEMBERS', 5)),
#  (983, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_OBS_30_CNT_SOCIAL_CIRCLE', 5)),
#  (984, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_OWN_CAR_AGE', 5)),
#  (985, ('prev_onehot_NAME_TYPE_SUITE_nan', 5)),
#  (986, ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan', 5)),
#  (987,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Auto_technology_divide_count_SK_ID_CURR',
#    5)),
#  (988, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 5)),
#  (989, ('prev_CNT_PAYMENT_min', 5)),
#  (990,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min', 5)),
#  (991, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_mean', 5)),
#  (992, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_min', 5)),
#  (993,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    5)),
#  (994,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean',
#    5)),
#  (995, ('prev_RATE_DOWN_PAYMENT_sum', 5)),
#  (996, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_median', 5)),
#  (997,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    5)),
#  (998,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    5)),
#  (999, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median', 5)),
#  ...]
