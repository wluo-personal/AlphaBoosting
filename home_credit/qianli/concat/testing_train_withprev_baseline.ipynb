# %%
import os
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
PATH = '/home/kai/data/kaggle/homecredit/'

# %%
train = pd.read_pickle(PATH + 'inter/train_only_0.pkl')
test = pd.read_pickle(PATH + 'inter/test_only_0.pkl')
# train = pd.read_pickle(PATH + 'test/train_w_prev_2.pkl')
# test = pd.read_pickle(PATH + 'test/test_w_prev_2.pkl')

print(train.shape,test.shape)
train.shape, test.shape
prev = pd.read_pickle(PATH + 'test/prev2curr_0.pkl')
print(prev.shape)
pos = pd.read_pickle(PATH + 'inter/poscash2curr.pkl')
print(pos.shape)
cred = pd.read_pickle(PATH + 'inter/credit2curr.pkl')
print(cred.shape)
install = pd.read_pickle(PATH + 'inter/install2curr.pkl')
print(install.shape)
bureau = pd.read_pickle(PATH + 'inter/bureau2curr.pkl')
print(bureau.shape)
# Out:
# (307511, 1225) (48744, 1224)
# (356255, 116)
# (356255, 502)
# (356255, 60)
# (356255, 554)

# %%
# files = [prev,pos,cred,install,bureau]
files = [pos,cred,install,bureau]
for tmp in files:
#     cols = [col for col in tmp.columns if 'std' not in col]
#     tmp = tmp[cols]
#     print(tmp.shape)
    train = train.merge(tmp, on='SK_ID_CURR', how='left')
    test = test.merge(tmp, on='SK_ID_CURR', how='left')
    print(train.shape,test.shape)
# Out:
# (307511, 1340) (48744, 1339)
# (307511, 1841) (48744, 1840)
# (307511, 1900) (48744, 1899)
# (307511, 2453) (48744, 2452)

# %%
# train.to_pickle(PATH + 'test/train_1.pkl')
# test.to_pickle(PATH + 'test/test_1.pkl')

# %%
# train = pd.read_pickle(PATH + 'test/train_1.pkl')
# test = pd.read_pickle(PATH + 'test/test_1.pkl')

# %%
print(train.shape, test.shape)
# Out:
# (307511, 2453) (48744, 2452)

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
PATH = '/home/kai/data/kaggle/homecredit/'
print('begin cv')
target = train['TARGET']
test_df = test.copy()
ignore_cols = ['ORGANIZATION_TYPE', 'TARGET', 'SK_ID_CURR']
features = [x for x in train.columns if x not in ignore_cols]
train = train[features]
test = test[features]

from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm

lgbm_train = lgbm.Dataset(data=train,
                          label=target,

                          categorical_feature=[],#categorical_feats,
                          free_raw_data=False)

# lgbm_params = {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 
#           'learning_rate': 0.01, 'num_leaves': 48, 'num_iteration': 4000, 'verbose': 0 ,
#           'colsample_bytree':.8, 'subsample':.9, 'max_depth':7, 'reg_alpha':.1, 'reg_lambda':.1, 
#           'min_split_gain':.01, 'min_child_weight':1,'num_threads': 12,'feature_fraction': 0.2,
#               'scale_pos_weight':1}
lgbm_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'learning_rate': 0.05,
    'num_iteration': 4000,
    'num_threads': 8,

    'num_leaves': int(round(44.368535336628419)),
    'feature_fraction': 0.28231763168020257,
    'bagging_fraction': 0.94901525271474951,
    'max_depth': int(round(8.0430115561596267)),
    'lambda_l1': 0.30680079516647751,
    'lambda_l2': 0.079128660903201031,
    'min_split_gain': 0.054005067457890979,
    'min_child_weight': 98.172643147364937}


cv_results = lgbm.cv(train_set=lgbm_train,
                     params=lgbm_params,
                     nfold=5,
                     early_stopping_rounds=150,
                     verbose_eval=100,
                     metrics=['auc'])

optimum_boost_rounds = np.argmax(cv_results['auc-mean'])
print('Optimum boost rounds = {}'.format(optimum_boost_rounds))
print('Best CV result = {}'.format(np.max(cv_results['auc-mean'])))

clf = lgbm.train(train_set=lgbm_train,
                 params=lgbm_params,
                 num_boost_round=optimum_boost_rounds,
                verbose_eval=100)

""" Predict on test set and create submission """
y_pred = clf.predict(test)
out_df = pd.DataFrame({'SK_ID_CURR': test_df['SK_ID_CURR'], 'TARGET': y_pred})
#     small_len = out_df[out_df['TARGET']< threshold1]
#     large_len = out_df[out_df['TARGET']> threshold2]
#     print('length of small and large,',len(small_len),len(large_len))
print((out_df['TARGET']>0.5).sum(),'more than half')
# Out:
# begin cv
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:390: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	cv_agg's auc: 0.779132 + 0.00324799
# [200]	cv_agg's auc: 0.789638 + 0.00288865
# [300]	cv_agg's auc: 0.792656 + 0.00258207
# [400]	cv_agg's auc: 0.793768 + 0.00251348
# [500]	cv_agg's auc: 0.794278 + 0.00250652
# [600]	cv_agg's auc: 0.794232 + 0.00250003
# Optimum boost rounds = 527
# Best CV result = 0.7944102226555453
# /home/kai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# 215 more than half

# %% [markdown]
# without std bayes para, 7788 (train with prev)
# with std bayes para, 7789 (train without prev)

# %%
(out_df['TARGET']>0.5).sum()
out_df.to_csv(PATH+'submission/06_29_0.csv', index = False)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import lightgbm as lgbm
fig, (ax, ax1) = plt.subplots(1, 2, figsize=[15, 7])
lgbm.plot_importance(clf, ax=ax, max_num_features=30, importance_type='split')
lgbm.plot_importance(clf, ax=ax1, max_num_features=30, importance_type='gain')
ax.set_title('Importance by splits')
ax1.set_title('Importance by gain')
plt.tight_layout()
plt.show()

x = [x for x in zip(clf.feature_name(), clf.feature_importance('gain'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_2', 44618.43893909454)),
#  (1, ('EXT_SOURCE_3', 38191.19681215286)),
#  (2, ('EXT_SOURCE_1', 17131.662755966187)),
#  (3,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 9562.412023544312)),
#  (4, ('AMT_CREDIT_divide_AMT_ANNUITY', 8818.131184101105)),
#  (5, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 8060.260680198669)),
#  (6,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_max',
#    7037.910512447357)),
#  (7, ('DAYS_BIRTH', 5801.746730804443)),
#  (8, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 5703.616059064865)),
#  (9, ('CODE_GENDER', 4934.960584163666)),
#  (10, ('bureau_DAYS_CREDIT_median', 4769.7915506362915)),
#  (11, ('one_hotNAME_EDUCATION_TYPE_Higher_education', 4644.377899169922)),
#  (12,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_mean',
#    4606.771881103516)),
#  (13, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 4223.537695884705)),
#  (14, ('bureau_DAYS_CREDIT_mean', 4178.156384468079)),
#  (15,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR',
#    3234.934332370758)),
#  (16,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median',
#    2892.846396923065)),
#  (17, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 2768.8332147598267)),
#  (18, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 2727.9008555412292)),
#  (19, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 2723.880184173584)),
#  (20,
#   ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR',
#    2421.465964794159)),
#  (21,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    2244.1916332244873)),
#  (22,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    2180.263382911682)),
#  (23, ('AMT_GOODS_PRICE', 2050.674334049225)),
#  (24,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 1870.7919669151306)),
#  (25,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_max',
#    1763.4104132652283)),
#  (26, ('AMT_ANNUITY', 1730.2480154037476)),
#  (27, ('bureau_DAYS_CREDIT_max', 1719.130536556244)),
#  (28, ('poscash_CNT_INSTALMENT_FUTURE_std', 1688.488293647766)),
#  (29,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_sum', 1645.6509580612183)),
#  (30,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_sum',
#    1597.567211151123)),
#  (31, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 1554.2964515686035)),
#  (32,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum',
#    1501.0914096832275)),
#  (33, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 1493.8974213600159)),
#  (34, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 1487.7709693908691)),
#  (35, ('bureau_DAYS_CREDIT_UPDATE_median', 1484.4523711204529)),
#  (36, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 1418.7297039031982)),
#  (37,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR',
#    1412.0188431739807)),
#  (38,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    1378.0258359909058)),
#  (39,
#   ('one_hotNAME_EDUCATION_TYPE_Secondary_/_secondary_special',
#    1326.3271503448486)),
#  (40,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median',
#    1313.5608863830566)),
#  (41,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_sum',
#    1276.6807498931885)),
#  (42,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_max',
#    1275.8925857543945)),
#  (43, ('install_DAYS_ENTRY_PAYMENT_std', 1232.6253385543823)),
#  (44,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    1218.6339948177338)),
#  (45,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median',
#    1188.3722915649414)),
#  (46, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 1185.4462175369263)),
#  (47,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median',
#    1170.446509361267)),
#  (48,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std', 1155.655531167984)),
#  (49,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_sum',
#    1154.413727760315)),
#  (50, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_std', 1154.105800628662)),
#  (51,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 1113.7620816230774)),
#  (52, ('install_DAYS_INSTALMENT_std', 1079.2143230438232)),
#  (53, ('AMT_ANNUITY_divide_DAYS_BIRTH', 1061.405846118927)),
#  (54, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_mean', 1055.9639658927917)),
#  (55,
#   ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR',
#    1051.642451763153)),
#  (56, ('REGION_POPULATION_RELATIVE', 1037.457937002182)),
#  (57, ('install_AMT_PAYMENT_sum', 1025.801519393921)),
#  (58,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    1017.9495506286621)),
#  (59, ('one_hotNAME_INCOME_TYPE_Working', 1010.8489756584167)),
#  (60, ('poscash_MONTHS_BALANCE_std', 1007.9870681762695)),
#  (61, ('bureau_DAYS_ENDDATE_FACT_max', 986.2112164497375)),
#  (62, ('one_hotNAME_FAMILY_STATUS_Married', 984.771484375)),
#  (63, ('poscash_CNT_INSTALMENT_FUTURE_mean', 981.6985034942627)),
#  (64, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 974.8956079483032)),
#  (65, ('bureau_DAYS_CREDIT_ENDDATE_max', 969.3361673355103)),
#  (66,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean',
#    958.8249664306641)),
#  (67, ('DAYS_ID_PUBLISH', 950.2162809371948)),
#  (68, ('REGION_RATING_CLIENT_W_CITY', 945.4358921051025)),
#  (69, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 944.2343311309814)),
#  (70, ('prev_CNT_PAYMENT_mean', 942.0568261146545)),
#  (71, ('bureau_onehot_CREDIT_ACTIVE_Active', 909.8652968406677)),
#  (72, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 908.1107320785522)),
#  (73, ('OWN_CAR_AGE', 894.0320925712585)),
#  (74, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_min', 883.5563049316406)),
#  (75,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean',
#    869.5180644989014)),
#  (76,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    861.5594730377197)),
#  (77, ('bureau_onehot_CREDIT_TYPE_Microloan', 858.7153115272522)),
#  (78, ('AMT_CREDIT_divide_DAYS_BIRTH', 857.4950113296509)),
#  (79, ('DAYS_EMPLOYED', 857.0959806442261)),
#  (80, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 851.3373289108276)),
#  (81,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 837.8540515899658)),
#  (82, ('bureau_DAYS_CREDIT_ENDDATE_median', 835.6065258979797)),
#  (83, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 820.1073231697083)),
#  (84,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_max', 817.6710247993469)),
#  (85,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 798.9691190719604)),
#  (86, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_mean', 788.7326636314392)),
#  (87, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_std', 776.7191801071167)),
#  (88,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min',
#    760.1293840408325)),
#  (89,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum', 725.3256101608276)),
#  (90,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    724.2746639251709)),
#  (91, ('FLAG_DOCUMENT_3', 719.7986664772034)),
#  (92,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Active_divide_positivecount_SK_ID_CURR_SK_DPD',
#    700.9737062454224)),
#  (93, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 695.185567855835)),
#  (94,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE',
#    691.0730791091919)),
#  (95, ('AMT_ANNUITY_divide_prev_AMT_ANNUITY_median', 666.3945202827454)),
#  (96, ('DAYS_LAST_PHONE_CHANGE', 665.961564540863)),
#  (97,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min', 658.5588326454163)),
#  (98, ('creditcard_CNT_DRAWINGS_CURRENT_std', 657.5647850036621)),
#  (99, ('prev_HOUR_APPR_PROCESS_START_mean', 651.1178240776062)),
#  (100, ('AMT_CREDIT', 647.063889503479)),
#  (101,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    641.9480791091919)),
#  (102, ('prev_CNT_PAYMENT_max', 634.5657253265381)),
#  (103,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 631.0837616920471)),
#  (104, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 626.2834115028381)),
#  (105,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 621.9617853164673)),
#  (106, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 610.728967666626)),
#  (107,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR',
#    604.4430332183838)),
#  (108, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 593.1852607727051)),
#  (109, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 582.0662560462952)),
#  (110, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 575.2327642440796)),
#  (111,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_sum', 575.1873650550842)),
#  (112,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 570.7008504867554)),
#  (113,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_min',
#    564.8639240264893)),
#  (114,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std',
#    561.8184270858765)),
#  (115, ('install_AMT_PAYMENT_min', 557.5220928192139)),
#  (116,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_std',
#    546.9186148643494)),
#  (117,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    546.3621320724487)),
#  (118, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 544.23011302948)),
#  (119,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min',
#    540.2213082313538)),
#  (120,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_mean',
#    535.7828969955444)),
#  (121, ('poscash_MONTHS_BALANCE_sum', 533.4898076057434)),
#  (122, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 525.4846525192261)),
#  (123, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 521.1486420631409)),
#  (124, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 517.3335218429565)),
#  (125, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 515.8175249099731)),
#  (126, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 513.9888272285461)),
#  (127, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 507.7321789264679)),
#  (128,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean',
#    506.7841067314148)),
#  (129, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 502.6852025985718)),
#  (130,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max', 499.0063338279724)),
#  (131,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    498.53467893600464)),
#  (132, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 496.99787950515747)),
#  (133,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min',
#    493.80155992507935)),
#  (134, ('poscash_onehot_NAME_CONTRACT_STATUS_Active', 493.2166657447815)),
#  (135, ('TOTALAREA_MODE', 492.8673515319824)),
#  (136, ('install_DAYS_ENTRY_PAYMENT_max', 488.4502077102661)),
#  (137, ('one_hotOCCUPATION_TYPE_Core_staff', 487.6480679512024)),
#  (138,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 480.11272621154785)),
#  (139, ('bureau_DAYS_CREDIT_ENDDATE_mean', 473.9790654182434)),
#  (140,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median',
#    471.1380491256714)),
#  (141,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    470.96272373199463)),
#  (142,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median',
#    469.1536707878113)),
#  (143, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 468.5128617286682)),
#  (144, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 466.36621046066284)),
#  (145, ('one_hotNAME_INCOME_TYPE_State_servant', 459.6195900440216)),
#  (146,
#   ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR',
#    457.45948028564453)),
#  (147,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    455.4137964248657)),
#  (148,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    446.1670923233032)),
#  (149, ('install_count_SK_ID_CURR', 444.3092432022095)),
#  (150, ('install_DAYS_ENTRY_PAYMENT_min', 438.78395318984985)),
#  (151, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 436.1460609436035)),
#  (152,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 435.6357088088989)),
#  (153,
#   ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 433.8241844177246)),
#  (154, ('poscash_MONTHS_BALANCE_min', 431.10248923301697)),
#  (155, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 427.69111824035645)),
#  (156,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    426.3376703262329)),
#  (157,
#   ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR',
#    423.8947296142578)),
#  (158,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    422.89066791534424)),
#  (159,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    420.8158507347107)),
#  (160, ('LIVINGAREA_AVG', 420.4054298400879)),
#  (161, ('creditcard_CNT_DRAWINGS_CURRENT_mean', 419.35779762268066)),
#  (162, ('REGION_RATING_CLIENT', 418.18960189819336)),
#  (163, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 414.1147825717926)),
#  (164, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 413.37800884246826)),
#  (165, ('poscash_CNT_INSTALMENT_std', 412.6373920440674)),
#  (166, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 411.7529368400574)),
#  (167, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 409.28976821899414)),
#  (168,
#   ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 407.19938373565674)),
#  (169, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 402.5694122314453)),
#  (170, ('install_AMT_INSTALMENT_sum', 399.3037214279175)),
#  (171,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    398.16880893707275)),
#  (172,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    394.4174528121948)),
#  (173,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 392.93223810195923)),
#  (174, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 391.9284930229187)),
#  (175, ('APARTMENTS_MEDI', 391.4094567298889)),
#  (176, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 389.8792505264282)),
#  (177, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 388.8542573451996)),
#  (178, ('install_AMT_PAYMENT_median', 388.1635808944702)),
#  (179, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 387.78291511535645)),
#  (180,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    387.21503925323486)),
#  (181,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    384.4902410507202)),
#  (182, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 382.5052170753479)),
#  (183, ('bureau_DAYS_CREDIT_min', 381.45097064971924)),
#  (184,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    380.06941843032837)),
#  (185,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max',
#    372.1225504875183)),
#  (186,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR',
#    364.87897062301636)),
#  (187,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_std',
#    360.51908922195435)),
#  (188,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum',
#    356.9046392440796)),
#  (189, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_mean', 355.4207019805908)),
#  (190,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    355.07348108291626)),
#  (191,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_std',
#    354.97968912124634)),
#  (192, ('prev_DAYS_DECISION_median', 354.02755069732666)),
#  (193,
#   ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR',
#    353.7662191390991)),
#  (194,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    350.6025958061218)),
#  (195, ('bureau_onehot_CREDIT_TYPE_Mortgage', 348.888090133667)),
#  (196, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 348.2553668022156)),
#  (197, ('install_AMT_PAYMENT_std', 347.9208474159241)),
#  (198,
#   ('prev_onehot_CODE_REJECT_REASON_SCOFR_divide_count_SK_ID_CURR',
#    347.81252574920654)),
#  (199, ('bureau_DAYS_CREDIT_UPDATE_std', 347.07301902770996)),
#  (200, ('AMT_ANNUITY_divide_prev_AMT_ANNUITY_mean', 346.01752948760986)),
#  (201,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    344.6110019683838)),
#  (202,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    343.8520975112915)),
#  (203,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    343.1908292770386)),
#  (204, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 339.62598848342896)),
#  (205, ('prev_HOUR_APPR_PROCESS_START_max', 337.2892599105835)),
#  (206, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 335.91281747817993)),
#  (207,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    333.20030307769775)),
#  (208, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 332.6979994773865)),
#  (209, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 332.22810077667236)),
#  (210,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 329.9113931655884)),
#  (211, ('REG_CITY_NOT_LIVE_CITY', 328.00136852264404)),
#  (212, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 325.9893608093262)),
#  (213, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 325.26311111450195)),
#  (214,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    323.70732164382935)),
#  (215,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std',
#    323.12649631500244)),
#  (216,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    321.98854875564575)),
#  (217,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max',
#    319.16913080215454)),
#  (218, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 318.71084928512573)),
#  (219, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 314.03685760498047)),
#  (220,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 313.1428716182709)),
#  (221, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 312.913631439209)),
#  (222,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 311.9339818954468)),
#  (223, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 311.73580169677734)),
#  (224,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 309.210168838501)),
#  (225, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 308.9340181350708)),
#  (226, ('poscash_count_SK_ID_CURR', 308.8289804458618)),
#  (227, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 307.9576106071472)),
#  (228, ('poscash_SK_DPD_DEF_std', 307.46918964385986)),
#  (229, ('install_AMT_INSTALMENT_max', 307.32761001586914)),
#  (230,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std',
#    302.8479676246643)),
#  (231, ('bureau_DAYS_CREDIT_UPDATE_max', 302.8153405189514)),
#  (232,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    301.74061012268066)),
#  (233, ('prev_DAYS_DECISION_max', 301.41361236572266)),
#  (234, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 300.59256887435913)),
#  (235, ('install_DAYS_ENTRY_PAYMENT_median', 300.07398223876953)),
#  (236,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median',
#    299.93899965286255)),
#  (237, ('poscash_CNT_INSTALMENT_max', 299.48519706726074)),
#  (238, ('install_DAYS_ENTRY_PAYMENT_sum', 299.20845890045166)),
#  (239, ('poscash_MONTHS_BALANCE_median', 298.03482818603516)),
#  (240,
#   ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    296.7898998260498)),
#  (241, ('prev_DAYS_LAST_DUE_1ST_VERSION_max', 294.71226978302)),
#  (242, ('YEARS_BEGINEXPLUATATION_MEDI', 294.45265007019043)),
#  (243,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_mean',
#    293.81344985961914)),
#  (244, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 293.4365916252136)),
#  (245, ('prev_CNT_PAYMENT_median', 292.10976123809814)),
#  (246,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    291.4244213104248)),
#  (247, ('poscash_SK_DPD_DEF_mean', 291.1882038116455)),
#  (248, ('YEARS_BEGINEXPLUATATION_MODE', 289.796040058136)),
#  (249, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 289.56813621520996)),
#  (250,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    289.42768955230713)),
#  (251, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 288.7282009124756)),
#  (252, ('install_DAYS_INSTALMENT_max', 288.7112340927124)),
#  (253, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 288.4644203186035)),
#  (254,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean',
#    288.05937099456787)),
#  (255,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std',
#    287.98368072509766)),
#  (256,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    287.8789806365967)),
#  (257, ('LIVINGAREA_MEDI', 285.4509687423706)),
#  (258, ('DAYS_REGISTRATION', 284.0495295524597)),
#  (259,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    281.1689496040344)),
#  (260,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median',
#    279.9513006210327)),
#  (261, ('REGION_RATING_CLIENT_times_livingsum_AVG', 277.95430755615234)),
#  (262,
#   ('WEEKDAY_APPR_PROCESS_START_divide_prev_WEEKDAY_APPR_PROCESS_START_median',
#    277.70465993881226)),
#  (263, ('one_hotOCCUPATION_TYPE_Drivers', 276.8401188850403)),
#  (264,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean',
#    276.3996796607971)),
#  (265,
#   ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_median', 276.2336001396179)),
#  (266,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    275.17409896850586)),
#  (267, ('livingsum_AVG_divide_members', 274.85625076293945)),
#  (268,
#   ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 274.55879974365234)),
#  (269, ('poscash_MONTHS_BALANCE_max', 270.9647026062012)),
#  (270, ('prev_onehot_NAME_YIELD_GROUP_2.0', 270.69753980636597)),
#  (271,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_std',
#    270.43512058258057)),
#  (272, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_sum', 270.2931852340698)),
#  (273,
#   ('creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    268.4546298980713)),
#  (274,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median',
#    266.9330792427063)),
#  (275,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    266.41980838775635)),
#  (276,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    266.2370433807373)),
#  (277,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_min',
#    265.18276929855347)),
#  (278, ('bureau_AMT_CREDIT_SUM_DEBT_std', 263.77710247039795)),
#  (279,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean',
#    263.5403609275818)),
#  (280,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 263.48039722442627)),
#  (281,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    262.8904700279236)),
#  (282,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    262.825421333313)),
#  (283, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 262.78138875961304)),
#  (284, ('poscash_CNT_INSTALMENT_FUTURE_max', 262.675820350647)),
#  (285, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 261.159818649292)),
#  (286,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    259.3670997619629)),
#  (287, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 259.23063111305237)),
#  (288, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 258.4158682823181)),
#  (289, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 258.0134916305542)),
#  (290,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 257.9326009750366)),
#  (291, ('AMT_INCOME_TOTAL_divide_prev_AMT_ANNUITY_mean', 257.10447216033936)),
#  (292,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean',
#    256.84420013427734)),
#  (293, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 256.03914737701416)),
#  (294,
#   ('AMT_GOODS_PRICE_divide_prev_AMT_GOODS_PRICE_mean', 255.70519924163818)),
#  (295,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    255.36565732955933)),
#  (296,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum',
#    254.44330883026123)),
#  (297, ('bureau_DAYS_CREDIT_ENDDATE_sum', 254.376540184021)),
#  (298,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_mean',
#    254.3712396621704)),
#  (299,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    254.3571915626526)),
#  (300, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 253.85037994384766)),
#  (301, ('install_AMT_INSTALMENT_std', 253.13179445266724)),
#  (302, ('prev_DAYS_FIRST_DUE_median', 252.71889209747314)),
#  (303,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 252.4094820022583)),
#  (304, ('prev_DAYS_DECISION_min', 252.269362449646)),
#  (305,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_std',
#    252.07170915603638)),
#  (306, ('AMT_CREDIT_divide_prev_AMT_CREDIT_mean', 251.4561824798584)),
#  (307, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 249.70881366729736)),
#  (308, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 249.569842338562)),
#  (309,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    248.72589302062988)),
#  (310, ('bureau_DAYS_CREDIT_ENDDATE_std', 247.57719945907593)),
#  (311, ('prev_AMT_ANNUITY_min', 247.38611602783203)),
#  (312, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 247.0028796195984)),
#  (313,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median',
#    246.91013717651367)),
#  (314, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 245.38002014160156)),
#  (315,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE',
#    245.23715925216675)),
#  (316, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 244.77480030059814)),
#  (317, ('install_DAYS_INSTALMENT_sum', 244.70270109176636)),
#  (318,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std',
#    242.92205810546875)),
#  (319,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean',
#    242.5547971725464)),
#  (320,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max',
#    242.26630926132202)),
#  (321, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in', 241.11579513549805)),
#  (322,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    240.541268825531)),
#  (323, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 239.42837953567505)),
#  (324, ('AMT_CREDIT_divide_prev_AMT_CREDIT_median', 239.26962423324585)),
#  (325, ('bureau_AMT_CREDIT_SUM_sum', 239.18614101409912)),
#  (326,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean',
#    237.37980270385742)),
#  (327,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum',
#    237.21933889389038)),
#  (328,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    237.16028690338135)),
#  (329,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median',
#    236.9431619644165)),
#  (330,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median',
#    236.58918952941895)),
#  (331, ('bureau_DAYS_ENDDATE_FACT_sum', 236.50495100021362)),
#  (332,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_median',
#    235.74464225769043)),
#  (333, ('install_DAYS_INSTALMENT_min', 235.67317056655884)),
#  (334, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_max', 235.37444829940796)),
#  (335, ('AMT_INCOME_TOTAL', 234.27517890930176)),
#  (336, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_sum', 233.03016996383667)),
#  (337,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median',
#    232.12720108032227)),
#  (338,
#   ('creditcard_AMT_RECIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    231.7990951538086)),
#  (339,
#   ('AMT_GOODS_PRICE_divide_prev_AMT_GOODS_PRICE_median', 231.4562201499939)),
#  (340,
#   ('WEEKDAY_APPR_PROCESS_START_divide_prev_WEEKDAY_APPR_PROCESS_START_mean',
#    230.64548063278198)),
#  (341,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median',
#    230.59383916854858)),
#  (342, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 230.34167909622192)),
#  (343, ('livingsum_MEDI_divide_members', 230.1081771850586)),
#  (344, ('prev_AMT_CREDIT_median', 228.70877075195312)),
#  (345,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    227.56681728363037)),
#  (346, ('bureau_DAYS_ENDDATE_FACT_mean', 226.31576108932495)),
#  (347,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    225.7978801727295)),
#  (348,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 225.49415969848633)),
#  (349, ('LIVINGAREA_MODE', 224.71792697906494)),
#  (350,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    223.888596534729)),
#  (351, ('YEARS_BEGINEXPLUATATION_AVG', 223.1345419883728)),
#  (352, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_min', 222.41517639160156)),
#  (353,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    222.3403196334839)),
#  (354, ('install_DAYS_INSTALMENT_median', 222.03465843200684)),
#  (355, ('bureau_AMT_CREDIT_SUM_min', 221.2170114517212)),
#  (356, ('prev_onehot_NAME_YIELD_GROUP_1.0', 220.9059772491455)),
#  (357,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    220.6035509109497)),
#  (358, ('bureau_DAYS_CREDIT_UPDATE_mean', 219.49636840820312)),
#  (359,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_1.0_divide_count_SK_ID_CURR',
#    219.35685873031616)),
#  (360,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    218.52957153320312)),
#  (361,
#   ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_std',
#    218.50841617584229)),
#  (362,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean',
#    218.3974802494049)),
#  (363,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_mean', 218.06346893310547)),
#  (364,
#   ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean',
#    217.40250205993652)),
#  (365, ('install_AMT_PAYMENT_max', 216.89856338500977)),
#  (366,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 216.8317904472351)),
#  (367,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR',
#    216.64844274520874)),
#  (368,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min',
#    216.62401866912842)),
#  (369, ('FLOORSMAX_AVG', 216.56295204162598)),
#  (370,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    216.44600296020508)),
#  (371,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    216.36870908737183)),
#  (372,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    215.79446029663086)),
#  (373,
#   ('creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median', 214.89013195037842)),
#  (374,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    214.15274906158447)),
#  (375,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 213.89899730682373)),
#  (376, ('prev_CNT_PAYMENT_sum', 213.51512956619263)),
#  (377, ('prev_AMT_CREDIT_divide_DAYS_DECISION_median', 213.351637840271)),
#  (378,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    212.64444017410278)),
#  (379, ('APARTMENTS_AVG', 211.73145961761475)),
#  (380,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_max',
#    211.2079758644104)),
#  (381,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum',
#    211.17436122894287)),
#  (382, ('bureau_AMT_CREDIT_SUM_max', 210.46054935455322)),
#  (383, ('prev_DAYS_LAST_DUE_1ST_VERSION_sum', 210.41174125671387)),
#  (384,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median',
#    209.40528011322021)),
#  (385,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 209.32831811904907)),
#  (386, ('prev_DAYS_DECISION_mean', 209.23129796981812)),
#  (387,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    208.8953595161438)),
#  (388,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    208.59143829345703)),
#  (389,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    208.52947616577148)),
#  (390, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 208.0474305152893)),
#  (391,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 207.49320793151855)),
#  (392, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 207.21197032928467)),
#  (393,
#   ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE',
#    207.16906070709229)),
#  (394,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_median',
#    205.46347188949585)),
#  (395,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    204.74008178710938)),
#  (396, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_mean', 203.75258016586304)),
#  (397,
#   ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_std',
#    203.34145832061768)),
#  (398,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    203.28777980804443)),
#  (399, ('poscash_CNT_INSTALMENT_FUTURE_median', 201.8706293106079)),
#  (400, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 201.71950149536133)),
#  (401,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std',
#    201.67834949493408)),
#  (402, ('AMT_CREDIT_divide_OWN_CAR_AGE', 201.30564498901367)),
#  (403,
#   ('prev_onehot_NAME_PRODUCT_TYPE_walk-in_divide_count_SK_ID_CURR',
#    200.61749935150146)),
#  (404, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_mean', 200.49207973480225)),
#  (405, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_max', 200.20560884475708)),
#  (406, ('HOUR_APPR_PROCESS_START', 199.65113878250122)),
#  (407,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max',
#    199.44391012191772)),
#  (408, ('bureau_DAYS_ENDDATE_FACT_median', 199.34387063980103)),
#  (409,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std',
#    198.2334303855896)),
#  (410,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_1.0_divide_count_SK_ID_CURR',
#    198.15219116210938)),
#  (411,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    198.1347141265869)),
#  (412,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    196.42248058319092)),
#  (413,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    196.252788066864)),
#  (414, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_mean', 196.11686849594116)),
#  (415,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    195.86656951904297)),
#  (416, ('AMT_GOODS_PRICE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 195.2251968383789)),
#  (417,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_min', 194.8218913078308)),
#  (418, ('AMT_ANNUITY_divide_DEF_30_CNT_SOCIAL_CIRCLE', 194.81577014923096)),
#  (419, ('poscash_CNT_INSTALMENT_sum', 194.48694896697998)),
#  (420, ('OWN_CAR_AGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 194.37381410598755)),
#  (421, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_mean', 193.77590036392212)),
#  (422,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    193.03665828704834)),
#  (423,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_median',
#    192.83913135528564)),
#  (424, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_median', 191.1218981742859)),
#  (425, ('bureau_DAYS_CREDIT_sum', 190.3340606689453)),
#  (426,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_max', 190.12207174301147)),
#  (427, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_min', 189.50174045562744)),
#  (428,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_mean',
#    189.35939598083496)),
#  (429,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_sum',
#    189.20601081848145)),
#  (430, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_min', 188.91507816314697)),
#  (431,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_mean', 188.21460056304932)),
#  (432,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    188.1344232559204)),
#  (433,
#   ('prev_AMT_APPLICATION_divide_DAYS_DECISION_median', 187.8599910736084)),
#  (434,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    187.7533597946167)),
#  (435,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    187.30469036102295)),
#  (436,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median',
#    186.75843334197998)),
#  (437, ('bureau_DAYS_ENDDATE_FACT_std', 186.31973934173584)),
#  (438, ('prev_DAYS_DECISION_sum', 185.9652099609375)),
#  (439, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 185.53072690963745)),
#  (440, ('bureau_AMT_CREDIT_SUM_DEBT_max', 185.45490074157715)),
#  (441, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 184.76909828186035)),
#  (442,
#   ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    184.18760108947754)),
#  (443,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max',
#    183.70106029510498)),
#  (444,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 182.8232307434082)),
#  (445, ('bureau_DAYS_CREDIT_std', 182.6063108444214)),
#  (446,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    182.02827167510986)),
#  (447,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    181.8139991760254)),
#  (448, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 181.3861207962036)),
#  (449, ('install_AMT_INSTALMENT_min', 181.33844089508057)),
#  (450, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 179.7853307723999)),
#  (451, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 179.66434860229492)),
#  (452,
#   ('prev_onehot_NAME_PORTFOLIO_POS_divide_count_SK_ID_CURR',
#    179.51981019973755)),
#  (453, ('NAME_CONTRACT_TYPE', 179.09429740905762)),
#  (454, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_max', 178.96839046478271)),
#  (455, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 178.7505693435669)),
#  (456,
#   ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_median', 178.64580059051514)),
#  (457, ('bureau_DAYS_CREDIT_UPDATE_min', 178.56744003295898)),
#  (458,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    178.56647205352783)),
#  (459,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_0.0_divide_count_SK_ID_CURR',
#    178.46120071411133)),
#  (460,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    178.1658010482788)),
#  (461, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_std', 178.0949501991272)),
#  (462, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_min', 177.69866037368774)),
#  (463,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    177.57133102416992)),
#  (464,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_std',
#    177.3480978012085)),
#  (465, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 176.78941822052002)),
#  (466, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_median', 176.6693296432495)),
#  (467, ('REGION_RATING_CLIENT_times_livingsum_MEDI', 176.41069984436035)),
#  (468,
#   ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 175.54242038726807)),
#  (469,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    175.25550174713135)),
#  (470,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_max', 174.75715255737305)),
#  (471, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 174.72750091552734)),
#  (472,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    173.62588024139404)),
#  (473,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    172.98980951309204)),
#  (474,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_mean',
#    172.83361911773682)),
#  (475,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    172.66019821166992)),
#  (476,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_min',
#    172.17574214935303)),
#  (477,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_0.0_divide_count_SK_ID_CURR',
#    172.1597695350647)),
#  (478, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 171.27004861831665)),
#  (479,
#   ('prev_onehot_NAME_PAYMENT_TYPE_Cash_through_the_bank_divide_count_SK_ID_CURR',
#    170.82686042785645)),
#  (480, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_median', 169.9251093864441)),
#  (481,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    169.64012956619263)),
#  (482, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_mean', 169.04619121551514)),
#  (483,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_mean', 168.51782035827637)),
#  (484,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_median', 168.3129916191101)),
#  (485,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    167.88366079330444)),
#  (486,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_mean', 167.64819049835205)),
#  (487,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    167.492938041687)),
#  (488,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    167.43031883239746)),
#  (489,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 167.21703100204468)),
#  (490, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 166.95636749267578)),
#  (491, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_max', 166.6142988204956)),
#  (492, ('OWN_CAR_AGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 166.26479816436768)),
#  (493, ('bureau_AMT_CREDIT_SUM_median', 165.28775072097778)),
#  (494,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_min', 164.82203102111816)),
#  (495,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    164.68373823165894)),
#  (496,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum',
#    164.65351009368896)),
#  (497, ('prev_DAYS_LAST_DUE_1ST_VERSION_mean', 164.2352476119995)),
#  (498,
#   ('prev_onehot_NAME_YIELD_GROUP_3.0_divide_count_SK_ID_CURR',
#    163.99632167816162)),
#  (499,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    163.90452194213867)),
#  (500, ('prev_onehot_CODE_REJECT_REASON_HC', 163.73160076141357)),
#  (501, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 163.70912885665894)),
#  (502,
#   ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 163.17207193374634)),
#  (503, ('livingsum_MEDI', 162.6461009979248)),
#  (504, ('poscash_MONTHS_BALANCE_mean', 162.31679916381836)),
#  (505,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_mean',
#    162.2149305343628)),
#  (506, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_min', 161.80097103118896)),
#  (507,
#   ('DEF_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    161.7754020690918)),
#  (508,
#   ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_mean', 161.05303955078125)),
#  (509,
#   ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    160.80181884765625)),
#  (510, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 160.40620040893555)),
#  (511,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_median',
#    160.0030779838562)),
#  (512, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_max', 159.29887914657593)),
#  (513, ('bureau_count_SK_ID_CURR', 159.18313026428223)),
#  (514, ('bureau_onehot_CREDIT_TYPE_Credit_card', 158.8113899230957)),
#  (515,
#   ('prev_onehot_NAME_PRODUCT_TYPE_XNA_divide_count_SK_ID_CURR',
#    158.65749835968018)),
#  (516,
#   ('prev_onehot_NAME_PORTFOLIO_Cash_divide_count_SK_ID_CURR',
#    157.81652069091797)),
#  (517, ('install_AMT_PAYMENT_mean', 157.62345838546753)),
#  (518, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_mean', 157.21634912490845)),
#  (519, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_median', 157.16543006896973)),
#  (520,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    157.06229972839355)),
#  (521, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 157.05911922454834)),
#  (522,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Consumer_electronics_divide_count_SK_ID_CURR',
#    156.90905094146729)),
#  (523, ('bureau_AMT_CREDIT_SUM_std', 156.6292634010315)),
#  (524, ('poscash_SK_DPD_divide_MONTHS_BALANCE_std', 155.9649019241333)),
#  (525,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max',
#    155.89212036132812)),
#  (526, ('livingsum_MODE', 155.7389030456543)),
#  (527, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 155.59474086761475)),
#  (528, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_max', 155.52004957199097)),
#  (529,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_std',
#    155.39533138275146)),
#  (530, ('prev_AMT_APPLICATION_median', 155.26605224609375)),
#  (531,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    155.11734008789062)),
#  (532, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_median', 154.9565200805664)),
#  (533, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 154.9201202392578)),
#  (534,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    154.90271186828613)),
#  (535, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_mean', 154.75293350219727)),
#  (536,
#   ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean',
#    154.00109910964966)),
#  (537,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    153.52340078353882)),
#  (538,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max',
#    152.82996225357056)),
#  (539,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    152.70090103149414)),
#  (540, ('REGION_RATING_CLIENT_times_livingsum_MODE', 152.60459899902344)),
#  (541, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 152.34257984161377)),
#  (542, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 152.28041982650757)),
#  (543, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 152.19754076004028)),
#  (544,
#   ('AMT_INCOME_TOTAL_divide_prev_AMT_APPLICATION_mean', 151.8544692993164)),
#  (545,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Canceled_divide_count_SK_ID_CURR',
#    150.91476011276245)),
#  (546,
#   ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean',
#    149.9880599975586)),
#  (547,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    149.5873508453369)),
#  (548, ('bureau_AMT_CREDIT_MAX_OVERDUE_mean', 149.32891082763672)),
#  (549,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    149.09822940826416)),
#  (550,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    149.0433521270752)),
#  (551,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    148.93886947631836)),
#  (552, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_sum', 148.63419198989868)),
#  (553, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 148.61658000946045)),
#  (554, ('prev_DAYS_FIRST_DUE_sum', 148.31358003616333)),
#  (555,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    148.2097682952881)),
#  (556, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_median', 147.91358947753906)),
#  (557,
#   ('prev_onehot_NAME_PAYMENT_TYPE_XNA_divide_count_SK_ID_CURR',
#    147.91272974014282)),
#  (558,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    147.3404278755188)),
#  (559, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 147.3371706008911)),
#  (560,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min',
#    147.29639053344727)),
#  (561, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 146.92539882659912)),
#  (562, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_sum', 146.91510009765625)),
#  (563,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_min',
#    146.73956966400146)),
#  (564, ('prev_HOUR_APPR_PROCESS_START_median', 146.65423107147217)),
#  (565,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    146.55023050308228)),
#  (566,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    146.3438491821289)),
#  (567,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_median',
#    145.72742080688477)),
#  (568,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_sum',
#    145.62565326690674)),
#  (569, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 145.3858995437622)),
#  (570,
#   ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 144.78481006622314)),
#  (571,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_mean', 144.45940113067627)),
#  (572,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_2.0_divide_count_SK_ID_CURR',
#    144.2032012939453)),
#  (573, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_median', 144.14954948425293)),
#  (574, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_mean', 144.0750207901001)),
#  (575,
#   ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 143.76434087753296)),
#  (576, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 143.72147941589355)),
#  (577,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
# ...
#    96.0245008468628)),
#  (822, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_max', 95.8838586807251)),
#  (823, ('creditcard_CNT_INSTALMENT_MATURE_CUM_mean', 95.31224060058594)),
#  (824,
#   ('creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std',
#    95.08159065246582)),
#  (825,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    95.0221996307373)),
#  (826,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    94.87557888031006)),
#  (827,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    93.81179904937744)),
#  (828,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    93.73855018615723)),
#  (829,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_std',
#    93.2775297164917)),
#  (830,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    93.25102043151855)),
#  (831,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    93.02334117889404)),
#  (832,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    93.01967096328735)),
#  (833,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_max',
#    93.00153017044067)),
#  (834,
#   ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_median', 92.89459991455078)),
#  (835, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_sum', 92.88037014007568)),
#  (836,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    92.82290029525757)),
#  (837, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_mean', 92.75244998931885)),
#  (838,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_sum',
#    92.68140029907227)),
#  (839, ('bureau_MONTHS_BALANCE_max_mean', 92.51132011413574)),
#  (840, ('BASEMENTAREA_MODE', 92.21762895584106)),
#  (841,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    92.14416027069092)),
#  (842, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_min', 91.90390110015869)),
#  (843, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_mean', 91.89619874954224)),
#  (844,
#   ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_sum', 91.67738056182861)),
#  (845,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_median',
#    91.16418886184692)),
#  (846,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    91.00247001647949)),
#  (847,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min',
#    90.59020900726318)),
#  (848, ('creditcard_CNT_DRAWINGS_CURRENT_sum', 90.54439926147461)),
#  (849,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    90.33757972717285)),
#  (850,
#   ('OBS_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE',
#    90.16930103302002)),
#  (851,
#   ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_REGISTRATION', 90.14771914482117)),
#  (852,
#   ('creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_mean',
#    90.0836009979248)),
#  (853, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_median', 90.08288097381592)),
#  (854,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_mean',
#    89.69211959838867)),
#  (855,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    89.59928894042969)),
#  (856,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    89.5919017791748)),
#  (857,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    89.57300901412964)),
#  (858,
#   ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 89.56274938583374)),
#  (859, ('ENTRANCES_AVG', 89.29499912261963)),
#  (860,
#   ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_mean', 89.25908994674683)),
#  (861,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_median', 88.88593006134033)),
#  (862, ('poscash_SK_DPD_divide_MONTHS_BALANCE_min', 88.84379005432129)),
#  (863,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    88.81471014022827)),
#  (864,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_std',
#    88.58888149261475)),
#  (865,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    88.52279949188232)),
#  (866,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_std',
#    88.43739700317383)),
#  (867, ('AMT_ANNUITY_divide_OWN_CAR_AGE', 88.27910041809082)),
#  (868,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_mean',
#    88.1575984954834)),
#  (869,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    87.99883937835693)),
#  (870,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_median',
#    87.75430059432983)),
#  (871, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_max', 87.71653938293457)),
#  (872,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    87.60600996017456)),
#  (873,
#   ('creditcard_onehot_NAME_CONTRACT_STATUS_Active_divide_count_SK_ID_CURR',
#    87.36502075195312)),
#  (874, ('prev_AMT_CREDIT_sum', 87.03304862976074)),
#  (875,
#   ('creditcard_AMT_RECIVABLE_divide_MONTHS_BALANCE_std', 86.89259719848633)),
#  (876,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CREDIT_DAY_OVERDUE_median',
#    86.68192100524902)),
#  (877,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_max', 86.32909965515137)),
#  (878,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    86.18798065185547)),
#  (879, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_sum', 85.71578168869019)),
#  (880,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    85.61728096008301)),
#  (881,
#   ('creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_median', 85.54880332946777)),
#  (882, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 85.47410011291504)),
#  (883,
#   ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_median', 85.26458930969238)),
#  (884,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_SK_DPD_mean',
#    85.22329902648926)),
#  (885,
#   ('creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std',
#    85.21294116973877)),
#  (886, ('creditcard_CNT_DRAWINGS_POS_CURRENT_mean', 84.9993486404419)),
#  (887,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_max',
#    84.86012077331543)),
#  (888, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 84.51246976852417)),
#  (889,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_std',
#    84.48727083206177)),
#  (890, ('bureau_onehot_STATUS_1_std', 84.47195100784302)),
#  (891, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 84.40145969390869)),
#  (892,
#   ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 83.98703861236572)),
#  (893,
#   ('DEF_60_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    83.94200038909912)),
#  (894,
#   ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_std', 83.86260032653809)),
#  (895,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    83.51121997833252)),
#  (896, ('bureau_AMT_CREDIT_MAX_OVERDUE_std', 83.28685092926025)),
#  (897, ('bureau_onehot_STATUS_X_min', 83.1097502708435)),
#  (898, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_sum', 82.74271869659424)),
#  (899, ('bureau_AMT_ANNUITY_std', 82.4602403640747)),
#  (900,
#   ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_median', 82.36422061920166)),
#  (901, ('creditcard_count_SK_ID_CURR', 82.24448823928833)),
#  (902,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    82.23522996902466)),
#  (903,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    82.21496105194092)),
#  (904,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_max',
#    82.07334899902344)),
#  (905, ('bureau_MONTHS_BALANCE_median_median', 81.89485931396484)),
#  (906, ('bureau_MONTHS_BALANCE_min_mean', 81.860680103302)),
#  (907,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 81.74887943267822)),
#  (908,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    81.56661891937256)),
#  (909,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    81.5254602432251)),
#  (910,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    81.34716129302979)),
#  (911, ('bureau_MONTHS_BALANCE_sum_sum', 81.2452301979065)),
#  (912,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_min',
#    81.1234016418457)),
#  (913,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OBS_30_CNT_SOCIAL_CIRCLE',
#    81.09828090667725)),
#  (914, ('REG_CITY_NOT_WORK_CITY', 81.06909942626953)),
#  (915,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    81.02490997314453)),
#  (916,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    80.9434003829956)),
#  (917,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max',
#    80.51420021057129)),
#  (918,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    80.41181135177612)),
#  (919,
#   ('creditcard_AMT_BALANCE_divide_MONTHS_BALANCE_std', 80.31507968902588)),
#  (920,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum',
#    80.29090929031372)),
#  (921,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_median', 80.28121042251587)),
#  (922,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    80.22665023803711)),
#  (923,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    80.01259899139404)),
#  (924, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 79.97552013397217)),
#  (925, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 79.64223003387451)),
#  (926,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 79.56655073165894)),
#  (927,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean',
#    79.52868938446045)),
#  (928,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    79.39527034759521)),
#  (929,
#   ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_max', 79.33960103988647)),
#  (930,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean',
#    79.22768878936768)),
#  (931, ('one_hotOCCUPATION_TYPE_High_skill_tech_staff', 79.16177868843079)),
#  (932,
#   ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_CNT_FAM_MEMBERS', 79.08093070983887)),
#  (933, ('bureau_AMT_CREDIT_MAX_OVERDUE_max', 79.0262680053711)),
#  (934, ('prev_AMT_CREDIT_mean', 78.939199924469)),
#  (935,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    78.8992509841919)),
#  (936,
#   ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 78.64239978790283)),
#  (937,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_mean', 78.61342906951904)),
#  (938, ('prev_AMT_CREDIT_divide_DAYS_DECISION_max', 78.44051122665405)),
#  (939,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    78.43490886688232)),
#  (940,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_min', 78.29079818725586)),
#  (941,
#   ('bureau_AMT_ANNUITY_divide_DAYS_CREDIT_UPDATE_sum', 78.20469951629639)),
#  (942, ('prev_AMT_APPLICATION_sum', 78.14383792877197)),
#  (943, ('bureau_MONTHS_BALANCE_median_min', 78.05360984802246)),
#  (944,
#   ('OBS_60_CNT_SOCIAL_CIRCLE_divide_DEF_30_CNT_SOCIAL_CIRCLE',
#    77.82950019836426)),
#  (945, ('one_hotNAME_HOUSING_TYPE_Office_apartment', 77.81868934631348)),
#  (946,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_mean',
#    77.80777883529663)),
#  (947,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min',
#    77.76530075073242)),
#  (948,
#   ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 77.52643871307373)),
#  (949,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    77.24434113502502)),
#  (950, ('bureau_onehot_CREDIT_TYPE_Consumer_credit', 77.10056972503662)),
#  (951, ('prev_AMT_DOWN_PAYMENT_max', 76.97014999389648)),
#  (952, ('prev_RATE_DOWN_PAYMENT_max', 76.85329914093018)),
#  (953,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_max',
#    76.8193998336792)),
#  (954, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_max', 76.73215007781982)),
#  (955,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    76.68777847290039)),
#  (956,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_max', 76.51367092132568)),
#  (957, ('bureau_onehot_STATUS_C_mean', 76.39527893066406)),
#  (958,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_median',
#    76.38969993591309)),
#  (959,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_max',
#    76.3410792350769)),
#  (960, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_mean', 76.1382303237915)),
#  (961, ('ENTRANCES_MODE', 76.12871932983398)),
#  (962,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    76.1176404953003)),
#  (963, ('BASEMENTAREA_MEDI', 75.98455047607422)),
#  (964,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max',
#    75.78019046783447)),
#  (965, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_mean', 75.70575904846191)),
#  (966,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    75.68496036529541)),
#  (967, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_max', 75.65544986724854)),
#  (968,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_PAYMENT_CURRENT_sum',
#    75.50432014465332)),
#  (969, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_max', 75.38944053649902)),
#  (970, ('poscash_SK_DPD_sum', 75.12465047836304)),
#  (971,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max',
#    75.05779933929443)),
#  (972,
#   ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR',
#    75.05257987976074)),
#  (973, ('bureau_onehot_STATUS_0_mean', 74.93980026245117)),
#  (974,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_median',
#    74.65839004516602)),
#  (975,
#   ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_median', 74.5599193572998)),
#  (976,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean',
#    74.48245143890381)),
#  (977,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    74.35551881790161)),
#  (978,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    74.19525909423828)),
#  (979,
#   ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_mean', 74.10610008239746)),
#  (980, ('YEARS_BUILD_MODE', 74.04255962371826)),
#  (981,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_std',
#    73.91734838485718)),
#  (982,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    73.86409950256348)),
#  (983,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CNT_CREDIT_PROLONG_std',
#    73.70319938659668)),
#  (984,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_std',
#    73.47159957885742)),
#  (985,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    73.44787979125977)),
#  (986,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_min',
#    73.3112998008728)),
#  (987,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    73.2752103805542)),
#  (988,
#   ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_median',
#    73.12308025360107)),
#  (989,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    73.09830951690674)),
#  (990,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_min',
#    72.60331964492798)),
#  (991, ('YEARS_BUILD_MEDI', 72.53786945343018)),
#  (992,
#   ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_mean',
#    72.4231104850769)),
#  (993, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_min', 72.39289140701294)),
#  (994, ('bureau_DAYS_CREDIT_UPDATE_sum', 72.27283096313477)),
#  (995,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_mean',
#    72.24308109283447)),
#  (996,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    71.86432075500488)),
#  (997,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_mean',
#    71.61570072174072)),
#  (998,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    71.5837812423706)),
#  (999,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    71.4704999923706)),
#  ...]

# %%
x = [x for x in zip(clf.feature_name(), clf.feature_importance('split'))]
x.sort(key=lambda x: x[1], reverse=True)
x = [(i, j) for i, j in enumerate(x)]
x
# Out:
# [(0, ('EXT_SOURCE_1', 292)),
#  (1, ('AMT_CREDIT_divide_AMT_ANNUITY', 287)),
#  (2, ('EXT_SOURCE_2', 237)),
#  (3, ('EXT_SOURCE_3', 215)),
#  (4, ('DAYS_BIRTH', 195)),
#  (5,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_max',
#    135)),
#  (6, ('AMT_CREDIT_divide_AMT_GOODS_PRICE', 133)),
#  (7, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_min', 120)),
#  (8,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_mean',
#    102)),
#  (9, ('AMT_ANNUITY_divide_AMT_GOODS_PRICE', 98)),
#  (10, ('AMT_ANNUITY_divide_DAYS_EMPLOYED', 89)),
#  (11, ('CODE_GENDER', 87)),
#  (12, ('AMT_ANNUITY', 86)),
#  (13, ('AMT_INCOME_TOTAL_divide_AMT_ANNUITY', 80)),
#  (14,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_max',
#    78)),
#  (15, ('REGION_POPULATION_RELATIVE', 75)),
#  (16, ('AMT_GOODS_PRICE', 73)),
#  (17, ('AMT_CREDIT_divide_DAYS_EMPLOYED', 73)),
#  (18, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_sum', 70)),
#  (19, ('DAYS_ID_PUBLISH', 69)),
#  (20,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_sum', 69)),
#  (21, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_mean', 66)),
#  (22, ('poscash_CNT_INSTALMENT_FUTURE_std', 66)),
#  (23, ('AMT_INCOME_TOTAL_divide_DAYS_EMPLOYED', 64)),
#  (24, ('bureau_DAYS_CREDIT_max', 62)),
#  (25,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Refused_divide_count_SK_ID_CURR', 61)),
#  (26, ('bureau_DAYS_ENDDATE_FACT_max', 61)),
#  (27, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_std', 60)),
#  (28, ('bureau_DAYS_CREDIT_ENDDATE_max', 60)),
#  (29, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_median', 59)),
#  (30, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min', 57)),
#  (31, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_max', 55)),
#  (32, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min', 54)),
#  (33, ('bureau_DAYS_CREDIT_median', 52)),
#  (34, ('bureau_DAYS_CREDIT_ENDDATE_median', 51)),
#  (35, ('one_hotNAME_EDUCATION_TYPE_Higher_education', 50)),
#  (36, ('prev_onehot_CODE_REJECT_REASON_XAP_divide_count_SK_ID_CURR', 50)),
#  (37,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_sum',
#    50)),
#  (38,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_std',
#    49)),
#  (39, ('DAYS_EMPLOYED', 48)),
#  (40,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_max', 47)),
#  (41, ('AMT_GOODS_PRICE_divide_DAYS_EMPLOYED', 46)),
#  (42, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_std', 46)),
#  (43, ('one_hotNAME_FAMILY_STATUS_Married', 44)),
#  (44, ('AMT_ANNUITY_divide_DAYS_BIRTH', 44)),
#  (45, ('AMT_ANNUITY_divide_DAYS_ID_PUBLISH', 43)),
#  (46, ('poscash_MONTHS_BALANCE_std', 43)),
#  (47, ('AMT_CREDIT_divide_CNT_FAM_MEMBERS', 42)),
#  (48, ('prev_onehot_NAME_YIELD_GROUP_2.0_divide_count_SK_ID_CURR', 42)),
#  (49, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_sum', 42)),
#  (50, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_min', 42)),
#  (51, ('AMT_CREDIT_divide_DAYS_BIRTH', 41)),
#  (52, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_sum', 41)),
#  (53, ('AMT_ANNUITY_divide_prev_AMT_ANNUITY_median', 41)),
#  (54, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_median', 41)),
#  (55,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_min',
#    41)),
#  (56, ('prev_CNT_PAYMENT_mean', 40)),
#  (57,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    40)),
#  (58, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_max', 40)),
#  (59, ('AMT_ANNUITY_divide_DAYS_REGISTRATION', 39)),
#  (60, ('install_AMT_PAYMENT_sum', 39)),
#  (61, ('bureau_DAYS_CREDIT_mean', 39)),
#  (62, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_FAM_MEMBERS', 38)),
#  (63, ('AMT_GOODS_PRICE_divide_DAYS_ID_PUBLISH', 37)),
#  (64,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_sum',
#    37)),
#  (65, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_std', 37)),
#  (66, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_sum', 37)),
#  (67, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_std', 36)),
#  (68,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_mean',
#    36)),
#  (69, ('install_AMT_PAYMENT_min', 36)),
#  (70, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_median', 36)),
#  (71, ('OWN_CAR_AGE_divide_DAYS_REGISTRATION', 35)),
#  (72, ('install_DAYS_ENTRY_PAYMENT_std', 35)),
#  (73, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_std', 35)),
#  (74, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_max', 35)),
#  (75, ('AMT_CREDIT', 34)),
#  (76, ('AMT_INCOME_TOTAL_divide_AMT_CREDIT', 34)),
#  (77, ('AMT_ANNUITY_divide_CNT_FAM_MEMBERS', 34)),
#  (78,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Approved_divide_count_SK_ID_CURR', 34)),
#  (79, ('prev_onehot_NAME_TYPE_SUITE_nan_divide_count_SK_ID_CURR', 34)),
#  (80,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    34)),
#  (81, ('prev_HOUR_APPR_PROCESS_START_mean', 34)),
#  (82, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_std', 34)),
#  (83, ('creditcard_CNT_DRAWINGS_ATM_CURRENT_mean', 34)),
#  (84, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_median', 34)),
#  (85, ('DAYS_LAST_PHONE_CHANGE', 33)),
#  (86, ('poscash_CNT_INSTALMENT_FUTURE_mean', 33)),
#  (87, ('bureau_onehot_CREDIT_ACTIVE_Active', 33)),
#  (88, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_mean', 33)),
#  (89, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_min', 32)),
#  (90, ('creditcard_CNT_DRAWINGS_CURRENT_std', 32)),
#  (91, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_sum', 32)),
#  (92, ('install_DAYS_INSTALMENT_std', 32)),
#  (93, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_min', 32)),
#  (94, ('FLAG_DOCUMENT_3', 31)),
#  (95, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_AVG', 31)),
#  (96, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_EMPLOYED', 31)),
#  (97,
#   ('prev_onehot_NAME_TYPE_SUITE_Unaccompanied_divide_count_SK_ID_CURR', 31)),
#  (98, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_mean', 31)),
#  (99, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_max', 31)),
#  (100, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_min', 31)),
#  (101, ('one_hotNAME_EDUCATION_TYPE_Secondary_/_secondary_special', 30)),
#  (102, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 30)),
#  (103, ('install_DAYS_ENTRY_PAYMENT_max', 30)),
#  (104, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_median', 30)),
#  (105, ('bureau_DAYS_CREDIT_ENDDATE_mean', 30)),
#  (106, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_mean', 30)),
#  (107, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_sum', 30)),
#  (108, ('AMT_INCOME_TOTAL_divide_AMT_GOODS_PRICE', 29)),
#  (109, ('OWN_CAR_AGE_divide_DAYS_BIRTH', 29)),
#  (110,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    29)),
#  (111, ('bureau_DAYS_CREDIT_UPDATE_std', 29)),
#  (112, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_max', 29)),
#  (113, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_sum', 29)),
#  (114, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_mean', 29)),
#  (115, ('AMT_INCOME_TOTAL_divide_DAYS_REGISTRATION', 28)),
#  (116, ('AMT_INCOME_TOTAL_divide_DAYS_ID_PUBLISH', 28)),
#  (117, ('AMT_GOODS_PRICE_divide_DAYS_REGISTRATION', 28)),
#  (118, ('OWN_CAR_AGE_divide_DAYS_EMPLOYED', 28)),
#  (119, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_BIRTH', 28)),
#  (120,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Active_divide_positivecount_SK_ID_CURR_SK_DPD',
#    28)),
#  (121, ('poscash_MONTHS_BALANCE_sum', 28)),
#  (122, ('bureau_DAYS_CREDIT_UPDATE_median', 28)),
#  (123, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_max', 28)),
#  (124, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_max', 28)),
#  (125, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_mean', 28)),
#  (126, ('AMT_CREDIT_divide_DAYS_ID_PUBLISH', 27)),
#  (127, ('prev_WEEKDAY_APPR_PROCESS_START_mean', 27)),
#  (128, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_sum', 27)),
#  (129,
#   ('WEEKDAY_APPR_PROCESS_START_divide_prev_WEEKDAY_APPR_PROCESS_START_median',
#    27)),
#  (130, ('poscash_onehot_NAME_CONTRACT_STATUS_Active', 27)),
#  (131, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_std', 27)),
#  (132,
#   ('bureau_onehot_CREDIT_TYPE_Mortgage_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    27)),
#  (133, ('bureau_DAYS_CREDIT_min', 27)),
#  (134, ('DAYS_LAST_PHONE_CHANGE_divide_CNT_CHILDREN', 26)),
#  (135, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_min', 26)),
#  (136, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_median', 26)),
#  (137, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_min', 26)),
#  (138, ('install_AMT_PAYMENT_median', 26)),
#  (139, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_mean', 26)),
#  (140, ('bureau_DAYS_CREDIT_UPDATE_max', 26)),
#  (141, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_sum', 26)),
#  (142, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_min', 26)),
#  (143, ('OWN_CAR_AGE', 25)),
#  (144, ('AMT_GOODS_PRICE_divide_DAYS_BIRTH', 25)),
#  (145, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_REGISTRATION', 25)),
#  (146, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_min', 25)),
#  (147, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_mean', 25)),
#  (148, ('poscash_MONTHS_BALANCE_median', 25)),
#  (149, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_median', 25)),
#  (150, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_max', 25)),
#  (151, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_mean', 25)),
#  (152, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_max', 25)),
#  (153, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_std', 25)),
#  (154, ('prev_onehot_NAME_YIELD_GROUP_1.0_divide_count_SK_ID_CURR', 24)),
#  (155, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean', 24)),
#  (156,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    24)),
#  (157,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    24)),
#  (158, ('prev_DAYS_DECISION_median', 24)),
#  (159, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_max', 24)),
#  (160, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_sum', 24)),
#  (161, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_median', 24)),
#  (162, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_median', 24)),
#  (163,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_std',
#    24)),
#  (164, ('bureau_AMT_CREDIT_SUM_DEBT_mean', 24)),
#  (165, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_mean', 24)),
#  (166, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_sum', 24)),
#  (167, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_min', 24)),
#  (168, ('one_hotOCCUPATION_TYPE_Core_staff', 23)),
#  (169, ('AMT_INCOME_TOTAL_divide_DAYS_BIRTH', 23)),
#  (170, ('DAYS_LAST_PHONE_CHANGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 23)),
#  (171,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_nan_divide_count_SK_ID_CURR', 23)),
#  (172, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_max', 23)),
#  (173, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_sum', 23)),
#  (174, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 23)),
#  (175, ('prev_HOUR_APPR_PROCESS_START_max', 23)),
#  (176, ('AMT_ANNUITY_divide_prev_AMT_ANNUITY_mean', 23)),
#  (177, ('AMT_INCOME_TOTAL_divide_prev_AMT_ANNUITY_mean', 23)),
#  (178, ('install_count_SK_ID_CURR', 23)),
#  (179, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_mean', 23)),
#  (180,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_mean',
#    23)),
#  (181, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_sum', 23)),
#  (182, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_min', 23)),
#  (183, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_ENDDATE_mean', 23)),
#  (184, ('DAYS_REGISTRATION', 22)),
#  (185, ('APARTMENTS_MEDI', 22)),
#  (186, ('YEARS_BEGINEXPLUATATION_MEDI', 22)),
#  (187, ('AMT_GOODS_PRICE_divide_CNT_FAM_MEMBERS', 22)),
#  (188, ('OWN_CAR_AGE_divide_DAYS_ID_PUBLISH', 22)),
#  (189, ('prev_CNT_PAYMENT_max', 22)),
#  (190, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_max', 22)),
#  (191, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_min', 22)),
#  (192, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_median', 22)),
#  (193, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_sum', 22)),
#  (194, ('YEARS_BEGINEXPLUATATION_MODE', 21)),
#  (195, ('TOTALAREA_MODE', 21)),
#  (196, ('livingsum_AVG_divide_members', 21)),
#  (197, ('AMT_CREDIT_divide_DAYS_REGISTRATION', 21)),
#  (198, ('AMT_ANNUITY_divide_DAYS_LAST_PHONE_CHANGE', 21)),
#  (199, ('AMT_GOODS_PRICE_divide_OWN_CAR_AGE', 21)),
#  (200,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 21)),
#  (201, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum', 21)),
#  (202, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_min', 21)),
#  (203, ('install_DAYS_ENTRY_PAYMENT_median', 21)),
#  (204, ('bureau_DAYS_ENDDATE_FACT_mean', 21)),
#  (205, ('bureau_DAYS_CREDIT_ENDDATE_sum', 21)),
#  (206, ('AMT_INCOME_TOTAL', 20)),
#  (207, ('REGION_RATING_CLIENT_W_CITY', 20)),
#  (208, ('one_hotOCCUPATION_TYPE_Drivers', 20)),
#  (209, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_BIRTH', 20)),
#  (210, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_REGISTRATION', 20)),
#  (211, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 20)),
#  (212,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity_divide_count_SK_ID_CURR',
#    20)),
#  (213,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    20)),
#  (214, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 20)),
#  (215, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_min', 20)),
#  (216,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    20)),
#  (217, ('prev_DAYS_LAST_DUE_1ST_VERSION_median', 20)),
#  (218, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_median', 20)),
#  (219, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_min', 20)),
#  (220, ('AMT_GOODS_PRICE_divide_prev_AMT_GOODS_PRICE_median', 20)),
#  (221,
#   ('WEEKDAY_APPR_PROCESS_START_divide_prev_WEEKDAY_APPR_PROCESS_START_mean',
#    20)),
#  (222, ('poscash_CNT_INSTALMENT_std', 20)),
#  (223, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_mean', 20)),
#  (224, ('REG_CITY_NOT_LIVE_CITY', 19)),
#  (225, ('one_hotNAME_INCOME_TYPE_State_servant', 19)),
#  (226, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_LAST_PHONE_CHANGE', 19)),
#  (227, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_ID_PUBLISH', 19)),
#  (228,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    19)),
#  (229, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_median', 19)),
#  (230, ('prev_DAYS_DECISION_max', 19)),
#  (231, ('prev_AMT_CREDIT_median', 19)),
#  (232,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    19)),
#  (233, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_sum', 19)),
#  (234, ('bureau_onehot_CREDIT_TYPE_Microloan', 19)),
#  (235, ('bureau_DAYS_ENDDATE_FACT_median', 19)),
#  (236, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_median', 19)),
#  (237, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_max', 19)),
#  (238, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_sum', 19)),
#  (239, ('bureau_DAYS_CREDIT_ENDDATE_std', 19)),
#  (240, ('LIVINGAREA_AVG', 18)),
#  (241, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MODE', 18)),
#  (242, ('AMT_INCOME_TOTAL_divide_OWN_CAR_AGE', 18)),
#  (243, ('DAYS_LAST_PHONE_CHANGE_divide_DAYS_EMPLOYED', 18)),
#  (244, ('DAYS_LAST_PHONE_CHANGE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 18)),
#  (245,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_1.0_divide_count_SK_ID_CURR', 18)),
#  (246,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    18)),
#  (247,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    18)),
#  (248, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 18)),
#  (249, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_mean', 18)),
#  (250,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 18)),
#  (251, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_max', 18)),
#  (252,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    18)),
#  (253, ('AMT_CREDIT_divide_prev_AMT_CREDIT_mean', 18)),
#  (254, ('poscash_MONTHS_BALANCE_min', 18)),
#  (255, ('install_AMT_INSTALMENT_sum', 18)),
#  (256,
#   ('bureau_onehot_CREDIT_ACTIVE_Active_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    18)),
#  (257, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_DEBT_std', 18)),
#  (258, ('bureau_DAYS_CREDIT_sum', 18)),
#  (259, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_mean', 18)),
#  (260, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_sum', 18)),
#  (261, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_mean', 18)),
#  (262, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_mean', 18)),
#  (263, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_median', 18)),
#  (264, ('HOUR_APPR_PROCESS_START', 17)),
#  (265, ('AMT_CREDIT_divide_DAYS_LAST_PHONE_CHANGE', 17)),
#  (266, ('OWN_CAR_AGE_divide_DAYS_LAST_PHONE_CHANGE', 17)),
#  (267, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_mean', 17)),
#  (268, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_mean', 17)),
#  (269, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_min', 17)),
#  (270, ('prev_DAYS_DECISION_min', 17)),
#  (271,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    17)),
#  (272, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_mean', 17)),
#  (273, ('prev_AMT_ANNUITY_min', 17)),
#  (274, ('prev_AMT_CREDIT_divide_DAYS_DECISION_median', 17)),
#  (275, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_median', 17)),
#  (276, ('install_DAYS_ENTRY_PAYMENT_sum', 17)),
#  (277,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_DAYS_INSTALMENT_median',
#    17)),
#  (278,
#   ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_DAYS_INSTALMENT_std', 17)),
#  (279, ('install_AMT_PAYMENT_std', 17)),
#  (280, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_median', 17)),
#  (281, ('bureau_AMT_CREDIT_SUM_DEBT_std', 17)),
#  (282, ('bureau_DAYS_ENDDATE_FACT_std', 17)),
#  (283, ('bureau_DAYS_CREDIT_UPDATE_mean', 17)),
#  (284, ('bureau_AMT_CREDIT_SUM_min', 17)),
#  (285, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_std', 17)),
#  (286, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_mean', 17)),
#  (287, ('one_hotNAME_INCOME_TYPE_Working', 16)),
#  (288, ('AMT_CREDIT_divide_DEF_30_CNT_SOCIAL_CIRCLE', 16)),
#  (289, ('AMT_GOODS_PRICE_divide_DAYS_LAST_PHONE_CHANGE', 16)),
#  (290, ('AMT_GOODS_PRICE_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 16)),
#  (291, ('prev_onehot_NAME_CLIENT_TYPE_Refreshed_divide_count_SK_ID_CURR', 16)),
#  (292, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max', 16)),
#  (293, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_median', 16)),
#  (294,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    16)),
#  (295, ('prev_DAYS_DECISION_mean', 16)),
#  (296,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    16)),
#  (297,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    16)),
#  (298, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_max', 16)),
#  (299, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_median', 16)),
#  (300, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_sum', 16)),
#  (301, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_max', 16)),
#  (302, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_min', 16)),
#  (303, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_median', 16)),
#  (304, ('prev_AMT_CREDIT_divide_DAYS_DECISION_sum', 16)),
#  (305, ('poscash_count_SK_ID_CURR', 16)),
#  (306, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_std', 16)),
#  (307, ('install_DAYS_INSTALMENT_median', 16)),
#  (308, ('install_DAYS_INSTALMENT_max', 16)),
#  (309, ('install_DAYS_INSTALMENT_min', 16)),
#  (310,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_median',
#    16)),
#  (311, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_std', 16)),
#  (312, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_std', 16)),
#  (313, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_mean', 16)),
#  (314, ('APARTMENTS_AVG', 15)),
#  (315, ('YEARS_BEGINEXPLUATATION_AVG', 15)),
#  (316, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_MON', 15)),
#  (317, ('prev_onehot_NAME_YIELD_GROUP_2.0', 15)),
#  (318,
#   ('prev_onehot_CHANNEL_TYPE_AP+_(Cash_loan)_divide_count_SK_ID_CURR', 15)),
#  (319,
#   ('prev_onehot_CHANNEL_TYPE_Credit_and_cash_offices_divide_count_SK_ID_CURR',
#    15)),
#  (320, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_min', 15)),
#  (321,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    15)),
#  (322, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_median', 15)),
#  (323, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_mean', 15)),
#  (324, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_median', 15)),
#  (325, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_min', 15)),
#  (326, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 15)),
#  (327, ('prev_DAYS_FIRST_DUE_median', 15)),
#  (328, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_median', 15)),
#  (329, ('prev_DAYS_LAST_DUE_1ST_VERSION_max', 15)),
#  (330, ('prev_AMT_CREDIT_divide_DAYS_DECISION_mean', 15)),
#  (331, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_mean', 15)),
#  (332, ('AMT_CREDIT_divide_prev_AMT_CREDIT_median', 15)),
#  (333, ('poscash_MONTHS_BALANCE_max', 15)),
#  (334,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    15)),
#  (335, ('install_AMT_INSTALMENT_max', 15)),
#  (336, ('install_AMT_INSTALMENT_std', 15)),
#  (337, ('bureau_DAYS_CREDIT_std', 15)),
#  (338, ('bureau_DAYS_CREDIT_UPDATE_min', 15)),
#  (339, ('bureau_AMT_CREDIT_SUM_sum', 15)),
#  (340, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_min', 15)),
#  (341, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_sum', 15)),
#  (342, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_median', 15)),
#  (343, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_std', 15)),
#  (344, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_min', 15)),
#  (345, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_std', 15)),
#  (346, ('LIVINGAREA_MEDI', 14)),
#  (347, ('prev_onehot_NAME_CONTRACT_STATUS_Refused', 14)),
#  (348, ('prev_onehot_CODE_REJECT_REASON_HC_divide_count_SK_ID_CURR', 14)),
#  (349, ('prev_onehot_CODE_REJECT_REASON_SCO_divide_count_SK_ID_CURR', 14)),
#  (350, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in_divide_count_SK_ID_CURR', 14)),
#  (351,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Consumer_electronics_divide_count_SK_ID_CURR',
#    14)),
#  (352,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 14)),
#  (353, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max', 14)),
#  (354, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_max', 14)),
#  (355, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_max', 14)),
#  (356, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 14)),
#  (357, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 14)),
#  (358, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_min', 14)),
#  (359,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    14)),
#  (360, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median', 14)),
#  (361,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    14)),
#  (362, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_max', 14)),
#  (363, ('prev_DAYS_DECISION_sum', 14)),
#  (364,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    14)),
#  (365, ('prev_AMT_APPLICATION_median', 14)),
#  (366, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_mean', 14)),
#  (367,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    14)),
#  (368,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max', 14)),
#  (369, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_max', 14)),
#  (370, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_min', 14)),
#  (371, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_mean', 14)),
#  (372, ('AMT_INCOME_TOTAL_divide_prev_AMT_APPLICATION_mean', 14)),
#  (373, ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_RECIVABLE_median', 14)),
#  (374, ('creditcard_CNT_DRAWINGS_CURRENT_mean', 14)),
#  (375, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_std', 14)),
#  (376, ('install_DAYS_ENTRY_PAYMENT_min', 14)),
#  (377, ('install_DAYS_INSTALMENT_sum', 14)),
#  (378,
#   ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_AMT_INSTALMENT_minus_AMT_PAYMENT_min',
#    14)),
#  (379, ('bureau_AMT_CREDIT_SUM_DEBT_max', 14)),
#  (380, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_sum', 14)),
#  (381, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_min', 14)),
#  (382, ('bureau_AMT_CREDIT_SUM_median', 14)),
#  (383, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_sum', 14)),
#  (384, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_std', 14)),
#  (385, ('bureau_AMT_CREDIT_SUM_divide_DAYS_ENDDATE_FACT_std', 14)),
#  (386, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_mean', 14)),
#  (387, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_sum', 14)),
#  (388, ('FLAG_DOCUMENT_18', 13)),
#  (389, ('livingsum_MEDI_divide_members', 13)),
#  (390, ('REGION_RATING_CLIENT_W_CITY_times_livingsum_MEDI', 13)),
#  (391, ('AMT_INCOME_TOTAL_divide_CNT_FAM_MEMBERS', 13)),
#  (392,
#   ('prev_onehot_NAME_CONTRACT_STATUS_Canceled_divide_count_SK_ID_CURR', 13)),
#  (393,
#   ('prev_onehot_NAME_PAYMENT_TYPE_Cash_through_the_bank_divide_count_SK_ID_CURR',
#    13)),
#  (394,
#   ('prev_onehot_CHANNEL_TYPE_Channel_of_corporate_sales_divide_count_SK_ID_CURR',
#    13)),
#  (395, ('prev_onehot_NAME_YIELD_GROUP_3.0_divide_count_SK_ID_CURR', 13)),
#  (396,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_0.0_divide_count_SK_ID_CURR', 13)),
#  (397,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean', 13)),
#  (398, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 13)),
#  (399, ('prev_CNT_PAYMENT_sum', 13)),
#  (400,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    13)),
#  (401, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_max', 13)),
#  (402, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_median', 13)),
#  (403, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_mean', 13)),
#  (404,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    13)),
#  (405, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_median', 13)),
#  (406, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_mean', 13)),
#  (407, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_min', 13)),
#  (408,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_min',
#    13)),
#  (409, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_mean', 13)),
#  (410, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_min', 13)),
#  (411,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    13)),
#  (412, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 13)),
#  (413,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    13)),
#  (414, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_max', 13)),
#  (415,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    13)),
#  (416,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    13)),
#  (417,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    13)),
#  (418, ('prev_DAYS_FIRST_DUE_sum', 13)),
#  (419,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 13)),
#  (420,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    13)),
#  (421, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_mean', 13)),
#  (422, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_median', 13)),
#  (423, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_mean', 13)),
#  (424, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_max', 13)),
#  (425,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    13)),
#  (426, ('prev_AMT_CREDIT_divide_DAYS_DECISION_min', 13)),
#  (427, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_sum', 13)),
#  (428, ('prev_AMT_ANNUITY_divide_AMT_CREDIT_max', 13)),
#  (429, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_min', 13)),
#  (430, ('AMT_GOODS_PRICE_divide_prev_AMT_GOODS_PRICE_mean', 13)),
#  (431, ('poscash_SK_DPD_DEF_std', 13)),
#  (432,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_median',
#    13)),
#  (433,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_median',
#    13)),
#  (434, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_CURRENT_mean', 13)),
#  (435, ('install_AMT_INSTALMENT_min', 13)),
#  (436, ('install_AMT_PAYMENT_max', 13)),
#  (437, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_mean', 13)),
#  (438, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_std', 13)),
#  (439, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_min', 13)),
#  (440, ('bureau_AMT_CREDIT_SUM_max', 13)),
#  (441, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_sum', 13)),
#  (442, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_max', 13)),
#  (443, ('LANDAREA_MEDI', 12)),
#  (444, ('CONTACT', 12)),
#  (445, ('one_hotOCCUPATION_TYPE_Medicine_staff', 12)),
#  (446, ('one_hotWALLSMATERIAL_MODE_Stone,_brick', 12)),
#  (447, ('AMT_INCOME_TOTAL_divide_DAYS_LAST_PHONE_CHANGE', 12)),
#  (448, ('AMT_CREDIT_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 12)),
#  (449, ('AMT_ANNUITY_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 12)),
#  (450, ('OWN_CAR_AGE_divide_CNT_FAM_MEMBERS', 12)),
#  (451, ('prev_onehot_NAME_PAYMENT_TYPE_XNA_divide_count_SK_ID_CURR', 12)),
#  (452, ('prev_onehot_NAME_PORTFOLIO_POS_divide_count_SK_ID_CURR', 12)),
#  (453, ('prev_onehot_CHANNEL_TYPE_Country-wide_divide_count_SK_ID_CURR', 12)),
#  (454,
#   ('prev_onehot_NAME_SELLER_INDUSTRY_Furniture_divide_count_SK_ID_CURR', 12)),
#  (455, ('prev_onehot_NAME_YIELD_GROUP_0.0_divide_count_SK_ID_CURR', 12)),
#  (456,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_2.0_divide_count_SK_ID_CURR', 12)),
#  (457, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_median', 12)),
#  (458, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_min', 12)),
#  (459, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_median', 12)),
#  (460,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    12)),
#  (461, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_sum', 12)),
#  (462,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    12)),
#  (463,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    12)),
#  (464,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    12)),
#  (465, ('prev_DAYS_FIRST_DUE_max', 12)),
#  (466, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum', 12)),
#  (467, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_sum', 12)),
#  (468, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_sum', 12)),
#  (469,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 12)),
#  (470, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_min', 12)),
#  (471,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean',
#    12)),
#  (472, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_min', 12)),
#  (473, ('prev_AMT_ANNUITY_median', 12)),
#  (474, ('prev_AMT_GOODS_PRICE_divide_DAYS_DECISION_min', 12)),
#  (475, ('prev_DAYS_LAST_DUE_1ST_VERSION_mean', 12)),
#  (476,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    12)),
#  (477,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean',
#    12)),
#  (478,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    12)),
#  (479, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 12)),
#  (480, ('poscash_CNT_INSTALMENT_median', 12)),
#  (481, ('poscash_CNT_INSTALMENT_sum', 12)),
#  (482, ('poscash_CNT_INSTALMENT_max', 12)),
#  (483,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_RECIVABLE_median', 12)),
#  (484,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_MONTHS_BALANCE_median', 12)),
#  (485, ('install_AMT_INSTALMENT_minus_AMT_PAYMENT_max', 12)),
#  (486, ('bureau_onehot_CREDIT_TYPE_Credit_card', 12)),
#  (487, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_min', 12)),
#  (488, ('bureau_AMT_CREDIT_SUM_DEBT_sum', 12)),
#  (489, ('bureau_DAYS_ENDDATE_FACT_sum', 12)),
#  (490, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_mean', 12)),
#  (491, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_std', 12)),
#  (492, ('LIVINGAREA_MODE', 11)),
#  (493, ('livingsum_MODE_divide_members', 11)),
#  (494, ('AMT_GOODS_PRICE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 11)),
#  (495, ('prev_onehot_NAME_PORTFOLIO_Cash_divide_count_SK_ID_CURR', 11)),
#  (496, ('prev_onehot_NAME_SELLER_INDUSTRY_XNA_divide_count_SK_ID_CURR', 11)),
#  (497,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum',
#    11)),
#  (498,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_min',
#    11)),
#  (499, ('prev_DAYS_TERMINATION_sum', 11)),
#  (500, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 11)),
#  (501, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_median', 11)),
#  (502, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_min', 11)),
#  (503, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median', 11)),
#  (504, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 11)),
#  (505,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    11)),
#  (506,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    11)),
#  (507, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_median', 11)),
#  (508,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    11)),
#  (509,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    11)),
#  (510, ('prev_AMT_GOODS_PRICE_mean', 11)),
#  (511, ('prev_AMT_GOODS_PRICE_median', 11)),
#  (512,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum', 11)),
#  (513, ('prev_AMT_CREDIT_divide_AMT_DOWN_PAYMENT_median', 11)),
#  (514,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    11)),
#  (515,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    11)),
#  (516,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    11)),
#  (517, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_median', 11)),
#  (518, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_max', 11)),
#  (519, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_sum', 11)),
#  (520,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    11)),
#  (521, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_min', 11)),
#  (522,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median',
#    11)),
#  (523,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    11)),
#  (524,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_min',
#    11)),
#  (525, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_max', 11)),
#  (526, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_mean', 11)),
#  (527, ('prev_AMT_ANNUITY_divide_AMT_APPLICATION_max', 11)),
#  (528, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_max', 11)),
#  (529, ('prev_AMT_ANNUITY_divide_DAYS_DECISION_min', 11)),
#  (530, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 11)),
#  (531, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_median', 11)),
#  (532, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_max', 11)),
#  (533, ('prev_AMT_ANNUITY_divide_CNT_PAYMENT_sum', 11)),
#  (534,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_mean',
#    11)),
#  (535, ('poscash_CNT_INSTALMENT_FUTURE_median', 11)),
#  (536, ('poscash_CNT_INSTALMENT_FUTURE_max', 11)),
#  (537, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_mean', 11)),
#  (538, ('creditcard_CNT_DRAWINGS_POS_CURRENT_std', 11)),
#  (539,
#   ('install_positivecount_SK_ID_CURR_AMT_INSTALMENT_minus_AMT_PAYMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    11)),
#  (540, ('install_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_median', 11)),
#  (541, ('bureau_positivecount_SK_ID_CURR_AMT_CREDIT_SUM_DEBT', 11)),
#  (542, ('bureau_onehot_CREDIT_TYPE_Mortgage', 11)),
#  (543,
#   ('bureau_onehot_CREDIT_TYPE_Microloan_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    11)),
#  (544, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_std', 11)),
#  (545, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_UPDATE_median', 11)),
#  (546, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_std', 11)),
#  (547, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_max', 11)),
#  (548, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_LIMIT_mean', 11)),
#  (549, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_ANNUITY_max', 11)),
#  (550, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_std', 11)),
#  (551, ('FLOORSMAX_AVG', 10)),
#  (552, ('NONLIVINGAREA_MEDI', 10)),
#  (553, ('one_hotNAME_HOUSING_TYPE_Office_apartment', 10)),
#  (554, ('one_hotOCCUPATION_TYPE_High_skill_tech_staff', 10)),
#  (555, ('REGION_RATING_CLIENT_times_livingsum_AVG', 10)),
#  (556, ('AMT_CREDIT_divide_OWN_CAR_AGE', 10)),
#  (557, ('AMT_GOODS_PRICE_divide_OBS_60_CNT_SOCIAL_CIRCLE', 10)),
#  (558, ('AMT_REQ_CREDIT_BUREAU_MON_divide_DAYS_REGISTRATION', 10)),
#  (559, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OWN_CAR_AGE', 10)),
#  (560, ('prev_onehot_NAME_SELLER_INDUSTRY_Connectivity', 10)),
#  (561, ('prev_onehot_NAME_YIELD_GROUP_1.0', 10)),
#  (562,
#   ('prev_onehot_NAME_CONTRACT_TYPE_Cash_loans_divide_count_SK_ID_CURR', 10)),
#  (563, ('prev_onehot_NAME_PRODUCT_TYPE_XNA_divide_count_SK_ID_CURR', 10)),
#  (564, ('prev_onehot_NAME_YIELD_GROUP_4.0_divide_count_SK_ID_CURR', 10)),
#  (565, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_mean', 10)),
#  (566, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_median', 10)),
#  (567, ('prev_CNT_PAYMENT_median', 10)),
#  (568,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 10)),
#  (569, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 10)),
#  (570, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_median', 10)),
#  (571,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    10)),
#  (572, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_median', 10)),
#  (573, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_max', 10)),
#  (574, ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_sum', 10)),
#  (575, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_min', 10)),
#  (576, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_max', 10)),
#  (577, ('prev_AMT_DOWN_PAYMENT_divide_AMT_GOODS_PRICE_sum', 10)),
#  (578, ('prev_WEEKDAY_APPR_PROCESS_START_median', 10)),
#  (579, ('prev_AMT_APPLICATION_divide_DAYS_DECISION_sum', 10)),
#  (580,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    10)),
#  (581, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_mean', 10)),
#  (582, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_median', 10)),
#  (583,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_sum',
#    10)),
#  (584, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_min', 10)),
#  (585, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_median', 10)),
#  (586,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    10)),
#  (587, ('prev_AMT_GOODS_PRICE_sum', 10)),
#  (588,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    10)),
#  (589,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    10)),
#  (590, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 10)),
#  (591,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    10)),
#  (592, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_sum', 10)),
#  (593,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    10)),
#  (594,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    10)),
#  (595, ('prev_AMT_ANNUITY_divide_AMT_DOWN_PAYMENT_min', 10)),
#  (596, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_mean', 10)),
#  (597, ('prev_AMT_ANNUITY_divide_RATE_DOWN_PAYMENT_min', 10)),
#  (598,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 10)),
#  (599, ('prev_AMT_ANNUITY_mean', 10)),
#  (600, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_min', 10)),
#  (601, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_mean', 10)),
#  (602,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    10)),
#  (603,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    10)),
#  (604, ('prev_DAYS_LAST_DUE_1ST_VERSION_sum', 10)),
#  (605, ('prev_HOUR_APPR_PROCESS_START_median', 10)),
#  (606, ('AMT_INCOME_TOTAL_divide_prev_AMT_CREDIT_mean', 10)),
#  (607, ('poscash_SK_DPD_DEF_mean', 10)),
#  (608, ('poscash_MONTHS_BALANCE_mean', 10)),
#  (609, ('poscash_SK_DPD_DEF_divide_CNT_INSTALMENT_sum', 10)),
#  (610,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median', 10)),
#  (611,
#   ('creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    10)),
#  (612, ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_RECIVABLE_median', 10)),
#  (613, ('install_DAYS_ENTRY_PAYMENT_mean', 10)),
#  (614, ('install_AMT_PAYMENT_mean', 10)),
#  (615, ('bureau_count_SK_ID_CURR', 10)),
#  (616, ('bureau_DAYS_ENDDATE_FACT_min', 10)),
#  (617, ('bureau_AMT_CREDIT_SUM_divide_AMT_CREDIT_SUM_OVERDUE_min', 10)),
#  (618, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_median', 10)),
#  (619, ('bureau_AMT_CREDIT_SUM_divide_DAYS_CREDIT_UPDATE_max', 10)),
#  (620, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_OVERDUE_max', 10)),
#  (621, ('bureau_MONTHS_BALANCE_std_sum', 10)),
#  (622, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_mean', 10)),
#  (623, ('bureau_AMT_CREDIT_SUM_divide_CNT_CREDIT_PROLONG_max', 10)),
#  (624, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_median', 10)),
#  (625, ('bureau_AMT_CREDIT_MAX_OVERDUE_mean', 10)),
#  (626, ('ENTRANCES_MEDI', 9)),
#  (627, ('one_hotOCCUPATION_TYPE_Accountants', 9)),
#  (628, ('OBS_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 9)),
#  (629, ('AMT_GOODS_PRICE_divide_DEF_30_CNT_SOCIAL_CIRCLE', 9)),
#  (630, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_REGISTRATION', 9)),
#  (631, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_DAYS_ID_PUBLISH', 9)),
#  (632, ('prev_onehot_NAME_CLIENT_TYPE_New_divide_count_SK_ID_CURR', 9)),
#  (633, ('prev_onehot_CHANNEL_TYPE_Contact_center_divide_count_SK_ID_CURR', 9)),
#  (634,
#   ('prev_onehot_NFLAG_INSURED_ON_APPROVAL_0.0_divide_count_SK_ID_CURR', 9)),
#  (635,
#   ('prev_onehot_FLAG_NAME_CASH_LOAN_PURPOSE_0.0_divide_count_SK_ID_CURR', 9)),
#  (636, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median', 9)),
#  (637, ('prev_AMT_APPLICATION_divide_CNT_PAYMENT_sum', 9)),
#  (638, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 9)),
#  (639,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 9)),
#  (640, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_max', 9)),
#  (641,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    9)),
#  (642, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_mean', 9)),
#  (643, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_min', 9)),
#  (644,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    9)),
#  (645, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_min', 9)),
#  (646, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_median', 9)),
#  (647, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_mean', 9)),
#  (648,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    9)),
#  (649, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 9)),
#  (650, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 9)),
#  (651, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_mean', 9)),
#  (652,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    9)),
#  (653,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max',
#    9)),
#  (654, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_mean', 9)),
#  (655, ('prev_AMT_ANNUITY_divide_DAYS_TERMINATION_max', 9)),
#  (656, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_median', 9)),
#  (657, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_mean', 9)),
#  (658, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_max', 9)),
#  (659,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    9)),
#  (660, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_mean', 9)),
#  (661, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_median', 9)),
#  (662,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum', 9)),
#  (663, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_median', 9)),
#  (664,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median',
#    9)),
#  (665, ('poscash_CNT_INSTALMENT_FUTURE_sum', 9)),
#  (666,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_median',
#    9)),
#  (667,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_std', 9)),
#  (668, ('creditcard_CNT_DRAWINGS_POS_CURRENT_mean', 9)),
#  (669, ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_mean', 9)),
#  (670, ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_std', 9)),
#  (671,
#   ('install_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT_divide_positivecount_SK_ID_CURR_DAYS_ENTRY_PAYMENT_minus_DAYS_INSTALMENT',
#    9)),
#  (672, ('bureau_AMT_CREDIT_SUM_divide_CREDIT_DAY_OVERDUE_mean', 9)),
#  (673, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_max', 9)),
#  (674, ('bureau_AMT_CREDIT_SUM_mean', 9)),
#  (675, ('bureau_AMT_CREDIT_SUM_std', 9)),
#  (676, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_max', 9)),
#  (677,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_median', 9)),
#  (678, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_LIMIT_max', 9)),
#  (679, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_median', 9)),
#  (680, ('bureau_MONTHS_BALANCE_std_median', 9)),
#  (681, ('bureau_DAYS_CREDIT_ENDDATE_min', 9)),
#  (682, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_sum', 9)),
#  (683, ('bureau_onehot_STATUS_0_std', 9)),
#  (684, ('bureau_onehot_STATUS_1_std', 9)),
#  (685, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_median', 9)),
#  (686, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_UPDATE_std', 9)),
#  (687, ('REGION_RATING_CLIENT', 8)),
#  (688, ('COMMONAREA_AVG', 8)),
#  (689, ('NONLIVINGAREA_AVG', 8)),
#  (690, ('OBS_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 8)),
#  (691, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_OBS_30_CNT_SOCIAL_CIRCLE', 8)),
#  (692, ('AMT_ANNUITY_divide_DEF_30_CNT_SOCIAL_CIRCLE', 8)),
#  (693, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_OBS_30_CNT_SOCIAL_CIRCLE', 8)),
#  (694, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_OBS_30_CNT_SOCIAL_CIRCLE', 8)),
#  (695, ('prev_onehot_CODE_REJECT_REASON_SCOFR_divide_count_SK_ID_CURR', 8)),
#  (696, ('prev_onehot_NAME_PRODUCT_TYPE_x-sell_divide_count_SK_ID_CURR', 8)),
#  (697,
#   ('prev_onehot_FLAG_NAME_GOODS_CATEGORY_1.0_divide_count_SK_ID_CURR', 8)),
#  (698, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median', 8)),
#  (699, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_sum', 8)),
#  (700,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 8)),
#  (701, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_median', 8)),
#  (702, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_min', 8)),
#  (703, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_max', 8)),
#  (704,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    8)),
#  (705, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_max', 8)),
#  (706, ('prev_AMT_CREDIT_divide_CNT_PAYMENT_sum', 8)),
#  (707,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_max',
#    8)),
#  (708, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 8)),
#  (709, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_max', 8)),
#  (710,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    8)),
#  (711, ('prev_RATE_DOWN_PAYMENT_mean', 8)),
#  (712, ('prev_RATE_DOWN_PAYMENT_median', 8)),
#  (713, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_sum', 8)),
#  (714,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min',
#    8)),
#  (715,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum',
#    8)),
#  (716, ('prev_AMT_APPLICATION_divide_AMT_CREDIT_sum', 8)),
#  (717,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_mean',
#    8)),
#  (718,
# ...
#  (775, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_CREDIT_ENDDATE_min', 8)),
#  (776, ('bureau_onehot_STATUS_1_max', 8)),
#  (777, ('ENTRANCES_AVG', 7)),
#  (778, ('BASEMENTAREA_MEDI', 7)),
#  (779, ('livingsum_MODE', 7)),
#  (780, ('livingsum_MEDI', 7)),
#  (781, ('DEF_30_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 7)),
#  (782, ('DEF_60_CNT_SOCIAL_CIRCLE_divide_REGION_POPULATION_RELATIVE', 7)),
#  (783, ('AMT_INCOME_TOTAL_divide_DEF_30_CNT_SOCIAL_CIRCLE', 7)),
#  (784, ('AMT_INCOME_TOTAL_divide_AMT_REQ_CREDIT_BUREAU_YEAR', 7)),
#  (785, ('AMT_ANNUITY_divide_OWN_CAR_AGE', 7)),
#  (786, ('AMT_GOODS_PRICE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 7)),
#  (787, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_CNT_FAM_MEMBERS', 7)),
#  (788, ('OWN_CAR_AGE_divide_DEF_60_CNT_SOCIAL_CIRCLE', 7)),
#  (789, ('prev_onehot_CODE_REJECT_REASON_HC', 7)),
#  (790, ('prev_onehot_NAME_CLIENT_TYPE_Repeater_divide_count_SK_ID_CURR', 7)),
#  (791, ('prev_onehot_CHANNEL_TYPE_Stone_divide_count_SK_ID_CURR', 7)),
#  (792,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_mean', 7)),
#  (793,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 7)),
#  (794,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_sum',
#    7)),
#  (795, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_mean', 7)),
#  (796, ('prev_AMT_DOWN_PAYMENT_divide_RATE_DOWN_PAYMENT_max', 7)),
#  (797, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_mean', 7)),
#  (798, ('prev_AMT_APPLICATION_divide_DAYS_TERMINATION_median', 7)),
#  (799, ('prev_AMT_CREDIT_divide_DAYS_TERMINATION_mean', 7)),
#  (800, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_sum', 7)),
#  (801, ('prev_AMT_GOODS_PRICE_divide_RATE_DOWN_PAYMENT_median', 7)),
#  (802, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 7)),
#  (803, ('prev_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 7)),
#  (804, ('prev_WEEKDAY_APPR_PROCESS_START_min', 7)),
#  (805, ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_max', 7)),
#  (806, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_mean', 7)),
#  (807, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_min', 7)),
#  (808, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 7)),
#  (809, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_max', 7)),
#  (810,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    7)),
#  (811,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_min',
#    7)),
#  (812, ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_median', 7)),
#  (813, ('prev_AMT_GOODS_PRICE_min', 7)),
#  (814, ('prev_AMT_CREDIT_sum', 7)),
#  (815, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_max', 7)),
#  (816, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_min', 7)),
#  (817,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_mean', 7)),
#  (818,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median', 7)),
#  (819,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_min', 7)),
#  (820,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_sum', 7)),
#  (821, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_median', 7)),
#  (822, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 7)),
#  (823,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    7)),
#  (824, ('prev_AMT_DOWN_PAYMENT_sum', 7)),
#  (825,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    7)),
#  (826,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_sum',
#    7)),
#  (827, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_sum', 7)),
#  (828,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    7)),
#  (829,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    7)),
#  (830,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    7)),
#  (831,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    7)),
#  (832,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    7)),
#  (833, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean', 7)),
#  (834, ('prev_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_sum', 7)),
#  (835,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    7)),
#  (836,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    7)),
#  (837,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    7)),
#  (838, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median', 7)),
#  (839,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 7)),
#  (840,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_sum', 7)),
#  (841, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_median', 7)),
#  (842,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_median', 7)),
#  (843, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_mean', 7)),
#  (844, ('prev_AMT_APPLICATION_divide_AMT_GOODS_PRICE_median', 7)),
#  (845,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_mean',
#    7)),
#  (846, ('prev_AMT_DOWN_PAYMENT_divide_CNT_PAYMENT_sum', 7)),
#  (847,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 7)),
#  (848,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 7)),
#  (849,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    7)),
#  (850, ('prev_AMT_APPLICATION_divide_AMT_DOWN_PAYMENT_median', 7)),
#  (851,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    7)),
#  (852,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 7)),
#  (853,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_median',
#    7)),
#  (854,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min',
#    7)),
#  (855,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_sum',
#    7)),
#  (856, ('prev_AMT_CREDIT_divide_DAYS_DECISION_max', 7)),
#  (857, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_sum', 7)),
#  (858,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_max', 7)),
#  (859,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_min', 7)),
#  (860,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 7)),
#  (861, ('poscash_SK_DPD_sum', 7)),
#  (862, ('poscash_SK_DPD_divide_MONTHS_BALANCE_std', 7)),
#  (863, ('poscash_SK_DPD_DEF_divide_MONTHS_BALANCE_sum', 7)),
#  (864,
#   ('creditcard_onehot_NAME_CONTRACT_STATUS_Active_divide_count_SK_ID_CURR',
#    7)),
#  (865,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_TOTAL_RECEIVABLE_std', 7)),
#  (866,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_mean',
#    7)),
#  (867,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_OTHER_CURRENT_mean',
#    7)),
#  (868, ('creditcard_AMT_RECIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std', 7)),
#  (869,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_DRAWINGS_ATM_CURRENT_mean',
#    7)),
#  (870,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_POS_CURRENT_sum', 7)),
#  (871,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_AMT_TOTAL_RECEIVABLE_median',
#    7)),
#  (872,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_sum', 7)),
#  (873, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_sum', 7)),
#  (874, ('creditcard_AMT_BALANCE_divide_AMT_RECIVABLE_median', 7)),
#  (875, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_DAYS_CREDIT_UPDATE_min', 7)),
#  (876, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_sum', 7)),
#  (877, ('bureau_DAYS_CREDIT_UPDATE_sum', 7)),
#  (878, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_median', 7)),
#  (879,
#   ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_mean', 7)),
#  (880, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_OVERDUE_max', 7)),
#  (881, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_std', 7)),
#  (882, ('bureau_AMT_CREDIT_SUM_DEBT_divide_AMT_CREDIT_SUM_LIMIT_min', 7)),
#  (883, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_ENDDATE_median', 7)),
#  (884, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CNT_CREDIT_PROLONG_median', 7)),
#  (885, ('bureau_AMT_ANNUITY_std', 7)),
#  (886, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_CREDIT_DAY_OVERDUE_median', 7)),
#  (887, ('bureau_onehot_STATUS_1_mean', 7)),
#  (888, ('YEARS_BUILD_AVG', 6)),
#  (889, ('LIVINGAPARTMENTS_AVG', 6)),
#  (890, ('APARTMENTS_MODE', 6)),
#  (891, ('BASEMENTAREA_MODE', 6)),
#  (892, ('YEARS_BUILD_MODE', 6)),
#  (893, ('COMMONAREA_MODE', 6)),
#  (894, ('ENTRANCES_MODE', 6)),
#  (895, ('FLOORSMAX_MODE', 6)),
#  (896, ('COMMONAREA_MEDI', 6)),
#  (897, ('FLOORSMAX_MEDI', 6)),
#  (898, ('FLAG_DOCUMENT_16', 6)),
#  (899, ('AMT_INCOME_TOTAL_divide_OBS_60_CNT_SOCIAL_CIRCLE', 6)),
#  (900, ('AMT_CREDIT_divide_OBS_60_CNT_SOCIAL_CIRCLE', 6)),
#  (901, ('AMT_ANNUITY_divide_OBS_60_CNT_SOCIAL_CIRCLE', 6)),
#  (902, ('AMT_REQ_CREDIT_BUREAU_QRT_divide_DAYS_BIRTH', 6)),
#  (903, ('AMT_REQ_CREDIT_BUREAU_YEAR_divide_CNT_CHILDREN', 6)),
#  (904, ('prev_onehot_NAME_PRODUCT_TYPE_walk-in', 6)),
#  (905, ('prev_onehot_NAME_PORTFOLIO_XNA_divide_count_SK_ID_CURR', 6)),
#  (906, ('prev_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_min', 6)),
#  (907, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 6)),
#  (908, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_max', 6)),
#  (909,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    6)),
#  (910,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    6)),
#  (911, ('prev_DAYS_TERMINATION_min', 6)),
#  (912, ('prev_AMT_ANNUITY_divide_AMT_GOODS_PRICE_sum', 6)),
#  (913,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_mean',
#    6)),
#  (914, ('prev_WEEKDAY_APPR_PROCESS_START_max', 6)),
#  (915,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    6)),
#  (916, ('prev_AMT_GOODS_PRICE_divide_DAYS_TERMINATION_max', 6)),
#  (917,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_median',
#    6)),
#  (918, ('prev_AMT_CREDIT_divide_RATE_DOWN_PAYMENT_mean', 6)),
#  (919,
#   ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DRAWING_minus_DAYS_FIRST_DUE_median',
#    6)),
#  (920,
#   ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_mean',
#    6)),
#  (921, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_TERMINATION_sum', 6)),
#  (922, ('prev_AMT_GOODS_PRICE_max', 6)),
#  (923, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum', 6)),
#  (924, ('prev_AMT_CREDIT_min', 6)),
#  (925, ('prev_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_mean', 6)),
#  (926,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_max',
#    6)),
#  (927, ('prev_AMT_DOWN_PAYMENT_median', 6)),
#  (928, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_mean', 6)),
#  (929, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_DECISION_median', 6)),
#  (930,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_TERMINATION_max',
#    6)),
#  (931,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    6)),
#  (932,
#   ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_median',
#    6)),
#  (933, ('prev_DAYS_FIRST_DUE_min', 6)),
#  (934,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_median',
#    6)),
#  (935, ('prev_AMT_CREDIT_divide_AMT_GOODS_PRICE_sum', 6)),
#  (936, ('prev_DAYS_LAST_DUE_1ST_VERSION_minus_DAYS_LAST_DUE_max', 6)),
#  (937,
#   ('prev_AMT_GOODS_PRICE_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_max', 6)),
#  (938, ('prev_AMT_ANNUITY_divide_DAYS_FIRST_DUE_max', 6)),
#  (939,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_max',
#    6)),
#  (940, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_mean', 6)),
#  (941,
#   ('prev_AMT_ANNUITY_divide_DAYS_LAST_DUE_minus_DAYS_TERMINATION_sum', 6)),
#  (942, ('prev_AMT_APPLICATION_divide_DAYS_LAST_DUE_max', 6)),
#  (943,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_min', 6)),
#  (944, ('prev_AMT_CREDIT_divide_DAYS_FIRST_DRAWING_sum', 6)),
#  (945, ('prev_AMT_GOODS_PRICE_divide_DAYS_LAST_DUE_median', 6)),
#  (946,
#   ('prev_AMT_DOWN_PAYMENT_divide_DAYS_FIRST_DRAWING_minus_DAYS_TERMINATION_median',
#    6)),
#  (947, ('prev_AMT_APPLICATION_mean', 6)),
#  (948, ('prev_AMT_APPLICATION_min', 6)),
#  (949, ('prev_AMT_APPLICATION_sum', 6)),
#  (950,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DRAWING_minus_DAYS_LAST_DUE_1ST_VERSION_mean',
#    6)),
#  (951,
#   ('prev_AMT_CREDIT_divide_DAYS_FIRST_DUE_minus_DAYS_LAST_DUE_1ST_VERSION_sum',
#    6)),
#  (952, ('prev_AMT_APPLICATION_divide_RATE_DOWN_PAYMENT_mean', 6)),
#  (953,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_median',
#    6)),
#  (954,
#   ('prev_AMT_APPLICATION_divide_DAYS_FIRST_DUE_minus_DAYS_TERMINATION_max',
#    6)),
#  (955, ('prev_AMT_DOWN_PAYMENT_divide_DAYS_LAST_DUE_1ST_VERSION_min', 6)),
#  (956, ('prev_AMT_GOODS_PRICE_divide_CNT_PAYMENT_mean', 6)),
#  (957, ('prev_AMT_CREDIT_divide_DAYS_LAST_DUE_1ST_VERSION_mean', 6)),
#  (958, ('poscash_positivecount_SK_ID_CURR_SK_DPD', 6)),
#  (959,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Returned_to_the_store_divide_positivecount_SK_ID_CURR_SK_DPD',
#    6)),
#  (960,
#   ('poscash_onehot_NAME_CONTRACT_STATUS_Signed_divide_positivecount_SK_ID_CURR_SK_DPD',
#    6)),
#  (961, ('poscash_CNT_INSTALMENT_mean', 6)),
#  (962, ('creditcard_count_SK_ID_CURR', 6)),
#  (963, ('creditcard_AMT_BALANCE_divide_AMT_PAYMENT_TOTAL_CURRENT_mean', 6)),
#  (964,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_CURRENT_mean', 6)),
#  (965,
#   ('creditcard_AMT_DRAWINGS_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_sum', 6)),
#  (966,
#   ('creditcard_AMT_TOTAL_RECEIVABLE_divide_CNT_DRAWINGS_POS_CURRENT_std', 6)),
#  (967,
#   ('creditcard_AMT_PAYMENT_TOTAL_CURRENT_divide_CNT_INSTALMENT_MATURE_CUM_median',
#    6)),
#  (968, ('creditcard_AMT_BALANCE_divide_AMT_DRAWINGS_CURRENT_mean', 6)),
#  (969, ('creditcard_SK_DPD_divide_SK_DPD_minus_SK_DPD_DEF_mean', 6)),
#  (970, ('creditcard_AMT_BALANCE_divide_AMT_CREDIT_LIMIT_ACTUAL_mean', 6)),
#  (971, ('creditcard_AMT_DRAWINGS_CURRENT_divide_CNT_DRAWINGS_CURRENT_std', 6)),
#  (972,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_CNT_DRAWINGS_POS_CURRENT_mean',
#    6)),
#  (973,
#   ('creditcard_AMT_CREDIT_LIMIT_ACTUAL_divide_AMT_DRAWINGS_CURRENT_median',
#    6)),
#  (974,
#   ('creditcard_AMT_PAYMENT_CURRENT_divide_AMT_PAYMENT_TOTAL_CURRENT_std', 6)),
#  (975, ('creditcard_AMT_DRAWINGS_CURRENT_divide_MONTHS_BALANCE_mean', 6)),
#  (976, ('creditcard_AMT_RECIVABLE_divide_AMT_TOTAL_RECEIVABLE_mean', 6)),
#  (977, ('creditcard_AMT_BALANCE_divide_CNT_INSTALMENT_MATURE_CUM_mean', 6)),
#  (978, ('install_AMT_INSTALMENT_median', 6)),
#  (979,
#   ('bureau_onehot_CREDIT_TYPE_Consumer_credit_divide_positivecount_SK_ID_CURR_CREDIT_DAY_OVERDUE',
#    6)),
#  (980, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_mean', 6)),
#  (981, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_DAYS_ENDDATE_FACT_min', 6)),
#  (982, ('bureau_onehot_STATUS_C_mean', 6)),
#  (983, ('bureau_MONTHS_BALANCE_median_mean', 6)),
#  (984, ('bureau_MONTHS_BALANCE_median_median', 6)),
#  (985, ('bureau_MONTHS_BALANCE_median_min', 6)),
#  (986, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_mean', 6)),
#  (987, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_CREDIT_DAY_OVERDUE_max', 6)),
#  (988, ('bureau_MONTHS_BALANCE_max_mean', 6)),
#  (989, ('bureau_MONTHS_BALANCE_min_mean', 6)),
#  (990, ('bureau_MONTHS_BALANCE_min_median', 6)),
#  (991, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_median', 6)),
#  (992, ('bureau_AMT_CREDIT_MAX_OVERDUE_divide_AMT_CREDIT_SUM_DEBT_std', 6)),
#  (993, ('bureau_AMT_CREDIT_SUM_DEBT_divide_DAYS_CREDIT_median', 6)),
#  (994, ('bureau_AMT_CREDIT_SUM_OVERDUE_divide_DAYS_CREDIT_min', 6)),
#  (995, ('bureau_STATUS_NUM_divide_MONTHS_BALANCE_std_median', 6)),
#  (996, ('bureau_AMT_CREDIT_SUM_DEBT_divide_CREDIT_DAY_OVERDUE_max', 6)),
#  (997, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_mean', 6)),
#  (998, ('bureau_AMT_CREDIT_SUM_LIMIT_divide_AMT_CREDIT_SUM_OVERDUE_std', 6)),
#  (999, ('bureau_MONTHS_BALANCE_mean_median', 6)),
#  ...]
