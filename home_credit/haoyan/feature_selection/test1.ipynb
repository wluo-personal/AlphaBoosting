# %%
import pandas as pd
import os

PATH = '/home/kai/data/kaggle/homecredit/'

# %%
x = pd.read_pickle(PATH + 'feature_selection/missing.pkl')
x[x>0.8].index.values
# Out:
# array(['SK_DPD_DEF_std_std',
#        'AMT_REQ_CREDIT_BUREAU_HOUR_divide_AMT_REQ_CREDIT_BUREAU_DAY',
#        'SK_DPD_std_std', 'prev_RATE_INTEREST_PRIMARY_mean',
#        'prev_RATE_INTEREST_PRIMARY_median',
#        'prev_RATE_INTEREST_PRIMARY_max', 'prev_RATE_INTEREST_PRIMARY_min',
#        'prev_RATE_INTEREST_PRIVILEGED_mean',
#        'prev_RATE_INTEREST_PRIVILEGED_median',
#        'prev_RATE_INTEREST_PRIVILEGED_max',
#        'prev_RATE_INTEREST_PRIVILEGED_min', 'SK_DPD_DEF_max_std',
#        'SK_DPD_DEF_mean_std', 'SK_DPD_DEF_min_std',
#        'inst_slope_AMT_LATE_PAYMENT_std_std',
#        'inst_normalslope_AMT_LATE_PAYMENT_std_std',
#        'inst_normalslope_RATE_LATE_PAYMENT_std_std',
#        'inst_slope_RATE_LATE_PAYMENT_std_std', 'SK_DPD_max_std',
#        'SK_DPD_min_std', 'SK_DPD_mean_std',
#        'AMT_REQ_CREDIT_BUREAU_DAY_divide_AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_HOUR_divide_AMT_REQ_CREDIT_BUREAU_WEEK',
# ...
