# %%
import pandas as pd
import numpy as np

PATH = '/home/kai/data/kaggle/homecredit/'
inst0 = pd.read_csv(PATH + 'POS_CASH_balance.csv')

# %%
inst0.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0     1803195      182943             -31            48.0
# 1     1715348      367990             -33            36.0
# 2     1784872      397406             -32            12.0
# 3     1903291      269225             -35            48.0
# 4     2341044      334279             -35            36.0
#
#    CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                   45.0               Active       0           0
# 1                   35.0               Active       0           0
# 2                    9.0               Active       0           0
# 3                   42.0               Active       0           0
# 4                   35.0               Active       0           0

# %%
inst = inst0.sort_values('MONTHS_BALANCE', ascending=False)

# %%
inst[inst['SK_DPD']>0]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 7157243     2671485      384723              -1            49.0
# 463338      1736113      417170              -1            48.0
# 3771231     1365201      233450              -1            12.0
# 464421      2028865      352148              -1            26.0
# 4734711     1185753      142841              -1            48.0
# 3767767     1968487      156803              -1            36.0
# 8463338     1793999      318763              -1             8.0
# 8463505     1373673      211998              -1            24.0
# 6090551     1205951      358361              -1             6.0
# 8463256     2140112      448061              -1             4.0
# 8463259     1581760      345870              -1            10.0
# 8463266     2347821      277823              -1             8.0
# 8463276     1679072      304010              -1             8.0
# 4735959     2833033      140949              -1            54.0
# ...

# %%
inst[inst['SK_ID_PREV']==2341044]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 35079       2341044      334279              -1            36.0
# 8121485     2341044      334279              -2            36.0
# 5510813     2341044      334279              -3            36.0
# 5036210     2341044      334279              -4            36.0
# 3167287     2341044      334279              -5            36.0
# 1609156     2341044      334279              -6            36.0
# 333189      2341044      334279              -7            36.0
# 498854      2341044      334279              -8            36.0
# 4943150     2341044      334279              -9            36.0
# 1121811     2341044      334279             -10            36.0
# 3151727     2341044      334279             -11            36.0
# 2906227     2341044      334279             -12            36.0
# 4618451     2341044      334279             -13            36.0
# 1994729     2341044      334279             -14            36.0
# ...
