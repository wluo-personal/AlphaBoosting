# %%
import pandas as pd
import numpy as np

PATH = '/home/kai/data/kaggle/homecredit/'
inst0 = pd.read_csv(PATH + 'POS_CASH_balance.csv')

# %%
inst0.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0     1803195      182943             -31            48.0
# 1     1715348      367990             -33            36.0
# 2     1784872      397406             -32            12.0
# 3     1903291      269225             -35            48.0
# 4     2341044      334279             -35            36.0
#
#    CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                   45.0               Active       0           0
# 1                   35.0               Active       0           0
# 2                    9.0               Active       0           0
# 3                   42.0               Active       0           0
# 4                   35.0               Active       0           0

# %%
inst = inst0.sort_values('MONTHS_BALANCE', ascending=False)

# %%
inst = inst.merge(inst.groupby('SK_ID_PREV').size().reset_index(), on='SK_ID_PREV', how='left')

# %%
inst0.NAME_CONTRACT_STATUS.unique()
# Out:
# array(['Active', 'Completed', 'Signed', 'Approved',
#        'Returned to the store', 'Demand', 'Canceled', 'XNA',
#        'Amortized debt'], dtype=object)

# %%
inst[(inst['NAME_CONTRACT_STATUS']=='Canceled')]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 156216      1160113      236646              -2             NaN
# 248727      2239989      347381              -2             NaN
# 266377      1546576      397946              -3             NaN
# 404288      2122901      390665              -3             NaN
# 877220      2200360      256843              -6             NaN
# 1366720     2134263      366250              -8             NaN
# 2733669     1287451      408925             -14             NaN
# 3491969     1976128      349795             -18             NaN
# 3562522     1720362      387292             -19             NaN
# 4255801     1176218      253007             -23             NaN
# 5112909     1531600      103793             -28             NaN
# 5211122     1764746      256152             -29             NaN
# 5212913     1071058      382630             -29            24.0
# 6050597     2762733      307509             -37            12.0
# ...

# %%
inst[(inst['NAME_CONTRACT_STATUS']=='Demand') & (inst['SK_DPD']>0)]['SK_DPD'].max()
# Out:
# 4050

# %%
inst[(inst['NAME_CONTRACT_STATUS']=='Demand') & (inst['SK_DPD']>0)]
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 1011        1691592      192536              -1             7.0
# 1541        2399733      375200              -1             7.0
# 2449        1358869      340885              -1             8.0
# 3861        1308432      417372              -1             4.0
# 4141        2437327      305786              -1            24.0
# 4199        1779500      218915              -1             6.0
# 4969        2295239      121088              -1             8.0
# 5160        2204310      435701              -1             8.0
# 14814       2595976      347082              -1             6.0
# 28677       2035711      151513              -1            11.0
# 29173       1519638      343524              -1            28.0
# 36022       2505003      200561              -1             4.0
# 43101       1730347      385366              -1             6.0
# 45078       1975381      259192              -1            12.0
# ...

# %%
inst0[inst0['SK_ID_PREV']==2362171].sort_values('MONTHS_BALANCE', ascending=False)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 9793438     2362171      276629              -3            12.0
# 9791901     2362171      276629              -4            12.0
# 7715780     2362171      276629              -5            12.0
# 9793433     2362171      276629              -6            12.0
# 9791890     2362171      276629              -7            12.0
# 7714611     2362171      276629              -8            12.0
# 9791917     2362171      276629              -9            12.0
# 7715774     2362171      276629             -10            12.0
# 7714625     2362171      276629             -11            12.0
# 7714674     2362171      276629             -12            12.0
# 7714662     2362171      276629             -13            12.0
# 7714645     2362171      276629             -14            12.0
# 7714070     2362171      276629             -15            12.0
# 9794450     2362171      276629             -16            12.0
# ...
