# %%
import pandas as pd
import numpy as np

# %%
report = pd.read_csv('add_each_col_score_v3_.csv')

# %%
base = report[report.colName=='noadd'].iloc[0]
base_holdout_overall = base['holdout_overall']
base_cv_mean = base['val_mean']

# %%
available = report[(report.holdout_overall<base_holdout_overall)&(report.val_mean<base_cv_mean)]
available
# Out:
# Empty DataFrame
# Columns: [colName, holdout_overall, holdout_mean, val_mean, train_mean]
# Index: []

# %%
report.sort_values('holdout_overall')
# Out:
#                                                colName  holdout_overall  \
# 0                                                noadd         0.426123
# 169  model+city+creative_type+osv_count_in_previous...         0.426137
# 201  app_id+advert_name+user_tags+osv_count_in_prev...         0.426160
# 184  city+user_tags+creative_type+osv_count_in_next...         0.426163
# 42   model+advert_name+user_tags+creative_type_coun...         0.426169
# 59   model+advert_name+creative_type+osv_count_in_p...         0.426175
# 187  app_id+city+advert_name+user_tags_count_in_nex...         0.426187
# 143  city+advert_name+creative_type+osv_count_in_ne...         0.426189
# 25   app_id+advert_name+user_tags+creative_type_cou...         0.426192
# 31   app_id+city+advert_name+user_tags_count_in_nex...         0.426196
# 129  city+user_tags+creative_type+osv_count_in_prev...         0.426200
# 146  city+advert_name+user_tags+osv_count_in_next_n...         0.426212
# ...
