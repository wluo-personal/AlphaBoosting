# %%
__file__=''
import os,sys
import pandas as pd
sys.path.append(os.path.join(os.path.dirname(__file__),'../LIB/'))
sys.path.append(os.path.join(os.path.dirname(__file__),'../../../../automl/automl_libs/'))
from env import FILE
from sklearn.feature_extraction import FeatureHasher
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
from tqdm import tqdm
from scipy.sparse import csc_matrix, csr_matrix, hstack
import time
import numpy as np
import pickle

from keras.layers import Dense,Input,LSTM,Bidirectional,Activation,Conv1D,GRU,CuDNNGRU,Flatten,BatchNormalization,CuDNNLSTM,Activation,BatchNormalization
from keras.callbacks import Callback
from keras.layers import Dropout,Embedding,GlobalMaxPooling1D, MaxPooling1D, Add, Flatten
from keras.preprocessing import text, sequence
from keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate, SpatialDropout1D
from keras import initializers, regularizers, constraints, optimizers, layers, callbacks
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import Model
from keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.preprocessing import text, sequence
from sklearn.metrics import log_loss,roc_auc_score
from keras.regularizers import l1
from keras.regularizers import l2
from keras.regularizers import l1_l2
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold
import re
from keras import backend as K
import time
import gc
# To get learning rate
# Out:
# /home/kai/anaconda3/envs/tf_gpu/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train = pd.read_pickle(FILE.train_ori.value)
print('train shape is: {}'.format(train.shape))
test = pd.read_pickle(FILE.test_ori.value)
print('test shape is: {}'.format(test.shape))
train_length = len(train)

X_shiyi = pd.read_pickle(FILE.shiyi_fillna_ori.value)
# X_shiyi['weekDay'] = X_shiyi['time_day'] % 7 +1
print(X_shiyi.shape)

train = train.merge(X_shiyi[['time_hour','instance_id']],how='inner',on='instance_id')
test = test.merge(X_shiyi[['time_hour','instance_id']],how='inner',on='instance_id')


X = pd.concat([train,test],sort=False)
print(X.shape)
X = X.reset_index(drop=True)

# X_clean = pd.read_csv('../../data/original/cleaned_data_price_final.csv')
# X_append = pd.read_pickle('../../data/nn_features/clean.pkl')



print(X.shape)
# assert np.sum(X_clean['instance_id'].values != X['instance_id'].values) == 0
# assert np.sum(X_append['instance_id'].values != X['instance_id'].values) == 0
# X['model'] = X_append['model_v4'].values


ignore_columns = ['instance_id','time','click'] + ['creative_is_js', 'creative_is_voicead', 'app_paid']
# Out:
# train shape is: (1001650, 35)
# test shape is: (40024, 34)
# (1041674, 229)
# (1041674, 36)
# (1041674, 36)

# %% [markdown]
# # PB 4236

# %%
# need_process_col = list(set(X.columns) - set(ignore_columns))
# X_ = X[need_process_col].copy()


# doc_col = ['user_tags','model']
# non_doc_col = [f for f in need_process_col if f not in doc_col]
# # doc_col = doc_col + []
# # non_doc_col = non_doc_col+['user_tags']
# counter = 0

# X_doc = X[doc_col].copy()
# for col in tqdm(non_doc_col):
#     X_[col] = le.fit_transform(X_[col].astype(str))
#     X_[col] = col + '_'+X_[col].astype(str)
    
# for col in tqdm(doc_col):
#     X_doc[col] = X_doc[col].astype(str)

# %%
need_process_col = list(set(X.columns) - set(ignore_columns))
X_ = X[need_process_col].copy()


doc_col = ['user_tags','model']
non_doc_col = [f for f in need_process_col if f not in doc_col]
# doc_col = doc_col + []
# non_doc_col = non_doc_col+['user_tags']
counter = 0

X_doc = X[doc_col].copy()
for col in tqdm(non_doc_col):
    test_values = set(X_[col].iloc[train_length:].astype(str).unique())
    train_values = set(X_[col].iloc[:train_length].astype(str).unique())
    intersection = train_values.intersection(test_values)
    out_liyer = list(train_values.union(test_values) - intersection)
    if len(out_liyer) > 0:
        out_liyer_mapping = pd.Series(index=list(out_liyer),data=1)
        filtered = (X_[col].astype(str).map(out_liyer_mapping) == 1)
        X_.loc[filtered,col] = np.nan
        
        
    X_[col] = le.fit_transform(X_[col].astype(str))
    X_[col] = col + '_'+X_[col].astype(str)
    
for col in tqdm(doc_col):
    X_doc[col] = X_doc[col].astype(str)
# Out:
# 100%|██████████| 28/28 [01:15<00:00,  2.71s/it]
# 100%|██████████| 2/2 [00:00<00:00,  6.43it/s]

# %%
def get_tok(X,col,train_length,d_filter='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'):
    X[col] = X[col].astype(str)

    tok_all=text.Tokenizer(num_words=X[col].nunique(),lower=False,filters=d_filter)
    tok_all.fit_on_texts(list(X[col].values))

    tok_train=text.Tokenizer(num_words=X[col].iloc[:train_length].nunique(),lower=False,filters=d_filter)
    tok_train.fit_on_texts(list(X[col].iloc[:train_length].values))

    tok_test=text.Tokenizer(num_words=X[col].iloc[train_length:].nunique(),lower=False,filters=d_filter)
    tok_test.fit_on_texts(list(X[col].iloc[train_length:].values))
    word_intersection = set(tok_train.word_index.keys()).intersection(set(tok_test.word_index.keys()))

    self_index = {}
    count = 1
    for word in word_intersection:
        self_index[word] = count
        count+=1
    self_index['unknown'] = count
    print('max index is: {}'.format(count))

    for word in tok_all.word_index.keys():
        tok_all.word_index[word] = self_index.get(word,count)
    return tok_all

# %% [markdown]
# # Combine columns

# %%
# # def comb_fe(X,cols,sep=' '):
# #     ret = X[cols[0]].astype(str).copy()
# #     for col in cols[1:]:
# #         ret = ret + sep + X[col].astype(str)
# #     return ret.values

# def process_slot(x):
#     x = re.sub(r'[-_]',' ',x)
#     x = x.split(' ')
#     ret = ['p{}_'.format(c)+x[c] for c in range(len(x))]
#     ret = ' '.join(ret)
#     return ret

# def comb_fe(X,cols,sep=' '):
#     def add_col_name(x,colName,splitter=' ' ,sep=' '):
#         ret = [colName+'_'+each for each in x.split(splitter)]
#         return sep.join(ret)
#     ret = pd.DataFrame()
#     if cols[0] == 'user_tags':
#         ret['comb'] = X['user_tags'].astype(str).apply(add_col_name,colName='userTags',splitter=',',sep=sep)
#     else:
#         if cols[0] in original_name_col:
#             ret['comb'] = X[cols[0]].astype(str).copy()
#         else:
#             ret['comb'] = X[cols[0]].astype(str).apply(add_col_name,colName=cols[0],splitter=' ',sep=sep)

#     for col in tqdm(cols[1:]):
#         if col == 'user_tags':
#             ret['new_feature'] = X['user_tags'].astype(str).apply(add_col_name,colName='userTags',splitter=',',sep=sep)
#         else:
#             if col in original_name_col:
#                 ret['new_feature'] = X[col].astype(str).copy()
#             else:
#                 ret['new_feature'] = X[col].astype(str).apply(add_col_name,colName=col,splitter=' ',sep=sep)
#         ret['comb'] =( ret['comb'] + sep + ret['new_feature']).values
#     return ret['comb'].values

# processed_col = []
# original_name_col = ['model','make','os','osv']
# # cob_col = [['model','make','os','osv']]
# # cob_col = [['model','make','os','osv'],['model','app_id','inner_slot_id','creative_width', 'creative_height']]
# # cob_col = [['model', 'osv']]
# cob_col=[]
# doc_col=['user_tags','model']
# # doc_col=['user_tags']
# X_doc = X[doc_col].copy()
# processed_col.extend(doc_col)
# for each in cob_col:
#     feature_name = '_'.join(each)
#     processed_col.extend(each)
#     doc_col.append(feature_name)
#     X_doc[feature_name] = comb_fe(X,each)
    
# non_doc_col = list(set(X.columns) - set(ignore_columns) - set(processed_col))
# X_ = X[non_doc_col].copy()

# for col in tqdm(non_doc_col):
#     X_[col] = le.fit_transform(X_[col].astype(str))
#     X_[col] = col + '_'+X_[col].astype(str)
    
# for col in tqdm(doc_col):
#     if col=='inner_slot_id':
#         X_doc[col] = X_doc[col].astype(str).apply(process_slot)
#     else:
#         X_doc[col] = X_doc[col].astype(str)

# %%
# train_index = pickle.load(open(FILE.train_index.value,'rb'))
# holdout_index = pickle.load(open(FILE.holdout_index.value,'rb'))

# train_index = pickle.load(open('../../data/original/adversarial_train_index.pickle','rb'))
# holdout_index = pickle.load(open('../../data/original/adversarial_ho_index.pickle','rb'))

# %%
train_index = train.index
holdout_index = None

# %%
num_folds = 5
seed = 1001
train_index_list = []
val_index_list = []
folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=seed)
for t,v in folds.split(train.loc[train_index],train.loc[train_index,'click']):
    train_index_list.append(train.loc[train_index].iloc[t].index)
    val_index_list.append(train.loc[train_index].iloc[v].index)
    
# check = []
# for i in val_index_list:
#     check.extend(list(i))
# assert len(set(check+list(holdout_index))) == len(train)

# %%
train_fold_y = {}
val_fold_y = {}
if holdout_index is not None:
    holdout_y = train.loc[holdout_index,'click'].values
else:
    holdout_y = None
for fold in range(num_folds):
    train_fold_y[fold] = train.loc[train_index_list[fold],'click'].values
    val_fold_y[fold] = train.loc[val_index_list[fold],'click'].values

# %%
info_dict = {}
train_all_dict = {}
train_fold_dict = {}

val_fold_dict = {}

holdout_input_dict = {}
test_input_dict = {}
maxlen = 1
prefix_input_nonDoc = 'input_'
prefix_input_Doc = 'input_rnn_'
for col in tqdm(non_doc_col):

    maxlen = 1
    tok=text.Tokenizer(num_words=X_[col].nunique(),lower=False,filters='@')
    tok.fit_on_texts(list(X_[col]))
    info_dict.update({prefix_input_nonDoc+col:{'tok':tok}})
    t = tok.texts_to_sequences(list(X_[col].iloc[:train_length].values))
    te = tok.texts_to_sequences(list(X_[col].iloc[train_length:].values))
    train_all_dict[prefix_input_nonDoc+col] = sequence.pad_sequences(t,maxlen=maxlen)
    test_input_dict[prefix_input_nonDoc+col] = sequence.pad_sequences(te,maxlen=maxlen)
    if holdout_index is not None:
        holdout_input_dict[prefix_input_nonDoc+col] = train_all_dict[prefix_input_nonDoc+col][list(holdout_index)]
    
    for fold in range(num_folds):
        if train_fold_dict.get(fold) is None:
            train_fold_dict[fold] = {}
            val_fold_dict[fold] = {}
        train_fold_dict[fold].update({prefix_input_nonDoc+col: train_all_dict[prefix_input_nonDoc+col][list(train_index_list[fold])]})
        val_fold_dict[fold].update({prefix_input_nonDoc+col:train_all_dict[prefix_input_nonDoc+col][list(val_index_list[fold])]})
        
sequence_size_dict = {}
for col in tqdm(doc_col):
    if col == 'user_tags':
        maxlen = 50
        tok = get_tok(X_doc,col=col,train_length=train_length,d_filter=',')
#         tok=text.Tokenizer(num_words=X_doc[col].nunique(),lower=False, filters=',')
#         tok.fit_on_texts(list(X_doc[col]))

        
    elif col == 'model':
        maxlen = 15
#         tok = get_tok(X_doc,col=col,train_length=train_length)
        tok=text.Tokenizer(num_words=X_doc[col].nunique(),lower=False,filters=' ')
        tok.fit_on_texts(list(X_doc[col]))
    else:
        maxlen = 15
#         tok = get_tok(X_doc,col=col,train_length=train_length)
        tok=text.Tokenizer(num_words=X_doc[col].nunique(),lower=False)
        tok.fit_on_texts(list(X_doc[col]))
    info_dict.update({prefix_input_Doc+col:{'tok':tok}})
    sequence_size_dict[col] = maxlen
    t = tok.texts_to_sequences(list(X_doc[col].iloc[:train_length].values))
    te = tok.texts_to_sequences(list(X_doc[col].iloc[train_length:].values))
    train_all_dict[prefix_input_Doc+col] = sequence.pad_sequences(t,maxlen=maxlen)
    test_input_dict[prefix_input_Doc+col] = sequence.pad_sequences(te,maxlen=maxlen)
    if holdout_index is not None:
        holdout_input_dict[prefix_input_Doc+col] = train_all_dict[prefix_input_Doc+col][list(holdout_index)]
    
    for fold in range(num_folds):
        if train_fold_dict.get(fold) is None:
            train_fold_dict[fold] = {}
            val_fold_dict[fold] = {}
        train_fold_dict[fold].update({prefix_input_Doc+col: train_all_dict[prefix_input_Doc+col][list(train_index_list[fold])]})
        val_fold_dict[fold].update({prefix_input_Doc+col:train_all_dict[prefix_input_Doc+col][list(val_index_list[fold])]})
# Out:
# 100%|██████████| 28/28 [04:36<00:00,  9.89s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
# max index is: 1313
# 100%|██████████| 2/2 [00:48<00:00, 24.39s/it]

# %% [markdown]
# # Build NN model only use model

# %% [markdown]
# # 0.41479

# %%
def get_nn_model(cols,doc_cols=[],numu_cols=[]):
    """
    cols, used to do ebd and dense layers
    doc_cols: used to do rnn
    there can be overlaps
    """
    input_list = []
    concat_list = []
    numu_list = []
    for col in cols:
        max_feature = len(info_dict[prefix_input_nonDoc+col]['tok'].index_word)
#         max_feature = len(set(info_dict[prefix_input_nonDoc+col]['tok'].index_word.values()))
        embed_size = int(np.log2(max_feature)/np.log2(1.5))
        if embed_size< 2:
            embed_size = 2
        cur_input = Input(shape=(1, ),name = prefix_input_nonDoc+col)
        
       
        embed_layer = Embedding(max_feature,
                            embed_size,
                            input_length=1,
                            trainable=True,
                            embeddings_regularizer=l2(0.0005),
                            name='ebd_'+col)(cur_input)
        embed_layer = SpatialDropout1D(0.5)(embed_layer)
        x = Flatten()(embed_layer)
        input_list.append(cur_input)
        concat_list.append(x)
    for col in doc_cols:
       
        max_feature = len(info_dict[prefix_input_Doc+col]['tok'].index_word)
#         max_feature = len(set(info_dict[prefix_input_Doc+col]['tok'].index_word.values()))
        embed_size = int(np.log2(max_feature)/np.log2(1.5))
        if embed_size< 2:
            embed_size = 2
        input_shape = sequence_size_dict[col]
        cur_input = Input(shape=(input_shape, ),name = prefix_input_Doc+col)
        if col == 'model':
            embed_layer = Embedding(max_feature,
                            embed_size,
                            input_length=input_shape,
                            trainable=True,
                            embeddings_regularizer=l2(0.0005),
                            name='ebd_rnn_'+col)(cur_input)
            x = SpatialDropout1D(0.5)(embed_layer)
            x = Bidirectional(CuDNNGRU(25, return_sequences=True))(x)
            x = Conv1D(25, kernel_size = 3, padding = "valid", kernel_initializer = "glorot_uniform")(x)
#             x2 = Conv1D(99, kernel_size = 2, padding = "valid", kernel_initializer = "glorot_uniform")(x)
            x_aveP = GlobalAveragePooling1D()(x)
            x_maxP = GlobalMaxPooling1D()(x)
#             x_aveP2 = GlobalAveragePooling1D()(x2)
#             x_maxP2 = GlobalMaxPooling1D()(x2)
            x = concatenate([x_aveP,x_maxP])
        else:
            embed_layer = Embedding(max_feature,
                            embed_size,
                            input_length=input_shape,
                            trainable=True,
                            embeddings_regularizer=l2(0.0005),
                            name='ebd_rnn_'+col)(cur_input)
            x = SpatialDropout1D(0.5)(embed_layer)
            x = Bidirectional(CuDNNGRU(25, return_sequences=True))(x)
            x = Conv1D(25, kernel_size = 3, padding = "valid", kernel_initializer = "glorot_uniform")(x)
            x_aveP = GlobalAveragePooling1D()(x)
            x_maxP = GlobalMaxPooling1D()(x)
            x = concatenate([x_aveP,x_maxP])
        input_list.append(cur_input)
        concat_list.append(x)

    if len(numu_cols) > 0:
        print('add numu...')
        nu_shape = len(numu_cols)
        cur_input = Input(shape=(nu_shape, ),name = prefix_input_nu)
        x = BatchNormalization()(cur_input)
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)
        input_list.append(cur_input)
        numu_list.append(x)
       
    if len(concat_list) > 1:
        x = concatenate(concat_list)
#     x = BatchNormalization()(x)
    

    if len(numu_list)>0:
        x = concatenate([x]+numu_list)
#         x = BatchNormalization()(x)
        
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.2)(x)
    
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.2)(x)

    preds = Dense(1, activation="sigmoid")(x)
    model = Model(input_list, preds)
    model.compile(loss='binary_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])    
    return model

# %%
# def get_nn_model(cols,doc_cols=[],numu_cols=[]):
#     """
#     cols, used to do ebd and dense layers
#     doc_cols: used to do rnn
#     there can be overlaps
#     """
#     input_list = []
#     concat_list = []
#     numu_list = []
#     for col in cols:
#         max_feature = len(info_dict[prefix_input_nonDoc+col]['tok'].index_word)
#         embed_size = int(np.log2(max_feature)/np.log2(1.5))
#         if embed_size< 2:
#             embed_size = 2
#         cur_input = Input(shape=(1, ),name = prefix_input_nonDoc+col)
        
       
#         embed_layer = Embedding(max_feature,
#                             embed_size,
#                             input_length=1,
#                             trainable=True,
#                             embeddings_regularizer=l2(0.0005),
#                             name='ebd_'+col)(cur_input)
#         embed_layer = SpatialDropout1D(0.5)(embed_layer)
#         x = Flatten()(embed_layer)
#         input_list.append(cur_input)
#         concat_list.append(x)
#     for col in doc_cols:
#         max_feature = len(info_dict[prefix_input_Doc+col]['tok'].index_word)
#         embed_size = int(np.log2(max_feature)/np.log2(1.5))
#         if embed_size< 2:
#             embed_size = 2
#         input_shape = sequence_size_dict[col]
#         cur_input = Input(shape=(input_shape, ),name = prefix_input_Doc+col)
#         embed_layer = Embedding(max_feature,
#                             embed_size,
#                             input_length=input_shape,
#                             trainable=True,
#                             embeddings_regularizer=l2(0.0005),
#                             name='ebd_rnn_'+col)(cur_input)
#         x = SpatialDropout1D(0.5)(embed_layer)
#         x = Bidirectional(CuDNNGRU(256, return_sequences=True))(x)
#         x = Conv1D(128, kernel_size = 3, padding = "valid", kernel_initializer = "glorot_uniform")(x)
#         x_aveP = GlobalAveragePooling1D()(x)
#         x_maxP = GlobalMaxPooling1D()(x)
#         x = concatenate([x_aveP, x_maxP]) 
#         input_list.append(cur_input)
#         concat_list.append(x)
# #         concat_list.append(x)
#     if len(numu_cols) > 0:
#         print('add numu...')
#         nu_shape = len(numu_cols)
#         cur_input = Input(shape=(nu_shape, ),name = prefix_input_nu)
#         x = BatchNormalization()(cur_input)
#         x = Dense(128, activation='relu')(x)
#         x = Dropout(0.2)(x)
#         input_list.append(cur_input)
#         numu_list.append(x)
       
#     if len(concat_list) > 1:
#         x = concatenate(concat_list)
# #     x = BatchNormalization()(x)
#     x = Dense(512, activation='relu')(x)
#     x = Dropout(0.2)(x)

#     if len(numu_list)>0:
#         x = concatenate([x]+numu_list)
#     x = Dense(128, activation='relu')(x)
#     x = Dropout(0.2)(x)

#     preds = Dense(1, activation="sigmoid")(x)
#     model = Model(input_list, preds)
#     model.compile(loss='binary_crossentropy',optimizer=Adam(),metrics=['accuracy'])    
#     return model

# %%
def train_each_fold(input_train_dict,input_val_dict,y_train,y_val,cols,doc_col=[],tolerance=30,train_batch_size=5000):
    model = get_nn_model(cols,doc_col)
    cur_to = 0
    best_logloss = None
    best_weights = None
    count = 0
    base_lr = 0.001
    while True:
        model.fit(input_train_dict, y_train, 
                  batch_size=train_batch_size, 
                  epochs=1,
                  verbose=1,
                  shuffle=True,
                  )
        preds = model.predict(input_val_dict,5000,verbose=1)
        logloss = log_loss(y_val,preds)
        roc = roc_auc_score(y_val,preds)
        print(logloss)
        print(roc)
        if best_logloss is None:
            best_logloss = logloss
            best_weights = model.get_weights()
        else:
            if best_logloss > logloss:
                best_logloss = logloss
                best_weights = model.get_weights()
                cur_to = 0
            else:
                cur_to +=1
        if cur_to == tolerance:
            break
        print('best logloss is: {}'.format(best_logloss))
        print('remainning trial is: {}/{}'.format(cur_to,tolerance))
        print('total epoch trained: {}'.format(count))
        count+=1
    model.set_weights(best_weights)
    return model

# %%
def nn_K_fold(train_fold_dict,
              val_fold_dict,
              train_fold_y,
              val_fold_y,
              test_input_dict,
              val_index_list,
              train_df,
              test_df,
              pred_col_name = 'predicted_score',
              holdout_input_dict=None,
              holdout_y=None,
              holdout_index_list=None,
              nondoc_cols=[],
              doc_cols=[],
              tolerance=30,
              train_batch_size=5000,
              preds_batch=5000):
    """
    train_fold_dict: format, key - foldNum, value - nn input 
    train_fold_y: label for train fold, fotmat, key -foldNum, value - label
    val_fold_dict: format, key - foldNum, value - nn input 
    val_fold_y: label for val fold, fotmat, key -foldNum, value - label
    test_input_dict: format, key - foldNum, value - nn input 
    holdout_input_dict: Noneable, if none, not using holdout
    holdout_y: Noneable, label for holdout
    cols: all cols used to do ebd
    doc_cols, cols that are used to do rnn
    val_index_list: cv, going to predict and generate oof
    holdout_index_list: going to predict on each fold
    train_df: 'dataframe which only has id columns, which will be used to store oof prediction'
    test_df: 'dataframe which only has id columns, which will be used to store test prediction'
    """
    train_df = train_df.copy()
    test_df = test_df.copy()
    n_fold = len(train_fold_dict)
    test_preds_list = []
    val_score_list = []
    hold_out_preds_list = []
    holdout_score_list = []
    train_score_list = []
    cv_score_list = []
    train_df[pred_col_name] = np.nan
    test_df[pred_col_name] = np.nan
    
    for fold in range(n_fold):
        print('start fold {}...'.format(fold))
        model = train_each_fold(train_fold_dict[fold],
                                val_fold_dict[fold],
                                train_fold_y[fold],
                                val_fold_y[fold],
                                nondoc_cols,
                                doc_cols,
                                tolerance=tolerance,
                                train_batch_size=train_batch_size)
        train_preds =  model.predict(train_fold_dict[fold],preds_batch,verbose=1)
        val_preds = model.predict(val_fold_dict[fold],preds_batch,verbose=1)
        train_loss = log_loss(train_fold_y[fold],train_preds)
        val_loss = log_loss(val_fold_y[fold],val_preds)
        train_df.loc[val_index_list[fold],pred_col_name] = val_preds
        test_preds = model.predict(test_input_dict,preds_batch,verbose=1)
        test_preds_list.append(test_preds)
        val_score_list.append(val_loss)
        train_score_list.append(train_loss)
        print('Fold {} finish! val loss: {}.'.format(fold,val_loss))
        if holdout_index_list is not None:
            ho_preds = model.predict(holdout_input_dict,preds_batch,verbose=1)
            ho_loss = log_loss(holdout_y,ho_preds)
            ho_roc = roc_auc_score(holdout_y,ho_preds)
            holdout_score_list.append(ho_loss)
            hold_out_preds_list.append(ho_preds)
            print('hold out loss: {}'.format(ho_loss))
        del model
        gc.collect()
        time.sleep(5)
            
    print('finish training... calculating evl matrix')
    test_preds_list = np.array(test_preds_list)
    hold_out_preds_list = np.array(hold_out_preds_list)
    test_preds_final = np.mean(test_preds_list,axis=0)
    cv_score_mean = np.mean(val_score_list)
    train_score_mean = np.mean(train_score_list)
    test_df[pred_col_name] = test_preds_final
    print('cv mean is: {}'.format(cv_score_mean))
    if holdout_index_list is not None:
        ho_preds_final = np.mean(hold_out_preds_list,axis=0)
        ho_loss_overall = log_loss(holdout_y,ho_preds_final)
        ho_roc_overall = roc_auc_score(holdout_y,ho_preds_final)
        train_df.loc[holdout_index_list,pred_col_name] = ho_preds_final
        print('holdout loss overall is: {}'.format(ho_loss_overall))
        print('holdout roc overall is: {}'.format(ho_roc_overall))
        return train_df,test_df,cv_score_mean,ho_loss_overall,train_score_mean
    else:
        return train_df,test_df,cv_score_mean,0.0,train_score_mean

# %%
train_df = train[['instance_id']].copy()
test_df = test[['instance_id']].copy()

train_save,test_save,cv_,ho_,ta_ = nn_K_fold(train_fold_dict,
                                      val_fold_dict,
                                      train_fold_y,
                                      val_fold_y,
                                      test_input_dict,
                                      val_index_list,
                                      train_df,
                                      test_df,
                                      pred_col_name = 'predicted_score',
                                      holdout_input_dict=holdout_input_dict,
                                      holdout_y=holdout_y,
                                      holdout_index_list=holdout_index,
                                      nondoc_cols=non_doc_col,
                                      doc_cols=doc_col,
                                      tolerance=30,
                                      preds_batch=5000)
# Out:
# start fold 0...
# Epoch 1/1
# 801319/801319 [==============================] - 18s 22us/step - loss: 0.4450 - acc: 0.8004
# 200331/200331 [==============================] - 2s 8us/step
# 0.4219723944542178
# 0.7584635978843495
# best logloss is: 0.4219723944542178
# remainning trial is: 0/30
# total epoch trained: 0
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4292 - acc: 0.8044
# 200331/200331 [==============================] - 2s 8us/step
# 0.4194895363780392
# 0.7613547153148326
# best logloss is: 0.4194895363780392
# remainning trial is: 0/30
# total epoch trained: 1
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4284 - acc: 0.8047
# 200331/200331 [==============================] - 1s 7us/step
# 0.41946538645941506
# 0.7620248128086045
# best logloss is: 0.41946538645941506
# remainning trial is: 0/30
# total epoch trained: 2
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4278 - acc: 0.8049
# 200331/200331 [==============================] - 1s 7us/step
# 0.4187788061804766
# 0.7628084639576553
# best logloss is: 0.4187788061804766
# remainning trial is: 0/30
# total epoch trained: 3
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4275 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.4183539360100068
# 0.7634519966220612
# best logloss is: 0.4183539360100068
# remainning trial is: 0/30
# total epoch trained: 4
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4273 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.418944600767536
# 0.762708585452948
# best logloss is: 0.4183539360100068
# remainning trial is: 1/30
# total epoch trained: 5
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4268 - acc: 0.8053
# 200331/200331 [==============================] - 2s 8us/step
# 0.41789676074385906
# 0.7638754115704115
# best logloss is: 0.41789676074385906
# remainning trial is: 0/30
# total epoch trained: 6
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4268 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.42035837796145353
# 0.7638757691014375
# best logloss is: 0.41789676074385906
# remainning trial is: 1/30
# total epoch trained: 7
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4269 - acc: 0.8053
# 200331/200331 [==============================] - 1s 7us/step
# 0.4178307590960558
# 0.7638255003174754
# best logloss is: 0.4178307590960558
# remainning trial is: 0/30
# total epoch trained: 8
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4264 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.41894619635075864
# 0.7638039558032856
# best logloss is: 0.4178307590960558
# remainning trial is: 1/30
# total epoch trained: 9
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4264 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.41754844191230367
# 0.7652080796879135
# best logloss is: 0.41754844191230367
# remainning trial is: 0/30
# total epoch trained: 10
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4264 - acc: 0.8053
# 200331/200331 [==============================] - 1s 7us/step
# 0.41848701093968654
# 0.7642508785928277
# best logloss is: 0.41754844191230367
# remainning trial is: 1/30
# total epoch trained: 11
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4263 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.41844895916778124
# 0.7646686455691247
# best logloss is: 0.41754844191230367
# remainning trial is: 2/30
# total epoch trained: 12
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4261 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.41752895205842544
# 0.7655525316574285
# best logloss is: 0.41752895205842544
# remainning trial is: 0/30
# total epoch trained: 13
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4261 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.4177041048815676
# 0.7646370494597758
# best logloss is: 0.41752895205842544
# remainning trial is: 1/30
# total epoch trained: 14
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.41740844991060155
# 0.7647891178609406
# best logloss is: 0.41740844991060155
# remainning trial is: 0/30
# total epoch trained: 15
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4174326355123291
# 0.7644581309876244
# best logloss is: 0.41740844991060155
# remainning trial is: 1/30
# total epoch trained: 16
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8058
# 200331/200331 [==============================] - 2s 7us/step
# 0.4167790791876234
# 0.7662125222620864
# best logloss is: 0.4167790791876234
# remainning trial is: 0/30
# total epoch trained: 17
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4259 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4177149389347049
# 0.7657928423968992
# best logloss is: 0.4167790791876234
# remainning trial is: 1/30
# total epoch trained: 18
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8059
# 200331/200331 [==============================] - 1s 7us/step
# 0.41811345575117487
# 0.7654677180142517
# best logloss is: 0.4167790791876234
# remainning trial is: 2/30
# total epoch trained: 19
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4259 - acc: 0.8055
# 200331/200331 [==============================] - 2s 8us/step
# 0.4172823760227867
# 0.7651433706448159
# best logloss is: 0.4167790791876234
# remainning trial is: 3/30
# total epoch trained: 20
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8056
# 200331/200331 [==============================] - 2s 7us/step
# 0.4168031737460686
# 0.765770529406383
# best logloss is: 0.4167790791876234
# remainning trial is: 4/30
# total epoch trained: 21
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8059
# 200331/200331 [==============================] - 1s 7us/step
# 0.41673263208915157
# 0.7662309343658946
# best logloss is: 0.41673263208915157
# remainning trial is: 0/30
# total epoch trained: 22
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.41680003093991314
# 0.76623269735021
# best logloss is: 0.41673263208915157
# remainning trial is: 1/30
# total epoch trained: 23
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8057
# 200331/200331 [==============================] - 2s 8us/step
# 0.4167721443547463
# 0.7660633454371508
# best logloss is: 0.41673263208915157
# remainning trial is: 2/30
# total epoch trained: 24
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8055
# 200331/200331 [==============================] - 1s 7us/step
# 0.4166111298690867
# 0.7661943698675624
# best logloss is: 0.4166111298690867
# remainning trial is: 0/30
# total epoch trained: 25
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4176810186133022
# 0.7653526172247141
# best logloss is: 0.4166111298690867
# remainning trial is: 1/30
# total epoch trained: 26
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.4168781874653798
# 0.765671634601498
# best logloss is: 0.4166111298690867
# remainning trial is: 2/30
# total epoch trained: 27
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4170218708019541
# 0.7655309354520059
# best logloss is: 0.4166111298690867
# remainning trial is: 3/30
# total epoch trained: 28
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41708259607345016
# 0.7662033134689805
# best logloss is: 0.4166111298690867
# remainning trial is: 4/30
# total epoch trained: 29
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.4172416682160687
# 0.765881800580458
# best logloss is: 0.4166111298690867
# remainning trial is: 5/30
# total epoch trained: 30
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8059
# 200331/200331 [==============================] - 1s 7us/step
# 0.4167933360719714
# 0.7662463439139635
# best logloss is: 0.4166111298690867
# remainning trial is: 6/30
# total epoch trained: 31
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.4169440964380258
# 0.7663832759473924
# best logloss is: 0.4166111298690867
# remainning trial is: 7/30
# total epoch trained: 32
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8059
# 200331/200331 [==============================] - 2s 8us/step
# 0.4172499625503911
# 0.7662928632038735
# best logloss is: 0.4166111298690867
# remainning trial is: 8/30
# total epoch trained: 33
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41700702385857263
# 0.7661796243951938
# best logloss is: 0.4166111298690867
# remainning trial is: 9/30
# total epoch trained: 34
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8058
# 200331/200331 [==============================] - 2s 7us/step
# 0.41681448338364757
# 0.7656018882477735
# best logloss is: 0.4166111298690867
# remainning trial is: 10/30
# total epoch trained: 35
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.4173058658060172
# 0.7659369127546042
# best logloss is: 0.4166111298690867
# remainning trial is: 11/30
# total epoch trained: 36
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.4170788543297907
# 0.7664052479324128
# best logloss is: 0.4166111298690867
# remainning trial is: 12/30
# total epoch trained: 37
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.4164415028875867
# 0.7664402037369273
# best logloss is: 0.4164415028875867
# remainning trial is: 0/30
# total epoch trained: 38
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41685498758379186
# 0.7657612724464467
# best logloss is: 0.4164415028875867
# remainning trial is: 1/30
# total epoch trained: 39
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41668153325661406
# 0.7660450489337357
# best logloss is: 0.4164415028875867
# remainning trial is: 2/30
# total epoch trained: 40
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.4167327646671737
# 0.766164742645939
# best logloss is: 0.4164415028875867
# remainning trial is: 3/30
# total epoch trained: 41
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41649776524523896
# 0.76603555599549
# best logloss is: 0.4164415028875867
# remainning trial is: 4/30
# total epoch trained: 42
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41607270654720035
# 0.7671274943612565
# best logloss is: 0.41607270654720035
# remainning trial is: 0/30
# total epoch trained: 43
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8059
# 200331/200331 [==============================] - 2s 8us/step
# 0.4167305300639619
# 0.7666556031399181
# best logloss is: 0.41607270654720035
# remainning trial is: 1/30
# total epoch trained: 44
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.4163825356325134
# 0.7663857817190577
# best logloss is: 0.41607270654720035
# remainning trial is: 2/30
# total epoch trained: 45
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8059
# 200331/200331 [==============================] - 2s 8us/step
# 0.41624260118868056
# 0.766560082832688
# best logloss is: 0.41607270654720035
# remainning trial is: 3/30
# total epoch trained: 46
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.416751413864942
# 0.7664097520401423
# best logloss is: 0.41607270654720035
# remainning trial is: 4/30
# total epoch trained: 47
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8058
# 200331/200331 [==============================] - 2s 8us/step
# 0.41666984583060124
# 0.7654326450429432
# best logloss is: 0.41607270654720035
# remainning trial is: 5/30
# total epoch trained: 48
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.4164004597881675
# 0.7666050489576954
# best logloss is: 0.41607270654720035
# remainning trial is: 6/30
# total epoch trained: 49
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8060
# 200331/200331 [==============================] - 2s 7us/step
# 0.41624624385465064
# 0.7669877088151421
# best logloss is: 0.41607270654720035
# remainning trial is: 7/30
# total epoch trained: 50
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41657085408893907
# 0.7663083713568846
# best logloss is: 0.41607270654720035
# remainning trial is: 8/30
# total epoch trained: 51
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41653169991137085
# 0.7664668910588508
# best logloss is: 0.41607270654720035
# remainning trial is: 9/30
# total epoch trained: 52
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8059
# 200331/200331 [==============================] - 1s 7us/step
# 0.41682702985576214
# 0.7665978329399302
# best logloss is: 0.41607270654720035
# remainning trial is: 10/30
# total epoch trained: 53
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.4165351969337446
# 0.7662210856979841
# best logloss is: 0.41607270654720035
# remainning trial is: 11/30
# total epoch trained: 54
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41646280529440916
# 0.7664381650660376
# best logloss is: 0.41607270654720035
# remainning trial is: 12/30
# total epoch trained: 55
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41657250509662824
# 0.7666223300416681
# best logloss is: 0.41607270654720035
# remainning trial is: 13/30
# total epoch trained: 56
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8057
# 200331/200331 [==============================] - 2s 7us/step
# 0.4163010976293828
# 0.7671701202048633
# best logloss is: 0.41607270654720035
# remainning trial is: 14/30
# total epoch trained: 57
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.4166831739262172
# 0.7666460506001148
# best logloss is: 0.41607270654720035
# remainning trial is: 15/30
# total epoch trained: 58
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.41629426415916526
# 0.7670423470746686
# best logloss is: 0.41607270654720035
# remainning trial is: 16/30
# total epoch trained: 59
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 2s 8us/step
# 0.41659183638648445
# 0.7668389142703685
# best logloss is: 0.41607270654720035
# remainning trial is: 17/30
# total epoch trained: 60
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41635079608025566
# 0.7667500622104768
# best logloss is: 0.41607270654720035
# remainning trial is: 18/30
# total epoch trained: 61
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200331/200331 [==============================] - 2s 8us/step
# 0.4162638296291132
# 0.7663981411711167
# best logloss is: 0.41607270654720035
# remainning trial is: 19/30
# total epoch trained: 62
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41643306103154254
# 0.7668852907045082
# best logloss is: 0.41607270654720035
# remainning trial is: 20/30
# total epoch trained: 63
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.4162480032320487
# 0.7670366929936516
# best logloss is: 0.41607270654720035
# remainning trial is: 21/30
# total epoch trained: 64
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41649418790560916
# 0.7663424678338155
# best logloss is: 0.41607270654720035
# remainning trial is: 22/30
# total epoch trained: 65
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8063
# 200331/200331 [==============================] - 2s 8us/step
# 0.4162376195372842
# 0.7668138661087619
# best logloss is: 0.41607270654720035
# remainning trial is: 23/30
# total epoch trained: 66
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41700063097179657
# 0.7665081387045458
# best logloss is: 0.41607270654720035
# remainning trial is: 24/30
# total epoch trained: 67
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41636863482904396
# 0.7668443614298145
# best logloss is: 0.41607270654720035
# remainning trial is: 25/30
# total epoch trained: 68
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41597395251701497
# 0.7672730000121895
# best logloss is: 0.41597395251701497
# remainning trial is: 0/30
# total epoch trained: 69
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8061
# 200331/200331 [==============================] - 2s 8us/step
# 0.416033104154226
# 0.766977913091585
# best logloss is: 0.41597395251701497
# remainning trial is: 1/30
# total epoch trained: 70
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.41635319085406075
# 0.7670188804298226
# best logloss is: 0.41597395251701497
# remainning trial is: 2/30
# total epoch trained: 71
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.41629259484868025
# 0.7666478554073366
# best logloss is: 0.41597395251701497
# remainning trial is: 3/30
# total epoch trained: 72
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 2s 8us/step
# 0.41730124129966567
# 0.7668535139108048
# best logloss is: 0.41597395251701497
# remainning trial is: 4/30
# total epoch trained: 73
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.41667293059772
# 0.7666390805073051
# best logloss is: 0.41597395251701497
# remainning trial is: 5/30
# total epoch trained: 74
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.4161557337205696
# 0.7667424997048125
# best logloss is: 0.41597395251701497
# remainning trial is: 6/30
# total epoch trained: 75
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41625090957490984
# 0.7670594531916508
# best logloss is: 0.41597395251701497
# remainning trial is: 7/30
# total epoch trained: 76
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41602769573805287
# 0.7677024719982115
# best logloss is: 0.41597395251701497
# remainning trial is: 8/30
# total epoch trained: 77
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41633184930277434
# 0.7674425820295541
# best logloss is: 0.41597395251701497
# remainning trial is: 9/30
# total epoch trained: 78
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.4170834574395381
# 0.7669230000070046
# best logloss is: 0.41597395251701497
# remainning trial is: 10/30
# total epoch trained: 79
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8063
# 200331/200331 [==============================] - 1s 7us/step
# 0.41601938675932093
# 0.7671596371445513
# best logloss is: 0.41597395251701497
# remainning trial is: 11/30
# total epoch trained: 80
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41655767340658767
# 0.7677723784381172
# best logloss is: 0.41597395251701497
# remainning trial is: 12/30
# total epoch trained: 81
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8061
# 200331/200331 [==============================] - 2s 8us/step
# 0.4161046531595486
# 0.7672290421011798
# best logloss is: 0.41597395251701497
# remainning trial is: 13/30
# total epoch trained: 82
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41622982091612376
# 0.7671564470906131
# best logloss is: 0.41597395251701497
# remainning trial is: 14/30
# total epoch trained: 83
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41590375687485026
# 0.7670154648924618
# best logloss is: 0.41590375687485026
# remainning trial is: 0/30
# total epoch trained: 84
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159180541261039
# 0.767407051434196
# best logloss is: 0.41590375687485026
# remainning trial is: 1/30
# total epoch trained: 85
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41588658126121897
# 0.7674287024636534
# best logloss is: 0.41588658126121897
# remainning trial is: 0/30
# total epoch trained: 86
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4164185839446354
# 0.767178759611209
# best logloss is: 0.41588658126121897
# remainning trial is: 1/30
# total epoch trained: 87
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8063
# 200331/200331 [==============================] - 2s 8us/step
# 0.4160512760725143
# 0.7677324553411002
# best logloss is: 0.41588658126121897
# remainning trial is: 2/30
# total epoch trained: 88
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4158227669211264
# 0.7674618211930857
# best logloss is: 0.4158227669211264
# remainning trial is: 0/30
# total epoch trained: 89
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8065
# 200331/200331 [==============================] - 1s 7us/step
# 0.41608025915472696
# 0.767020932806721
# best logloss is: 0.4158227669211264
# remainning trial is: 1/30
# total epoch trained: 90
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8063
# 200331/200331 [==============================] - 2s 7us/step
# 0.41630120150811073
# 0.7670776434147586
# best logloss is: 0.4158227669211264
# remainning trial is: 2/30
# total epoch trained: 91
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 2s 7us/step
# 0.41615840327099435
# 0.7671465649017213
# best logloss is: 0.4158227669211264
# remainning trial is: 3/30
# total epoch trained: 92
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4246 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.4160955122398529
# 0.7669825043695295
# best logloss is: 0.4158227669211264
# remainning trial is: 4/30
# total epoch trained: 93
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.41592942555462814
# 0.7675002912182234
# best logloss is: 0.4158227669211264
# remainning trial is: 5/30
# total epoch trained: 94
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8064
# 200331/200331 [==============================] - 2s 8us/step
# 0.41593205825735946
# 0.767468079356645
# best logloss is: 0.4158227669211264
# remainning trial is: 6/30
# total epoch trained: 95
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8062
# 200331/200331 [==============================] - 2s 8us/step
# 0.4162651153714267
# 0.7675413534020411
# best logloss is: 0.4158227669211264
# remainning trial is: 7/30
# total epoch trained: 96
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41623705024958246
# 0.7667827590298022
# best logloss is: 0.4158227669211264
# remainning trial is: 8/30
# total epoch trained: 97
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4160546500835436
# 0.7671321620795695
# best logloss is: 0.4158227669211264
# remainning trial is: 9/30
# total epoch trained: 98
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8061
# 200331/200331 [==============================] - 1s 7us/step
# 0.41585986964421207
# 0.7675379361416392
# best logloss is: 0.4158227669211264
# remainning trial is: 10/30
# total epoch trained: 99
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8061
# 200331/200331 [==============================] - 2s 8us/step
# 0.41656306394717757
# 0.7670153636246377
# best logloss is: 0.4158227669211264
# remainning trial is: 11/30
# total epoch trained: 100
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.41593419188355807
# 0.7673854908643959
# best logloss is: 0.4158227669211264
# remainning trial is: 12/30
# total epoch trained: 101
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8063
# 200331/200331 [==============================] - 2s 7us/step
# 0.41606161585424684
# 0.7672824571581724
# best logloss is: 0.4158227669211264
# remainning trial is: 13/30
# total epoch trained: 102
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159663359585059
# 0.7673270612879108
# best logloss is: 0.4158227669211264
# remainning trial is: 14/30
# total epoch trained: 103
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159467340129319
# 0.7672788812996703
# best logloss is: 0.4158227669211264
# remainning trial is: 15/30
# total epoch trained: 104
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8064
# 200331/200331 [==============================] - 2s 8us/step
# 0.4165125485302799
# 0.7668707258381737
# best logloss is: 0.4158227669211264
# remainning trial is: 16/30
# total epoch trained: 105
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8064
# 200331/200331 [==============================] - 2s 8us/step
# 0.41600312151306407
# 0.767418667785625
# best logloss is: 0.4158227669211264
# remainning trial is: 17/30
# total epoch trained: 106
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8063
# 200331/200331 [==============================] - 1s 7us/step
# 0.4167920350195664
# 0.7669161011854402
# best logloss is: 0.4158227669211264
# remainning trial is: 18/30
# total epoch trained: 107
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8063
# 200331/200331 [==============================] - 1s 7us/step
# 0.4161896847096739
# 0.7668755082953593
# best logloss is: 0.4158227669211264
# remainning trial is: 19/30
# total epoch trained: 108
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.4161084459487067
# 0.7673909081055831
# best logloss is: 0.4158227669211264
# remainning trial is: 20/30
# total epoch trained: 109
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8064
# 200331/200331 [==============================] - 2s 8us/step
# 0.4162387873025297
# 0.7665023524976052
# best logloss is: 0.4158227669211264
# remainning trial is: 21/30
# total epoch trained: 110
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.41640016781502687
# 0.7671203752253924
# best logloss is: 0.4158227669211264
# remainning trial is: 22/30
# total epoch trained: 111
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8064
# 200331/200331 [==============================] - 2s 8us/step
# 0.41650322509821974
# 0.7665247402837687
# best logloss is: 0.4158227669211264
# remainning trial is: 23/30
# total epoch trained: 112
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159183984581429
# 0.7674613151672456
# best logloss is: 0.4158227669211264
# remainning trial is: 24/30
# total epoch trained: 113
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8062
# 200331/200331 [==============================] - 1s 7us/step
# 0.4161087577936529
# 0.7668546874584272
# best logloss is: 0.4158227669211264
# remainning trial is: 25/30
# total epoch trained: 114
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.4160024451603119
# 0.7673694321214365
# best logloss is: 0.4158227669211264
# remainning trial is: 26/30
# total epoch trained: 115
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.41604985880565043
# 0.7677078862632368
# best logloss is: 0.4158227669211264
# remainning trial is: 27/30
# total epoch trained: 116
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8065
# 200331/200331 [==============================] - 2s 8us/step
# 0.4159403668663571
# 0.7674783242456862
# best logloss is: 0.4158227669211264
# remainning trial is: 28/30
# total epoch trained: 117
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8065
# 200331/200331 [==============================] - 2s 8us/step
# 0.4159899643253795
# 0.7674015791340141
# best logloss is: 0.4158227669211264
# remainning trial is: 29/30
# total epoch trained: 118
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8064
# 200331/200331 [==============================] - 1s 7us/step
# 0.41597396801446623
# 0.7674589314182175
# 801319/801319 [==============================] - 6s 7us/step
# 200331/200331 [==============================] - 1s 7us/step
# 40024/40024 [==============================] - 0s 5us/step
# Fold 0 finish! val loss: 0.4158227669211264.
# start fold 1...
# Epoch 1/1
# 801319/801319 [==============================] - 17s 21us/step - loss: 0.4450 - acc: 0.7994
# 200331/200331 [==============================] - 2s 10us/step
# 0.420694532591578
# 0.7616002998914797
# best logloss is: 0.420694532591578
# remainning trial is: 0/30
# total epoch trained: 0
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4297 - acc: 0.8039
# 200331/200331 [==============================] - 1s 7us/step
# 0.41854703758449635
# 0.7629533635680449
# best logloss is: 0.41854703758449635
# remainning trial is: 0/30
# total epoch trained: 1
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4288 - acc: 0.8047
# 200331/200331 [==============================] - 2s 8us/step
# 0.419216093763504
# 0.763237791364866
# best logloss is: 0.41854703758449635
# remainning trial is: 1/30
# total epoch trained: 2
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4283 - acc: 0.8049
# 200331/200331 [==============================] - 1s 7us/step
# 0.4188738079002237
# 0.7637225240198483
# best logloss is: 0.41854703758449635
# remainning trial is: 2/30
# total epoch trained: 3
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4276 - acc: 0.8050
# 200331/200331 [==============================] - 1s 7us/step
# 0.41826151334461364
# 0.7652910129450207
# best logloss is: 0.41826151334461364
# remainning trial is: 0/30
# total epoch trained: 4
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4273 - acc: 0.8051
# 200331/200331 [==============================] - 2s 8us/step
# 0.4174153386762345
# 0.766290445620584
# best logloss is: 0.4174153386762345
# remainning trial is: 0/30
# total epoch trained: 5
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4271 - acc: 0.8050
# 200331/200331 [==============================] - 1s 7us/step
# 0.41794700268986845
# 0.7652384999000388
# best logloss is: 0.4174153386762345
# remainning trial is: 1/30
# total epoch trained: 6
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4269 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.41784890403174296
# 0.765458455728552
# best logloss is: 0.4174153386762345
# remainning trial is: 2/30
# total epoch trained: 7
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4267 - acc: 0.8051
# 200331/200331 [==============================] - 1s 7us/step
# 0.4175921122624083
# 0.7665916291304855
# best logloss is: 0.4174153386762345
# remainning trial is: 3/30
# total epoch trained: 8
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4267 - acc: 0.8052
# 200331/200331 [==============================] - 1s 7us/step
# 0.41734181174769747
# 0.766480601923365
# best logloss is: 0.41734181174769747
# remainning trial is: 0/30
# total epoch trained: 9
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4266 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.4174298534640353
# 0.7657916113623604
# best logloss is: 0.41734181174769747
# remainning trial is: 1/30
# total epoch trained: 10
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4263 - acc: 0.8051
# 200331/200331 [==============================] - 1s 7us/step
# 0.41696333703610805
# 0.7665605466440213
# best logloss is: 0.41696333703610805
# remainning trial is: 0/30
# total epoch trained: 11
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4262 - acc: 0.8055
# 200331/200331 [==============================] - 1s 7us/step
# 0.416989655019053
# 0.766304445564401
# best logloss is: 0.41696333703610805
# remainning trial is: 1/30
# total epoch trained: 12
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4263 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.4176729954978967
# 0.7663210957020545
# best logloss is: 0.41696333703610805
# remainning trial is: 2/30
# total epoch trained: 13
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4263 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.41705072268248944
# 0.7671029067998613
# best logloss is: 0.41696333703610805
# remainning trial is: 3/30
# total epoch trained: 14
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4261 - acc: 0.8055
# 200331/200331 [==============================] - 2s 8us/step
# 0.4169466785857306
# 0.7672305003421823
# best logloss is: 0.4169466785857306
# remainning trial is: 0/30
# total epoch trained: 15
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4260 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.41648693461332637
# 0.767161079799864
# best logloss is: 0.41648693461332637
# remainning trial is: 0/30
# total epoch trained: 16
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4259 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.4163979110035815
# 0.767797668686997
# best logloss is: 0.4163979110035815
# remainning trial is: 0/30
# total epoch trained: 17
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4261 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4172860506924156
# 0.7678002964812995
# best logloss is: 0.4163979110035815
# remainning trial is: 1/30
# total epoch trained: 18
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4260 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4167139092158159
# 0.7668594489258396
# best logloss is: 0.4163979110035815
# remainning trial is: 2/30
# total epoch trained: 19
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4259 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4168459065454734
# 0.7676488995179194
# best logloss is: 0.4163979110035815
# remainning trial is: 3/30
# total epoch trained: 20
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.4166444515040438
# 0.7675576803911703
# best logloss is: 0.4163979110035815
# remainning trial is: 4/30
# total epoch trained: 21
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8054
# 200331/200331 [==============================] - 2s 8us/step
# 0.41619303929661144
# 0.7682970021572164
# best logloss is: 0.41619303929661144
# remainning trial is: 0/30
# total epoch trained: 22
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8055
# 200331/200331 [==============================] - 1s 7us/step
# 0.4172075211066331
# 0.7676161546884035
# best logloss is: 0.41619303929661144
# remainning trial is: 1/30
# total epoch trained: 23
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8054
# 200331/200331 [==============================] - 1s 7us/step
# 0.4165131326043209
# 0.7678458236911418
# best logloss is: 0.41619303929661144
# remainning trial is: 2/30
# total epoch trained: 24
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8058
# 200331/200331 [==============================] - 2s 8us/step
# 0.41592961229168884
# 0.7685250973185591
# best logloss is: 0.41592961229168884
# remainning trial is: 0/30
# total epoch trained: 25
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.41637490239554165
# 0.7676781117216003
# best logloss is: 0.41592961229168884
# remainning trial is: 1/30
# total epoch trained: 26
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.4160649501803365
# 0.7681698062457869
# best logloss is: 0.41592961229168884
# remainning trial is: 2/30
# total epoch trained: 27
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8056
# 200331/200331 [==============================] - 1s 7us/step
# 0.41666401253332136
# 0.7679167749988287
# best logloss is: 0.41592961229168884
# remainning trial is: 3/30
# total epoch trained: 28
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8058
# 200331/200331 [==============================] - 2s 8us/step
# 0.4160757084165141
# 0.7679956720321822
# best logloss is: 0.41592961229168884
# remainning trial is: 4/30
# total epoch trained: 29
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8054
# 200331/200331 [==============================] - 2s 8us/step
# 0.416818817571559
# 0.7671971678773348
# best logloss is: 0.41592961229168884
# remainning trial is: 5/30
# total epoch trained: 30
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4258 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.41902527471044326
# 0.7685246606059628
# best logloss is: 0.41592961229168884
# remainning trial is: 6/30
# total epoch trained: 31
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159739280076262
# 0.7683823940373189
# best logloss is: 0.41592961229168884
# remainning trial is: 7/30
# total epoch trained: 32
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8058
# 200331/200331 [==============================] - 2s 8us/step
# 0.4171414152364349
# 0.7681928692290975
# best logloss is: 0.41592961229168884
# remainning trial is: 8/30
# total epoch trained: 33
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.4160873368123233
# 0.7685953265937091
# best logloss is: 0.41592961229168884
# remainning trial is: 9/30
# total epoch trained: 34
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8055
# 200331/200331 [==============================] - 1s 7us/step
# 0.41598061308533324
# 0.7684316369852721
# best logloss is: 0.41592961229168884
# remainning trial is: 10/30
# total epoch trained: 35
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8058
# 200331/200331 [==============================] - 1s 7us/step
# 0.4161395872287173
# 0.7688367577798085
# best logloss is: 0.41592961229168884
# remainning trial is: 11/30
# total epoch trained: 36
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8059
# 200331/200331 [==============================] - 1s 7us/step
# 0.4165970972793356
# 0.7684655748641026
# best logloss is: 0.41592961229168884
# remainning trial is: 12/30
# total epoch trained: 37
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4256 - acc: 0.8058
# 200331/200331 [==============================] - 2s 8us/step
# 0.41660822671615044
# 0.7684696460969183
# best logloss is: 0.41592961229168884
# remainning trial is: 13/30
# total epoch trained: 38
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8059
# 200331/200331 [==============================] - 2s 8us/step
# 0.41638983150426406
# 0.7681221001721661
# best logloss is: 0.41592961229168884
# remainning trial is: 14/30
# total epoch trained: 39
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8057
# 200331/200331 [==============================] - 2s 8us/step
# 0.41636332567068324
# 0.7685044640581455
# best logloss is: 0.41592961229168884
# remainning trial is: 15/30
# total epoch trained: 40
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8057
# 200331/200331 [==============================] - 2s 8us/step
# 0.41625342722219283
# 0.7682628084067841
# best logloss is: 0.41592961229168884
# remainning trial is: 16/30
# total epoch trained: 41
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8057
# 200331/200331 [==============================] - 1s 7us/step
# 0.4159829621495469
# 0.76895254418306
# best logloss is: 0.41592961229168884
# remainning trial is: 17/30
# total epoch trained: 42
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4257 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.41612820559785574
# 0.7683152175210602
# best logloss is: 0.41592961229168884
# remainning trial is: 18/30
# total epoch trained: 43
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8060
# 200331/200331 [==============================] - 2s 8us/step
# 0.41592718838498954
# 0.7688947551079403
# best logloss is: 0.41592718838498954
# remainning trial is: 0/30
# total epoch trained: 44
# Epoch 1/1
# 801319/801319 [==============================] - 15s 19us/step - loss: 0.4254 - acc: 0.8060
# 200331/200331 [==============================] - 1s 7us/step
# 0.41612887271999904
# 0.7684455289257407
# best logloss is: 0.41592718838498954
# remainning trial is: 1/30
# ...
# 200329/200329 [==============================] - 2s 8us/step
# 0.4175390173748379
# 0.7656465043548746
# best logloss is: 0.4175335770587195
# remainning trial is: 1/30
# total epoch trained: 38
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8059
# 200329/200329 [==============================] - 1s 7us/step
# 0.41776734486936135
# 0.7656523833989164
# best logloss is: 0.4175335770587195
# remainning trial is: 2/30
# total epoch trained: 39
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8058
# 200329/200329 [==============================] - 2s 8us/step
# 0.41741193662484405
# 0.7654494822863784
# best logloss is: 0.41741193662484405
# remainning trial is: 0/30
# total epoch trained: 40
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8061
# 200329/200329 [==============================] - 2s 8us/step
# 0.41753783549637585
# 0.7656933097285838
# best logloss is: 0.41741193662484405
# remainning trial is: 1/30
# total epoch trained: 41
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.417582038999379
# 0.7652174282834683
# best logloss is: 0.41741193662484405
# remainning trial is: 2/30
# total epoch trained: 42
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4253 - acc: 0.8057
# 200329/200329 [==============================] - 2s 8us/step
# 0.41779516630380403
# 0.7653204565291629
# best logloss is: 0.41741193662484405
# remainning trial is: 3/30
# total epoch trained: 43
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8057
# 200329/200329 [==============================] - 2s 8us/step
# 0.4172601372731699
# 0.7659390721283317
# best logloss is: 0.4172601372731699
# remainning trial is: 0/30
# total epoch trained: 44
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4252 - acc: 0.8057
# 200329/200329 [==============================] - 1s 7us/step
# 0.4178826828349168
# 0.7655625861743778
# best logloss is: 0.4172601372731699
# remainning trial is: 1/30
# total epoch trained: 45
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8057
# 200329/200329 [==============================] - 1s 7us/step
# 0.4179384387041354
# 0.7652731017230651
# best logloss is: 0.4172601372731699
# remainning trial is: 2/30
# total epoch trained: 46
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8057
# 200329/200329 [==============================] - 1s 7us/step
# 0.41755244976862765
# 0.7661135854047489
# best logloss is: 0.4172601372731699
# remainning trial is: 3/30
# total epoch trained: 47
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8059
# 200329/200329 [==============================] - 1s 7us/step
# 0.41740178534199307
# 0.7653633552545311
# best logloss is: 0.4172601372731699
# remainning trial is: 4/30
# total epoch trained: 48
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4255 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.41729073271501727
# 0.7659819430492099
# best logloss is: 0.4172601372731699
# remainning trial is: 5/30
# total epoch trained: 49
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.41783754592403577
# 0.765603154883477
# best logloss is: 0.4172601372731699
# remainning trial is: 6/30
# total epoch trained: 50
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8058
# 200329/200329 [==============================] - 2s 8us/step
# 0.41746694717383803
# 0.7654022793476223
# best logloss is: 0.4172601372731699
# remainning trial is: 7/30
# total epoch trained: 51
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8058
# 200329/200329 [==============================] - 1s 7us/step
# 0.41749622934196295
# 0.7656838809518667
# best logloss is: 0.4172601372731699
# remainning trial is: 8/30
# total epoch trained: 52
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8058
# 200329/200329 [==============================] - 1s 7us/step
# 0.4171228962490995
# 0.7664282422399684
# best logloss is: 0.4171228962490995
# remainning trial is: 0/30
# total epoch trained: 53
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200329/200329 [==============================] - 1s 7us/step
# 0.4180794204488201
# 0.7651768273838189
# best logloss is: 0.4171228962490995
# remainning trial is: 1/30
# total epoch trained: 54
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.4179044163425271
# 0.7655060743706631
# best logloss is: 0.4171228962490995
# remainning trial is: 2/30
# total epoch trained: 55
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8058
# 200329/200329 [==============================] - 2s 8us/step
# 0.41797803392560323
# 0.7655593618717204
# best logloss is: 0.4171228962490995
# remainning trial is: 3/30
# total epoch trained: 56
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4251 - acc: 0.8058
# 200329/200329 [==============================] - 1s 7us/step
# 0.4178384528404359
# 0.7645871239116345
# best logloss is: 0.4171228962490995
# remainning trial is: 4/30
# total epoch trained: 57
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.4176492478104189
# 0.7655907670041119
# best logloss is: 0.4171228962490995
# remainning trial is: 5/30
# total epoch trained: 58
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8061
# 200329/200329 [==============================] - 2s 8us/step
# 0.4173790804627736
# 0.7655800306331357
# best logloss is: 0.4171228962490995
# remainning trial is: 6/30
# total epoch trained: 59
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.41735807989957924
# 0.7657324290013631
# best logloss is: 0.4171228962490995
# remainning trial is: 7/30
# total epoch trained: 60
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.41745332554288933
# 0.7658353519816078
# best logloss is: 0.4171228962490995
# remainning trial is: 8/30
# total epoch trained: 61
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.41670653354669623
# 0.7666296815412306
# best logloss is: 0.41670653354669623
# remainning trial is: 0/30
# total epoch trained: 62
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.41730011105064335
# 0.7657691291268596
# best logloss is: 0.41670653354669623
# remainning trial is: 1/30
# total epoch trained: 63
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8058
# 200329/200329 [==============================] - 2s 8us/step
# 0.41710058077344747
# 0.7663944434151092
# best logloss is: 0.41670653354669623
# remainning trial is: 2/30
# total epoch trained: 64
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8061
# 200329/200329 [==============================] - 2s 8us/step
# 0.41717174866553264
# 0.7658758926512492
# best logloss is: 0.41670653354669623
# remainning trial is: 3/30
# total epoch trained: 65
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4250 - acc: 0.8061
# 200329/200329 [==============================] - 1s 7us/step
# 0.4172463587038421
# 0.7659785197290615
# best logloss is: 0.41670653354669623
# remainning trial is: 4/30
# total epoch trained: 66
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.4172821051799894
# 0.7660883704133983
# best logloss is: 0.41670653354669623
# remainning trial is: 5/30
# total epoch trained: 67
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4246 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.4175051310181961
# 0.7660055968380229
# best logloss is: 0.41670653354669623
# remainning trial is: 6/30
# total epoch trained: 68
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.41708278935523185
# 0.7661264088355768
# best logloss is: 0.41670653354669623
# remainning trial is: 7/30
# total epoch trained: 69
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.4180097262495815
# 0.7659040144258128
# best logloss is: 0.41670653354669623
# remainning trial is: 8/30
# total epoch trained: 70
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.4173881881937966
# 0.7656515105728954
# best logloss is: 0.41670653354669623
# remainning trial is: 9/30
# total epoch trained: 71
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.4176608422466929
# 0.7652875266141994
# best logloss is: 0.41670653354669623
# remainning trial is: 10/30
# total epoch trained: 72
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.4171967897159919
# 0.7659679673376548
# best logloss is: 0.41670653354669623
# remainning trial is: 11/30
# total epoch trained: 73
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4245 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.4171506489817477
# 0.765959999040731
# best logloss is: 0.41670653354669623
# remainning trial is: 12/30
# total epoch trained: 74
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.4173901993091283
# 0.765694273487036
# best logloss is: 0.41670653354669623
# remainning trial is: 13/30
# total epoch trained: 75
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8059
# 200329/200329 [==============================] - 1s 7us/step
# 0.4173493402644291
# 0.7657534292236292
# best logloss is: 0.41670653354669623
# remainning trial is: 14/30
# total epoch trained: 76
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.41705401196847486
# 0.766032579098428
# best logloss is: 0.41670653354669623
# remainning trial is: 15/30
# total epoch trained: 77
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 1s 7us/step
# 0.4173522007494281
# 0.7666693750746331
# best logloss is: 0.41670653354669623
# remainning trial is: 16/30
# total epoch trained: 78
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4246 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.41754322233194363
# 0.7653958413941682
# best logloss is: 0.41670653354669623
# remainning trial is: 17/30
# total epoch trained: 79
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8062
# 200329/200329 [==============================] - 1s 7us/step
# 0.41698040419912846
# 0.7661914838739806
# best logloss is: 0.41670653354669623
# remainning trial is: 18/30
# total epoch trained: 80
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8059
# 200329/200329 [==============================] - 2s 8us/step
# 0.417352618693007
# 0.7659171057979381
# best logloss is: 0.41670653354669623
# remainning trial is: 19/30
# total epoch trained: 81
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8062
# 200329/200329 [==============================] - 1s 7us/step
# 0.41790647769161376
# 0.7653055519909939
# best logloss is: 0.41670653354669623
# remainning trial is: 20/30
# total epoch trained: 82
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4245 - acc: 0.8061
# 200329/200329 [==============================] - 2s 8us/step
# 0.41693002411186647
# 0.7660356360258873
# best logloss is: 0.41670653354669623
# remainning trial is: 21/30
# total epoch trained: 83
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4246 - acc: 0.8061
# 200329/200329 [==============================] - 2s 7us/step
# 0.4173200780732499
# 0.765933388890558
# best logloss is: 0.41670653354669623
# remainning trial is: 22/30
# total epoch trained: 84
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.41718012138298866
# 0.7662546331968978
# best logloss is: 0.41670653354669623
# remainning trial is: 23/30
# total epoch trained: 85
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.41721113782803854
# 0.7658552415907206
# best logloss is: 0.41670653354669623
# remainning trial is: 24/30
# total epoch trained: 86
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4244 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.4172887274990575
# 0.7662013990334682
# best logloss is: 0.41670653354669623
# remainning trial is: 25/30
# total epoch trained: 87
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8061
# 200329/200329 [==============================] - 1s 7us/step
# 0.41730983648197584
# 0.7654404702637225
# best logloss is: 0.41670653354669623
# remainning trial is: 26/30
# total epoch trained: 88
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4249 - acc: 0.8060
# 200329/200329 [==============================] - 2s 8us/step
# 0.4180830573308933
# 0.7659593189664002
# best logloss is: 0.41670653354669623
# remainning trial is: 27/30
# total epoch trained: 89
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8061
# 200329/200329 [==============================] - 2s 7us/step
# 0.4176193753544885
# 0.7650223362381967
# best logloss is: 0.41670653354669623
# remainning trial is: 28/30
# total epoch trained: 90
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4248 - acc: 0.8059
# 200329/200329 [==============================] - 1s 7us/step
# 0.41734478223337523
# 0.7658463356167396
# best logloss is: 0.41670653354669623
# remainning trial is: 29/30
# total epoch trained: 91
# Epoch 1/1
# 801321/801321 [==============================] - 15s 19us/step - loss: 0.4247 - acc: 0.8062
# 200329/200329 [==============================] - 1s 7us/step
# 0.4171270087655148
# 0.76631216577785
# 801321/801321 [==============================] - 6s 7us/step
# 200329/200329 [==============================] - 1s 7us/step
# 40024/40024 [==============================] - 0s 7us/step
# Fold 4 finish! val loss: 0.41670653354669623.
# finish training... calculating evl matrix
# cv mean is: 0.41637609885422877

# %%
def save_oof(train_df,test_df,cv,ta,ho=None,file_name='',path='../../data/nn_ebd/'):
    try:
        report = pd.read_csv(path+'report.csv')
    except:
        print('no report found! generate a new one!')
        report = pd.DataFrame()
    new_record = pd.DataFrame({'ho':[ho],'cv':[cv],'train_mean':[ta],'file':[file_name]})
    report = pd.concat([report,new_record],sort=False)
    train_df.to_pickle(path+'train/'+file_name+'.pkl')
    print(train_df.shape)
    test_df.to_csv(path+'test/'+file_name+'.csv',index=False)
    print(test_df.shape)
    report.to_csv(path+'report.csv',index=False)
    print('done!')

# %% [markdown]
# #

# %%
save_oof(train_save,test_save,cv_,ta_,ho_,file_name='v4Model_RNNModelTag_ebdNANExclude_noholdout_lr0.003')
# Out:
# (1001650, 2)
# (40024, 2)
# done!

# %%
name_dict = {'new_modelMakeOsOSV_rnnEBD':
             [['model','make','os','osv']],
             'new_modelMakeOsOSV+modelAppidInnerslotCreateWCreativeH_rnnEBD':
             [['model','make','os','osv'],['model','app_id','inner_slot_id','creative_width', 'creative_height']],
             'new_modelOSV':[['model', 'osv']],'new_model_onlyuTagRNN_100patience':[],}

# %%
tok=text.Tokenizer(num_words=100,lower=False)
tok.fit_on_texts(list(['9.2.1 Iphone']))
tok.word_index
# Out:
# {'1': 3, '2': 2, '9': 1, 'Iphone': 4}

# %%
tok=text.Tokenizer(num_words=100,lower=False,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n')
tok.fit_on_texts(list(['9.2.1 Iphone']))
tok.word_index
# Out:
# {'1': 3, '2': 2, '9': 1, 'Iphone': 4}

# %%
tok.word_index
# Out:
# {'1': 3, '2': 2, '9': 1, 'Iphone': 4}

# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})

# %%
df.iloc[0]
# Out:
# A    1
# B    2
# Name: 0, dtype: int64
