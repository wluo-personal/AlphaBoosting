# %%
import pickle 
import pandas as pd

# %%
df = pd.read_pickle('countVectorize_layer1_512_layer2_None_layer3_None.pkl')
df.to_csv('countVectorize_layer1_512_layer2_None_layer3_None.csv',index=False)

# %%
df
# Out:
#                instance_id  predicted_score
# 0      6930856710792380886         0.183253
# 1      5460409694420131920         0.295301
# 2       982813438159141507         0.106093
# 3       529991959116679673         0.149323
# 4      5357053206615171780         0.008588
# 5       792454096205931185         0.127262
# 6      7020394095530516431         0.004077
# 7      3223889685220093136         0.264074
# 8      6022950513423196038         0.373927
# 9      8354622923398290680         0.283858
# 10     7690103784039999411         0.280541
# 11     5358262661276445953         0.194811
# 12       85281227856840133         0.389030
# 13     5516720759995212120         0.007955
# 14     6034220552009226001         0.244248
# 15     4346026994855587682         0.003342
# 16     2510829946206717570         0.219196
# 17     8632119382197977662         0.319336
# 18     3356938582169526102         0.409009
# 19     7717605286446460982         0.312301
# ...
